# %%
import pandas as pd
import datetime

new = pd.read_csv('match_exclusion_excepts_20201224.csv')
old = pd.read_csv('match_drug_arr_exclusion_20201110.csv')

new.drop(columns=['Unnamed: 0', 'level_0', 'index', 'Unnamed: 0.1', 'Unnamed: 0.1.1'],inplace=True)
old.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1'],inplace=True)
new.rename(columns={"opID": "oID"},inplace=True)

new['NRS_time'] = pd.to_datetime(new['NRS_time'])
old['NRS_time'] = pd.to_datetime(old['NRS_time'])

# %% [markdown]
# # 새로 들어오는 opid

# %%
df_old=pd.read_csv('match_exclusion_completed_20201109_opid.csv', sep = ',')
olds = df_old['opid'].values.flatten()

passed=[]
for idx in range(len(new)):
    if new.loc[idx,'opid'] in olds:
        passed.append(idx)
        
arrcheck = new.drop(passed)
arrcheck
# Out:
#             oID       hid gender   birthdate            NRS_time  Value  bed  \
# 20     21887855  52062573      M  1962-10-29 2019-04-09 21:05:00    8.0    3
# 52     21729093  27372553      F  1940-08-20 2019-04-12 00:05:00    5.0    2
# 86     22018435  52162752      F  1964-02-15 2019-04-16 20:25:00    5.0    1
# 87     22018435  52162752      F  1964-02-15 2019-04-16 20:40:00    5.0    1
# 552    22490770  50230130      M  1955-03-10 2019-05-14 15:50:00    5.0   12
# ...         ...       ...    ...         ...                 ...    ...  ...
# 10455  31495281  35769343      F  1975-07-20 2020-10-19 22:55:00    4.0    3
# 10456  31495281  35769343      F  1975-07-20 2020-10-19 23:10:00    4.0    3
# 10529  31509206  17975450      F  1949-02-10 2020-10-21 14:50:00    3.0    1
# 10634  31626430  53375157      F  1976-12-20 2020-10-26 21:15:00    7.0    3
# 10635  31626430  53375157      F  1976-12-20 2020-10-26 21:30:00    6.0    3
#
# ...

# %% [markdown]
# # 기존의 arrhythmia 통과한 opid

# %%
passed_ids = old['opid'].values.flatten()

drops=[]
for idx in range(len(new)):
    if new.loc[idx,'opid'] not in passed_ids:
        drops.append(idx)

notarr = new.drop(drops)
notarr.reset_index(inplace=True)
print(len(notarr))

already_in = []
in_8390 = []
for i in range(len(notarr)):
    ori = old[old['NRS_time']==notarr.loc[i,'NRS_time']].index.tolist()
    
    if len(ori)>0 :
        for j in ori:
            if old.loc[j,'opid']==notarr.loc[i,'opid']:
                already_in.append(i)
                in_8390.append(j)
len(already_in), len(in_8390)
# Out:
# 9904
# (8207, 8207)

# %%
notarr.drop(already_in,inplace=True)
notarr
# Out:
#       index       oID       hid gender   birthdate            NRS_time  Value  \
# 3         3  21864256  52049619      F  1991-09-24 2019-04-08 20:50:00    5.0
# 6         6  21863954  47393105      F  1972-09-21 2019-04-09 12:15:00    4.0
# 10       12  21863915  37019789      F  1975-11-02 2019-04-09 15:20:00    4.0
# 12       14  21878556  52079780      M  1959-08-25 2019-04-09 17:25:00    7.0
# 18       21  21886522  52057519      M  1949-01-21 2019-04-09 21:10:00    5.0
# ...     ...       ...       ...    ...         ...                 ...    ...
# 9885  10785  31715531  42889043      F  1977-03-01 2020-10-30 15:55:00    6.0
# 9886  10786  31692399  54320756      F  1938-05-27 2020-10-30 16:00:00    6.0
 'PACU1_10_200731_154200.vital',
 'PACU1_10_200731_154200.vital',
 'PACU1_3_200814_004111.vital',
 'PACU1_3_200814_004111.vital',
 'PACU1_3_200814_004111.vital',
 'PACU1_1_200916_162304.vital',
 'PACU1_1_200916_162304.vital',
 'PACU1_1_200916_162304.vital',
 'PACU1_3_201019_204425.vital',
 'PACU1_3_201019_204425.vital',
 'PACU1_4_201029_000016.vital',
 'PACU1_4_201029_000016.vital',
 'PACU1_4_201029_000016.vital',
 'PACU1_4_201029_000016.vital']

checklist=[]
for element in plist:
    if element in yy:
        checklist.append(element)
        #print(element)
        
len(xx),len(checklist)
# Out:
# (67, 65)

# %%
notarr.drop(columns=['index'],inplace=True)

# %%
ftn_match = pd.concat([old, arrcheck,notarr], ignore_index=True)

# %%
len(old),len(arrcheck),len(notarr)
# Out:
# (8390, 139, 1697)

# %%
ftn_match
# Out:
#             oID       hid gender   birthdate            NRS_time  Value  bed  \
# 0      21863852  51597829      F  1998-08-13 2019-04-08 12:00:00    6.0    1
# 1      21863852  51597829      F  1998-08-13 2019-04-08 12:20:00    6.0    1
# 2      21864256  52049619      F  1991-09-24 2019-04-08 20:40:00    7.0    1
# 3      21884764  52067408      F  1972-10-25 2019-04-09 11:30:00    4.0    2
# 4      21863954  47393105      F  1972-09-21 2019-04-09 12:00:00    6.0    3
# ...         ...       ...    ...         ...                 ...    ...  ...
# 10221  31715531  42889043      F  1977-03-01 2020-10-30 15:55:00    6.0   12
# 10222  31692399  54320756      F  1938-05-27 2020-10-30 16:00:00    6.0    8
# 10223  31713962  53745840      F  1980-07-07 2020-10-30 17:10:00    3.0    5
# 10224  31600302  51659688      M  1956-01-30 2020-10-31 13:45:00    7.0    3
# 10225  31600302  51659688      M  1956-01-30 2020-10-31 14:00:00    5.0    3
#
# ...

# %%
ftn_match.to_csv('ftn+_match_10226_20201224.csv')

# %%
ftn_match.dtypes
# Out:
# oID                     int64
# hid                     int64
# gender                 object
# birthdate      datetime64[ns]
# NRS_time       datetime64[ns]
# Value                 float64
# bed                     int64
# opend_time     datetime64[ns]
# opid                    int64
# path                   object
# opday                  object
# age           timedelta64[ns]
# dtype: object

# %%
ftn_match.dtypes
# Out:
# oID                     int64
# hid                     int64
# gender                 object
# birthdate      datetime64[ns]
# NRS_time       datetime64[ns]
# Value                 float64
# bed                     int64
# opend_time     datetime64[ns]
# opid                    int64
# path                   object
# opday          datetime64[ns]
# age           timedelta64[ns]
# age_yr                 object
# dtype: object

# %%
ftn_match['birthdate'] = pd.to_datetime(ftn_match['birthdate'])
ftn_match['opend_time'] = pd.to_datetime(ftn_match['opend_time'])
ftn_match['opday']=ftn_match['opend_time'].dt.date 
ftn_match['opday'] = pd.to_datetime(ftn_match['opday'])
ftn_match['age'] = ftn_match['opday'] - ftn_match['birthdate']
ftn_match['age'] = ftn_match['age'].astype('timedelta64[D]')

ftn_match['age_year'] = [int(ds/365) for ds in ftn_match['age'].values.flatten()]
ftn_match.drop(columns=['age'],inplace=True)
age_ftn = ftn_match[ftn_match['age_year']>=18]
age_ftn.to_csv('ftn+_age_match_20201224.csv')
