# %%
import statsmodels.api as sm


def smooth(y):
    #return savitzky_golay(y, window_size=2001, order=3)
    return lowess(y)

# 0.2가 제일 잘 없앴음
def lowess(y, f=0.2):
    x = np.arange(0, len(y))
    return sm.nonparametric.lowess(y, x, frac=f, it=0)[:, 1].T

import numpy as np
import pandas as pd
import os, pickle, sys
from scipy import signal
#sys.path.append('DL_model')


### input 설정
SRATE = 250 # 250Hz
LEN_INPUT = 20 # input 10s
LEN_PER_NRS = 60 # vital length for each NRS
OVERLAP = 2
n_aug = int((LEN_PER_NRS-LEN_INPUT)/OVERLAP) + 1 # data augmentation 개수




input_path = '../DL_model/dataset/preprocess4/input3/'
if not os.path.exists(input_path[:-1]):
    os.mkdir(input_path[:-1])

if os.path.exists(input_path+'x_train_pacu.npz'):
    print('loading train...', flush=True, end='')
    x_train_pacu = np.load(input_path+'x_train_pacu.npz', allow_pickle=True)['arr_0']
    y_train_pacu = np.load(input_path+'y_train_pacu.npz')['arr_0']
    x_test_pacu = np.load(input_path+'x_test_pacu.npz', allow_pickle=True)['arr_0']
    y_test_pacu = np.load(input_path+'y_test_pacu.npz')['arr_0']
    print('done', flush=True)

else:
    false_row_list_preop = []
    
    vital_path = '../../cranberry2/Preprocessing/vital_data/PPG_100Hz_ECG_100Hz_pacu_2min/'
    ecg_path = '../../cranberry2/Preprocessing/vital_data/ECG_250Hz_pacu_2min/ECG,'
    df_preprocess_pacu = pickle.load(open('../DL_model/cache/preprocess3/input3/df_preprocess_pacu_agender','rb'))
    df_demograph = pd.read_csv('../DL_model/caseids_age_gender.csv')
    

    ### test set에 해당하는 file_path
    caseid_test = pickle.load(open('../DL_model/caseid_test_new', 'rb'))
    caseid_train = pickle.load(open('../DL_model/caseid_train_new', 'rb'))
    caseid_val = pickle.load(open('../DL_model/caseid_val_new', 'rb'))
    
    non_lis = []
    x_train_pacu, y_train_pacu = [], []
    x_test_pacu, y_test_pacu = [], []
    x_val_pacu, y_val_pacu = [], []
    age_train_pacu, gender_train_pacu = [], []
    age_test_pacu, gender_test_pacu = [], []
    age_val_pacu, gender_val_pacu = [], []

    cnt = 0
    for _, row in df_preprocess_pacu.iterrows():
        cnt += 1
        if cnt<=5400:
            continue
            
            
        print('loading data {}/{} ...'.format(cnt, len(df_preprocess_pacu)), end='')
        row_demo = df_demograph[df_demograph['caseids']==row['caseids']].iloc[0]
            

        # vital data - PPG (resampling 100 Hz to 250 Hz)
        df_vital = pickle.load(open(vital_path+row['file_path'], 'rb')).reset_index()
        pleth_samp = df_vital[['Pleth']].fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()
        pleth_resamp = signal.resample(pleth_samp, 120*SRATE)
        ppg_per_NRS = np.full(30000, np.nan)
        ppg_per_NRS[0:len(pleth_resamp)] = pleth_resamp
        

        # vital data - ECG (250Hz)
        ecg_samp = pickle.load(open(ecg_path+row['file_path'][:-3]+'vital', 'rb')).reset_index()[['ECG']]
        ecg_samp = ecg_samp.fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()[0:30000]
        ecg_per_NRS = np.full(30000,np.nan)
        ecg_per_NRS[0:len(ecg_samp)] = ecg_samp
   

        save_path = '../../cranberry2/Preprocessing/cache/lowess_filtered/pacu_'+row['caseids']
        # 한 NRS에 대해 23개의 input 확인
        for i in range(0,30):
            # input이 전처리 통과한 경우
            if row[str(i+1)]:
                start_idx = i*OVERLAP*SRATE # 500i
                end_idx = (i*OVERLAP+LEN_INPUT)*SRATE # 500i + 1000
                
                # input의 normalization
                ppg_inp = np.copy(ppg_per_NRS[start_idx:end_idx])
                if np.sum(np.isnan(ppg_inp))!=0:
                    ppg_inp = pd.DataFrame(ppg_inp).fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()
                
                pleth_inp = ppg_inp - smooth(ppg_inp)
                pleth_inp = pleth_inp - np.nanmean(pleth_inp)

                ecg_inp = np.copy(ecg_per_NRS[start_idx:end_idx])
                if np.sum(np.isnan(ecg_inp))!=0:
                    ecg_inp = pd.DataFrame(ecg_inp).fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()
                
                ecg_inp = ecg_inp - smooth(ecg_inp)
                ecg_inp = (ecg_inp - np.nanmean(ecg_inp)) / np.nanstd(ecg_inp)
                
                
                pickle.dump([pleth_inp, ecg_inp], open(save_path+'_{}'.format(i), 'wb'))
                # 해당 caseid가 test set에 속하는 경우
                if row['caseids'] in caseid_test:
                    age_test_pacu.append(int(row_demo['age']))
                    if row_demo['gender']=='F':
                        gender_test_pacu.append(1)
                    else:
                        gender_test_pacu.append(0)
                    x_test_pacu.append([pleth_inp, ecg_inp])
                    y_test_pacu.append(int(float(row['NRS'])))

                # 해당 caseid가 train set에 해당하는 경우
                elif row['caseids'] in caseid_val:
                    age_val_pacu.append(int(row_demo['age']))
                    if row_demo['gender']=='F':
                        gender_val_pacu.append(1)
                    else:
                        gender_val_pacu.append(0)                    
                    x_val_pacu.append([pleth_inp, ecg_inp])
                    y_val_pacu.append(int(float(row['NRS'])))
                    
                elif row['caseids'] in caseid_train:
                    age_train_pacu.append(int(row_demo['age']))
                    if row_demo['gender']=='F':
                        gender_train_pacu.append(1)
                    else:
                        gender_train_pacu.append(0)                    
                    x_train_pacu.append([pleth_inp, ecg_inp])
                    y_train_pacu.append(int(float(row['NRS'])))
                    
                else:
                    non_lis.append(row['caseids'])
                    
        print('completed')

    x_train_pacu = np.array(x_train_pacu, np.float32)
    x_test_pacu = np.array(x_test_pacu, np.float32)
    y_train_pacu = np.array(y_train_pacu, int)
    y_test_pacu = np.array(y_test_pacu, int)
    x_val_pacu = np.array(x_val_pacu, np.float32)
    y_val_pacu = np.array(y_val_pacu, int)
    
    age_train_pacu = np.array(age_train_pacu, int)
    age_test_pacu = np.array(age_test_pacu, int)
    age_val_pacu = np.array(age_val_pacu, int)
    gender_train_pacu = np.array(gender_train_pacu, int)
    gender_test_pacu = np.array(gender_test_pacu, int)
    gender_val_pacu = np.array(gender_val_pacu, int)
    
        
    # 저장하기
    print('saving...', end='', flush=True)
    np.savez_compressed(input_path+'x_train_pacu4.npz', x_train_pacu)
    np.savez_compressed(input_path+'x_test_pacu4.npz', x_test_pacu)
    np.savez_compressed(input_path+'x_val_pacu4.npz', x_val_pacu)
    np.savez_compressed(input_path+'y_train_pacu4.npz', y_train_pacu)
    np.savez_compressed(input_path+'y_test_pacu4.npz', y_test_pacu)
    np.savez_compressed(input_path+'y_val_pacu4.npz', y_val_pacu)
    
    np.savez_compressed(input_path+'age_train_pacu4.npz', age_train_pacu)
    np.savez_compressed(input_path+'age_test_pacu4.npz', age_test_pacu)
    np.savez_compressed(input_path+'age_val_pacu4.npz', age_val_pacu)    
    np.savez_compressed(input_path+'gender_train_pacu4.npz', gender_train_pacu)
    np.savez_compressed(input_path+'gender_test_pacu4.npz', gender_test_pacu)
    np.savez_compressed(input_path+'gender_val_pacu4.npz', gender_val_pacu)    
    
    print('done', flush=True)

    
    
    
print('size of training set(pacu):', len(x_train_pacu))
print('size of validation set(pacu):', len(x_val_pacu))
print('size of test set(pacu):', len(x_test_pacu))
# Out:
# loading data 5401/7253 ...completed
# loading data 5402/7253 ...completed
# loading data 5403/7253 ...completed
# loading data 5404/7253 ...completed
# loading data 5405/7253 ...completed
# loading data 5406/7253 ...completed
# loading data 5407/7253 ...completed
# loading data 5408/7253 ...completed
# loading data 5409/7253 ...completed
# loading data 5410/7253 ...completed
# loading data 5411/7253 ...completed
# loading data 5412/7253 ...completed
# loading data 5413/7253 ...completed
# loading data 5414/7253 ...completed
# loading data 5415/7253 ...completed
# loading data 5416/7253 ...completed
# loading data 5417/7253 ...completed
# loading data 5418/7253 ...completed
# loading data 5419/7253 ...completed
# loading data 5420/7253 ...completed
# loading data 5421/7253 ...completed
# loading data 5422/7253 ...completed
# loading data 5423/7253 ...completed
# loading data 5424/7253 ...completed
# loading data 5425/7253 ...completed
# loading data 5426/7253 ...completed
# loading data 5427/7253 ...completed
# loading data 5428/7253 ...completed
# loading data 5429/7253 ...completed
# loading data 5430/7253 ...completed
# loading data 5431/7253 ...completed
# loading data 5432/7253 ...completed
# loading data 5433/7253 ...completed
# loading data 5434/7253 ...completed
# loading data 5435/7253 ...completed
# loading data 5436/7253 ...completed
# loading data 5437/7253 ...completed
# loading data 5438/7253 ...completed
# loading data 5439/7253 ...completed
# loading data 5440/7253 ...completed
# loading data 5441/7253 ...completed
# loading data 5442/7253 ...completed
# loading data 5443/7253 ...completed
# loading data 5444/7253 ...completed
# loading data 5445/7253 ...completed
# loading data 5446/7253 ...completed
# loading data 5447/7253 ...completed
# loading data 5448/7253 ...completed
# loading data 5449/7253 ...completed
# loading data 5450/7253 ...completed
# loading data 5451/7253 ...completed
# loading data 5452/7253 ...completed
# loading data 5453/7253 ...completed
# loading data 5454/7253 ...completed
# loading data 5455/7253 ...completed
# loading data 5456/7253 ...completed
# loading data 5457/7253 ...completed
# loading data 5458/7253 ...completed
# loading data 5459/7253 ...completed
# loading data 5460/7253 ...completed
# loading data 5461/7253 ...completed
# loading data 5462/7253 ...completed
# loading data 5463/7253 ...completed
# loading data 5464/7253 ...completed
# loading data 5465/7253 ...completed
# loading data 5466/7253 ...completed
# loading data 5467/7253 ...completed
# loading data 5468/7253 ...completed
# loading data 5469/7253 ...completed
# loading data 5470/7253 ...completed
# loading data 5471/7253 ...completed
# loading data 5472/7253 ...completed
# loading data 5473/7253 ...completed
# loading data 5474/7253 ...completed
# loading data 5475/7253 ...completed
# loading data 5476/7253 ...completed
# loading data 5477/7253 ...completed
# loading data 5478/7253 ...completed
# loading data 5479/7253 ...completed
# loading data 5480/7253 ...completed
# loading data 5481/7253 ...completed
# loading data 5482/7253 ...completed
# loading data 5483/7253 ...completed
# loading data 5484/7253 ...completed
# loading data 5485/7253 ...completed
# loading data 5486/7253 ...completed
# loading data 5487/7253 ...completed
# loading data 5488/7253 ...completed
# loading data 5489/7253 ...completed
# loading data 5490/7253 ...completed
# loading data 5491/7253 ...completed
# loading data 5492/7253 ...completed
# loading data 5493/7253 ...completed
# loading data 5494/7253 ...completed
# loading data 5495/7253 ...completed
# loading data 5496/7253 ...completed
# loading data 5497/7253 ...completed
# loading data 5498/7253 ...completed
# loading data 5499/7253 ...completed
# loading data 5500/7253 ...completed
# loading data 5501/7253 ...completed
# loading data 5502/7253 ...completed
# loading data 5503/7253 ...completed
# loading data 5504/7253 ...completed
# loading data 5505/7253 ...completed
# loading data 5506/7253 ...completed
# loading data 5507/7253 ...completed
# loading data 5508/7253 ...completed
# loading data 5509/7253 ...completed
# loading data 5510/7253 ...completed
# loading data 5511/7253 ...completed
# loading data 5512/7253 ...completed
# loading data 5513/7253 ...completed
# loading data 5514/7253 ...completed
# loading data 5515/7253 ...completed
# loading data 5516/7253 ...completed
# loading data 5517/7253 ...completed
# loading data 5518/7253 ...completed
# loading data 5519/7253 ...completed
# loading data 5520/7253 ...completed
# loading data 5521/7253 ...completed
# loading data 5522/7253 ...completed
# loading data 5523/7253 ...completed
# loading data 5524/7253 ...completed
# loading data 5525/7253 ...completed
# loading data 5526/7253 ...completed
# loading data 5527/7253 ...completed
# loading data 5528/7253 ...completed
# loading data 5529/7253 ...completed
# loading data 5530/7253 ...completed
# loading data 5531/7253 ...completed
# loading data 5532/7253 ...completed
# loading data 5533/7253 ...completed
# loading data 5534/7253 ...completed
# loading data 5535/7253 ...completed
# loading data 5536/7253 ...completed
# loading data 5537/7253 ...completed
# loading data 5538/7253 ...completed
# loading data 5539/7253 ...completed
# loading data 5540/7253 ...completed
# loading data 5541/7253 ...completed
# loading data 5542/7253 ...completed
# loading data 5543/7253 ...completed
# loading data 5544/7253 ...completed
# loading data 5545/7253 ...completed
# loading data 5546/7253 ...completed
# loading data 5547/7253 ...completed
# loading data 5548/7253 ...completed
# loading data 5549/7253 ...completed
# loading data 5550/7253 ...completed
# loading data 5551/7253 ...completed
# loading data 5552/7253 ...completed
# loading data 5553/7253 ...completed
# loading data 5554/7253 ...completed
# loading data 5555/7253 ...completed
# loading data 5556/7253 ...completed
# loading data 5557/7253 ...completed
# loading data 5558/7253 ...completed
# loading data 5559/7253 ...completed
# loading data 5560/7253 ...completed
# loading data 5561/7253 ...completed
# loading data 5562/7253 ...completed
# loading data 5563/7253 ...completed
# loading data 5564/7253 ...completed
# loading data 5565/7253 ...completed
# loading data 5566/7253 ...completed
# loading data 5567/7253 ...completed
# loading data 5568/7253 ...completed
# loading data 5569/7253 ...completed
# loading data 5570/7253 ...completed
# loading data 5571/7253 ...completed
# loading data 5572/7253 ...completed
# loading data 5573/7253 ...completed
# loading data 5574/7253 ...completed
# loading data 5575/7253 ...completed
# loading data 5576/7253 ...completed
# loading data 5577/7253 ...completed
# loading data 5578/7253 ...completed
# loading data 5579/7253 ...completed
# loading data 5580/7253 ...completed
# loading data 5581/7253 ...completed
# loading data 5582/7253 ...completed
# loading data 5583/7253 ...completed
# loading data 5584/7253 ...completed
# loading data 5585/7253 ...completed
# loading data 5586/7253 ...completed
# loading data 5587/7253 ...completed
# loading data 5588/7253 ...completed
# loading data 5589/7253 ...completed
# loading data 5590/7253 ...completed
# loading data 5591/7253 ...completed
# loading data 5592/7253 ...completed
# loading data 5593/7253 ...completed
# loading data 5594/7253 ...completed
# loading data 5595/7253 ...completed
# loading data 5596/7253 ...completed
# loading data 5597/7253 ...completed
# loading data 5598/7253 ...completed
# loading data 5599/7253 ...completed
# loading data 5600/7253 ...completed
# loading data 5601/7253 ...completed
# loading data 5602/7253 ...completed
# loading data 5603/7253 ...completed
# loading data 5604/7253 ...completed
# loading data 5605/7253 ...completed
# loading data 5606/7253 ...completed
# loading data 5607/7253 ...completed
# loading data 5608/7253 ...completed
# loading data 5609/7253 ...completed
# loading data 5610/7253 ...completed
# loading data 5611/7253 ...completed
# loading data 5612/7253 ...completed
# loading data 5613/7253 ...completed
# loading data 5614/7253 ...completed
# loading data 5615/7253 ...completed
# loading data 5616/7253 ...completed
# loading data 5617/7253 ...completed
# loading data 5618/7253 ...completed
# loading data 5619/7253 ...completed
# loading data 5620/7253 ...completed
# loading data 5621/7253 ...completed
# loading data 5622/7253 ...completed
# loading data 5623/7253 ...completed
# loading data 5624/7253 ...completed
# loading data 5625/7253 ...completed
# loading data 5626/7253 ...completed
# loading data 5627/7253 ...completed
# loading data 5628/7253 ...completed
# loading data 5629/7253 ...completed
# loading data 5630/7253 ...completed
# loading data 5631/7253 ...completed
# loading data 5632/7253 ...completed
# loading data 5633/7253 ...completed
# loading data 5634/7253 ...completed
# loading data 5635/7253 ...completed
# loading data 5636/7253 ...completed
# loading data 5637/7253 ...completed
# loading data 5638/7253 ...completed
# loading data 5639/7253 ...completed
# loading data 5640/7253 ...completed
# loading data 5641/7253 ...completed
# loading data 5642/7253 ...completed
# loading data 5643/7253 ...completed
# loading data 5644/7253 ...completed
# loading data 5645/7253 ...completed
# loading data 5646/7253 ...completed
# loading data 5647/7253 ...completed
# loading data 5648/7253 ...completed
# loading data 5649/7253 ...completed
# loading data 5650/7253 ...completed
# loading data 5651/7253 ...completed
# loading data 5652/7253 ...completed
# loading data 5653/7253 ...completed
# loading data 5654/7253 ...completed
# loading data 5655/7253 ...completed
# loading data 5656/7253 ...completed
# loading data 5657/7253 ...completed
# loading data 5658/7253 ...completed
# loading data 5659/7253 ...completed
# loading data 5660/7253 ...completed
# loading data 5661/7253 ...completed
# loading data 5662/7253 ...completed
# loading data 5663/7253 ...completed
# loading data 5664/7253 ...completed
# loading data 5665/7253 ...completed
# loading data 5666/7253 ...completed
# loading data 5667/7253 ...completed
# loading data 5668/7253 ...completed
# loading data 5669/7253 ...completed
# loading data 5670/7253 ...completed
# loading data 5671/7253 ...completed
# loading data 5672/7253 ...completed
# loading data 5673/7253 ...completed
# loading data 5674/7253 ...completed
# loading data 5675/7253 ...completed
# loading data 5676/7253 ...completed
# loading data 5677/7253 ...completed
# loading data 5678/7253 ...completed
# loading data 5679/7253 ...completed
# loading data 5680/7253 ...completed
# loading data 5681/7253 ...completed
# loading data 5682/7253 ...completed
# loading data 5683/7253 ...completed
# loading data 5684/7253 ...completed
# loading data 5685/7253 ...completed
# loading data 5686/7253 ...completed
# loading data 5687/7253 ...completed
# loading data 5688/7253 ...completed
# loading data 5689/7253 ...completed
# loading data 5690/7253 ...completed
# loading data 5691/7253 ...completed
# loading data 5692/7253 ...completed
# loading data 5693/7253 ...completed
# loading data 5694/7253 ...completed
# loading data 5695/7253 ...completed
# loading data 5696/7253 ...completed
# loading data 5697/7253 ...completed
# loading data 5698/7253 ...completed
# loading data 5699/7253 ...completed
# loading data 5700/7253 ...completed
# loading data 5701/7253 ...completed
# loading data 5702/7253 ...completed
# loading data 5703/7253 ...completed
# loading data 5704/7253 ...completed
# loading data 5705/7253 ...completed
# loading data 5706/7253 ...completed
# loading data 5707/7253 ...completed
# loading data 5708/7253 ...completed
# loading data 5709/7253 ...completed
# loading data 5710/7253 ...completed
# loading data 5711/7253 ...completed
# loading data 5712/7253 ...completed
# loading data 5713/7253 ...completed
# loading data 5714/7253 ...completed
# loading data 5715/7253 ...completed
# loading data 5716/7253 ...completed
# loading data 5717/7253 ...completed
# loading data 5718/7253 ...completed
# loading data 5719/7253 ...completed
# loading data 5720/7253 ...completed
# loading data 5721/7253 ...completed
# loading data 5722/7253 ...completed
# loading data 5723/7253 ...completed
# loading data 5724/7253 ...completed
# loading data 5725/7253 ...completed
# loading data 5726/7253 ...completed
# loading data 5727/7253 ...completed
# loading data 5728/7253 ...completed
# loading data 5729/7253 ...completed
# loading data 5730/7253 ...completed
# loading data 5731/7253 ...completed
# loading data 5732/7253 ...completed
# loading data 5733/7253 ...completed
# loading data 5734/7253 ...completed
# loading data 5735/7253 ...completed
# loading data 5736/7253 ...completed
# loading data 5737/7253 ...completed
# loading data 5738/7253 ...completed
# loading data 5739/7253 ...completed
# loading data 5740/7253 ...completed
# loading data 5741/7253 ...completed
# loading data 5742/7253 ...completed
# loading data 5743/7253 ...completed
# loading data 5744/7253 ...completed
# loading data 5745/7253 ...completed
# loading data 5746/7253 ...completed
# loading data 5747/7253 ...completed
# loading data 5748/7253 ...completed
# loading data 5749/7253 ...completed
# loading data 5750/7253 ...completed
# loading data 5751/7253 ...completed
# loading data 5752/7253 ...completed
# loading data 5753/7253 ...completed
# loading data 5754/7253 ...completed
# loading data 5755/7253 ...completed
# loading data 5756/7253 ...completed
# loading data 5757/7253 ...completed
# loading data 5758/7253 ...completed
# loading data 5759/7253 ...completed
# loading data 5760/7253 ...completed
# loading data 5761/7253 ...completed
# loading data 5762/7253 ...completed
# loading data 5763/7253 ...completed
# loading data 5764/7253 ...completed
# loading data 5765/7253 ...completed
# loading data 5766/7253 ...completed
# loading data 5767/7253 ...completed
# loading data 5768/7253 ...completed
# loading data 5769/7253 ...completed
# loading data 5770/7253 ...completed
# loading data 5771/7253 ...completed
# loading data 5772/7253 ...completed
# loading data 5773/7253 ...completed
# loading data 5774/7253 ...completed
# loading data 5775/7253 ...completed
# loading data 5776/7253 ...completed
# loading data 5777/7253 ...completed
# loading data 5778/7253 ...completed
# loading data 5779/7253 ...completed
# loading data 5780/7253 ...completed
# loading data 5781/7253 ...completed
# loading data 5782/7253 ...completed
# loading data 5783/7253 ...completed
# loading data 5784/7253 ...completed
# loading data 5785/7253 ...completed
# loading data 5786/7253 ...completed
# loading data 5787/7253 ...completed
# loading data 5788/7253 ...completed
# loading data 5789/7253 ...completed
# loading data 5790/7253 ...completed
# loading data 5791/7253 ...completed
# loading data 5792/7253 ...completed
# loading data 5793/7253 ...completed
# loading data 5794/7253 ...completed
# loading data 5795/7253 ...completed
# loading data 5796/7253 ...completed
# loading data 5797/7253 ...completed
# loading data 5798/7253 ...completed
# loading data 5799/7253 ...completed
# loading data 5800/7253 ...completed
# loading data 5801/7253 ...completed
# loading data 5802/7253 ...completed
# loading data 5803/7253 ...completed
# loading data 5804/7253 ...completed
# loading data 5805/7253 ...completed
# loading data 5806/7253 ...completed
# loading data 5807/7253 ...completed
# loading data 5808/7253 ...completed
# loading data 5809/7253 ...completed
# loading data 5810/7253 ...completed
# loading data 5811/7253 ...completed
# loading data 5812/7253 ...completed
# loading data 5813/7253 ...completed
# loading data 5814/7253 ...completed
# loading data 5815/7253 ...completed
# loading data 5816/7253 ...completed
# loading data 5817/7253 ...completed
# loading data 5818/7253 ...completed
# loading data 5819/7253 ...completed
# loading data 5820/7253 ...completed
# loading data 5821/7253 ...completed
# loading data 5822/7253 ...completed
# loading data 5823/7253 ...completed
# loading data 5824/7253 ...completed
# loading data 5825/7253 ...completed
# loading data 5826/7253 ...completed
# loading data 5827/7253 ...completed
# loading data 5828/7253 ...completed
# loading data 5829/7253 ...completed
# loading data 5830/7253 ...completed
# loading data 5831/7253 ...completed
# loading data 5832/7253 ...completed
# loading data 5833/7253 ...completed
# loading data 5834/7253 ...completed
# loading data 5835/7253 ...completed
# loading data 5836/7253 ...completed
# loading data 5837/7253 ...completed
# loading data 5838/7253 ...completed
# loading data 5839/7253 ...completed
# loading data 5840/7253 ...completed
# loading data 5841/7253 ...completed
# loading data 5842/7253 ...completed
# loading data 5843/7253 ...completed
# loading data 5844/7253 ...completed
# loading data 5845/7253 ...completed
# loading data 5846/7253 ...completed
# loading data 5847/7253 ...completed
# loading data 5848/7253 ...completed
# loading data 5849/7253 ...completed
# loading data 5850/7253 ...completed
# loading data 5851/7253 ...completed
# loading data 5852/7253 ...completed
# loading data 5853/7253 ...completed
# loading data 5854/7253 ...completed
# loading data 5855/7253 ...completed
# loading data 5856/7253 ...completed
# loading data 5857/7253 ...completed
# loading data 5858/7253 ...completed
# loading data 5859/7253 ...completed
# loading data 5860/7253 ...completed
# loading data 5861/7253 ...completed
# loading data 5862/7253 ...completed
# loading data 5863/7253 ...completed
# loading data 5864/7253 ...completed
# loading data 5865/7253 ...completed
# loading data 5866/7253 ...completed
# loading data 5867/7253 ...completed
# loading data 5868/7253 ...completed
# loading data 5869/7253 ...completed
# loading data 5870/7253 ...completed
# loading data 5871/7253 ...completed
# loading data 5872/7253 ...completed
# loading data 5873/7253 ...completed
# loading data 5874/7253 ...completed
# loading data 5875/7253 ...completed
# loading data 5876/7253 ...completed
# loading data 5877/7253 ...completed
# loading data 5878/7253 ...completed
# loading data 5879/7253 ...completed
# loading data 5880/7253 ...completed
# loading data 5881/7253 ...completed
# loading data 5882/7253 ...completed
# loading data 5883/7253 ...completed
# loading data 5884/7253 ...completed
# loading data 5885/7253 ...completed
# loading data 5886/7253 ...completed
# loading data 5887/7253 ...completed
# loading data 5888/7253 ...completed
# loading data 5889/7253 ...completed
# loading data 5890/7253 ...completed
# loading data 5891/7253 ...completed
# loading data 5892/7253 ...completed
# loading data 5893/7253 ...completed
# loading data 5894/7253 ...completed
# loading data 5895/7253 ...completed
# loading data 5896/7253 ...completed
# loading data 5897/7253 ...completed
# loading data 5898/7253 ...completed
# loading data 5899/7253 ...completed
# loading data 5900/7253 ...completed
# loading data 5901/7253 ...completed
# loading data 5902/7253 ...completed
# loading data 5903/7253 ...completed
# loading data 5904/7253 ...completed
# loading data 5905/7253 ...completed
# loading data 5906/7253 ...completed
# loading data 5907/7253 ...completed
# loading data 5908/7253 ...completed
# loading data 5909/7253 ...completed
# loading data 5910/7253 ...completed
# loading data 5911/7253 ...completed
# loading data 5912/7253 ...completed
# loading data 5913/7253 ...completed
# loading data 5914/7253 ...completed
# loading data 5915/7253 ...completed
# loading data 5916/7253 ...completed
# loading data 5917/7253 ...completed
# loading data 5918/7253 ...completed
# loading data 5919/7253 ...completed
# loading data 5920/7253 ...completed
# loading data 5921/7253 ...completed
# loading data 5922/7253 ...completed
# loading data 5923/7253 ...completed
# loading data 5924/7253 ...completed
# loading data 5925/7253 ...completed
# loading data 5926/7253 ...completed
# loading data 5927/7253 ...completed
# loading data 5928/7253 ...completed
# loading data 5929/7253 ...completed
# loading data 5930/7253 ...completed
# loading data 5931/7253 ...completed
# loading data 5932/7253 ...completed
# loading data 5933/7253 ...completed
# loading data 5934/7253 ...completed
# loading data 5935/7253 ...completed
# loading data 5936/7253 ...completed
# loading data 5937/7253 ...completed
# loading data 5938/7253 ...completed
# loading data 5939/7253 ...completed
# loading data 5940/7253 ...completed
# loading data 5941/7253 ...completed
# loading data 5942/7253 ...completed
# loading data 5943/7253 ...completed
# loading data 5944/7253 ...completed
# loading data 5945/7253 ...completed
# loading data 5946/7253 ...completed
# loading data 5947/7253 ...completed
# loading data 5948/7253 ...completed
# loading data 5949/7253 ...completed
# loading data 5950/7253 ...completed
# loading data 5951/7253 ...completed
# loading data 5952/7253 ...completed
# loading data 5953/7253 ...completed
# loading data 5954/7253 ...completed
# loading data 5955/7253 ...completed
# loading data 5956/7253 ...completed
# loading data 5957/7253 ...completed
# loading data 5958/7253 ...completed
# loading data 5959/7253 ...completed
# loading data 5960/7253 ...completed
# loading data 5961/7253 ...completed
# loading data 5962/7253 ...completed
# loading data 5963/7253 ...completed
# loading data 5964/7253 ...completed
# loading data 5965/7253 ...completed
# loading data 5966/7253 ...completed
# loading data 5967/7253 ...completed
# loading data 5968/7253 ...completed
# loading data 5969/7253 ...completed
# loading data 5970/7253 ...completed
# loading data 5971/7253 ...completed
# loading data 5972/7253 ...completed
# loading data 5973/7253 ...completed
# loading data 5974/7253 ...completed
# loading data 5975/7253 ...completed
# loading data 5976/7253 ...completed
# loading data 5977/7253 ...completed
# loading data 5978/7253 ...completed
# loading data 5979/7253 ...completed
# loading data 5980/7253 ...completed
# loading data 5981/7253 ...completed
# loading data 5982/7253 ...completed
# loading data 5983/7253 ...completed
# loading data 5984/7253 ...completed
# loading data 5985/7253 ...completed
# loading data 5986/7253 ...completed
# loading data 5987/7253 ...completed
# loading data 5988/7253 ...completed
# loading data 5989/7253 ...completed
# loading data 5990/7253 ...completed
# loading data 5991/7253 ...completed
# loading data 5992/7253 ...completed
# loading data 5993/7253 ...completed
# loading data 5994/7253 ...completed
# loading data 5995/7253 ...completed
# loading data 5996/7253 ...completed
# loading data 5997/7253 ...completed
# loading data 5998/7253 ...completed
# loading data 5999/7253 ...completed
# loading data 6000/7253 ...completed
# loading data 6001/7253 ...completed
# loading data 6002/7253 ...completed
# loading data 6003/7253 ...completed
# loading data 6004/7253 ...completed
# loading data 6005/7253 ...completed
# loading data 6006/7253 ...completed
# loading data 6007/7253 ...completed
# loading data 6008/7253 ...completed
# loading data 6009/7253 ...completed
# loading data 6010/7253 ...completed
# loading data 6011/7253 ...completed
# loading data 6012/7253 ...completed
# loading data 6013/7253 ...completed
# loading data 6014/7253 ...completed
# loading data 6015/7253 ...completed
# loading data 6016/7253 ...completed
# loading data 6017/7253 ...completed
# loading data 6018/7253 ...completed
# loading data 6019/7253 ...completed
# loading data 6020/7253 ...completed
# loading data 6021/7253 ...completed
# loading data 6022/7253 ...completed
# loading data 6023/7253 ...completed
# loading data 6024/7253 ...completed
# loading data 6025/7253 ...completed
# loading data 6026/7253 ...completed
# loading data 6027/7253 ...completed
# loading data 6028/7253 ...completed
# loading data 6029/7253 ...completed
# loading data 6030/7253 ...completed
# loading data 6031/7253 ...completed
# loading data 6032/7253 ...completed
# loading data 6033/7253 ...completed
# loading data 6034/7253 ...completed
# loading data 6035/7253 ...completed
# loading data 6036/7253 ...completed
# loading data 6037/7253 ...completed
# loading data 6038/7253 ...completed
# loading data 6039/7253 ...completed
# loading data 6040/7253 ...completed
# loading data 6041/7253 ...completed
# loading data 6042/7253 ...completed
# loading data 6043/7253 ...completed
# loading data 6044/7253 ...completed
# loading data 6045/7253 ...completed
# loading data 6046/7253 ...completed
# loading data 6047/7253 ...completed
# loading data 6048/7253 ...completed
# loading data 6049/7253 ...completed
# loading data 6050/7253 ...completed
# loading data 6051/7253 ...completed
# loading data 6052/7253 ...completed
# loading data 6053/7253 ...completed
# loading data 6054/7253 ...completed
# loading data 6055/7253 ...completed
# loading data 6056/7253 ...completed
# loading data 6057/7253 ...completed
# loading data 6058/7253 ...completed
# loading data 6059/7253 ...completed
# loading data 6060/7253 ...completed
# loading data 6061/7253 ...completed
# loading data 6062/7253 ...completed
# loading data 6063/7253 ...completed
# loading data 6064/7253 ...completed
# loading data 6065/7253 ...completed
# loading data 6066/7253 ...completed
# loading data 6067/7253 ...completed
# loading data 6068/7253 ...completed
# loading data 6069/7253 ...completed
# loading data 6070/7253 ...completed
# loading data 6071/7253 ...completed
# loading data 6072/7253 ...completed
# loading data 6073/7253 ...completed
# loading data 6074/7253 ...completed
# loading data 6075/7253 ...completed
# loading data 6076/7253 ...completed
# loading data 6077/7253 ...completed
# loading data 6078/7253 ...completed
# loading data 6079/7253 ...completed
# loading data 6080/7253 ...completed
# loading data 6081/7253 ...completed
# loading data 6082/7253 ...completed
# loading data 6083/7253 ...completed
# loading data 6084/7253 ...completed
# loading data 6085/7253 ...completed
# loading data 6086/7253 ...completed
# loading data 6087/7253 ...completed
# loading data 6088/7253 ...completed
# loading data 6089/7253 ...completed
# loading data 6090/7253 ...completed
# loading data 6091/7253 ...completed
# loading data 6092/7253 ...completed
# loading data 6093/7253 ...completed
# loading data 6094/7253 ...completed
# loading data 6095/7253 ...completed
# loading data 6096/7253 ...completed
# loading data 6097/7253 ...completed
# loading data 6098/7253 ...completed
# loading data 6099/7253 ...completed
# loading data 6100/7253 ...completed
# loading data 6101/7253 ...completed
# loading data 6102/7253 ...completed
# loading data 6103/7253 ...completed
# loading data 6104/7253 ...completed
# loading data 6105/7253 ...completed
# loading data 6106/7253 ...completed
# loading data 6107/7253 ...completed
# loading data 6108/7253 ...completed
# loading data 6109/7253 ...completed
# loading data 6110/7253 ...completed
# loading data 6111/7253 ...completed
# loading data 6112/7253 ...completed
# loading data 6113/7253 ...completed
# loading data 6114/7253 ...completed
# loading data 6115/7253 ...completed
# loading data 6116/7253 ...completed
# loading data 6117/7253 ...completed
# loading data 6118/7253 ...completed
# loading data 6119/7253 ...completed
# loading data 6120/7253 ...completed
# loading data 6121/7253 ...completed
# loading data 6122/7253 ...completed
# loading data 6123/7253 ...completed
# loading data 6124/7253 ...completed
# loading data 6125/7253 ...completed
# loading data 6126/7253 ...completed
# loading data 6127/7253 ...completed
# loading data 6128/7253 ...completed
# loading data 6129/7253 ...completed
# loading data 6130/7253 ...completed
# loading data 6131/7253 ...completed
# loading data 6132/7253 ...completed
# loading data 6133/7253 ...completed
# loading data 6134/7253 ...completed
# loading data 6135/7253 ...completed
# loading data 6136/7253 ...completed
# loading data 6137/7253 ...completed
# loading data 6138/7253 ...completed
# loading data 6139/7253 ...completed
# loading data 6140/7253 ...completed
# loading data 6141/7253 ...completed
# loading data 6142/7253 ...completed
# loading data 6143/7253 ...completed
# loading data 6144/7253 ...completed
# loading data 6145/7253 ...completed
# loading data 6146/7253 ...completed
# loading data 6147/7253 ...completed
# loading data 6148/7253 ...completed
# loading data 6149/7253 ...completed
# loading data 6150/7253 ...completed
# loading data 6151/7253 ...completed
# loading data 6152/7253 ...completed
# loading data 6153/7253 ...completed
# loading data 6154/7253 ...completed
# loading data 6155/7253 ...completed
# loading data 6156/7253 ...completed
# loading data 6157/7253 ...completed
# loading data 6158/7253 ...completed
# loading data 6159/7253 ...completed
# loading data 6160/7253 ...completed
# loading data 6161/7253 ...completed
# loading data 6162/7253 ...completed
# loading data 6163/7253 ...completed
# loading data 6164/7253 ...completed
# loading data 6165/7253 ...completed
# loading data 6166/7253 ...completed
# loading data 6167/7253 ...completed
# loading data 6168/7253 ...completed
# loading data 6169/7253 ...completed
# loading data 6170/7253 ...completed
# loading data 6171/7253 ...completed
# loading data 6172/7253 ...completed
# loading data 6173/7253 ...completed
# loading data 6174/7253 ...completed
# loading data 6175/7253 ...completed
# loading data 6176/7253 ...completed
# loading data 6177/7253 ...completed
# loading data 6178/7253 ...completed
# loading data 6179/7253 ...completed
# loading data 6180/7253 ...completed
# loading data 6181/7253 ...completed
# loading data 6182/7253 ...completed
# loading data 6183/7253 ...completed
# loading data 6184/7253 ...completed
# loading data 6185/7253 ...completed
# loading data 6186/7253 ...completed
# loading data 6187/7253 ...completed
# loading data 6188/7253 ...completed
# loading data 6189/7253 ...completed
# loading data 6190/7253 ...completed
# loading data 6191/7253 ...completed
# loading data 6192/7253 ...completed
# loading data 6193/7253 ...completed
# loading data 6194/7253 ...completed
# loading data 6195/7253 ...completed
# loading data 6196/7253 ...completed
# loading data 6197/7253 ...completed
# loading data 6198/7253 ...completed
# loading data 6199/7253 ...completed
# loading data 6200/7253 ...completed
# loading data 6201/7253 ...completed
# loading data 6202/7253 ...completed
# loading data 6203/7253 ...completed
# loading data 6204/7253 ...completed
# loading data 6205/7253 ...completed
# loading data 6206/7253 ...completed
# loading data 6207/7253 ...completed
# loading data 6208/7253 ...completed
# loading data 6209/7253 ...completed
# loading data 6210/7253 ...completed
# loading data 6211/7253 ...completed
# loading data 6212/7253 ...completed
# loading data 6213/7253 ...completed
# loading data 6214/7253 ...completed
# loading data 6215/7253 ...completed
# loading data 6216/7253 ...completed
# loading data 6217/7253 ...completed
# loading data 6218/7253 ...completed
# loading data 6219/7253 ...completed
# loading data 6220/7253 ...completed
# loading data 6221/7253 ...completed
# loading data 6222/7253 ...completed
# loading data 6223/7253 ...completed
# loading data 6224/7253 ...completed
# loading data 6225/7253 ...completed
# loading data 6226/7253 ...completed
# loading data 6227/7253 ...completed
# loading data 6228/7253 ...completed
# loading data 6229/7253 ...completed
# loading data 6230/7253 ...completed
# loading data 6231/7253 ...completed
# loading data 6232/7253 ...completed
# loading data 6233/7253 ...completed
# loading data 6234/7253 ...completed
# loading data 6235/7253 ...completed
# loading data 6236/7253 ...completed
# loading data 6237/7253 ...completed
# loading data 6238/7253 ...completed
# loading data 6239/7253 ...completed
# loading data 6240/7253 ...completed
# loading data 6241/7253 ...completed
# loading data 6242/7253 ...completed
# loading data 6243/7253 ...completed
# loading data 6244/7253 ...completed
# loading data 6245/7253 ...completed
# loading data 6246/7253 ...completed
# loading data 6247/7253 ...completed
# loading data 6248/7253 ...completed
# loading data 6249/7253 ...completed
# loading data 6250/7253 ...completed
# loading data 6251/7253 ...completed
# loading data 6252/7253 ...completed
# loading data 6253/7253 ...completed
# loading data 6254/7253 ...completed
# loading data 6255/7253 ...completed
# loading data 6256/7253 ...completed
# loading data 6257/7253 ...completed
# loading data 6258/7253 ...completed
# loading data 6259/7253 ...completed
# loading data 6260/7253 ...completed
# loading data 6261/7253 ...completed
# loading data 6262/7253 ...completed
# loading data 6263/7253 ...completed
# loading data 6264/7253 ...completed
# loading data 6265/7253 ...completed
# loading data 6266/7253 ...completed
# loading data 6267/7253 ...completed
# loading data 6268/7253 ...completed
# loading data 6269/7253 ...completed
# loading data 6270/7253 ...completed
# loading data 6271/7253 ...completed
# loading data 6272/7253 ...completed
# loading data 6273/7253 ...completed
# loading data 6274/7253 ...completed
# loading data 6275/7253 ...completed
# loading data 6276/7253 ...completed
# loading data 6277/7253 ...completed
# loading data 6278/7253 ...completed
# loading data 6279/7253 ...completed
# loading data 6280/7253 ...completed
# loading data 6281/7253 ...completed
# loading data 6282/7253 ...completed
# loading data 6283/7253 ...completed
# loading data 6284/7253 ...completed
# loading data 6285/7253 ...completed
# loading data 6286/7253 ...completed
# loading data 6287/7253 ...completed
# loading data 6288/7253 ...completed
# loading data 6289/7253 ...completed
# loading data 6290/7253 ...completed
# loading data 6291/7253 ...completed
# loading data 6292/7253 ...completed
# loading data 6293/7253 ...completed
# loading data 6294/7253 ...completed
# loading data 6295/7253 ...completed
# loading data 6296/7253 ...completed
# loading data 6297/7253 ...completed
# loading data 6298/7253 ...completed
# loading data 6299/7253 ...completed
# loading data 6300/7253 ...completed
# loading data 6301/7253 ...completed
# loading data 6302/7253 ...completed
# loading data 6303/7253 ...completed
# loading data 6304/7253 ...completed
# loading data 6305/7253 ...completed
# loading data 6306/7253 ...completed
# loading data 6307/7253 ...completed
# loading data 6308/7253 ...completed
# loading data 6309/7253 ...completed
# loading data 6310/7253 ...completed
# loading data 6311/7253 ...completed
# loading data 6312/7253 ...completed
# loading data 6313/7253 ...completed
# loading data 6314/7253 ...completed
# loading data 6315/7253 ...completed
# loading data 6316/7253 ...completed
# loading data 6317/7253 ...completed
# loading data 6318/7253 ...completed
# loading data 6319/7253 ...completed
# loading data 6320/7253 ...completed
# loading data 6321/7253 ...completed
# loading data 6322/7253 ...completed
# loading data 6323/7253 ...completed
# loading data 6324/7253 ...completed
# loading data 6325/7253 ...completed
# loading data 6326/7253 ...completed
# loading data 6327/7253 ...completed
# loading data 6328/7253 ...completed
# loading data 6329/7253 ...completed
# loading data 6330/7253 ...completed
# loading data 6331/7253 ...completed
# loading data 6332/7253 ...completed
# loading data 6333/7253 ...completed
# loading data 6334/7253 ...completed
# loading data 6335/7253 ...completed
# loading data 6336/7253 ...completed
# loading data 6337/7253 ...completed
# loading data 6338/7253 ...completed
# loading data 6339/7253 ...completed
# loading data 6340/7253 ...completed
# loading data 6341/7253 ...completed
# loading data 6342/7253 ...completed
# loading data 6343/7253 ...completed
# loading data 6344/7253 ...completed
# loading data 6345/7253 ...completed
# loading data 6346/7253 ...completed
# loading data 6347/7253 ...completed
# loading data 6348/7253 ...completed
# loading data 6349/7253 ...completed
# loading data 6350/7253 ...completed
# loading data 6351/7253 ...completed
# loading data 6352/7253 ...completed
# loading data 6353/7253 ...completed
# loading data 6354/7253 ...completed
# loading data 6355/7253 ...completed
# loading data 6356/7253 ...completed
# loading data 6357/7253 ...completed
# loading data 6358/7253 ...completed
# loading data 6359/7253 ...completed
# loading data 6360/7253 ...completed
# loading data 6361/7253 ...completed
# loading data 6362/7253 ...completed
# loading data 6363/7253 ...completed
# loading data 6364/7253 ...completed
# loading data 6365/7253 ...completed
# loading data 6366/7253 ...completed
# loading data 6367/7253 ...completed
# loading data 6368/7253 ...completed
# loading data 6369/7253 ...completed
# loading data 6370/7253 ...completed
# loading data 6371/7253 ...completed
# loading data 6372/7253 ...completed
# loading data 6373/7253 ...completed
# loading data 6374/7253 ...completed
# loading data 6375/7253 ...completed
# loading data 6376/7253 ...completed
# loading data 6377/7253 ...completed
# loading data 6378/7253 ...completed
# loading data 6379/7253 ...completed
# loading data 6380/7253 ...completed
# loading data 6381/7253 ...completed
# loading data 6382/7253 ...completed
# loading data 6383/7253 ...completed
# loading data 6384/7253 ...completed
# loading data 6385/7253 ...completed
# loading data 6386/7253 ...completed
# loading data 6387/7253 ...completed
# loading data 6388/7253 ...completed
# loading data 6389/7253 ...completed
# loading data 6390/7253 ...completed
# loading data 6391/7253 ...completed
# loading data 6392/7253 ...completed
# loading data 6393/7253 ...completed
# loading data 6394/7253 ...completed
# loading data 6395/7253 ...completed
# loading data 6396/7253 ...completed
# loading data 6397/7253 ...completed
# loading data 6398/7253 ...completed
# loading data 6399/7253 ...completed
# loading data 6400/7253 ...completed
# loading data 6401/7253 ...completed
# loading data 6402/7253 ...completed
# loading data 6403/7253 ...completed
# loading data 6404/7253 ...completed
# loading data 6405/7253 ...completed
# loading data 6406/7253 ...completed
# loading data 6407/7253 ...completed
# loading data 6408/7253 ...completed
# loading data 6409/7253 ...completed
# loading data 6410/7253 ...completed
# loading data 6411/7253 ...completed
# loading data 6412/7253 ...completed
# loading data 6413/7253 ...completed
# loading data 6414/7253 ...completed
# loading data 6415/7253 ...completed
# loading data 6416/7253 ...completed
# loading data 6417/7253 ...completed
# loading data 6418/7253 ...completed
# loading data 6419/7253 ...completed
# loading data 6420/7253 ...completed
# loading data 6421/7253 ...completed
# loading data 6422/7253 ...completed
# loading data 6423/7253 ...completed
# loading data 6424/7253 ...completed
# loading data 6425/7253 ...completed
# loading data 6426/7253 ...completed
# loading data 6427/7253 ...completed
# loading data 6428/7253 ...completed
# loading data 6429/7253 ...completed
# loading data 6430/7253 ...completed
# loading data 6431/7253 ...completed
# loading data 6432/7253 ...completed
# loading data 6433/7253 ...completed
# loading data 6434/7253 ...completed
# loading data 6435/7253 ...completed
# loading data 6436/7253 ...completed
# loading data 6437/7253 ...completed
# loading data 6438/7253 ...completed
# loading data 6439/7253 ...completed
# loading data 6440/7253 ...completed
# loading data 6441/7253 ...completed
# loading data 6442/7253 ...completed
# loading data 6443/7253 ...completed
# loading data 6444/7253 ...completed
# loading data 6445/7253 ...completed
# loading data 6446/7253 ...completed
# loading data 6447/7253 ...completed
# loading data 6448/7253 ...completed
# loading data 6449/7253 ...completed
# loading data 6450/7253 ...completed
# loading data 6451/7253 ...completed
# loading data 6452/7253 ...completed
# loading data 6453/7253 ...completed
# loading data 6454/7253 ...completed
# loading data 6455/7253 ...completed
# loading data 6456/7253 ...completed
# loading data 6457/7253 ...completed
# loading data 6458/7253 ...completed
# loading data 6459/7253 ...completed
# loading data 6460/7253 ...completed
# loading data 6461/7253 ...completed
# loading data 6462/7253 ...completed
# loading data 6463/7253 ...completed
# loading data 6464/7253 ...completed
# loading data 6465/7253 ...completed
# loading data 6466/7253 ...completed
# loading data 6467/7253 ...completed
# loading data 6468/7253 ...completed
# loading data 6469/7253 ...completed
# loading data 6470/7253 ...completed
# loading data 6471/7253 ...completed
# loading data 6472/7253 ...completed
# loading data 6473/7253 ...completed
# loading data 6474/7253 ...completed
# loading data 6475/7253 ...completed
# loading data 6476/7253 ...completed
# loading data 6477/7253 ...completed
# loading data 6478/7253 ...completed
# loading data 6479/7253 ...completed
# loading data 6480/7253 ...completed
# loading data 6481/7253 ...completed
# loading data 6482/7253 ...completed
# loading data 6483/7253 ...completed
# loading data 6484/7253 ...completed
# loading data 6485/7253 ...completed
# loading data 6486/7253 ...completed
# loading data 6487/7253 ...completed
# loading data 6488/7253 ...completed
# loading data 6489/7253 ...completed
# loading data 6490/7253 ...completed
# loading data 6491/7253 ...completed
# loading data 6492/7253 ...completed
# loading data 6493/7253 ...completed
# loading data 6494/7253 ...completed
# loading data 6495/7253 ...completed
# loading data 6496/7253 ...completed
# loading data 6497/7253 ...completed
# loading data 6498/7253 ...completed
# loading data 6499/7253 ...completed
# loading data 6500/7253 ...completed
# loading data 6501/7253 ...completed
# loading data 6502/7253 ...completed
# loading data 6503/7253 ...completed
# loading data 6504/7253 ...completed
# loading data 6505/7253 ...completed
# loading data 6506/7253 ...completed
# loading data 6507/7253 ...completed
# loading data 6508/7253 ...completed
# loading data 6509/7253 ...completed
# loading data 6510/7253 ...completed
# loading data 6511/7253 ...completed
# loading data 6512/7253 ...completed
# loading data 6513/7253 ...completed
# loading data 6514/7253 ...completed
# loading data 6515/7253 ...completed
# loading data 6516/7253 ...completed
# loading data 6517/7253 ...completed
# loading data 6518/7253 ...completed
# loading data 6519/7253 ...completed
# loading data 6520/7253 ...completed
# loading data 6521/7253 ...completed
# loading data 6522/7253 ...completed
# loading data 6523/7253 ...completed
# loading data 6524/7253 ...completed
# loading data 6525/7253 ...completed
# loading data 6526/7253 ...completed
# loading data 6527/7253 ...completed
# loading data 6528/7253 ...completed
# loading data 6529/7253 ...completed
# loading data 6530/7253 ...completed
# loading data 6531/7253 ...completed
# loading data 6532/7253 ...completed
# loading data 6533/7253 ...completed
# loading data 6534/7253 ...completed
# loading data 6535/7253 ...completed
# loading data 6536/7253 ...completed
# loading data 6537/7253 ...completed
# loading data 6538/7253 ...completed
# loading data 6539/7253 ...completed
# loading data 6540/7253 ...completed
# loading data 6541/7253 ...completed
# loading data 6542/7253 ...completed
# loading data 6543/7253 ...completed
# loading data 6544/7253 ...completed
# loading data 6545/7253 ...completed
# loading data 6546/7253 ...completed
# loading data 6547/7253 ...completed
# loading data 6548/7253 ...completed
# loading data 6549/7253 ...completed
# loading data 6550/7253 ...completed
# loading data 6551/7253 ...completed
# loading data 6552/7253 ...completed
# loading data 6553/7253 ...completed
# loading data 6554/7253 ...completed
# loading data 6555/7253 ...completed
# loading data 6556/7253 ...completed
# loading data 6557/7253 ...completed
# loading data 6558/7253 ...completed
# loading data 6559/7253 ...completed
# loading data 6560/7253 ...completed
# loading data 6561/7253 ...completed
# loading data 6562/7253 ...completed
# loading data 6563/7253 ...completed
# loading data 6564/7253 ...completed
# loading data 6565/7253 ...completed
# loading data 6566/7253 ...completed
# loading data 6567/7253 ...completed
# loading data 6568/7253 ...completed
# loading data 6569/7253 ...completed
# loading data 6570/7253 ...completed
# loading data 6571/7253 ...completed
# loading data 6572/7253 ...completed
# loading data 6573/7253 ...completed
# loading data 6574/7253 ...completed
# loading data 6575/7253 ...completed
# loading data 6576/7253 ...completed
# loading data 6577/7253 ...completed
# loading data 6578/7253 ...completed
# loading data 6579/7253 ...completed
# loading data 6580/7253 ...completed
# loading data 6581/7253 ...completed
# loading data 6582/7253 ...completed
# loading data 6583/7253 ...completed
# loading data 6584/7253 ...completed
# loading data 6585/7253 ...completed
# loading data 6586/7253 ...completed
# loading data 6587/7253 ...completed
# loading data 6588/7253 ...completed
# loading data 6589/7253 ...completed
# loading data 6590/7253 ...completed
# loading data 6591/7253 ...completed
# loading data 6592/7253 ...completed
# loading data 6593/7253 ...completed
# loading data 6594/7253 ...completed
# loading data 6595/7253 ...completed
# loading data 6596/7253 ...completed
# loading data 6597/7253 ...completed
# loading data 6598/7253 ...completed
# loading data 6599/7253 ...completed
# loading data 6600/7253 ...completed
# loading data 6601/7253 ...completed
# loading data 6602/7253 ...completed
# loading data 6603/7253 ...completed
# loading data 6604/7253 ...completed
# loading data 6605/7253 ...completed
# loading data 6606/7253 ...completed
# loading data 6607/7253 ...completed
# loading data 6608/7253 ...completed
# loading data 6609/7253 ...completed
# loading data 6610/7253 ...completed
# loading data 6611/7253 ...completed
# loading data 6612/7253 ...completed
# loading data 6613/7253 ...completed
# loading data 6614/7253 ...completed
# loading data 6615/7253 ...completed
# loading data 6616/7253 ...completed
# loading data 6617/7253 ...completed
# loading data 6618/7253 ...completed
# loading data 6619/7253 ...completed
# loading data 6620/7253 ...completed
# loading data 6621/7253 ...completed
# loading data 6622/7253 ...completed
# loading data 6623/7253 ...completed
# loading data 6624/7253 ...completed
# loading data 6625/7253 ...completed
# loading data 6626/7253 ...completed
# loading data 6627/7253 ...completed
# loading data 6628/7253 ...completed
# loading data 6629/7253 ...completed
# loading data 6630/7253 ...completed
# loading data 6631/7253 ...completed
# loading data 6632/7253 ...completed
# loading data 6633/7253 ...completed
# loading data 6634/7253 ...completed
# loading data 6635/7253 ...completed
# loading data 6636/7253 ...completed
# loading data 6637/7253 ...completed
# loading data 6638/7253 ...completed
# loading data 6639/7253 ...completed
# loading data 6640/7253 ...completed
# loading data 6641/7253 ...completed
# loading data 6642/7253 ...completed
# loading data 6643/7253 ...completed
# loading data 6644/7253 ...completed
# loading data 6645/7253 ...completed
# loading data 6646/7253 ...completed
# loading data 6647/7253 ...completed
# loading data 6648/7253 ...completed
# loading data 6649/7253 ...completed
# loading data 6650/7253 ...completed
# loading data 6651/7253 ...completed
# loading data 6652/7253 ...completed
# loading data 6653/7253 ...completed
# loading data 6654/7253 ...completed
# loading data 6655/7253 ...completed
# loading data 6656/7253 ...completed
# loading data 6657/7253 ...completed
# loading data 6658/7253 ...completed
# loading data 6659/7253 ...completed
# loading data 6660/7253 ...completed
# loading data 6661/7253 ...completed
# loading data 6662/7253 ...completed
# loading data 6663/7253 ...completed
# loading data 6664/7253 ...completed
# loading data 6665/7253 ...completed
# loading data 6666/7253 ...completed
# loading data 6667/7253 ...completed
# loading data 6668/7253 ...completed
# loading data 6669/7253 ...completed
# loading data 6670/7253 ...completed
# loading data 6671/7253 ...completed
# loading data 6672/7253 ...completed
# loading data 6673/7253 ...completed
# loading data 6674/7253 ...completed
# loading data 6675/7253 ...completed
# loading data 6676/7253 ...completed
# loading data 6677/7253 ...completed
# loading data 6678/7253 ...completed
# loading data 6679/7253 ...completed
# loading data 6680/7253 ...completed
# loading data 6681/7253 ...completed
# loading data 6682/7253 ...completed
# loading data 6683/7253 ...completed
# loading data 6684/7253 ...completed
# loading data 6685/7253 ...completed
# loading data 6686/7253 ...completed
# loading data 6687/7253 ...completed
# loading data 6688/7253 ...completed
# loading data 6689/7253 ...completed
# loading data 6690/7253 ...completed
# loading data 6691/7253 ...completed
# loading data 6692/7253 ...completed
# loading data 6693/7253 ...completed
# loading data 6694/7253 ...completed
# loading data 6695/7253 ...completed
# loading data 6696/7253 ...completed
# loading data 6697/7253 ...completed
# loading data 6698/7253 ...completed
# loading data 6699/7253 ...completed
# loading data 6700/7253 ...completed
# loading data 6701/7253 ...completed
# loading data 6702/7253 ...completed
# loading data 6703/7253 ...completed
# loading data 6704/7253 ...completed
# loading data 6705/7253 ...completed
# loading data 6706/7253 ...completed
# loading data 6707/7253 ...completed
# loading data 6708/7253 ...completed
# loading data 6709/7253 ...completed
# loading data 6710/7253 ...completed
# loading data 6711/7253 ...completed
# loading data 6712/7253 ...completed
# loading data 6713/7253 ...completed
# loading data 6714/7253 ...completed
# loading data 6715/7253 ...completed
# loading data 6716/7253 ...completed
# loading data 6717/7253 ...completed
# loading data 6718/7253 ...completed
# loading data 6719/7253 ...completed
# loading data 6720/7253 ...completed
# loading data 6721/7253 ...completed
# loading data 6722/7253 ...completed
# loading data 6723/7253 ...completed
# loading data 6724/7253 ...completed
# loading data 6725/7253 ...completed
# loading data 6726/7253 ...completed
# loading data 6727/7253 ...completed
# loading data 6728/7253 ...completed
# loading data 6729/7253 ...completed
# loading data 6730/7253 ...completed
# loading data 6731/7253 ...completed
# loading data 6732/7253 ...completed
# loading data 6733/7253 ...completed
# ...
# loading data 6813/7253 ...completed
# loading data 6814/7253 ...completed
# loading data 6815/7253 ...completed
# loading data 6816/7253 ...completed
# loading data 6817/7253 ...completed
# loading data 6818/7253 ...completed
# loading data 6819/7253 ...completed
# loading data 6820/7253 ...completed
# loading data 6821/7253 ...completed
# loading data 6822/7253 ...completed
# loading data 6823/7253 ...completed
# loading data 6824/7253 ...completed
# loading data 6825/7253 ...completed
# loading data 6826/7253 ...completed
# loading data 6827/7253 ...completed
# loading data 6828/7253 ...completed
# loading data 6829/7253 ...completed
# loading data 6830/7253 ...completed
# loading data 6831/7253 ...completed
# loading data 6832/7253 ...completed
# loading data 6833/7253 ...completed
# loading data 6834/7253 ...completed
# loading data 6835/7253 ...completed
# loading data 6836/7253 ...completed
# loading data 6837/7253 ...completed
# loading data 6838/7253 ...completed
# loading data 6839/7253 ...completed
# loading data 6840/7253 ...completed
# loading data 6841/7253 ...completed
# loading data 6842/7253 ...completed
# loading data 6843/7253 ...completed
# loading data 6844/7253 ...completed
# loading data 6845/7253 ...completed
# loading data 6846/7253 ...completed
# loading data 6847/7253 ...completed
# loading data 6848/7253 ...completed
# loading data 6849/7253 ...completed
# loading data 6850/7253 ...completed
# loading data 6851/7253 ...completed
# loading data 6852/7253 ...completed
# loading data 6853/7253 ...completed
# loading data 6854/7253 ...completed
# loading data 6855/7253 ...completed
# loading data 6856/7253 ...completed
# loading data 6857/7253 ...completed
# loading data 6858/7253 ...completed
# loading data 6859/7253 ...completed
# loading data 6860/7253 ...completed
# loading data 6861/7253 ...completed
# loading data 6862/7253 ...completed
# loading data 6863/7253 ...completed
# loading data 6864/7253 ...completed
# loading data 6865/7253 ...completed
# loading data 6866/7253 ...completed
# loading data 6867/7253 ...completed
# loading data 6868/7253 ...completed
# loading data 6869/7253 ...completed
# loading data 6870/7253 ...completed
# loading data 6871/7253 ...completed
# loading data 6872/7253 ...completed
# loading data 6873/7253 ...completed
# loading data 6874/7253 ...completed
# loading data 6875/7253 ...completed
# loading data 6876/7253 ...completed
# loading data 6877/7253 ...completed
# loading data 6878/7253 ...completed
# loading data 6879/7253 ...completed
# loading data 6880/7253 ...completed
# loading data 6881/7253 ...completed
# loading data 6882/7253 ...completed
# loading data 6883/7253 ...completed
# loading data 6884/7253 ...completed
# loading data 6885/7253 ...completed
# loading data 6886/7253 ...completed
# loading data 6887/7253 ...completed
# loading data 6888/7253 ...completed
# loading data 6889/7253 ...completed
# loading data 6890/7253 ...completed
# loading data 6891/7253 ...completed
# loading data 6892/7253 ...completed
# loading data 6893/7253 ...completed
# loading data 6894/7253 ...completed
# loading data 6895/7253 ...completed
# loading data 6896/7253 ...completed
# loading data 6897/7253 ...completed
# loading data 6898/7253 ...completed
# loading data 6899/7253 ...completed
# loading data 6900/7253 ...completed
# loading data 6901/7253 ...completed
# loading data 6902/7253 ...completed
# loading data 6903/7253 ...completed
# loading data 6904/7253 ...completed
# loading data 6905/7253 ...completed
# loading data 6906/7253 ...completed
# loading data 6907/7253 ...completed
# loading data 6908/7253 ...completed
# loading data 6909/7253 ...completed
# loading data 6910/7253 ...completed
# loading data 6911/7253 ...completed
# loading data 6912/7253 ...completed
# loading data 6913/7253 ...completed
# loading data 6914/7253 ...completed
# loading data 6915/7253 ...completed
# loading data 6916/7253 ...completed
# loading data 6917/7253 ...completed
# loading data 6918/7253 ...completed
# loading data 6919/7253 ...completed
# loading data 6920/7253 ...completed
# loading data 6921/7253 ...completed
# loading data 6922/7253 ...completed
# loading data 6923/7253 ...completed
# loading data 6924/7253 ...completed
# loading data 6925/7253 ...completed
# loading data 6926/7253 ...completed
# loading data 6927/7253 ...completed
# loading data 6928/7253 ...completed
# loading data 6929/7253 ...completed
# loading data 6930/7253 ...completed
# loading data 6931/7253 ...completed
# loading data 6932/7253 ...completed
# loading data 6933/7253 ...completed
# loading data 6934/7253 ...completed
# loading data 6935/7253 ...completed
# loading data 6936/7253 ...completed
# loading data 6937/7253 ...completed
# loading data 6938/7253 ...completed
# loading data 6939/7253 ...completed
# loading data 6940/7253 ...completed
# loading data 6941/7253 ...completed
# loading data 6942/7253 ...completed
# loading data 6943/7253 ...completed
# loading data 6944/7253 ...completed
# loading data 6945/7253 ...completed
# loading data 6946/7253 ...completed
# loading data 6947/7253 ...completed
# loading data 6948/7253 ...completed
# loading data 6949/7253 ...completed
# loading data 6950/7253 ...completed
# loading data 6951/7253 ...completed
# loading data 6952/7253 ...completed
# loading data 6953/7253 ...completed
# loading data 6954/7253 ...completed
# loading data 6955/7253 ...completed
# loading data 6956/7253 ...completed
# loading data 6957/7253 ...completed
# loading data 6958/7253 ...completed
# loading data 6959/7253 ...completed
# loading data 6960/7253 ...completed
# loading data 6961/7253 ...completed
# loading data 6962/7253 ...completed
# loading data 6963/7253 ...completed
# loading data 6964/7253 ...completed
# loading data 6965/7253 ...completed
# loading data 6966/7253 ...completed
# loading data 6967/7253 ...completed
# loading data 6968/7253 ...completed
# loading data 6969/7253 ...completed
# loading data 6970/7253 ...completed
# loading data 6971/7253 ...completed
# loading data 6972/7253 ...completed
# loading data 6973/7253 ...completed
# loading data 6974/7253 ...completed
# loading data 6975/7253 ...completed
# loading data 6976/7253 ...completed
# loading data 6977/7253 ...completed
# loading data 6978/7253 ...completed
# loading data 6979/7253 ...completed
# loading data 6980/7253 ...completed
# loading data 6981/7253 ...completed
# loading data 6982/7253 ...completed
# loading data 6983/7253 ...completed
# loading data 6984/7253 ...completed
# loading data 6985/7253 ...completed
# loading data 6986/7253 ...completed
# loading data 6987/7253 ...completed
# loading data 6988/7253 ...completed
# loading data 6989/7253 ...completed
# loading data 6990/7253 ...completed
# loading data 6991/7253 ...completed
# loading data 6992/7253 ...completed
# loading data 6993/7253 ...completed
# loading data 6994/7253 ...completed
# loading data 6995/7253 ...completed
# loading data 6996/7253 ...completed
# loading data 6997/7253 ...completed
# loading data 6998/7253 ...completed
# loading data 6999/7253 ...completed
# loading data 7000/7253 ...completed
# loading data 7001/7253 ...completed
# loading data 7002/7253 ...completed
# loading data 7003/7253 ...completed
# loading data 7004/7253 ...completed
# loading data 7005/7253 ...completed
# loading data 7006/7253 ...completed
# loading data 7007/7253 ...completed
# loading data 7008/7253 ...completed
# loading data 7009/7253 ...completed
# loading data 7010/7253 ...completed
# loading data 7011/7253 ...completed
# loading data 7012/7253 ...completed
# loading data 7013/7253 ...completed
# loading data 7014/7253 ...completed
# loading data 7015/7253 ...completed
# loading data 7016/7253 ...completed
# loading data 7017/7253 ...completed
# loading data 7018/7253 ...completed
# loading data 7019/7253 ...completed
# loading data 7020/7253 ...completed
# loading data 7021/7253 ...completed
# loading data 7022/7253 ...completed
# loading data 7023/7253 ...completed
# loading data 7024/7253 ...completed
# loading data 7025/7253 ...completed
# loading data 7026/7253 ...completed
# loading data 7027/7253 ...completed
# loading data 7028/7253 ...completed
# loading data 7029/7253 ...completed
# loading data 7030/7253 ...completed
# loading data 7031/7253 ...completed
# loading data 7032/7253 ...completed
# loading data 7033/7253 ...completed
# loading data 7034/7253 ...completed
# loading data 7035/7253 ...completed
# loading data 7036/7253 ...completed
# loading data 7037/7253 ...completed
# loading data 7038/7253 ...completed
# loading data 7039/7253 ...completed
# loading data 7040/7253 ...completed
# loading data 7041/7253 ...completed
# loading data 7042/7253 ...completed
# loading data 7043/7253 ...completed
# loading data 7044/7253 ...completed
# loading data 7045/7253 ...completed
# loading data 7046/7253 ...completed
# loading data 7047/7253 ...completed
# loading data 7048/7253 ...completed
# loading data 7049/7253 ...completed
# loading data 7050/7253 ...completed
# loading data 7051/7253 ...completed
# loading data 7052/7253 ...completed
# loading data 7053/7253 ...completed
# loading data 7054/7253 ...completed
# loading data 7055/7253 ...completed
# loading data 7056/7253 ...completed
# loading data 7057/7253 ...completed
# loading data 7058/7253 ...completed
# loading data 7059/7253 ...completed
# loading data 7060/7253 ...completed
# loading data 7061/7253 ...completed
# loading data 7062/7253 ...completed
# loading data 7063/7253 ...completed
# loading data 7064/7253 ...completed
# loading data 7065/7253 ...completed
# loading data 7066/7253 ...completed
# loading data 7067/7253 ...completed
# loading data 7068/7253 ...completed
# loading data 7069/7253 ...completed
# loading data 7070/7253 ...completed
# loading data 7071/7253 ...completed
# loading data 7072/7253 ...completed
# loading data 7073/7253 ...completed
# loading data 7074/7253 ...completed
# loading data 7075/7253 ...completed
# loading data 7076/7253 ...completed
# loading data 7077/7253 ...completed
# loading data 7078/7253 ...completed
# loading data 7079/7253 ...completed
# loading data 7080/7253 ...completed
# loading data 7081/7253 ...completed
# loading data 7082/7253 ...completed
# loading data 7083/7253 ...completed
# loading data 7084/7253 ...completed
# loading data 7085/7253 ...completed
# loading data 7086/7253 ...completed
# loading data 7087/7253 ...completed
# loading data 7088/7253 ...completed
# loading data 7089/7253 ...completed
# loading data 7090/7253 ...completed
# loading data 7091/7253 ...completed
# loading data 7092/7253 ...completed
# loading data 7093/7253 ...completed
# loading data 7094/7253 ...completed
# loading data 7095/7253 ...completed
# loading data 7096/7253 ...completed
# loading data 7097/7253 ...completed
# loading data 7098/7253 ...completed
# loading data 7099/7253 ...completed
# loading data 7100/7253 ...completed
# loading data 7101/7253 ...completed
# loading data 7102/7253 ...completed
# loading data 7103/7253 ...completed
# loading data 7104/7253 ...completed
# loading data 7105/7253 ...completed
# loading data 7106/7253 ...completed
# loading data 7107/7253 ...completed
# loading data 7108/7253 ...completed
# loading data 7109/7253 ...completed
# loading data 7110/7253 ...completed
# loading data 7111/7253 ...completed
# loading data 7112/7253 ...completed
# loading data 7113/7253 ...completed
# loading data 7114/7253 ...completed
# loading data 7115/7253 ...completed
# loading data 7116/7253 ...completed
# loading data 7117/7253 ...completed
# loading data 7118/7253 ...completed
# loading data 7119/7253 ...completed
# loading data 7120/7253 ...completed
# loading data 7121/7253 ...completed
# loading data 7122/7253 ...completed
# loading data 7123/7253 ...completed
# loading data 7124/7253 ...completed
# loading data 7125/7253 ...completed
# loading data 7126/7253 ...completed
# loading data 7127/7253 ...completed
# loading data 7128/7253 ...completed
# loading data 7129/7253 ...completed
# loading data 7130/7253 ...completed
# loading data 7131/7253 ...completed
# loading data 7132/7253 ...completed
# loading data 7133/7253 ...completed
# loading data 7134/7253 ...completed
# loading data 7135/7253 ...completed
# loading data 7136/7253 ...completed
# loading data 7137/7253 ...completed
# loading data 7138/7253 ...completed
# loading data 7139/7253 ...completed
# loading data 7140/7253 ...completed
# loading data 7141/7253 ...completed
# loading data 7142/7253 ...completed
# loading data 7143/7253 ...completed
# loading data 7144/7253 ...completed
# loading data 7145/7253 ...completed
# loading data 7146/7253 ...completed
# loading data 7147/7253 ...completed
# loading data 7148/7253 ...completed
# loading data 7149/7253 ...completed
# loading data 7150/7253 ...completed
# loading data 7151/7253 ...completed
# loading data 7152/7253 ...completed
# loading data 7153/7253 ...completed
# loading data 7154/7253 ...completed
# loading data 7155/7253 ...completed
# loading data 7156/7253 ...completed
# loading data 7157/7253 ...completed
# loading data 7158/7253 ...completed
# loading data 7159/7253 ...completed
# loading data 7160/7253 ...completed
# loading data 7161/7253 ...completed
# loading data 7162/7253 ...completed
# loading data 7163/7253 ...completed
# loading data 7164/7253 ...completed
# loading data 7165/7253 ...completed
# loading data 7166/7253 ...completed
# loading data 7167/7253 ...completed
# loading data 7168/7253 ...completed
# loading data 7169/7253 ...completed
# loading data 7170/7253 ...completed
# loading data 7171/7253 ...completed
# loading data 7172/7253 ...completed
# loading data 7173/7253 ...completed
# loading data 7174/7253 ...completed
# loading data 7175/7253 ...completed
# loading data 7176/7253 ...completed
# loading data 7177/7253 ...completed
# loading data 7178/7253 ...completed
# loading data 7179/7253 ...completed
# loading data 7180/7253 ...completed
# loading data 7181/7253 ...completed
# loading data 7182/7253 ...completed
# loading data 7183/7253 ...completed
# loading data 7184/7253 ...completed
# loading data 7185/7253 ...completed
# loading data 7186/7253 ...completed
# loading data 7187/7253 ...completed
# loading data 7188/7253 ...completed
# loading data 7189/7253 ...completed
# loading data 7190/7253 ...completed
# loading data 7191/7253 ...completed
# loading data 7192/7253 ...completed
# loading data 7193/7253 ...completed
# loading data 7194/7253 ...completed
# loading data 7195/7253 ...completed
# loading data 7196/7253 ...completed
# loading data 7197/7253 ...completed
# loading data 7198/7253 ...completed
# loading data 7199/7253 ...completed
# loading data 7200/7253 ...completed
# loading data 7201/7253 ...completed
# loading data 7202/7253 ...completed
# loading data 7203/7253 ...completed
# loading data 7204/7253 ...completed
# loading data 7205/7253 ...completed
# loading data 7206/7253 ...completed
# loading data 7207/7253 ...completed
# loading data 7208/7253 ...completed
# loading data 7209/7253 ...completed
# loading data 7210/7253 ...completed
# loading data 7211/7253 ...completed
# loading data 7212/7253 ...completed
# loading data 7213/7253 ...completed
# loading data 7214/7253 ...completed
# loading data 7215/7253 ...completed
# loading data 7216/7253 ...completed
# loading data 7217/7253 ...completed
# loading data 7218/7253 ...completed
# loading data 7219/7253 ...completed
# loading data 7220/7253 ...completed
# loading data 7221/7253 ...completed
# loading data 7222/7253 ...completed
# loading data 7223/7253 ...completed
# loading data 7224/7253 ...completed
# loading data 7225/7253 ...completed
# loading data 7226/7253 ...completed
# loading data 7227/7253 ...completed
# loading data 7228/7253 ...completed
# loading data 7229/7253 ...completed
# loading data 7230/7253 ...completed
# loading data 7231/7253 ...completed
# loading data 7232/7253 ...completed
# loading data 7233/7253 ...completed
# loading data 7234/7253 ...completed
# loading data 7235/7253 ...completed
# loading data 7236/7253 ...completed
# loading data 7237/7253 ...completed
# loading data 7238/7253 ...completed
# loading data 7239/7253 ...completed
# loading data 7240/7253 ...completed
# loading data 7241/7253 ...completed
# loading data 7242/7253 ...completed
# loading data 7243/7253 ...completed
# loading data 7244/7253 ...completed
# loading data 7245/7253 ...completed
# loading data 7246/7253 ...completed
# loading data 7247/7253 ...completed
# loading data 7248/7253 ...completed
# loading data 7249/7253 ...completed
# loading data 7250/7253 ...completed
# loading data 7251/7253 ...completed
# loading data 7252/7253 ...completed
# loading data 7253/7253 ...completed
# saving...done
# size of training set(pacu): 22296
# size of validation set(pacu): 2391
# size of test set(pacu): 2801
