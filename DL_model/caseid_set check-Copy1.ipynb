# %%
import pandas as pd
import pickle

df_match = pd.read_csv('match_age_pass_20201211.csv')
caseid_test = pickle.load(open('caseid_test','rb')).tolist()
caseid_val = pickle.load(open('caseid_val','rb')).tolist()
caseid_train = pickle.load(open('caseid_train','rb')).tolist()

# %%
caseid_test
# Out:
# ['PACU1_10_190528_110437.csv',
#  'PACU1_10_190709_172441.csv',
#  'PACU1_10_190723_125732.csv',
#  'PACU1_10_190820_163322.csv',
#  'PACU1_10_190821_102951.csv',
#  'PACU1_10_190821_140008.csv',
#  'PACU1_10_190821_154935.csv',
#  'PACU1_10_190827_134744.csv',
#  'PACU1_10_190829_170015.csv',
#  'PACU1_10_190830_135223.csv',
#  'PACU1_10_200115_155300.csv',
#  'PACU1_10_200205_120438.csv',
#  'PACU1_10_200205_145216.csv',
#  'PACU1_10_200211_172517.csv',
#  'PACU1_10_200214_134908.csv',
#  'PACU1_10_200217_165735.csv',
#  'PACU1_10_200221_102154.csv',
#  'PACU1_10_200228_130016.csv',
#  'PACU1_10_200507_132540.csv',
#  'PACU1_10_200521_103234.csv',
#  'PACU1_10_200521_164846.csv',
#  'PACU1_10_200529_151443.csv',
#  'PACU1_10_200603_131444.csv',
#  'PACU1_10_200612_095554.csv',
#  'PACU1_10_200616_173958.csv',
#  'PACU1_10_200617_142506.csv',
#  'PACU1_10_200716_103518.csv',
#  'PACU1_10_200811_131641.csv',
#  'PACU1_10_200820_103206.csv',
#  'PACU1_10_200918_163449.csv',
# ...

# %%
df_match['path'] = [f.split('.')[0]+'.csv' for f in df_match['path'].values.flatten()]
df_match
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0              3             3               3                 3
# 1              4             4               4                 4
# 2              6             6               6                 7
# 3              7             7               7                 8
# 4              9             9               9                10
# ...          ...           ...             ...               ...
# 6506        8267          8328            8385              9065
# 6507        8268          8329            8386              9066
# 6508        8269          8330            8387              9067
# 6509        8270          8331            8388              9068
# 6510        8271          8332            8389              9069
#
#       Unnamed: 0.1.1.1.1  Unnamed: 0.1.1.1.1.1  Unnamed: 0.1.1.1.1.1.1  \
# 0                    146                   146                     146
# ...

# %%
df_match.loc[0,'test'] = 1

# %%
df_match
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0              3             3               3                 3
# 1              4             4               4                 4
# 2              6             6               6                 7
# 3              7             7               7                 8
# 4              9             9               9                10
# ...          ...           ...             ...               ...
# 6506        8267          8328            8385              9065
# 6507        8268          8329            8386              9066
# 6508        8269          8330            8387              9067
# 6509        8270          8331            8388              9068
# 6510        8271          8332            8389              9069
#
#       Unnamed: 0.1.1.1.1  Unnamed: 0.1.1.1.1.1  Unnamed: 0.1.1.1.1.1.1  \
# 0                    146                   146                     146
# ...

# %%
opid = df_match['opid'].tolist()
opid = np.array(opid)
opid_unique = np.unique(opid)
print(opid)
print(opid_unique)
opid = opid.tolist()
opid_unique= opid_unique.tolist()

opid_dupl=[]
for ids in opid:
    if ids not in opid_unique:
        opid_dupl.append(ids)
print(len(opid_dupl))
# Out:
# [190409012 190409044 190409087 ... 201031004 201031004 201031002]
# [190409012 190409044 190409079 ... 201030108 201031002 201031004]
# 0

# %%
df_match['test']=0
df_match['val']=0
df_match['train']=0

for i in range(len(df_match)):
    if df_match.loc[i,'path'] in caseid_test:  
        df_match.loc[i,'test'] = 1
    if df_match.loc[i,'path'] in caseid_val:
        df_match.loc[i,'val'] = 1
    elif df_match.loc[i,'path'] in caseid_train:
        df_match.loc[i,'train'] = 1
        
print(df_match)
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0              3             3               3                 3
# 1              4             4               4                 4
# 2              6             6               6                 7
# 3              7             7               7                 8
# 4              9             9               9                10
# ...          ...           ...             ...               ...
# 6506        8267          8328            8385              9065
# 6507        8268          8329            8386              9066
# 6508        8269          8330            8387              9067
# 6509        8270          8331            8388              9068
# 6510        8271          8332            8389              9069
#
#       Unnamed: 0.1.1.1.1  Unnamed: 0.1.1.1.1.1  Unnamed: 0.1.1.1.1.1.1  \
# 0                    146                   146                     146
# ...

# %%
test_opid = np.unique(df_match[df_match['test']==1]['opid'].tolist())
train_opid = np.unique(df_match[df_match['train']==1]['opid'].tolist())
val_opid = np.unique(df_match[df_match['val']==1]['opid'].tolist())

# %%
set_test = set(test_opid)
set_train = set(train_opid)
set_val = set(val_opid)

# %%
print(len(set_test), len(set_test-set_train), len(set_train), len(set_train-set_test))
# Out:
# 386 382 3188 3184

# %%
print(len(set_test), len(set_test-set_val), len(set_val), len(set_val-set_test))
# Out:
# 386 386 359 359

# %%
print(len(set_train), len(set_train-set_val), len(set_val), len(set_val-set_train))
# Out:
# 3188 3184 359 355

# %%
len(set_train.union(set_test,set_val))
# Out:
# 3925

# %%
386*0.9*9
# Out:
# 3126.6000000000004
