# %%
import statsmodels.api as sm


def smooth(y):
    #return savitzky_golay(y, window_size=2001, order=3)
    return lowess(y)

# 0.2가 제일 잘 없앴음
def lowess(y, f=0.2):
    x = np.arange(0, len(y))
    return sm.nonparametric.lowess(y, x, frac=f, it=0)[:, 1].T

import numpy as np
import pandas as pd
import os, pickle, sys
from scipy import signal
#sys.path.append('DL_model')


### input 설정
SRATE = 250 # 250Hz
LEN_INPUT = 20 # input 10s
LEN_PER_NRS = 60 # vital length for each NRS
OVERLAP = 2
n_aug = int((LEN_PER_NRS-LEN_INPUT)/OVERLAP) + 1 # data augmentation 개수



input_path = '../DL_model/dataset/preprocess4/input3/'
if not os.path.exists(input_path[:-1]):
    os.mkdir(input_path[:-1])

if os.path.exists(input_path+'x_train_pacu.npz'):
    print('loading train...', flush=True, end='')
    x_train_pacu = np.load(input_path+'x_train_pacu.npz', allow_pickle=True)['arr_0']
    y_train_pacu = np.load(input_path+'y_train_pacu.npz')['arr_0']
    x_test_pacu = np.load(input_path+'x_test_pacu.npz', allow_pickle=True)['arr_0']
    y_test_pacu = np.load(input_path+'y_test_pacu.npz')['arr_0']
    print('done', flush=True)

else:
    false_row_list_preop = []
    
    vital_path = '../../cranberry2/Preprocessing/vital_data/PPG_100Hz_ECG_100Hz_pacu_2min/'
    ecg_path = '../../cranberry2/Preprocessing/vital_data/ECG_250Hz_pacu_2min/ECG,'
    df_preprocess_pacu = pickle.load(open('../DL_model/cache/preprocess3/input3/df_preprocess_pacu_agender','rb'))
    df_demograph = pd.read_csv('../DL_model/caseids_age_gender.csv')
    

    ### test set에 해당하는 file_path
    caseid_test = pickle.load(open('../DL_model/caseid_test_new', 'rb'))
    caseid_train = pickle.load(open('../DL_model/caseid_train_new', 'rb'))
    caseid_val = pickle.load(open('../DL_model/caseid_val_new', 'rb'))
    
    non_lis = []
    x_train_pacu, y_train_pacu = [], []
    x_test_pacu, y_test_pacu = [], []
    x_val_pacu, y_val_pacu = [], []
    age_train_pacu, gender_train_pacu = [], []
    age_test_pacu, gender_test_pacu = [], []
    age_val_pacu, gender_val_pacu = [], []

    cnt = 0
    for _, row in df_preprocess_pacu.iterrows():
        cnt += 1
        if cnt<=1800:
            continue
        if cnt>3600:
            break
            
            
        print('loading data {}/{} ...'.format(cnt, len(df_preprocess_pacu)), end='')
        row_demo = df_demograph[df_demograph['caseids']==row['caseids']].iloc[0]
            

        # vital data - PPG (resampling 100 Hz to 250 Hz)
        df_vital = pickle.load(open(vital_path+row['file_path'], 'rb')).reset_index()
        pleth_samp = df_vital[['Pleth']].fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()
        pleth_resamp = signal.resample(pleth_samp, 120*SRATE)
        ppg_per_NRS = np.full(30000, np.nan)
        ppg_per_NRS[0:len(pleth_resamp)] = pleth_resamp
        

        # vital data - ECG (250Hz)
        ecg_samp = pickle.load(open(ecg_path+row['file_path'][:-3]+'vital', 'rb')).reset_index()[['ECG']]
        ecg_samp = ecg_samp.fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()[0:30000]
        ecg_per_NRS = np.full(30000,np.nan)
        ecg_per_NRS[0:len(ecg_samp)] = ecg_samp
   

        save_path = '../../cranberry2/Preprocessing/cache/lowess_filtered/pacu_'+row['caseids']
        # 한 NRS에 대해 23개의 input 확인
        for i in range(0,30):
            # input이 전처리 통과한 경우
            if row[str(i+1)]:
                start_idx = i*OVERLAP*SRATE # 500i
                end_idx = (i*OVERLAP+LEN_INPUT)*SRATE # 500i + 1000
                
                # input의 normalization
                ppg_inp = np.copy(ppg_per_NRS[start_idx:end_idx])
                if np.sum(np.isnan(ppg_inp))!=0:
                    ppg_inp = pd.DataFrame(ppg_inp).fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()
                
                pleth_inp = ppg_inp - smooth(ppg_inp)
                pleth_inp = pleth_inp - np.nanmean(pleth_inp)

                ecg_inp = np.copy(ecg_per_NRS[start_idx:end_idx])
                if np.sum(np.isnan(ecg_inp))!=0:
                    ecg_inp = pd.DataFrame(ecg_inp).fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()
                
                ecg_inp = ecg_inp - smooth(ecg_inp)
                ecg_inp = (ecg_inp - np.nanmean(ecg_inp)) / np.nanstd(ecg_inp)
                
                
                pickle.dump([pleth_inp, ecg_inp],  open(save_path+'_{}'.format(i), 'wb'))
                # 해당 caseid가 test set에 속하는 경우
                if row['caseids'] in caseid_test:
                    age_test_pacu.append(int(row_demo['age']))
                    if row_demo['gender']=='F':
                        gender_test_pacu.append(1)
                    else:
                        gender_test_pacu.append(0)
                    x_test_pacu.append([pleth_inp, ecg_inp])
                    y_test_pacu.append(int(float(row['NRS'])))

                # 해당 caseid가 train set에 해당하는 경우
                elif row['caseids'] in caseid_val:
                    age_val_pacu.append(int(row_demo['age']))
                    if row_demo['gender']=='F':
                        gender_val_pacu.append(1)
                    else:
                        gender_val_pacu.append(0)                    
                    x_val_pacu.append([pleth_inp, ecg_inp])
                    y_val_pacu.append(int(float(row['NRS'])))
                    
                elif row['caseids'] in caseid_train:
                    age_train_pacu.append(int(row_demo['age']))
                    if row_demo['gender']=='F':
                        gender_train_pacu.append(1)
                    else:
                        gender_train_pacu.append(0)                    
                    x_train_pacu.append([pleth_inp, ecg_inp])
                    y_train_pacu.append(int(float(row['NRS'])))
                    
                else:
                    non_lis.append(row['caseids'])
                    
        print('completed')
        
        
    x_train_pacu = np.array(x_train_pacu, np.float32)
    x_test_pacu = np.array(x_test_pacu, np.float32)
    y_train_pacu = np.array(y_train_pacu, int)
    y_test_pacu = np.array(y_test_pacu, int)
    x_val_pacu = np.array(x_val_pacu, np.float32)
    y_val_pacu = np.array(y_val_pacu, int)
    
    age_train_pacu = np.array(age_train_pacu, int)
    age_test_pacu = np.array(age_test_pacu, int)
    age_val_pacu = np.array(age_val_pacu, int)
    gender_train_pacu = np.array(gender_train_pacu, int)
    gender_test_pacu = np.array(gender_test_pacu, int)
    gender_val_pacu = np.array(gender_val_pacu, int)
    
        
    # 저장하기
    print('saving...', end='', flush=True)
    np.savez_compressed(input_path+'x_train_pacu2.npz', x_train_pacu)
    np.savez_compressed(input_path+'x_test_pacu2.npz', x_test_pacu)
    np.savez_compressed(input_path+'x_val_pacu2.npz', x_val_pacu)
    np.savez_compressed(input_path+'y_train_pacu2.npz', y_train_pacu)
    np.savez_compressed(input_path+'y_test_pacu2.npz', y_test_pacu)
    np.savez_compressed(input_path+'y_val_pacu2.npz', y_val_pacu)
    
    np.savez_compressed(input_path+'age_train_pacu2.npz', age_train_pacu)
    np.savez_compressed(input_path+'age_test_pacu2.npz', age_test_pacu)
    np.savez_compressed(input_path+'age_val_pacu2.npz', age_val_pacu)    
    np.savez_compressed(input_path+'gender_train_pacu2.npz', gender_train_pacu)
    np.savez_compressed(input_path+'gender_test_pacu2.npz', gender_test_pacu)
    np.savez_compressed(input_path+'gender_val_pacu2.npz', gender_val_pacu)    
    
    print('done', flush=True)

    
    
    
print('size of training set(pacu):', len(x_train_pacu))
print('size of validation set(pacu):', len(x_val_pacu))
print('size of test set(pacu):', len(x_test_pacu))
# Out:
# loading data 1801/7253 ...completed
# loading data 1802/7253 ...completed
# loading data 1803/7253 ...completed
# loading data 1804/7253 ...completed
# loading data 1805/7253 ...completed
# loading data 1806/7253 ...completed
# loading data 1807/7253 ...completed
# loading data 1808/7253 ...completed
# loading data 1809/7253 ...completed
# loading data 1810/7253 ...completed
# loading data 1811/7253 ...completed
# loading data 1812/7253 ...completed
# loading data 1813/7253 ...completed
# loading data 1814/7253 ...completed
# loading data 1815/7253 ...completed
# loading data 1816/7253 ...completed
# loading data 1817/7253 ...completed
# loading data 1818/7253 ...completed
# loading data 1819/7253 ...completed
# loading data 1820/7253 ...completed
# loading data 1821/7253 ...completed
# loading data 1822/7253 ...completed
# loading data 1823/7253 ...completed
# loading data 1824/7253 ...completed
# loading data 1825/7253 ...completed
# loading data 1826/7253 ...completed
# loading data 1827/7253 ...completed
# loading data 1828/7253 ...completed
# loading data 1829/7253 ...completed
# loading data 1830/7253 ...completed
# loading data 1831/7253 ...completed
# loading data 1832/7253 ...completed
# loading data 1833/7253 ...completed
# loading data 1834/7253 ...completed
# loading data 1835/7253 ...completed
# loading data 1836/7253 ...completed
# loading data 1837/7253 ...completed
# loading data 1838/7253 ...completed
# loading data 1839/7253 ...completed
# loading data 1840/7253 ...completed
# loading data 1841/7253 ...completed
# loading data 1842/7253 ...completed
# loading data 1843/7253 ...completed
# loading data 1844/7253 ...completed
# loading data 1845/7253 ...completed
# loading data 1846/7253 ...completed
# loading data 1847/7253 ...completed
# loading data 1848/7253 ...completed
# loading data 1849/7253 ...completed
# loading data 1850/7253 ...completed
# loading data 1851/7253 ...completed
# loading data 1852/7253 ...completed
# loading data 1853/7253 ...completed
# loading data 1854/7253 ...completed
# loading data 1855/7253 ...completed
# loading data 1856/7253 ...completed
# loading data 1857/7253 ...completed
# loading data 1858/7253 ...completed
# loading data 1859/7253 ...completed
# loading data 1860/7253 ...completed
# loading data 1861/7253 ...completed
# loading data 1862/7253 ...completed
# loading data 1863/7253 ...completed
# loading data 1864/7253 ...completed
# loading data 1865/7253 ...completed
# loading data 1866/7253 ...completed
# loading data 1867/7253 ...completed
# loading data 1868/7253 ...completed
# loading data 1869/7253 ...completed
# loading data 1870/7253 ...completed
# loading data 1871/7253 ...completed
# loading data 1872/7253 ...completed
# loading data 1873/7253 ...completed
# loading data 1874/7253 ...completed
# loading data 1875/7253 ...completed
# loading data 1876/7253 ...completed
# loading data 1877/7253 ...completed
# loading data 1878/7253 ...completed
# loading data 1879/7253 ...completed
# loading data 1880/7253 ...completed
# loading data 1881/7253 ...completed
# loading data 1882/7253 ...completed
# loading data 1883/7253 ...completed
# loading data 1884/7253 ...completed
# loading data 1885/7253 ...completed
# loading data 1886/7253 ...completed
# loading data 1887/7253 ...completed
# loading data 1888/7253 ...completed
# loading data 1889/7253 ...completed
# loading data 1890/7253 ...completed
# loading data 1891/7253 ...completed
# loading data 1892/7253 ...completed
# loading data 1893/7253 ...completed
# loading data 1894/7253 ...completed
# loading data 1895/7253 ...completed
# loading data 1896/7253 ...completed
# loading data 1897/7253 ...completed
# loading data 1898/7253 ...completed
# loading data 1899/7253 ...completed
# loading data 1900/7253 ...completed
# loading data 1901/7253 ...completed
# loading data 1902/7253 ...completed
# loading data 1903/7253 ...completed
# loading data 1904/7253 ...completed
# loading data 1905/7253 ...completed
# loading data 1906/7253 ...completed
# loading data 1907/7253 ...completed
# loading data 1908/7253 ...completed
# loading data 1909/7253 ...completed
# loading data 1910/7253 ...completed
# loading data 1911/7253 ...completed
# loading data 1912/7253 ...completed
# loading data 1913/7253 ...completed
# loading data 1914/7253 ...completed
# loading data 1915/7253 ...completed
# loading data 1916/7253 ...completed
# loading data 1917/7253 ...completed
# loading data 1918/7253 ...completed
# loading data 1919/7253 ...completed
# loading data 1920/7253 ...completed
# loading data 1921/7253 ...completed
# loading data 1922/7253 ...completed
# loading data 1923/7253 ...completed
# loading data 1924/7253 ...completed
# loading data 1925/7253 ...completed
# loading data 1926/7253 ...completed
# loading data 1927/7253 ...completed
# loading data 1928/7253 ...completed
# loading data 1929/7253 ...completed
# loading data 1930/7253 ...completed
# loading data 1931/7253 ...completed
# loading data 1932/7253 ...completed
# loading data 1933/7253 ...completed
# loading data 1934/7253 ...completed
# loading data 1935/7253 ...completed
# loading data 1936/7253 ...completed
# loading data 1937/7253 ...completed
# loading data 1938/7253 ...completed
# loading data 1939/7253 ...completed
# loading data 1940/7253 ...completed
# loading data 1941/7253 ...completed
# loading data 1942/7253 ...completed
# loading data 1943/7253 ...completed
# loading data 1944/7253 ...completed
# loading data 1945/7253 ...completed
# loading data 1946/7253 ...completed
# loading data 1947/7253 ...completed
# loading data 1948/7253 ...completed
# loading data 1949/7253 ...completed
# loading data 1950/7253 ...completed
# loading data 1951/7253 ...completed
# loading data 1952/7253 ...completed
# loading data 1953/7253 ...completed
# loading data 1954/7253 ...completed
# loading data 1955/7253 ...completed
# loading data 1956/7253 ...completed
# loading data 1957/7253 ...completed
# loading data 1958/7253 ...completed
# loading data 1959/7253 ...completed
# loading data 1960/7253 ...completed
# loading data 1961/7253 ...completed
# loading data 1962/7253 ...completed
# loading data 1963/7253 ...completed
# loading data 1964/7253 ...completed
# loading data 1965/7253 ...completed
# loading data 1966/7253 ...completed
# loading data 1967/7253 ...completed
# loading data 1968/7253 ...completed
# loading data 1969/7253 ...completed
# loading data 1970/7253 ...completed
# loading data 1971/7253 ...completed
# loading data 1972/7253 ...completed
# loading data 1973/7253 ...completed
# loading data 1974/7253 ...completed
# loading data 1975/7253 ...completed
# loading data 1976/7253 ...completed
# loading data 1977/7253 ...completed
# loading data 1978/7253 ...completed
# loading data 1979/7253 ...completed
# loading data 1980/7253 ...completed
# loading data 1981/7253 ...completed
# loading data 1982/7253 ...completed
# loading data 1983/7253 ...completed
# loading data 1984/7253 ...completed
# loading data 1985/7253 ...completed
# loading data 1986/7253 ...completed
# loading data 1987/7253 ...completed
# loading data 1988/7253 ...completed
# loading data 1989/7253 ...completed
# loading data 1990/7253 ...completed
# loading data 1991/7253 ...completed
# loading data 1992/7253 ...completed
# loading data 1993/7253 ...completed
# loading data 1994/7253 ...completed
# loading data 1995/7253 ...completed
# loading data 1996/7253 ...completed
# loading data 1997/7253 ...completed
# loading data 1998/7253 ...completed
# loading data 1999/7253 ...completed
# loading data 2000/7253 ...completed
# loading data 2001/7253 ...completed
# loading data 2002/7253 ...completed
# loading data 2003/7253 ...completed
# loading data 2004/7253 ...completed
# loading data 2005/7253 ...completed
# loading data 2006/7253 ...completed
# loading data 2007/7253 ...completed
# loading data 2008/7253 ...completed
# loading data 2009/7253 ...completed
# loading data 2010/7253 ...completed
# loading data 2011/7253 ...completed
# loading data 2012/7253 ...completed
# loading data 2013/7253 ...completed
# loading data 2014/7253 ...completed
# loading data 2015/7253 ...completed
# loading data 2016/7253 ...completed
# loading data 2017/7253 ...completed
# loading data 2018/7253 ...completed
# loading data 2019/7253 ...completed
# loading data 2020/7253 ...completed
# loading data 2021/7253 ...completed
# loading data 2022/7253 ...completed
# loading data 2023/7253 ...completed
# loading data 2024/7253 ...completed
# loading data 2025/7253 ...completed
# loading data 2026/7253 ...completed
# loading data 2027/7253 ...completed
# loading data 2028/7253 ...completed
# loading data 2029/7253 ...completed
# loading data 2030/7253 ...completed
# loading data 2031/7253 ...completed
# loading data 2032/7253 ...completed
# loading data 2033/7253 ...completed
# loading data 2034/7253 ...completed
# loading data 2035/7253 ...completed
# loading data 2036/7253 ...completed
# loading data 2037/7253 ...completed
# loading data 2038/7253 ...completed
# loading data 2039/7253 ...completed
# loading data 2040/7253 ...completed
# loading data 2041/7253 ...completed
# loading data 2042/7253 ...completed
# loading data 2043/7253 ...completed
# loading data 2044/7253 ...completed
# loading data 2045/7253 ...completed
# loading data 2046/7253 ...completed
# loading data 2047/7253 ...completed
# loading data 2048/7253 ...completed
# loading data 2049/7253 ...completed
# loading data 2050/7253 ...completed
# loading data 2051/7253 ...completed
# loading data 2052/7253 ...completed
# loading data 2053/7253 ...completed
# loading data 2054/7253 ...completed
# loading data 2055/7253 ...completed
# loading data 2056/7253 ...completed
# loading data 2057/7253 ...completed
# loading data 2058/7253 ...completed
# loading data 2059/7253 ...completed
# loading data 2060/7253 ...completed
# loading data 2061/7253 ...completed
# loading data 2062/7253 ...completed
# loading data 2063/7253 ...completed
# loading data 2064/7253 ...completed
# loading data 2065/7253 ...completed
# loading data 2066/7253 ...completed
# loading data 2067/7253 ...completed
# loading data 2068/7253 ...completed
# loading data 2069/7253 ...completed
# loading data 2070/7253 ...completed
# loading data 2071/7253 ...completed
# loading data 2072/7253 ...completed
# loading data 2073/7253 ...completed
# loading data 2074/7253 ...completed
# loading data 2075/7253 ...completed
# loading data 2076/7253 ...completed
# loading data 2077/7253 ...completed
# loading data 2078/7253 ...completed
# loading data 2079/7253 ...completed
# loading data 2080/7253 ...completed
# loading data 2081/7253 ...completed
# loading data 2082/7253 ...completed
# loading data 2083/7253 ...completed
# loading data 2084/7253 ...completed
# loading data 2085/7253 ...completed
# loading data 2086/7253 ...completed
# loading data 2087/7253 ...completed
# loading data 2088/7253 ...completed
# loading data 2089/7253 ...completed
# loading data 2090/7253 ...completed
# loading data 2091/7253 ...completed
# loading data 2092/7253 ...completed
# loading data 2093/7253 ...completed
# loading data 2094/7253 ...completed
# loading data 2095/7253 ...completed
# loading data 2096/7253 ...completed
# loading data 2097/7253 ...completed
# loading data 2098/7253 ...completed
# loading data 2099/7253 ...completed
# loading data 2100/7253 ...completed
# loading data 2101/7253 ...completed
# loading data 2102/7253 ...completed
# loading data 2103/7253 ...completed
# loading data 2104/7253 ...completed
# loading data 2105/7253 ...completed
# loading data 2106/7253 ...completed
# loading data 2107/7253 ...completed
# loading data 2108/7253 ...completed
# loading data 2109/7253 ...completed
# loading data 2110/7253 ...completed
# loading data 2111/7253 ...completed
# loading data 2112/7253 ...completed
# loading data 2113/7253 ...completed
# loading data 2114/7253 ...completed
# loading data 2115/7253 ...completed
# loading data 2116/7253 ...completed
# loading data 2117/7253 ...completed
# loading data 2118/7253 ...completed
# loading data 2119/7253 ...completed
# loading data 2120/7253 ...completed
# loading data 2121/7253 ...completed
# loading data 2122/7253 ...completed
# loading data 2123/7253 ...completed
# loading data 2124/7253 ...completed
# loading data 2125/7253 ...completed
# loading data 2126/7253 ...completed
# loading data 2127/7253 ...completed
# loading data 2128/7253 ...completed
# loading data 2129/7253 ...completed
# loading data 2130/7253 ...completed
# loading data 2131/7253 ...completed
# loading data 2132/7253 ...completed
# loading data 2133/7253 ...completed
# loading data 2134/7253 ...completed
# loading data 2135/7253 ...completed
# loading data 2136/7253 ...completed
# loading data 2137/7253 ...completed
# loading data 2138/7253 ...completed
# loading data 2139/7253 ...completed
# loading data 2140/7253 ...completed
# loading data 2141/7253 ...completed
# loading data 2142/7253 ...completed
# loading data 2143/7253 ...completed
# loading data 2144/7253 ...completed
# loading data 2145/7253 ...completed
# loading data 2146/7253 ...completed
# loading data 2147/7253 ...completed
# loading data 2148/7253 ...completed
# loading data 2149/7253 ...completed
# loading data 2150/7253 ...completed
# loading data 2151/7253 ...completed
# loading data 2152/7253 ...completed
# loading data 2153/7253 ...completed
# loading data 2154/7253 ...completed
# loading data 2155/7253 ...completed
# loading data 2156/7253 ...completed
# loading data 2157/7253 ...completed
# loading data 2158/7253 ...completed
# loading data 2159/7253 ...completed
# loading data 2160/7253 ...completed
# loading data 2161/7253 ...completed
# loading data 2162/7253 ...completed
# loading data 2163/7253 ...completed
# loading data 2164/7253 ...completed
# loading data 2165/7253 ...completed
# loading data 2166/7253 ...completed
# loading data 2167/7253 ...completed
# loading data 2168/7253 ...completed
# loading data 2169/7253 ...completed
# loading data 2170/7253 ...completed
# loading data 2171/7253 ...completed
# loading data 2172/7253 ...completed
# loading data 2173/7253 ...completed
# loading data 2174/7253 ...completed
# loading data 2175/7253 ...completed
# loading data 2176/7253 ...completed
# loading data 2177/7253 ...completed
# loading data 2178/7253 ...completed
# loading data 2179/7253 ...completed
# loading data 2180/7253 ...completed
# loading data 2181/7253 ...completed
# loading data 2182/7253 ...completed
# loading data 2183/7253 ...completed
# loading data 2184/7253 ...completed
# loading data 2185/7253 ...completed
# loading data 2186/7253 ...completed
# loading data 2187/7253 ...completed
# loading data 2188/7253 ...completed
# loading data 2189/7253 ...completed
# loading data 2190/7253 ...completed
# loading data 2191/7253 ...completed
# loading data 2192/7253 ...completed
# loading data 2193/7253 ...completed
# loading data 2194/7253 ...completed
# loading data 2195/7253 ...completed
# loading data 2196/7253 ...completed
# loading data 2197/7253 ...completed
# loading data 2198/7253 ...completed
# loading data 2199/7253 ...completed
# loading data 2200/7253 ...completed
# loading data 2201/7253 ...completed
# loading data 2202/7253 ...completed
# loading data 2203/7253 ...completed
# loading data 2204/7253 ...completed
# loading data 2205/7253 ...completed
# loading data 2206/7253 ...completed
# loading data 2207/7253 ...completed
# loading data 2208/7253 ...completed
# loading data 2209/7253 ...completed
# loading data 2210/7253 ...completed
# loading data 2211/7253 ...completed
# loading data 2212/7253 ...completed
# loading data 2213/7253 ...completed
# loading data 2214/7253 ...completed
# loading data 2215/7253 ...completed
# loading data 2216/7253 ...completed
# loading data 2217/7253 ...completed
# loading data 2218/7253 ...completed
# loading data 2219/7253 ...completed
# loading data 2220/7253 ...completed
# loading data 2221/7253 ...completed
# loading data 2222/7253 ...completed
# loading data 2223/7253 ...completed
# loading data 2224/7253 ...completed
# loading data 2225/7253 ...completed
# loading data 2226/7253 ...completed
# loading data 2227/7253 ...completed
# loading data 2228/7253 ...completed
# loading data 2229/7253 ...completed
# loading data 2230/7253 ...completed
# loading data 2231/7253 ...completed
# loading data 2232/7253 ...completed
# loading data 2233/7253 ...completed
# loading data 2234/7253 ...completed
# loading data 2235/7253 ...completed
# loading data 2236/7253 ...completed
# loading data 2237/7253 ...completed
# loading data 2238/7253 ...completed
# loading data 2239/7253 ...completed
# loading data 2240/7253 ...completed
# loading data 2241/7253 ...completed
# loading data 2242/7253 ...completed
# loading data 2243/7253 ...completed
# loading data 2244/7253 ...completed
# loading data 2245/7253 ...completed
# loading data 2246/7253 ...completed
# loading data 2247/7253 ...completed
# loading data 2248/7253 ...completed
# loading data 2249/7253 ...completed
# loading data 2250/7253 ...completed
# loading data 2251/7253 ...completed
# loading data 2252/7253 ...completed
# loading data 2253/7253 ...completed
# loading data 2254/7253 ...completed
# loading data 2255/7253 ...completed
# loading data 2256/7253 ...completed
# loading data 2257/7253 ...completed
# loading data 2258/7253 ...completed
# loading data 2259/7253 ...completed
# loading data 2260/7253 ...completed
# loading data 2261/7253 ...completed
# loading data 2262/7253 ...completed
# loading data 2263/7253 ...completed
# loading data 2264/7253 ...completed
# loading data 2265/7253 ...completed
# loading data 2266/7253 ...completed
# loading data 2267/7253 ...completed
# loading data 2268/7253 ...completed
# loading data 2269/7253 ...completed
# loading data 2270/7253 ...completed
# loading data 2271/7253 ...completed
# loading data 2272/7253 ...completed
# loading data 2273/7253 ...completed
# loading data 2274/7253 ...completed
# loading data 2275/7253 ...completed
# loading data 2276/7253 ...completed
# loading data 2277/7253 ...completed
# loading data 2278/7253 ...completed
# loading data 2279/7253 ...completed
# loading data 2280/7253 ...completed
# loading data 2281/7253 ...completed
# loading data 2282/7253 ...completed
# loading data 2283/7253 ...completed
# loading data 2284/7253 ...completed
# loading data 2285/7253 ...completed
# loading data 2286/7253 ...completed
# loading data 2287/7253 ...completed
# loading data 2288/7253 ...completed
# loading data 2289/7253 ...completed
# loading data 2290/7253 ...completed
# loading data 2291/7253 ...completed
# loading data 2292/7253 ...completed
# loading data 2293/7253 ...completed
# loading data 2294/7253 ...completed
# loading data 2295/7253 ...completed
# loading data 2296/7253 ...completed
# loading data 2297/7253 ...completed
# loading data 2298/7253 ...completed
# loading data 2299/7253 ...completed
# loading data 2300/7253 ...completed
# loading data 2301/7253 ...completed
# loading data 2302/7253 ...completed
# loading data 2303/7253 ...completed
# loading data 2304/7253 ...completed
# loading data 2305/7253 ...completed
# loading data 2306/7253 ...completed
# loading data 2307/7253 ...completed
# loading data 2308/7253 ...completed
# loading data 2309/7253 ...completed
# loading data 2310/7253 ...completed
# loading data 2311/7253 ...completed
# loading data 2312/7253 ...completed
# loading data 2313/7253 ...completed
# loading data 2314/7253 ...completed
# loading data 2315/7253 ...completed
# loading data 2316/7253 ...completed
# loading data 2317/7253 ...completed
# loading data 2318/7253 ...completed
# loading data 2319/7253 ...completed
# loading data 2320/7253 ...completed
# loading data 2321/7253 ...completed
# loading data 2322/7253 ...completed
# loading data 2323/7253 ...completed
# loading data 2324/7253 ...completed
# loading data 2325/7253 ...completed
# loading data 2326/7253 ...completed
# loading data 2327/7253 ...completed
# loading data 2328/7253 ...completed
# loading data 2329/7253 ...completed
# loading data 2330/7253 ...completed
# loading data 2331/7253 ...completed
# loading data 2332/7253 ...completed
# loading data 2333/7253 ...completed
# loading data 2334/7253 ...completed
# loading data 2335/7253 ...completed
# loading data 2336/7253 ...completed
# loading data 2337/7253 ...completed
# loading data 2338/7253 ...completed
# loading data 2339/7253 ...completed
# loading data 2340/7253 ...completed
# loading data 2341/7253 ...completed
# loading data 2342/7253 ...completed
# loading data 2343/7253 ...completed
# loading data 2344/7253 ...completed
# loading data 2345/7253 ...completed
# loading data 2346/7253 ...completed
# loading data 2347/7253 ...completed
# loading data 2348/7253 ...completed
# loading data 2349/7253 ...completed
# loading data 2350/7253 ...completed
# loading data 2351/7253 ...completed
# loading data 2352/7253 ...completed
# loading data 2353/7253 ...completed
# loading data 2354/7253 ...completed
# loading data 2355/7253 ...completed
# loading data 2356/7253 ...completed
# loading data 2357/7253 ...completed
# loading data 2358/7253 ...completed
# loading data 2359/7253 ...completed
# loading data 2360/7253 ...completed
# loading data 2361/7253 ...completed
# loading data 2362/7253 ...completed
# loading data 2363/7253 ...completed
# loading data 2364/7253 ...completed
# loading data 2365/7253 ...completed
# loading data 2366/7253 ...completed
# loading data 2367/7253 ...completed
# loading data 2368/7253 ...completed
# loading data 2369/7253 ...completed
# loading data 2370/7253 ...completed
# loading data 2371/7253 ...completed
# loading data 2372/7253 ...completed
# loading data 2373/7253 ...completed
# loading data 2374/7253 ...completed
# loading data 2375/7253 ...completed
# loading data 2376/7253 ...completed
# loading data 2377/7253 ...completed
# loading data 2378/7253 ...completed
# loading data 2379/7253 ...completed
# loading data 2380/7253 ...completed
# loading data 2381/7253 ...completed
# loading data 2382/7253 ...completed
# loading data 2383/7253 ...completed
# loading data 2384/7253 ...completed
# loading data 2385/7253 ...completed
# loading data 2386/7253 ...completed
# loading data 2387/7253 ...completed
# loading data 2388/7253 ...completed
# loading data 2389/7253 ...completed
# loading data 2390/7253 ...completed
# loading data 2391/7253 ...completed
# loading data 2392/7253 ...completed
# loading data 2393/7253 ...completed
# loading data 2394/7253 ...completed
# loading data 2395/7253 ...completed
# loading data 2396/7253 ...completed
# loading data 2397/7253 ...completed
# loading data 2398/7253 ...completed
# loading data 2399/7253 ...completed
# loading data 2400/7253 ...completed
# loading data 2401/7253 ...completed
# loading data 2402/7253 ...completed
# loading data 2403/7253 ...completed
# loading data 2404/7253 ...completed
# loading data 2405/7253 ...completed
# loading data 2406/7253 ...completed
# loading data 2407/7253 ...completed
# loading data 2408/7253 ...completed
# loading data 2409/7253 ...completed
# loading data 2410/7253 ...completed
# loading data 2411/7253 ...completed
# loading data 2412/7253 ...completed
# loading data 2413/7253 ...completed
# loading data 2414/7253 ...completed
# loading data 2415/7253 ...completed
# loading data 2416/7253 ...completed
# loading data 2417/7253 ...completed
# loading data 2418/7253 ...completed
# loading data 2419/7253 ...completed
# loading data 2420/7253 ...completed
# loading data 2421/7253 ...completed
# loading data 2422/7253 ...completed
# loading data 2423/7253 ...completed
# loading data 2424/7253 ...completed
# loading data 2425/7253 ...completed
# loading data 2426/7253 ...completed
# loading data 2427/7253 ...completed
# loading data 2428/7253 ...completed
# loading data 2429/7253 ...completed
# loading data 2430/7253 ...completed
# loading data 2431/7253 ...completed
# loading data 2432/7253 ...completed
# loading data 2433/7253 ...completed
# loading data 2434/7253 ...completed
# loading data 2435/7253 ...completed
# loading data 2436/7253 ...completed
# loading data 2437/7253 ...completed
# loading data 2438/7253 ...completed
# loading data 2439/7253 ...completed
# loading data 2440/7253 ...completed
# loading data 2441/7253 ...completed
# loading data 2442/7253 ...completed
# loading data 2443/7253 ...completed
# loading data 2444/7253 ...completed
# loading data 2445/7253 ...completed
# loading data 2446/7253 ...completed
# loading data 2447/7253 ...completed
# loading data 2448/7253 ...completed
# loading data 2449/7253 ...completed
# loading data 2450/7253 ...completed
# loading data 2451/7253 ...completed
# loading data 2452/7253 ...completed
# loading data 2453/7253 ...completed
# loading data 2454/7253 ...completed
# loading data 2455/7253 ...completed
# loading data 2456/7253 ...completed
# loading data 2457/7253 ...completed
# loading data 2458/7253 ...completed
# loading data 2459/7253 ...completed
# loading data 2460/7253 ...completed
# loading data 2461/7253 ...completed
# loading data 2462/7253 ...completed
# loading data 2463/7253 ...completed
# loading data 2464/7253 ...completed
# loading data 2465/7253 ...completed
# loading data 2466/7253 ...completed
# loading data 2467/7253 ...completed
# loading data 2468/7253 ...completed
# loading data 2469/7253 ...completed
# loading data 2470/7253 ...completed
# loading data 2471/7253 ...completed
# loading data 2472/7253 ...completed
# loading data 2473/7253 ...completed
# loading data 2474/7253 ...completed
# loading data 2475/7253 ...completed
# loading data 2476/7253 ...completed
# loading data 2477/7253 ...completed
# loading data 2478/7253 ...completed
# loading data 2479/7253 ...completed
# loading data 2480/7253 ...completed
# loading data 2481/7253 ...completed
# loading data 2482/7253 ...completed
# loading data 2483/7253 ...completed
# loading data 2484/7253 ...completed
# loading data 2485/7253 ...completed
# loading data 2486/7253 ...completed
# loading data 2487/7253 ...completed
# loading data 2488/7253 ...completed
# loading data 2489/7253 ...completed
# loading data 2490/7253 ...completed
# loading data 2491/7253 ...completed
# loading data 2492/7253 ...completed
# loading data 2493/7253 ...completed
# loading data 2494/7253 ...completed
# loading data 2495/7253 ...completed
# loading data 2496/7253 ...completed
# loading data 2497/7253 ...completed
# loading data 2498/7253 ...completed
# loading data 2499/7253 ...completed
# loading data 2500/7253 ...completed
# loading data 2501/7253 ...completed
# loading data 2502/7253 ...completed
# loading data 2503/7253 ...completed
# loading data 2504/7253 ...completed
# loading data 2505/7253 ...completed
# loading data 2506/7253 ...completed
# loading data 2507/7253 ...completed
# loading data 2508/7253 ...completed
# loading data 2509/7253 ...completed
# loading data 2510/7253 ...completed
# loading data 2511/7253 ...completed
# loading data 2512/7253 ...completed
# loading data 2513/7253 ...completed
# loading data 2514/7253 ...completed
# loading data 2515/7253 ...completed
# loading data 2516/7253 ...completed
# loading data 2517/7253 ...completed
# loading data 2518/7253 ...completed
# loading data 2519/7253 ...completed
# loading data 2520/7253 ...completed
# loading data 2521/7253 ...completed
# loading data 2522/7253 ...completed
# loading data 2523/7253 ...completed
# loading data 2524/7253 ...completed
# loading data 2525/7253 ...completed
# loading data 2526/7253 ...completed
# loading data 2527/7253 ...completed
# loading data 2528/7253 ...completed
# loading data 2529/7253 ...completed
# loading data 2530/7253 ...completed
# loading data 2531/7253 ...completed
# loading data 2532/7253 ...completed
# loading data 2533/7253 ...completed
# loading data 2534/7253 ...completed
# loading data 2535/7253 ...completed
# loading data 2536/7253 ...completed
# loading data 2537/7253 ...completed
# loading data 2538/7253 ...completed
# loading data 2539/7253 ...completed
# loading data 2540/7253 ...completed
# loading data 2541/7253 ...completed
# loading data 2542/7253 ...completed
# loading data 2543/7253 ...completed
# loading data 2544/7253 ...completed
# loading data 2545/7253 ...completed
# loading data 2546/7253 ...completed
# loading data 2547/7253 ...completed
# loading data 2548/7253 ...completed
# loading data 2549/7253 ...completed
# loading data 2550/7253 ...completed
# loading data 2551/7253 ...completed
# loading data 2552/7253 ...completed
# loading data 2553/7253 ...completed
# loading data 2554/7253 ...completed
# loading data 2555/7253 ...completed
# loading data 2556/7253 ...completed
# loading data 2557/7253 ...completed
# loading data 2558/7253 ...completed
# loading data 2559/7253 ...completed
# loading data 2560/7253 ...completed
# loading data 2561/7253 ...completed
# loading data 2562/7253 ...completed
# loading data 2563/7253 ...completed
# loading data 2564/7253 ...completed
# loading data 2565/7253 ...completed
# loading data 2566/7253 ...completed
# loading data 2567/7253 ...completed
# loading data 2568/7253 ...completed
# loading data 2569/7253 ...completed
# loading data 2570/7253 ...completed
# loading data 2571/7253 ...completed
# loading data 2572/7253 ...completed
# loading data 2573/7253 ...completed
# loading data 2574/7253 ...completed
# loading data 2575/7253 ...completed
# loading data 2576/7253 ...completed
# loading data 2577/7253 ...completed
# loading data 2578/7253 ...completed
# loading data 2579/7253 ...completed
# loading data 2580/7253 ...completed
# loading data 2581/7253 ...completed
# loading data 2582/7253 ...completed
# loading data 2583/7253 ...completed
# loading data 2584/7253 ...completed
# loading data 2585/7253 ...completed
# loading data 2586/7253 ...completed
# loading data 2587/7253 ...completed
# loading data 2588/7253 ...completed
# loading data 2589/7253 ...completed
# loading data 2590/7253 ...completed
# loading data 2591/7253 ...completed
# loading data 2592/7253 ...completed
# loading data 2593/7253 ...completed
# loading data 2594/7253 ...completed
# loading data 2595/7253 ...completed
# loading data 2596/7253 ...completed
# loading data 2597/7253 ...completed
# loading data 2598/7253 ...completed
# loading data 2599/7253 ...completed
# loading data 2600/7253 ...completed
# loading data 2601/7253 ...completed
# loading data 2602/7253 ...completed
# loading data 2603/7253 ...completed
# loading data 2604/7253 ...completed
# loading data 2605/7253 ...completed
# loading data 2606/7253 ...completed
# loading data 2607/7253 ...completed
# loading data 2608/7253 ...completed
# loading data 2609/7253 ...completed
# loading data 2610/7253 ...completed
# loading data 2611/7253 ...completed
# loading data 2612/7253 ...completed
# loading data 2613/7253 ...completed
# loading data 2614/7253 ...completed
# loading data 2615/7253 ...completed
# loading data 2616/7253 ...completed
# loading data 2617/7253 ...completed
# loading data 2618/7253 ...completed
# loading data 2619/7253 ...completed
# loading data 2620/7253 ...completed
# loading data 2621/7253 ...completed
# loading data 2622/7253 ...completed
# loading data 2623/7253 ...completed
# loading data 2624/7253 ...completed
# loading data 2625/7253 ...completed
# loading data 2626/7253 ...completed
# loading data 2627/7253 ...completed
# loading data 2628/7253 ...completed
# loading data 2629/7253 ...completed
# loading data 2630/7253 ...completed
# loading data 2631/7253 ...completed
# loading data 2632/7253 ...completed
# loading data 2633/7253 ...completed
# loading data 2634/7253 ...completed
# loading data 2635/7253 ...completed
# loading data 2636/7253 ...completed
# loading data 2637/7253 ...completed
# loading data 2638/7253 ...completed
# loading data 2639/7253 ...completed
# loading data 2640/7253 ...completed
# loading data 2641/7253 ...completed
# loading data 2642/7253 ...completed
# loading data 2643/7253 ...completed
# loading data 2644/7253 ...completed
# loading data 2645/7253 ...completed
# loading data 2646/7253 ...completed
# loading data 2647/7253 ...completed
# loading data 2648/7253 ...completed
# loading data 2649/7253 ...completed
# loading data 2650/7253 ...completed
# loading data 2651/7253 ...completed
# loading data 2652/7253 ...completed
# loading data 2653/7253 ...completed
# loading data 2654/7253 ...completed
# loading data 2655/7253 ...completed
# loading data 2656/7253 ...completed
# loading data 2657/7253 ...completed
# loading data 2658/7253 ...completed
# loading data 2659/7253 ...completed
# loading data 2660/7253 ...completed
# loading data 2661/7253 ...completed
# loading data 2662/7253 ...completed
# loading data 2663/7253 ...completed
# loading data 2664/7253 ...completed
# loading data 2665/7253 ...completed
# loading data 2666/7253 ...completed
# loading data 2667/7253 ...completed
# loading data 2668/7253 ...completed
# loading data 2669/7253 ...completed
# loading data 2670/7253 ...completed
# loading data 2671/7253 ...completed
# loading data 2672/7253 ...completed
# loading data 2673/7253 ...completed
# loading data 2674/7253 ...completed
# loading data 2675/7253 ...completed
# loading data 2676/7253 ...completed
# loading data 2677/7253 ...completed
# loading data 2678/7253 ...completed
# loading data 2679/7253 ...completed
# loading data 2680/7253 ...completed
# loading data 2681/7253 ...completed
# loading data 2682/7253 ...completed
# loading data 2683/7253 ...completed
# loading data 2684/7253 ...completed
# loading data 2685/7253 ...completed
# loading data 2686/7253 ...completed
# loading data 2687/7253 ...completed
# loading data 2688/7253 ...completed
# loading data 2689/7253 ...completed
# loading data 2690/7253 ...completed
# loading data 2691/7253 ...completed
# loading data 2692/7253 ...completed
# loading data 2693/7253 ...completed
# loading data 2694/7253 ...completed
# loading data 2695/7253 ...completed
# loading data 2696/7253 ...completed
# loading data 2697/7253 ...completed
# loading data 2698/7253 ...completed
# loading data 2699/7253 ...completed
# loading data 2700/7253 ...completed
# loading data 2701/7253 ...completed
# loading data 2702/7253 ...completed
# loading data 2703/7253 ...completed
# loading data 2704/7253 ...completed
# loading data 2705/7253 ...completed
# loading data 2706/7253 ...completed
# loading data 2707/7253 ...completed
# loading data 2708/7253 ...completed
# loading data 2709/7253 ...completed
# loading data 2710/7253 ...completed
# loading data 2711/7253 ...completed
# loading data 2712/7253 ...completed
# loading data 2713/7253 ...completed
# loading data 2714/7253 ...completed
# loading data 2715/7253 ...completed
# loading data 2716/7253 ...completed
# loading data 2717/7253 ...completed
# loading data 2718/7253 ...completed
# loading data 2719/7253 ...completed
# loading data 2720/7253 ...completed
# loading data 2721/7253 ...completed
# loading data 2722/7253 ...completed
# loading data 2723/7253 ...completed
# loading data 2724/7253 ...completed
# loading data 2725/7253 ...completed
# loading data 2726/7253 ...completed
# loading data 2727/7253 ...completed
# loading data 2728/7253 ...completed
# loading data 2729/7253 ...completed
# loading data 2730/7253 ...completed
# loading data 2731/7253 ...completed
# loading data 2732/7253 ...completed
# loading data 2733/7253 ...completed
# loading data 2734/7253 ...completed
# loading data 2735/7253 ...completed
# loading data 2736/7253 ...completed
# loading data 2737/7253 ...completed
# loading data 2738/7253 ...completed
# loading data 2739/7253 ...completed
# loading data 2740/7253 ...completed
# loading data 2741/7253 ...completed
# loading data 2742/7253 ...completed
# loading data 2743/7253 ...completed
# loading data 2744/7253 ...completed
# loading data 2745/7253 ...completed
# loading data 2746/7253 ...completed
# loading data 2747/7253 ...completed
# loading data 2748/7253 ...completed
# loading data 2749/7253 ...completed
# loading data 2750/7253 ...completed
# loading data 2751/7253 ...completed
# loading data 2752/7253 ...completed
# loading data 2753/7253 ...completed
# loading data 2754/7253 ...completed
# loading data 2755/7253 ...completed
# loading data 2756/7253 ...completed
# loading data 2757/7253 ...completed
# loading data 2758/7253 ...completed
# loading data 2759/7253 ...completed
# loading data 2760/7253 ...completed
# loading data 2761/7253 ...completed
# loading data 2762/7253 ...completed
# loading data 2763/7253 ...completed
# loading data 2764/7253 ...completed
# loading data 2765/7253 ...completed
# loading data 2766/7253 ...completed
# loading data 2767/7253 ...completed
# loading data 2768/7253 ...completed
# loading data 2769/7253 ...completed
# loading data 2770/7253 ...completed
# loading data 2771/7253 ...completed
# loading data 2772/7253 ...completed
# loading data 2773/7253 ...completed
# loading data 2774/7253 ...completed
# loading data 2775/7253 ...completed
# loading data 2776/7253 ...completed
# loading data 2777/7253 ...completed
# loading data 2778/7253 ...completed
# loading data 2779/7253 ...completed
# loading data 2780/7253 ...completed
# loading data 2781/7253 ...completed
# loading data 2782/7253 ...completed
# loading data 2783/7253 ...completed
# loading data 2784/7253 ...completed
# loading data 2785/7253 ...completed
# loading data 2786/7253 ...completed
# loading data 2787/7253 ...completed
# loading data 2788/7253 ...completed
# loading data 2789/7253 ...completed
# loading data 2790/7253 ...completed
# loading data 2791/7253 ...completed
# loading data 2792/7253 ...completed
# loading data 2793/7253 ...completed
# loading data 2794/7253 ...completed
# loading data 2795/7253 ...completed
# loading data 2796/7253 ...completed
# loading data 2797/7253 ...completed
# loading data 2798/7253 ...completed
# loading data 2799/7253 ...completed
# loading data 2800/7253 ...completed
# loading data 2801/7253 ...completed
# loading data 2802/7253 ...completed
# loading data 2803/7253 ...completed
# loading data 2804/7253 ...completed
# loading data 2805/7253 ...completed
# loading data 2806/7253 ...completed
# loading data 2807/7253 ...completed
# loading data 2808/7253 ...completed
# loading data 2809/7253 ...completed
# loading data 2810/7253 ...completed
# loading data 2811/7253 ...completed
# loading data 2812/7253 ...completed
# loading data 2813/7253 ...completed
# loading data 2814/7253 ...completed
# loading data 2815/7253 ...completed
# loading data 2816/7253 ...completed
# loading data 2817/7253 ...completed
# loading data 2818/7253 ...completed
# loading data 2819/7253 ...completed
# loading data 2820/7253 ...completed
# loading data 2821/7253 ...completed
# loading data 2822/7253 ...completed
# loading data 2823/7253 ...completed
# loading data 2824/7253 ...completed
# loading data 2825/7253 ...completed
# loading data 2826/7253 ...completed
# loading data 2827/7253 ...completed
# loading data 2828/7253 ...completed
# loading data 2829/7253 ...completed
# loading data 2830/7253 ...completed
# loading data 2831/7253 ...completed
# loading data 2832/7253 ...completed
# loading data 2833/7253 ...completed
# loading data 2834/7253 ...completed
# loading data 2835/7253 ...completed
# loading data 2836/7253 ...completed
# loading data 2837/7253 ...completed
# loading data 2838/7253 ...completed
# loading data 2839/7253 ...completed
# loading data 2840/7253 ...completed
# loading data 2841/7253 ...completed
# loading data 2842/7253 ...completed
# loading data 2843/7253 ...completed
# loading data 2844/7253 ...completed
# loading data 2845/7253 ...completed
# loading data 2846/7253 ...completed
# loading data 2847/7253 ...completed
# loading data 2848/7253 ...completed
# loading data 2849/7253 ...completed
# loading data 2850/7253 ...completed
# loading data 2851/7253 ...completed
# loading data 2852/7253 ...completed
# loading data 2853/7253 ...completed
# loading data 2854/7253 ...completed
# loading data 2855/7253 ...completed
# loading data 2856/7253 ...completed
# loading data 2857/7253 ...completed
# loading data 2858/7253 ...completed
# loading data 2859/7253 ...completed
# loading data 2860/7253 ...completed
# loading data 2861/7253 ...completed
# loading data 2862/7253 ...completed
# loading data 2863/7253 ...completed
# loading data 2864/7253 ...completed
# loading data 2865/7253 ...completed
# loading data 2866/7253 ...completed
# loading data 2867/7253 ...completed
# loading data 2868/7253 ...completed
# loading data 2869/7253 ...completed
# loading data 2870/7253 ...completed
# loading data 2871/7253 ...completed
# loading data 2872/7253 ...completed
# loading data 2873/7253 ...completed
# loading data 2874/7253 ...completed
# loading data 2875/7253 ...completed
# loading data 2876/7253 ...completed
# loading data 2877/7253 ...completed
# loading data 2878/7253 ...completed
# loading data 2879/7253 ...completed
# loading data 2880/7253 ...completed
# loading data 2881/7253 ...completed
# loading data 2882/7253 ...completed
# loading data 2883/7253 ...completed
# loading data 2884/7253 ...completed
# loading data 2885/7253 ...completed
# loading data 2886/7253 ...completed
# loading data 2887/7253 ...completed
# loading data 2888/7253 ...completed
# loading data 2889/7253 ...completed
# loading data 2890/7253 ...completed
# loading data 2891/7253 ...completed
# loading data 2892/7253 ...completed
# loading data 2893/7253 ...completed
# loading data 2894/7253 ...completed
# loading data 2895/7253 ...completed
# loading data 2896/7253 ...completed
# loading data 2897/7253 ...completed
# loading data 2898/7253 ...completed
# loading data 2899/7253 ...completed
# loading data 2900/7253 ...completed
# loading data 2901/7253 ...completed
# loading data 2902/7253 ...completed
# loading data 2903/7253 ...completed
# loading data 2904/7253 ...completed
# loading data 2905/7253 ...completed
# loading data 2906/7253 ...completed
# loading data 2907/7253 ...completed
# loading data 2908/7253 ...completed
# loading data 2909/7253 ...completed
# loading data 2910/7253 ...completed
# loading data 2911/7253 ...completed
# loading data 2912/7253 ...completed
# loading data 2913/7253 ...completed
# loading data 2914/7253 ...completed
# loading data 2915/7253 ...completed
# loading data 2916/7253 ...completed
# loading data 2917/7253 ...completed
# loading data 2918/7253 ...completed
# loading data 2919/7253 ...completed
# loading data 2920/7253 ...completed
# loading data 2921/7253 ...completed
# loading data 2922/7253 ...completed
# loading data 2923/7253 ...completed
# loading data 2924/7253 ...completed
# loading data 2925/7253 ...completed
# loading data 2926/7253 ...completed
# loading data 2927/7253 ...completed
# loading data 2928/7253 ...completed
# loading data 2929/7253 ...completed
# loading data 2930/7253 ...completed
# loading data 2931/7253 ...completed
# loading data 2932/7253 ...completed
# loading data 2933/7253 ...completed
# loading data 2934/7253 ...completed
# loading data 2935/7253 ...completed
# loading data 2936/7253 ...completed
# loading data 2937/7253 ...completed
# loading data 2938/7253 ...completed
# loading data 2939/7253 ...completed
# loading data 2940/7253 ...completed
# loading data 2941/7253 ...completed
# loading data 2942/7253 ...completed
# loading data 2943/7253 ...completed
# loading data 2944/7253 ...completed
# loading data 2945/7253 ...completed
# loading data 2946/7253 ...completed
# loading data 2947/7253 ...completed
# loading data 2948/7253 ...completed
# loading data 2949/7253 ...completed
# loading data 2950/7253 ...completed
# loading data 2951/7253 ...completed
# loading data 2952/7253 ...completed
# loading data 2953/7253 ...completed
# loading data 2954/7253 ...completed
# loading data 2955/7253 ...completed
# loading data 2956/7253 ...completed
# loading data 2957/7253 ...completed
# loading data 2958/7253 ...completed
# loading data 2959/7253 ...completed
# loading data 2960/7253 ...completed
# loading data 2961/7253 ...completed
# loading data 2962/7253 ...completed
# loading data 2963/7253 ...completed
# loading data 2964/7253 ...completed
# loading data 2965/7253 ...completed
# loading data 2966/7253 ...completed
# loading data 2967/7253 ...completed
# loading data 2968/7253 ...completed
# loading data 2969/7253 ...completed
# loading data 2970/7253 ...completed
# loading data 2971/7253 ...completed
# loading data 2972/7253 ...completed
# loading data 2973/7253 ...completed
# loading data 2974/7253 ...completed
# loading data 2975/7253 ...completed
# loading data 2976/7253 ...completed
# loading data 2977/7253 ...completed
# loading data 2978/7253 ...completed
# loading data 2979/7253 ...completed
# loading data 2980/7253 ...completed
# loading data 2981/7253 ...completed
# loading data 2982/7253 ...completed
# loading data 2983/7253 ...completed
# loading data 2984/7253 ...completed
# loading data 2985/7253 ...completed
# loading data 2986/7253 ...completed
# loading data 2987/7253 ...completed
# loading data 2988/7253 ...completed
# loading data 2989/7253 ...completed
# loading data 2990/7253 ...completed
# loading data 2991/7253 ...completed
# loading data 2992/7253 ...completed
# loading data 2993/7253 ...completed
# loading data 2994/7253 ...completed
# loading data 2995/7253 ...completed
# loading data 2996/7253 ...completed
# loading data 2997/7253 ...completed
# loading data 2998/7253 ...completed
# loading data 2999/7253 ...completed
# loading data 3000/7253 ...completed
# loading data 3001/7253 ...completed
# loading data 3002/7253 ...completed
# loading data 3003/7253 ...completed
# loading data 3004/7253 ...completed
# loading data 3005/7253 ...completed
# loading data 3006/7253 ...completed
# loading data 3007/7253 ...completed
# loading data 3008/7253 ...completed
# loading data 3009/7253 ...completed
# loading data 3010/7253 ...completed
# loading data 3011/7253 ...completed
# loading data 3012/7253 ...completed
# loading data 3013/7253 ...completed
# loading data 3014/7253 ...completed
# loading data 3015/7253 ...completed
# loading data 3016/7253 ...completed
# loading data 3017/7253 ...completed
# loading data 3018/7253 ...completed
# loading data 3019/7253 ...completed
# loading data 3020/7253 ...completed
# loading data 3021/7253 ...completed
# loading data 3022/7253 ...completed
# loading data 3023/7253 ...completed
# loading data 3024/7253 ...completed
# loading data 3025/7253 ...completed
# loading data 3026/7253 ...completed
# loading data 3027/7253 ...completed
# loading data 3028/7253 ...completed
# loading data 3029/7253 ...completed
# loading data 3030/7253 ...completed
# loading data 3031/7253 ...completed
# loading data 3032/7253 ...completed
# loading data 3033/7253 ...completed
# loading data 3034/7253 ...completed
# loading data 3035/7253 ...completed
# loading data 3036/7253 ...completed
# loading data 3037/7253 ...completed
# loading data 3038/7253 ...completed
# loading data 3039/7253 ...completed
# loading data 3040/7253 ...completed
# loading data 3041/7253 ...completed
# loading data 3042/7253 ...completed
# loading data 3043/7253 ...completed
# loading data 3044/7253 ...completed
# loading data 3045/7253 ...completed
# loading data 3046/7253 ...completed
# loading data 3047/7253 ...completed
# loading data 3048/7253 ...completed
# loading data 3049/7253 ...completed
# loading data 3050/7253 ...completed
# loading data 3051/7253 ...completed
# loading data 3052/7253 ...completed
# loading data 3053/7253 ...completed
# loading data 3054/7253 ...completed
# loading data 3055/7253 ...completed
# loading data 3056/7253 ...completed
# loading data 3057/7253 ...completed
# loading data 3058/7253 ...completed
# loading data 3059/7253 ...completed
# loading data 3060/7253 ...completed
# loading data 3061/7253 ...completed
# loading data 3062/7253 ...completed
# loading data 3063/7253 ...completed
# loading data 3064/7253 ...completed
# loading data 3065/7253 ...completed
# loading data 3066/7253 ...completed
# loading data 3067/7253 ...completed
# loading data 3068/7253 ...completed
# loading data 3069/7253 ...completed
# loading data 3070/7253 ...completed
# loading data 3071/7253 ...completed
# loading data 3072/7253 ...completed
# loading data 3073/7253 ...completed
# loading data 3074/7253 ...completed
# loading data 3075/7253 ...completed
# loading data 3076/7253 ...completed
# loading data 3077/7253 ...completed
# loading data 3078/7253 ...completed
# loading data 3079/7253 ...completed
# loading data 3080/7253 ...completed
# loading data 3081/7253 ...completed
# loading data 3082/7253 ...completed
# loading data 3083/7253 ...completed
# loading data 3084/7253 ...completed
# loading data 3085/7253 ...completed
# loading data 3086/7253 ...completed
# loading data 3087/7253 ...completed
# loading data 3088/7253 ...completed
# loading data 3089/7253 ...completed
# loading data 3090/7253 ...completed
# loading data 3091/7253 ...completed
# loading data 3092/7253 ...completed
# loading data 3093/7253 ...completed
# loading data 3094/7253 ...completed
# loading data 3095/7253 ...completed
# loading data 3096/7253 ...completed
# loading data 3097/7253 ...completed
# loading data 3098/7253 ...completed
# loading data 3099/7253 ...completed
# loading data 3100/7253 ...completed
# loading data 3101/7253 ...completed
# loading data 3102/7253 ...completed
# loading data 3103/7253 ...completed
# loading data 3104/7253 ...completed
# loading data 3105/7253 ...completed
# loading data 3106/7253 ...completed
# loading data 3107/7253 ...completed
# loading data 3108/7253 ...completed
# loading data 3109/7253 ...completed
# loading data 3110/7253 ...completed
# loading data 3111/7253 ...completed
# loading data 3112/7253 ...completed
# loading data 3113/7253 ...completed
# loading data 3114/7253 ...completed
# loading data 3115/7253 ...completed
# loading data 3116/7253 ...completed
# loading data 3117/7253 ...completed
# loading data 3118/7253 ...completed
# loading data 3119/7253 ...completed
# loading data 3120/7253 ...completed
# loading data 3121/7253 ...completed
# loading data 3122/7253 ...completed
# loading data 3123/7253 ...completed
# loading data 3124/7253 ...completed
# loading data 3125/7253 ...completed
# loading data 3126/7253 ...completed
# loading data 3127/7253 ...completed
# loading data 3128/7253 ...completed
# loading data 3129/7253 ...completed
# loading data 3130/7253 ...completed
# loading data 3131/7253 ...completed
# loading data 3132/7253 ...completed
# loading data 3133/7253 ...completed
# ...
# loading data 3160/7253 ...completed
# loading data 3161/7253 ...completed
# loading data 3162/7253 ...completed
# loading data 3163/7253 ...completed
# loading data 3164/7253 ...completed
# loading data 3165/7253 ...completed
# loading data 3166/7253 ...completed
# loading data 3167/7253 ...completed
# loading data 3168/7253 ...completed
# loading data 3169/7253 ...completed
# loading data 3170/7253 ...completed
# loading data 3171/7253 ...completed
# loading data 3172/7253 ...completed
# loading data 3173/7253 ...completed
# loading data 3174/7253 ...completed
# loading data 3175/7253 ...completed
# loading data 3176/7253 ...completed
# loading data 3177/7253 ...completed
# loading data 3178/7253 ...completed
# loading data 3179/7253 ...completed
# loading data 3180/7253 ...completed
# loading data 3181/7253 ...completed
# loading data 3182/7253 ...completed
# loading data 3183/7253 ...completed
# loading data 3184/7253 ...completed
# loading data 3185/7253 ...completed
# loading data 3186/7253 ...completed
# loading data 3187/7253 ...completed
# loading data 3188/7253 ...completed
# loading data 3189/7253 ...completed
# loading data 3190/7253 ...completed
# loading data 3191/7253 ...completed
# loading data 3192/7253 ...completed
# loading data 3193/7253 ...completed
# loading data 3194/7253 ...completed
# loading data 3195/7253 ...completed
# loading data 3196/7253 ...completed
# loading data 3197/7253 ...completed
# loading data 3198/7253 ...completed
# loading data 3199/7253 ...completed
# loading data 3200/7253 ...completed
# loading data 3201/7253 ...completed
# loading data 3202/7253 ...completed
# loading data 3203/7253 ...completed
# loading data 3204/7253 ...completed
# loading data 3205/7253 ...completed
# loading data 3206/7253 ...completed
# loading data 3207/7253 ...completed
# loading data 3208/7253 ...completed
# loading data 3209/7253 ...completed
# loading data 3210/7253 ...completed
# loading data 3211/7253 ...completed
# loading data 3212/7253 ...completed
# loading data 3213/7253 ...completed
# loading data 3214/7253 ...completed
# loading data 3215/7253 ...completed
# loading data 3216/7253 ...completed
# loading data 3217/7253 ...completed
# loading data 3218/7253 ...completed
# loading data 3219/7253 ...completed
# loading data 3220/7253 ...completed
# loading data 3221/7253 ...completed
# loading data 3222/7253 ...completed
# loading data 3223/7253 ...completed
# loading data 3224/7253 ...completed
# loading data 3225/7253 ...completed
# loading data 3226/7253 ...completed
# loading data 3227/7253 ...completed
# loading data 3228/7253 ...completed
# loading data 3229/7253 ...completed
# loading data 3230/7253 ...completed
# loading data 3231/7253 ...completed
# loading data 3232/7253 ...completed
# loading data 3233/7253 ...completed
# loading data 3234/7253 ...completed
# loading data 3235/7253 ...completed
# loading data 3236/7253 ...completed
# loading data 3237/7253 ...completed
# loading data 3238/7253 ...completed
# loading data 3239/7253 ...completed
# loading data 3240/7253 ...completed
# loading data 3241/7253 ...completed
# loading data 3242/7253 ...completed
# loading data 3243/7253 ...completed
# loading data 3244/7253 ...completed
# loading data 3245/7253 ...completed
# loading data 3246/7253 ...completed
# loading data 3247/7253 ...completed
# loading data 3248/7253 ...completed
# loading data 3249/7253 ...completed
# loading data 3250/7253 ...completed
# loading data 3251/7253 ...completed
# loading data 3252/7253 ...completed
# loading data 3253/7253 ...completed
# loading data 3254/7253 ...completed
# loading data 3255/7253 ...completed
# loading data 3256/7253 ...completed
# loading data 3257/7253 ...completed
# loading data 3258/7253 ...completed
# loading data 3259/7253 ...completed
# loading data 3260/7253 ...completed
# loading data 3261/7253 ...completed
# loading data 3262/7253 ...completed
# loading data 3263/7253 ...completed
# loading data 3264/7253 ...completed
# loading data 3265/7253 ...completed
# loading data 3266/7253 ...completed
# loading data 3267/7253 ...completed
# loading data 3268/7253 ...completed
# loading data 3269/7253 ...completed
# loading data 3270/7253 ...completed
# loading data 3271/7253 ...completed
# loading data 3272/7253 ...completed
# loading data 3273/7253 ...completed
# loading data 3274/7253 ...completed
# loading data 3275/7253 ...completed
# loading data 3276/7253 ...completed
# loading data 3277/7253 ...completed
# loading data 3278/7253 ...completed
# loading data 3279/7253 ...completed
# loading data 3280/7253 ...completed
# loading data 3281/7253 ...completed
# loading data 3282/7253 ...completed
# loading data 3283/7253 ...completed
# loading data 3284/7253 ...completed
# loading data 3285/7253 ...completed
# loading data 3286/7253 ...completed
# loading data 3287/7253 ...completed
# loading data 3288/7253 ...completed
# loading data 3289/7253 ...completed
# loading data 3290/7253 ...completed
# loading data 3291/7253 ...completed
# loading data 3292/7253 ...completed
# loading data 3293/7253 ...completed
# loading data 3294/7253 ...completed
# loading data 3295/7253 ...completed
# loading data 3296/7253 ...completed
# loading data 3297/7253 ...completed
# loading data 3298/7253 ...completed
# loading data 3299/7253 ...completed
# loading data 3300/7253 ...completed
# loading data 3301/7253 ...completed
# loading data 3302/7253 ...completed
# loading data 3303/7253 ...completed
# loading data 3304/7253 ...completed
# loading data 3305/7253 ...completed
# loading data 3306/7253 ...completed
# loading data 3307/7253 ...completed
# loading data 3308/7253 ...completed
# loading data 3309/7253 ...completed
# loading data 3310/7253 ...completed
# loading data 3311/7253 ...completed
# loading data 3312/7253 ...completed
# loading data 3313/7253 ...completed
# loading data 3314/7253 ...completed
# loading data 3315/7253 ...completed
# loading data 3316/7253 ...completed
# loading data 3317/7253 ...completed
# loading data 3318/7253 ...completed
# loading data 3319/7253 ...completed
# loading data 3320/7253 ...completed
# loading data 3321/7253 ...completed
# loading data 3322/7253 ...completed
# loading data 3323/7253 ...completed
# loading data 3324/7253 ...completed
# loading data 3325/7253 ...completed
# loading data 3326/7253 ...completed
# loading data 3327/7253 ...completed
# loading data 3328/7253 ...completed
# loading data 3329/7253 ...completed
# loading data 3330/7253 ...completed
# loading data 3331/7253 ...completed
# loading data 3332/7253 ...completed
# loading data 3333/7253 ...completed
# loading data 3334/7253 ...completed
# loading data 3335/7253 ...completed
# loading data 3336/7253 ...completed
# loading data 3337/7253 ...completed
# loading data 3338/7253 ...completed
# loading data 3339/7253 ...completed
# loading data 3340/7253 ...completed
# loading data 3341/7253 ...completed
# loading data 3342/7253 ...completed
# loading data 3343/7253 ...completed
# loading data 3344/7253 ...completed
# loading data 3345/7253 ...completed
# loading data 3346/7253 ...completed
# loading data 3347/7253 ...completed
# loading data 3348/7253 ...completed
# loading data 3349/7253 ...completed
# loading data 3350/7253 ...completed
# loading data 3351/7253 ...completed
# loading data 3352/7253 ...completed
# loading data 3353/7253 ...completed
# loading data 3354/7253 ...completed
# loading data 3355/7253 ...completed
# loading data 3356/7253 ...completed
# loading data 3357/7253 ...completed
# loading data 3358/7253 ...completed
# loading data 3359/7253 ...completed
# loading data 3360/7253 ...completed
# loading data 3361/7253 ...completed
# loading data 3362/7253 ...completed
# loading data 3363/7253 ...completed
# loading data 3364/7253 ...completed
# loading data 3365/7253 ...completed
# loading data 3366/7253 ...completed
# loading data 3367/7253 ...completed
# loading data 3368/7253 ...completed
# loading data 3369/7253 ...completed
# loading data 3370/7253 ...completed
# loading data 3371/7253 ...completed
# loading data 3372/7253 ...completed
# loading data 3373/7253 ...completed
# loading data 3374/7253 ...completed
# loading data 3375/7253 ...completed
# loading data 3376/7253 ...completed
# loading data 3377/7253 ...completed
# loading data 3378/7253 ...completed
# loading data 3379/7253 ...completed
# loading data 3380/7253 ...completed
# loading data 3381/7253 ...completed
# loading data 3382/7253 ...completed
# loading data 3383/7253 ...completed
# loading data 3384/7253 ...completed
# loading data 3385/7253 ...completed
# loading data 3386/7253 ...completed
# loading data 3387/7253 ...completed
# loading data 3388/7253 ...completed
# loading data 3389/7253 ...completed
# loading data 3390/7253 ...completed
# loading data 3391/7253 ...completed
# loading data 3392/7253 ...completed
# loading data 3393/7253 ...completed
# loading data 3394/7253 ...completed
# loading data 3395/7253 ...completed
# loading data 3396/7253 ...completed
# loading data 3397/7253 ...completed
# loading data 3398/7253 ...completed
# loading data 3399/7253 ...completed
# loading data 3400/7253 ...completed
# loading data 3401/7253 ...completed
# loading data 3402/7253 ...completed
# loading data 3403/7253 ...completed
# loading data 3404/7253 ...completed
# loading data 3405/7253 ...completed
# loading data 3406/7253 ...completed
# loading data 3407/7253 ...completed
# loading data 3408/7253 ...completed
# loading data 3409/7253 ...completed
# loading data 3410/7253 ...completed
# loading data 3411/7253 ...completed
# loading data 3412/7253 ...completed
# loading data 3413/7253 ...completed
# loading data 3414/7253 ...completed
# loading data 3415/7253 ...completed
# loading data 3416/7253 ...completed
# loading data 3417/7253 ...completed
# loading data 3418/7253 ...completed
# loading data 3419/7253 ...completed
# loading data 3420/7253 ...completed
# loading data 3421/7253 ...completed
# loading data 3422/7253 ...completed
# loading data 3423/7253 ...completed
# loading data 3424/7253 ...completed
# loading data 3425/7253 ...completed
# loading data 3426/7253 ...completed
# loading data 3427/7253 ...completed
# loading data 3428/7253 ...completed
# loading data 3429/7253 ...completed
# loading data 3430/7253 ...completed
# loading data 3431/7253 ...completed
# loading data 3432/7253 ...completed
# loading data 3433/7253 ...completed
# loading data 3434/7253 ...completed
# loading data 3435/7253 ...completed
# loading data 3436/7253 ...completed
# loading data 3437/7253 ...completed
# loading data 3438/7253 ...completed
# loading data 3439/7253 ...completed
# loading data 3440/7253 ...completed
# loading data 3441/7253 ...completed
# loading data 3442/7253 ...completed
# loading data 3443/7253 ...completed
# loading data 3444/7253 ...completed
# loading data 3445/7253 ...completed
# loading data 3446/7253 ...completed
# loading data 3447/7253 ...completed
# loading data 3448/7253 ...completed
# loading data 3449/7253 ...completed
# loading data 3450/7253 ...completed
# loading data 3451/7253 ...completed
# loading data 3452/7253 ...completed
# loading data 3453/7253 ...completed
# loading data 3454/7253 ...completed
# loading data 3455/7253 ...completed
# loading data 3456/7253 ...completed
# loading data 3457/7253 ...completed
# loading data 3458/7253 ...completed
# loading data 3459/7253 ...completed
# loading data 3460/7253 ...completed
# loading data 3461/7253 ...completed
# loading data 3462/7253 ...completed
# loading data 3463/7253 ...completed
# loading data 3464/7253 ...completed
# loading data 3465/7253 ...completed
# loading data 3466/7253 ...completed
# loading data 3467/7253 ...completed
# loading data 3468/7253 ...completed
# loading data 3469/7253 ...completed
# loading data 3470/7253 ...completed
# loading data 3471/7253 ...completed
# loading data 3472/7253 ...completed
# loading data 3473/7253 ...completed
# loading data 3474/7253 ...completed
# loading data 3475/7253 ...completed
# loading data 3476/7253 ...completed
# loading data 3477/7253 ...completed
# loading data 3478/7253 ...completed
# loading data 3479/7253 ...completed
# loading data 3480/7253 ...completed
# loading data 3481/7253 ...completed
# loading data 3482/7253 ...completed
# loading data 3483/7253 ...completed
# loading data 3484/7253 ...completed
# loading data 3485/7253 ...completed
# loading data 3486/7253 ...completed
# loading data 3487/7253 ...completed
# loading data 3488/7253 ...completed
# loading data 3489/7253 ...completed
# loading data 3490/7253 ...completed
# loading data 3491/7253 ...completed
# loading data 3492/7253 ...completed
# loading data 3493/7253 ...completed
# loading data 3494/7253 ...completed
# loading data 3495/7253 ...completed
# loading data 3496/7253 ...completed
# loading data 3497/7253 ...completed
# loading data 3498/7253 ...completed
# loading data 3499/7253 ...completed
# loading data 3500/7253 ...completed
# loading data 3501/7253 ...completed
# loading data 3502/7253 ...completed
# loading data 3503/7253 ...completed
# loading data 3504/7253 ...completed
# loading data 3505/7253 ...completed
# loading data 3506/7253 ...completed
# loading data 3507/7253 ...completed
# loading data 3508/7253 ...completed
# loading data 3509/7253 ...completed
# loading data 3510/7253 ...completed
# loading data 3511/7253 ...completed
# loading data 3512/7253 ...completed
# loading data 3513/7253 ...completed
# loading data 3514/7253 ...completed
# loading data 3515/7253 ...completed
# loading data 3516/7253 ...completed
# loading data 3517/7253 ...completed
# loading data 3518/7253 ...completed
# loading data 3519/7253 ...completed
# loading data 3520/7253 ...completed
# loading data 3521/7253 ...completed
# loading data 3522/7253 ...completed
# loading data 3523/7253 ...completed
# loading data 3524/7253 ...completed
# loading data 3525/7253 ...completed
# loading data 3526/7253 ...completed
# loading data 3527/7253 ...completed
# loading data 3528/7253 ...completed
# loading data 3529/7253 ...completed
# loading data 3530/7253 ...completed
# loading data 3531/7253 ...completed
# loading data 3532/7253 ...completed
# loading data 3533/7253 ...completed
# loading data 3534/7253 ...completed
# loading data 3535/7253 ...completed
# loading data 3536/7253 ...completed
# loading data 3537/7253 ...completed
# loading data 3538/7253 ...completed
# loading data 3539/7253 ...completed
# loading data 3540/7253 ...completed
# loading data 3541/7253 ...completed
# loading data 3542/7253 ...completed
# loading data 3543/7253 ...completed
# loading data 3544/7253 ...completed
# loading data 3545/7253 ...completed
# loading data 3546/7253 ...completed
# loading data 3547/7253 ...completed
# loading data 3548/7253 ...completed
# loading data 3549/7253 ...completed
# loading data 3550/7253 ...completed
# loading data 3551/7253 ...completed
# loading data 3552/7253 ...completed
# loading data 3553/7253 ...completed
# loading data 3554/7253 ...completed
# loading data 3555/7253 ...completed
# loading data 3556/7253 ...completed
# loading data 3557/7253 ...completed
# loading data 3558/7253 ...completed
# loading data 3559/7253 ...completed
# loading data 3560/7253 ...completed
# loading data 3561/7253 ...completed
# loading data 3562/7253 ...completed
# loading data 3563/7253 ...completed
# loading data 3564/7253 ...completed
# loading data 3565/7253 ...completed
# loading data 3566/7253 ...completed
# loading data 3567/7253 ...completed
# loading data 3568/7253 ...completed
# loading data 3569/7253 ...completed
# loading data 3570/7253 ...completed
# loading data 3571/7253 ...completed
# loading data 3572/7253 ...completed
# loading data 3573/7253 ...completed
# loading data 3574/7253 ...completed
# loading data 3575/7253 ...completed
# loading data 3576/7253 ...completed
# loading data 3577/7253 ...completed
# loading data 3578/7253 ...completed
# loading data 3579/7253 ...completed
# loading data 3580/7253 ...completed
# loading data 3581/7253 ...completed
# loading data 3582/7253 ...completed
# loading data 3583/7253 ...completed
# loading data 3584/7253 ...completed
# loading data 3585/7253 ...completed
# loading data 3586/7253 ...completed
# loading data 3587/7253 ...completed
# loading data 3588/7253 ...completed
# loading data 3589/7253 ...completed
# loading data 3590/7253 ...completed
# loading data 3591/7253 ...completed
# loading data 3592/7253 ...completed
# loading data 3593/7253 ...completed
# loading data 3594/7253 ...completed
# loading data 3595/7253 ...completed
# loading data 3596/7253 ...completed
# loading data 3597/7253 ...completed
# loading data 3598/7253 ...completed
# loading data 3599/7253 ...completed
# loading data 3600/7253 ...completed
# saving...done
# size of training set(pacu): 21108
# size of validation set(pacu): 2396
# size of test set(pacu): 2501

# %%
import numpy as np
import pandas as pd
import os, pickle, sys
from scipy import signal
#sys.path.append('DL_model')


### input 설정
SRATE = 250 # 250Hz
LEN_INPUT = 20 # input 10s
LEN_PER_NRS = 60 # vital length for each NRS
OVERLAP = 2
n_aug = int((LEN_PER_NRS-LEN_INPUT)/OVERLAP) + 1 # data augmentation 개수




input_path = '../DL_model/dataset/preprocess3/input3-3/'
if not os.path.exists(input_path[:-1]):
    os.mkdir(input_path[:-1])

if True:
    false_row_list_preop = []
    
    vital_path = '../../cranberry2/Preprocessing/vital_data/PPG_100Hz_ECG_100Hz_pacu_2min/'
    ecg_path = '../../cranberry2/Preprocessing/vital_data/ECG_250Hz_pacu_2min/ECG,'
    df_preprocess_pacu = pickle.load(open('../DL_model/cache/preprocess3/input3/df_preprocess_pacu_agender','rb'))
    df_demograph = pd.read_csv('../DL_model/caseids_age_gender.csv')
    

    

    ### test set에 해당하는 file_path
    caseid_test = pickle.load(open('../DL_model/caseid_test', 'rb'))
    caseid_train = pickle.load(open('../DL_model/caseid_train', 'rb'))
    caseid_val = pickle.load(open('../DL_model/caseid_val', 'rb'))
    

    x_train_pacu, y_train_pacu = 0, 0
    x_test_pacu, y_test_pacu = 0, 0
    x_val_pacu, y_val_pacu = 0, 0

    cnt = 0
    wrong = 0
    for _, row in df_preprocess_pacu.iterrows():
        cnt += 1
        print('loading data {}/{} ...'.format(cnt, len(df_preprocess_pacu)), end='')
            
        if not row['caseids'] in df_demograph['caseids'].tolist():
            wrong+=1
            continue

        # 한 NRS에 대해 23개의 input 확인
        for i in range(30,51):
            # input이 전처리 통과한 경우
            if row[str(i+1)]:

                # 해당 caseid가 test set에 속하는 경우
                if row['caseids'] in caseid_test:
                    x_test_pacu+=1

                # 해당 caseid가 train set에 해당하는 경우
                elif row['caseids'] in caseid_val:
                    x_val_pacu+=1
                    
                else:
                    x_train_pacu+=1
        print('done')

    
    
print('size of training set(pacu):', (x_train_pacu))
print('size of validation set(pacu):', (x_val_pacu))
print('size of test set(pacu):', (x_test_pacu))
# Out:
# loading data 1/7253 ...done
# loading data 2/7253 ...done
# loading data 3/7253 ...done
# loading data 4/7253 ...done
# loading data 5/7253 ...done
# loading data 6/7253 ...done
# loading data 7/7253 ...done
# loading data 8/7253 ...done
# loading data 9/7253 ...done
# loading data 10/7253 ...done
# loading data 11/7253 ...done
# loading data 12/7253 ...done
# loading data 13/7253 ...done
# loading data 14/7253 ...done
# loading data 15/7253 ...done
# loading data 16/7253 ...done
# loading data 17/7253 ...done
# loading data 18/7253 ...done
# loading data 19/7253 ...done
# loading data 20/7253 ...done
# loading data 21/7253 ...done
# loading data 22/7253 ...done
# loading data 23/7253 ...done
# loading data 24/7253 ...done
# loading data 25/7253 ...done
# loading data 26/7253 ...done
# loading data 27/7253 ...done
# loading data 28/7253 ...done
# loading data 29/7253 ...done
# loading data 30/7253 ...done
# loading data 31/7253 ...done
# loading data 32/7253 ...done
# loading data 33/7253 ...done
# loading data 34/7253 ...done
# loading data 35/7253 ...done
# loading data 36/7253 ...done
# loading data 37/7253 ...done
# loading data 38/7253 ...done
# loading data 39/7253 ...done
# loading data 40/7253 ...done
# loading data 41/7253 ...done
# loading data 42/7253 ...done
# loading data 43/7253 ...done
# loading data 44/7253 ...done
# loading data 45/7253 ...done
# loading data 46/7253 ...done
# loading data 47/7253 ...done
# loading data 48/7253 ...done
# loading data 49/7253 ...done
# loading data 50/7253 ...done
# loading data 51/7253 ...done
# loading data 52/7253 ...done
# loading data 53/7253 ...done
# loading data 54/7253 ...done
# loading data 55/7253 ...done
# loading data 56/7253 ...done
# loading data 57/7253 ...done
# loading data 58/7253 ...done
# loading data 59/7253 ...done
# loading data 60/7253 ...done
# loading data 61/7253 ...done
# loading data 62/7253 ...done
# loading data 63/7253 ...done
# loading data 64/7253 ...done
# loading data 65/7253 ...done
# loading data 66/7253 ...done
# loading data 67/7253 ...done
# loading data 68/7253 ...done
# loading data 69/7253 ...done
# loading data 70/7253 ...done
# loading data 71/7253 ...done
# loading data 72/7253 ...done
# loading data 73/7253 ...done
# loading data 74/7253 ...done
# loading data 75/7253 ...done
# loading data 76/7253 ...done
# loading data 77/7253 ...done
# loading data 78/7253 ...done
# loading data 79/7253 ...done
# loading data 80/7253 ...done
# loading data 81/7253 ...done
# loading data 82/7253 ...done
# loading data 83/7253 ...done
# loading data 84/7253 ...done
# loading data 85/7253 ...done
# loading data 86/7253 ...done
# loading data 87/7253 ...done
# loading data 88/7253 ...done
# loading data 89/7253 ...done
# loading data 90/7253 ...done
# loading data 91/7253 ...done
# loading data 92/7253 ...done
# loading data 93/7253 ...done
# loading data 94/7253 ...done
# loading data 95/7253 ...done
# loading data 96/7253 ...done
# loading data 97/7253 ...done
# loading data 98/7253 ...done
# loading data 99/7253 ...done
# loading data 100/7253 ...done
# loading data 101/7253 ...done
# loading data 102/7253 ...done
# loading data 103/7253 ...done
# loading data 104/7253 ...done
# loading data 105/7253 ...done
# loading data 106/7253 ...done
# loading data 107/7253 ...done
# loading data 108/7253 ...done
# loading data 109/7253 ...done
# loading data 110/7253 ...done
# loading data 111/7253 ...done
# loading data 112/7253 ...done
# loading data 113/7253 ...done
# loading data 114/7253 ...done
# loading data 115/7253 ...done
# loading data 116/7253 ...done
# loading data 117/7253 ...done
# loading data 118/7253 ...done
# loading data 119/7253 ...done
# loading data 120/7253 ...done
# loading data 121/7253 ...done
# loading data 122/7253 ...done
# loading data 123/7253 ...done
# loading data 124/7253 ...done
# loading data 125/7253 ...done
# loading data 126/7253 ...done
# loading data 127/7253 ...done
# loading data 128/7253 ...done
# loading data 129/7253 ...done
# loading data 130/7253 ...done
# loading data 131/7253 ...done
# loading data 132/7253 ...done
# loading data 133/7253 ...done
# loading data 134/7253 ...done
# loading data 135/7253 ...done
# loading data 136/7253 ...done
# loading data 137/7253 ...done
# loading data 138/7253 ...done
# loading data 139/7253 ...done
# loading data 140/7253 ...done
# loading data 141/7253 ...done
# loading data 142/7253 ...done
# loading data 143/7253 ...done
# loading data 144/7253 ...done
# loading data 145/7253 ...done
# loading data 146/7253 ...done
# loading data 147/7253 ...done
# loading data 148/7253 ...done
# loading data 149/7253 ...done
# loading data 150/7253 ...done
# loading data 151/7253 ...done
# loading data 152/7253 ...done
# loading data 153/7253 ...done
# loading data 154/7253 ...done
# loading data 155/7253 ...done
# loading data 156/7253 ...done
# loading data 157/7253 ...done
# loading data 158/7253 ...done
# loading data 159/7253 ...done
# loading data 160/7253 ...done
# loading data 161/7253 ...done
# loading data 162/7253 ...done
# loading data 163/7253 ...done
# loading data 164/7253 ...done
# loading data 165/7253 ...done
# loading data 166/7253 ...done
# loading data 167/7253 ...done
# loading data 168/7253 ...done
# loading data 169/7253 ...done
# loading data 170/7253 ...done
# loading data 171/7253 ...done
# loading data 172/7253 ...done
# loading data 173/7253 ...done
# loading data 174/7253 ...done
# loading data 175/7253 ...done
# loading data 176/7253 ...done
# loading data 177/7253 ...done
# loading data 178/7253 ...done
# loading data 179/7253 ...done
# loading data 180/7253 ...done
# loading data 181/7253 ...done
# loading data 182/7253 ...done
# loading data 183/7253 ...done
# loading data 184/7253 ...done
# loading data 185/7253 ...done
# loading data 186/7253 ...done
# loading data 187/7253 ...done
# loading data 188/7253 ...done
# loading data 189/7253 ...done
# loading data 190/7253 ...done
# loading data 191/7253 ...done
# loading data 192/7253 ...done
# loading data 193/7253 ...done
# loading data 194/7253 ...done
# loading data 195/7253 ...done
# loading data 196/7253 ...done
# loading data 197/7253 ...done
# loading data 198/7253 ...done
# loading data 199/7253 ...done
# loading data 200/7253 ...done
# loading data 201/7253 ...done
# loading data 202/7253 ...done
# loading data 203/7253 ...done
# loading data 204/7253 ...done
# loading data 205/7253 ...done
# loading data 206/7253 ...done
# loading data 207/7253 ...done
# loading data 208/7253 ...done
# loading data 209/7253 ...done
# loading data 210/7253 ...done
# loading data 211/7253 ...done
# loading data 212/7253 ...done
# loading data 213/7253 ...done
# loading data 214/7253 ...done
# loading data 215/7253 ...done
# loading data 216/7253 ...done
# loading data 217/7253 ...done
# loading data 218/7253 ...done
# loading data 219/7253 ...done
# loading data 220/7253 ...done
# loading data 221/7253 ...done
# loading data 222/7253 ...done
# loading data 223/7253 ...done
# loading data 224/7253 ...done
# loading data 225/7253 ...done
# loading data 226/7253 ...done
# loading data 227/7253 ...done
# loading data 228/7253 ...done
# loading data 229/7253 ...done
# loading data 230/7253 ...done
# loading data 231/7253 ...done
# loading data 232/7253 ...done
# loading data 233/7253 ...done
# loading data 234/7253 ...done
# loading data 235/7253 ...done
# loading data 236/7253 ...done
# loading data 237/7253 ...done
# loading data 238/7253 ...done
# loading data 239/7253 ...done
# loading data 240/7253 ...done
# loading data 241/7253 ...done
# loading data 242/7253 ...done
# loading data 243/7253 ...done
# loading data 244/7253 ...done
# loading data 245/7253 ...done
# loading data 246/7253 ...done
# loading data 247/7253 ...done
# loading data 248/7253 ...done
# loading data 249/7253 ...done
# loading data 250/7253 ...done
# loading data 251/7253 ...done
# loading data 252/7253 ...done
# loading data 253/7253 ...done
# loading data 254/7253 ...done
# loading data 255/7253 ...done
# loading data 256/7253 ...done
# loading data 257/7253 ...done
# loading data 258/7253 ...done
# loading data 259/7253 ...done
# loading data 260/7253 ...done
# loading data 261/7253 ...done
# loading data 262/7253 ...done
# loading data 263/7253 ...done
# loading data 264/7253 ...done
# loading data 265/7253 ...done
# loading data 266/7253 ...done
# loading data 267/7253 ...done
# loading data 268/7253 ...done
# loading data 269/7253 ...done
# loading data 270/7253 ...done
# loading data 271/7253 ...done
# loading data 272/7253 ...done
# loading data 273/7253 ...done
# loading data 274/7253 ...done
# loading data 275/7253 ...done
# loading data 276/7253 ...done
# loading data 277/7253 ...done
# loading data 278/7253 ...done
# loading data 279/7253 ...done
# loading data 280/7253 ...done
# loading data 281/7253 ...done
# loading data 282/7253 ...done
# loading data 283/7253 ...done
# loading data 284/7253 ...done
# loading data 285/7253 ...done
# loading data 286/7253 ...done
# loading data 287/7253 ...done
# loading data 288/7253 ...done
# loading data 289/7253 ...done
# loading data 290/7253 ...done
# loading data 291/7253 ...done
# loading data 292/7253 ...done
# loading data 293/7253 ...done
# loading data 294/7253 ...done
# loading data 295/7253 ...done
# loading data 296/7253 ...done
# loading data 297/7253 ...done
# loading data 298/7253 ...done
# loading data 299/7253 ...done
# loading data 300/7253 ...done
# loading data 301/7253 ...done
# loading data 302/7253 ...done
# loading data 303/7253 ...done
# loading data 304/7253 ...done
# loading data 305/7253 ...done
# loading data 306/7253 ...done
# loading data 307/7253 ...done
# loading data 308/7253 ...done
# loading data 309/7253 ...done
# loading data 310/7253 ...done
# loading data 311/7253 ...done
# loading data 312/7253 ...done
# loading data 313/7253 ...done
# loading data 314/7253 ...done
# loading data 315/7253 ...done
# loading data 316/7253 ...done
# loading data 317/7253 ...done
# loading data 318/7253 ...done
# loading data 319/7253 ...done
# loading data 320/7253 ...done
# loading data 321/7253 ...done
# loading data 322/7253 ...done
# loading data 323/7253 ...done
# loading data 324/7253 ...done
# loading data 325/7253 ...done
# loading data 326/7253 ...done
# loading data 327/7253 ...done
# loading data 328/7253 ...done
# loading data 329/7253 ...done
# loading data 330/7253 ...done
# loading data 331/7253 ...done
# loading data 332/7253 ...done
# loading data 333/7253 ...done
# loading data 334/7253 ...done
# loading data 335/7253 ...done
# loading data 336/7253 ...done
# loading data 337/7253 ...done
# loading data 338/7253 ...done
# loading data 339/7253 ...done
# loading data 340/7253 ...done
# loading data 341/7253 ...done
# loading data 342/7253 ...done
# loading data 343/7253 ...done
# loading data 344/7253 ...done
# loading data 345/7253 ...done
# loading data 346/7253 ...done
# loading data 347/7253 ...done
# loading data 348/7253 ...done
# loading data 349/7253 ...done
# loading data 350/7253 ...done
# loading data 351/7253 ...done
# loading data 352/7253 ...done
# loading data 353/7253 ...done
# loading data 354/7253 ...done
# loading data 355/7253 ...done
# loading data 356/7253 ...done
# loading data 357/7253 ...done
# loading data 358/7253 ...done
# loading data 359/7253 ...done
# loading data 360/7253 ...done
# loading data 361/7253 ...done
# loading data 362/7253 ...done
# loading data 363/7253 ...done
# loading data 364/7253 ...done
# loading data 365/7253 ...done
# loading data 366/7253 ...done
# loading data 367/7253 ...done
# loading data 368/7253 ...done
# loading data 369/7253 ...done
# loading data 370/7253 ...done
# loading data 371/7253 ...done
# loading data 372/7253 ...done
# loading data 373/7253 ...done
# loading data 374/7253 ...done
# loading data 375/7253 ...done
# loading data 376/7253 ...done
# loading data 377/7253 ...done
# loading data 378/7253 ...done
# loading data 379/7253 ...done
# loading data 380/7253 ...done
# loading data 381/7253 ...done
# loading data 382/7253 ...done
# loading data 383/7253 ...done
# loading data 384/7253 ...done
# loading data 385/7253 ...done
# loading data 386/7253 ...done
# loading data 387/7253 ...done
# loading data 388/7253 ...done
# loading data 389/7253 ...done
# loading data 390/7253 ...done
# loading data 391/7253 ...done
# loading data 392/7253 ...done
# loading data 393/7253 ...done
# loading data 394/7253 ...done
# loading data 395/7253 ...done
# loading data 396/7253 ...done
# loading data 397/7253 ...done
# loading data 398/7253 ...done
# loading data 399/7253 ...done
# loading data 400/7253 ...done
# loading data 401/7253 ...done
# loading data 402/7253 ...done
# loading data 403/7253 ...done
# loading data 404/7253 ...done
# loading data 405/7253 ...done
# loading data 406/7253 ...done
# loading data 407/7253 ...done
# loading data 408/7253 ...done
# loading data 409/7253 ...done
# loading data 410/7253 ...done
# loading data 411/7253 ...done
# loading data 412/7253 ...done
# loading data 413/7253 ...done
# loading data 414/7253 ...done
# loading data 415/7253 ...done
# loading data 416/7253 ...done
# loading data 417/7253 ...done
# loading data 418/7253 ...done
# loading data 419/7253 ...done
# loading data 420/7253 ...done
# loading data 421/7253 ...done
# loading data 422/7253 ...done
# loading data 423/7253 ...done
# loading data 424/7253 ...done
# loading data 425/7253 ...done
# loading data 426/7253 ...done
# loading data 427/7253 ...done
# loading data 428/7253 ...done
# loading data 429/7253 ...done
# loading data 430/7253 ...done
# loading data 431/7253 ...done
# loading data 432/7253 ...done
# loading data 433/7253 ...done
# loading data 434/7253 ...done
# loading data 435/7253 ...done
# loading data 436/7253 ...done
# loading data 437/7253 ...done
# loading data 438/7253 ...done
# loading data 439/7253 ...done
# loading data 440/7253 ...done
# loading data 441/7253 ...done
# loading data 442/7253 ...done
# loading data 443/7253 ...done
# loading data 444/7253 ...done
# loading data 445/7253 ...done
# loading data 446/7253 ...done
# loading data 447/7253 ...done
# loading data 448/7253 ...done
# loading data 449/7253 ...done
# loading data 450/7253 ...done
# loading data 451/7253 ...done
# loading data 452/7253 ...done
# loading data 453/7253 ...done
# loading data 454/7253 ...done
# loading data 455/7253 ...done
# loading data 456/7253 ...done
# loading data 457/7253 ...done
# loading data 458/7253 ...done
# loading data 459/7253 ...done
# loading data 460/7253 ...done
# loading data 461/7253 ...done
# loading data 462/7253 ...done
# loading data 463/7253 ...done
# loading data 464/7253 ...done
# loading data 465/7253 ...done
# loading data 466/7253 ...done
# loading data 467/7253 ...done
# loading data 468/7253 ...done
# loading data 469/7253 ...done
# loading data 470/7253 ...done
# loading data 471/7253 ...done
# loading data 472/7253 ...done
# loading data 473/7253 ...done
# loading data 474/7253 ...done
# loading data 475/7253 ...done
# loading data 476/7253 ...done
# loading data 477/7253 ...done
# loading data 478/7253 ...done
# loading data 479/7253 ...done
# loading data 480/7253 ...done
# loading data 481/7253 ...done
# loading data 482/7253 ...done
# loading data 483/7253 ...done
# loading data 484/7253 ...done
# loading data 485/7253 ...done
# loading data 486/7253 ...done
# loading data 487/7253 ...done
# loading data 488/7253 ...done
# loading data 489/7253 ...done
# loading data 490/7253 ...done
# loading data 491/7253 ...done
# loading data 492/7253 ...done
# loading data 493/7253 ...done
# loading data 494/7253 ...done
# loading data 495/7253 ...done
# loading data 496/7253 ...done
# loading data 497/7253 ...done
# loading data 498/7253 ...done
# loading data 499/7253 ...done
# loading data 500/7253 ...done
# loading data 501/7253 ...done
# loading data 502/7253 ...done
# loading data 503/7253 ...done
# loading data 504/7253 ...done
# loading data 505/7253 ...done
# loading data 506/7253 ...done
# loading data 507/7253 ...done
# loading data 508/7253 ...done
# loading data 509/7253 ...done
# loading data 510/7253 ...done
# loading data 511/7253 ...done
# loading data 512/7253 ...done
# loading data 513/7253 ...done
# loading data 514/7253 ...done
# loading data 515/7253 ...done
# loading data 516/7253 ...done
# loading data 517/7253 ...done
# loading data 518/7253 ...done
# loading data 519/7253 ...done
# loading data 520/7253 ...done
# loading data 521/7253 ...done
# loading data 522/7253 ...done
# loading data 523/7253 ...done
# loading data 524/7253 ...done
# loading data 525/7253 ...done
# loading data 526/7253 ...done
# loading data 527/7253 ...done
# loading data 528/7253 ...done
# loading data 529/7253 ...done
# loading data 530/7253 ...done
# loading data 531/7253 ...done
# loading data 532/7253 ...done
# loading data 533/7253 ...done
# loading data 534/7253 ...done
# loading data 535/7253 ...done
# loading data 536/7253 ...done
# loading data 537/7253 ...done
# loading data 538/7253 ...done
# loading data 539/7253 ...done
# loading data 540/7253 ...done
# loading data 541/7253 ...done
# loading data 542/7253 ...done
# loading data 543/7253 ...done
# loading data 544/7253 ...done
# loading data 545/7253 ...done
# loading data 546/7253 ...done
# loading data 547/7253 ...done
# loading data 548/7253 ...done
# loading data 549/7253 ...done
# loading data 550/7253 ...done
# loading data 551/7253 ...done
# loading data 552/7253 ...done
# loading data 553/7253 ...done
# loading data 554/7253 ...done
# loading data 555/7253 ...done
# loading data 556/7253 ...done
# loading data 557/7253 ...done
# loading data 558/7253 ...done
# loading data 559/7253 ...done
# loading data 560/7253 ...done
# loading data 561/7253 ...done
# loading data 562/7253 ...done
# loading data 563/7253 ...done
# loading data 564/7253 ...done
# loading data 565/7253 ...done
# loading data 566/7253 ...done
# loading data 567/7253 ...done
# loading data 568/7253 ...done
# loading data 569/7253 ...done
# loading data 570/7253 ...done
# loading data 571/7253 ...done
# loading data 572/7253 ...done
# loading data 573/7253 ...done
# loading data 574/7253 ...done
# loading data 575/7253 ...done
# loading data 576/7253 ...done
# loading data 577/7253 ...done
# loading data 578/7253 ...done
# loading data 579/7253 ...done
# loading data 580/7253 ...done
# loading data 581/7253 ...done
# loading data 582/7253 ...done
# loading data 583/7253 ...done
# loading data 584/7253 ...done
# loading data 585/7253 ...done
# loading data 586/7253 ...done
# loading data 587/7253 ...done
# loading data 588/7253 ...done
# loading data 589/7253 ...done
# loading data 590/7253 ...done
# loading data 591/7253 ...done
# loading data 592/7253 ...done
# loading data 593/7253 ...done
# loading data 594/7253 ...done
# loading data 595/7253 ...done
# loading data 596/7253 ...done
# loading data 597/7253 ...done
# loading data 598/7253 ...done
# loading data 599/7253 ...done
# loading data 600/7253 ...done
# loading data 601/7253 ...done
# loading data 602/7253 ...done
# loading data 603/7253 ...done
# loading data 604/7253 ...done
# loading data 605/7253 ...done
# loading data 606/7253 ...done
# loading data 607/7253 ...done
# loading data 608/7253 ...done
# loading data 609/7253 ...done
# loading data 610/7253 ...done
# loading data 611/7253 ...done
# loading data 612/7253 ...done
# loading data 613/7253 ...done
# loading data 614/7253 ...done
# loading data 615/7253 ...done
# loading data 616/7253 ...done
# loading data 617/7253 ...done
# loading data 618/7253 ...done
# loading data 619/7253 ...done
# loading data 620/7253 ...done
# loading data 621/7253 ...done
# loading data 622/7253 ...done
# loading data 623/7253 ...done
# loading data 624/7253 ...done
# loading data 625/7253 ...done
# loading data 626/7253 ...done
# loading data 627/7253 ...done
# loading data 628/7253 ...done
# loading data 629/7253 ...done
# loading data 630/7253 ...done
# loading data 631/7253 ...done
# loading data 632/7253 ...done
# loading data 633/7253 ...done
# loading data 634/7253 ...done
# loading data 635/7253 ...done
# loading data 636/7253 ...done
# loading data 637/7253 ...done
# loading data 638/7253 ...done
# loading data 639/7253 ...done
# loading data 640/7253 ...done
# loading data 641/7253 ...done
# loading data 642/7253 ...done
# loading data 643/7253 ...done
# loading data 644/7253 ...done
# loading data 645/7253 ...done
# loading data 646/7253 ...done
# loading data 647/7253 ...done
# loading data 648/7253 ...done
# loading data 649/7253 ...done
# loading data 650/7253 ...done
# loading data 651/7253 ...done
# loading data 652/7253 ...done
# loading data 653/7253 ...done
# loading data 654/7253 ...done
# loading data 655/7253 ...done
# loading data 656/7253 ...done
# loading data 657/7253 ...done
# loading data 658/7253 ...done
# loading data 659/7253 ...done
# loading data 660/7253 ...done
# loading data 661/7253 ...done
# loading data 662/7253 ...done
# loading data 663/7253 ...done
# loading data 664/7253 ...done
# loading data 665/7253 ...done
# loading data 666/7253 ...done
# loading data 667/7253 ...done
# loading data 668/7253 ...done
# loading data 669/7253 ...done
# loading data 670/7253 ...done
# loading data 671/7253 ...done
# loading data 672/7253 ...done
# loading data 673/7253 ...done
# loading data 674/7253 ...done
# loading data 675/7253 ...done
# loading data 676/7253 ...done
# loading data 677/7253 ...done
# loading data 678/7253 ...done
# loading data 679/7253 ...done
# loading data 680/7253 ...done
# loading data 681/7253 ...done
# loading data 682/7253 ...done
# loading data 683/7253 ...done
# loading data 684/7253 ...done
# loading data 685/7253 ...done
# loading data 686/7253 ...done
# loading data 687/7253 ...done
# loading data 688/7253 ...done
# loading data 689/7253 ...done
# loading data 690/7253 ...done
# loading data 691/7253 ...done
# loading data 692/7253 ...done
# loading data 693/7253 ...done
# loading data 694/7253 ...done
# loading data 695/7253 ...done
# loading data 696/7253 ...done
# loading data 697/7253 ...done
# loading data 698/7253 ...done
# loading data 699/7253 ...done
# loading data 700/7253 ...done
# loading data 701/7253 ...done
# loading data 702/7253 ...done
# loading data 703/7253 ...done
# loading data 704/7253 ...done
# loading data 705/7253 ...done
# loading data 706/7253 ...done
# loading data 707/7253 ...done
# loading data 708/7253 ...done
# loading data 709/7253 ...done
# loading data 710/7253 ...done
# loading data 711/7253 ...done
# loading data 712/7253 ...done
# loading data 713/7253 ...done
# loading data 714/7253 ...done
# loading data 715/7253 ...done
# loading data 716/7253 ...done
# loading data 717/7253 ...done
# loading data 718/7253 ...done
# loading data 719/7253 ...done
# loading data 720/7253 ...done
# loading data 721/7253 ...done
# loading data 722/7253 ...done
# loading data 723/7253 ...done
# loading data 724/7253 ...done
# loading data 725/7253 ...done
# loading data 726/7253 ...done
# loading data 727/7253 ...done
# loading data 728/7253 ...done
# loading data 729/7253 ...done
# loading data 730/7253 ...done
# loading data 731/7253 ...done
# loading data 732/7253 ...done
# loading data 733/7253 ...done
# loading data 734/7253 ...done
# loading data 735/7253 ...done
# loading data 736/7253 ...done
# loading data 737/7253 ...done
# loading data 738/7253 ...done
# loading data 739/7253 ...done
# loading data 740/7253 ...done
# loading data 741/7253 ...done
# loading data 742/7253 ...done
# loading data 743/7253 ...done
# loading data 744/7253 ...done
# loading data 745/7253 ...done
# loading data 746/7253 ...done
# loading data 747/7253 ...done
# loading data 748/7253 ...done
# loading data 749/7253 ...done
# loading data 750/7253 ...done
# loading data 751/7253 ...done
# loading data 752/7253 ...done
# loading data 753/7253 ...done
# loading data 754/7253 ...done
# loading data 755/7253 ...done
# loading data 756/7253 ...done
# loading data 757/7253 ...done
# loading data 758/7253 ...done
# loading data 759/7253 ...done
# loading data 760/7253 ...done
# loading data 761/7253 ...done
# loading data 762/7253 ...done
# loading data 763/7253 ...done
# loading data 764/7253 ...done
# loading data 765/7253 ...done
# loading data 766/7253 ...done
# loading data 767/7253 ...done
# loading data 768/7253 ...done
# loading data 769/7253 ...done
# loading data 770/7253 ...done
# loading data 771/7253 ...done
# loading data 772/7253 ...done
# loading data 773/7253 ...done
# loading data 774/7253 ...done
# loading data 775/7253 ...done
# loading data 776/7253 ...done
# loading data 777/7253 ...done
# loading data 778/7253 ...done
# loading data 779/7253 ...done
# loading data 780/7253 ...done
# loading data 781/7253 ...done
# loading data 782/7253 ...done
# loading data 783/7253 ...done
# loading data 784/7253 ...done
# loading data 785/7253 ...done
# loading data 786/7253 ...done
# loading data 787/7253 ...done
# loading data 788/7253 ...done
# loading data 789/7253 ...done
# loading data 790/7253 ...done
# loading data 791/7253 ...done
# loading data 792/7253 ...done
# loading data 793/7253 ...done
# loading data 794/7253 ...done
# loading data 795/7253 ...done
# loading data 796/7253 ...done
# loading data 797/7253 ...done
# loading data 798/7253 ...done
# loading data 799/7253 ...done
# loading data 800/7253 ...done
# loading data 801/7253 ...done
# loading data 802/7253 ...done
# loading data 803/7253 ...done
# loading data 804/7253 ...done
# loading data 805/7253 ...done
# loading data 806/7253 ...done
# loading data 807/7253 ...done
# loading data 808/7253 ...done
# loading data 809/7253 ...done
# loading data 810/7253 ...done
# loading data 811/7253 ...done
# loading data 812/7253 ...done
# loading data 813/7253 ...done
# loading data 814/7253 ...done
# loading data 815/7253 ...done
# loading data 816/7253 ...done
# loading data 817/7253 ...done
# loading data 818/7253 ...done
# loading data 819/7253 ...done
# loading data 820/7253 ...done
# loading data 821/7253 ...done
# loading data 822/7253 ...done
# loading data 823/7253 ...done
# loading data 824/7253 ...done
# loading data 825/7253 ...done
# loading data 826/7253 ...done
# loading data 827/7253 ...done
# loading data 828/7253 ...done
# loading data 829/7253 ...done
# loading data 830/7253 ...done
# loading data 831/7253 ...done
# loading data 832/7253 ...done
# loading data 833/7253 ...done
# loading data 834/7253 ...done
# loading data 835/7253 ...done
# loading data 836/7253 ...done
# loading data 837/7253 ...done
# loading data 838/7253 ...done
# loading data 839/7253 ...done
# loading data 840/7253 ...done
# loading data 841/7253 ...done
# loading data 842/7253 ...done
# loading data 843/7253 ...done
# loading data 844/7253 ...done
# loading data 845/7253 ...done
# loading data 846/7253 ...done
# loading data 847/7253 ...done
# loading data 848/7253 ...done
# loading data 849/7253 ...done
# loading data 850/7253 ...done
# loading data 851/7253 ...done
# loading data 852/7253 ...done
# loading data 853/7253 ...done
# loading data 854/7253 ...done
# loading data 855/7253 ...done
# loading data 856/7253 ...done
# loading data 857/7253 ...done
# loading data 858/7253 ...done
# loading data 859/7253 ...done
# loading data 860/7253 ...done
# loading data 861/7253 ...done
# loading data 862/7253 ...done
# loading data 863/7253 ...done
# loading data 864/7253 ...done
# loading data 865/7253 ...done
# loading data 866/7253 ...done
# loading data 867/7253 ...done
# loading data 868/7253 ...done
# loading data 869/7253 ...done
# loading data 870/7253 ...done
# loading data 871/7253 ...done
# loading data 872/7253 ...done
# loading data 873/7253 ...done
# loading data 874/7253 ...done
# loading data 875/7253 ...done
# loading data 876/7253 ...done
# loading data 877/7253 ...done
# loading data 878/7253 ...done
# loading data 879/7253 ...done
# loading data 880/7253 ...done
# loading data 881/7253 ...done
# loading data 882/7253 ...done
# loading data 883/7253 ...done
# loading data 884/7253 ...done
# loading data 885/7253 ...done
# loading data 886/7253 ...done
# loading data 887/7253 ...done
# loading data 888/7253 ...done
# loading data 889/7253 ...done
# loading data 890/7253 ...done
# loading data 891/7253 ...done
# loading data 892/7253 ...done
# loading data 893/7253 ...done
# loading data 894/7253 ...done
# loading data 895/7253 ...done
# loading data 896/7253 ...done
# loading data 897/7253 ...done
# loading data 898/7253 ...done
# loading data 899/7253 ...done
# loading data 900/7253 ...done
# loading data 901/7253 ...done
# loading data 902/7253 ...done
# loading data 903/7253 ...done
# loading data 904/7253 ...done
# loading data 905/7253 ...done
# loading data 906/7253 ...done
# loading data 907/7253 ...done
# loading data 908/7253 ...done
# loading data 909/7253 ...done
# loading data 910/7253 ...done
# loading data 911/7253 ...done
# loading data 912/7253 ...done
# loading data 913/7253 ...done
# loading data 914/7253 ...done
# loading data 915/7253 ...done
# loading data 916/7253 ...done
# loading data 917/7253 ...done
# loading data 918/7253 ...done
# loading data 919/7253 ...done
# loading data 920/7253 ...done
# loading data 921/7253 ...done
# loading data 922/7253 ...done
# loading data 923/7253 ...done
# loading data 924/7253 ...done
# loading data 925/7253 ...done
# loading data 926/7253 ...done
# loading data 927/7253 ...done
# loading data 928/7253 ...done
# loading data 929/7253 ...done
# loading data 930/7253 ...done
# loading data 931/7253 ...done
# loading data 932/7253 ...done
# loading data 933/7253 ...done
# loading data 934/7253 ...done
# loading data 935/7253 ...done
# loading data 936/7253 ...done
# loading data 937/7253 ...done
# loading data 938/7253 ...done
# loading data 939/7253 ...done
# loading data 940/7253 ...done
# loading data 941/7253 ...done
# loading data 942/7253 ...done
# loading data 943/7253 ...done
# loading data 944/7253 ...done
# loading data 945/7253 ...done
# loading data 946/7253 ...done
# loading data 947/7253 ...done
# loading data 948/7253 ...done
# loading data 949/7253 ...done
# loading data 950/7253 ...done
# loading data 951/7253 ...done
# loading data 952/7253 ...done
# loading data 953/7253 ...done
# loading data 954/7253 ...done
# loading data 955/7253 ...done
# loading data 956/7253 ...done
# loading data 957/7253 ...done
# loading data 958/7253 ...done
# loading data 959/7253 ...done
# loading data 960/7253 ...done
# loading data 961/7253 ...done
# loading data 962/7253 ...done
# loading data 963/7253 ...done
# loading data 964/7253 ...done
# loading data 965/7253 ...done
# loading data 966/7253 ...done
# loading data 967/7253 ...done
# loading data 968/7253 ...done
# loading data 969/7253 ...done
# loading data 970/7253 ...done
# loading data 971/7253 ...done
# loading data 972/7253 ...done
# loading data 973/7253 ...done
# loading data 974/7253 ...done
# loading data 975/7253 ...done
# loading data 976/7253 ...done
# loading data 977/7253 ...done
# loading data 978/7253 ...done
# loading data 979/7253 ...done
# loading data 980/7253 ...done
# loading data 981/7253 ...done
# loading data 982/7253 ...done
# loading data 983/7253 ...done
# loading data 984/7253 ...done
# loading data 985/7253 ...done
# loading data 986/7253 ...done
# loading data 987/7253 ...done
# loading data 988/7253 ...done
# loading data 989/7253 ...done
# loading data 990/7253 ...done
# loading data 991/7253 ...done
# loading data 992/7253 ...done
# loading data 993/7253 ...done
# loading data 994/7253 ...done
# loading data 995/7253 ...done
# loading data 996/7253 ...done
# loading data 997/7253 ...done
# loading data 998/7253 ...done
# loading data 999/7253 ...done
# loading data 1000/7253 ...done
# loading data 1001/7253 ...done
# loading data 1002/7253 ...done
# loading data 1003/7253 ...done
# loading data 1004/7253 ...done
# loading data 1005/7253 ...done
# loading data 1006/7253 ...done
# loading data 1007/7253 ...done
# loading data 1008/7253 ...done
# loading data 1009/7253 ...done
# loading data 1010/7253 ...done
# loading data 1011/7253 ...done
# loading data 1012/7253 ...done
# loading data 1013/7253 ...done
# loading data 1014/7253 ...done
# loading data 1015/7253 ...done
# loading data 1016/7253 ...done
# loading data 1017/7253 ...done
# loading data 1018/7253 ...done
# loading data 1019/7253 ...done
# loading data 1020/7253 ...done
# loading data 1021/7253 ...done
# loading data 1022/7253 ...done
# loading data 1023/7253 ...done
# loading data 1024/7253 ...done
# loading data 1025/7253 ...done
# loading data 1026/7253 ...done
# loading data 1027/7253 ...done
# loading data 1028/7253 ...done
# loading data 1029/7253 ...done
# loading data 1030/7253 ...done
# loading data 1031/7253 ...done
# loading data 1032/7253 ...done
# loading data 1033/7253 ...done
# loading data 1034/7253 ...done
# loading data 1035/7253 ...done
# loading data 1036/7253 ...done
# loading data 1037/7253 ...done
# loading data 1038/7253 ...done
# loading data 1039/7253 ...done
# loading data 1040/7253 ...done
# loading data 1041/7253 ...done
# loading data 1042/7253 ...done
# loading data 1043/7253 ...done
# loading data 1044/7253 ...done
# loading data 1045/7253 ...done
# loading data 1046/7253 ...done
# loading data 1047/7253 ...done
# loading data 1048/7253 ...done
# loading data 1049/7253 ...done
# loading data 1050/7253 ...done
# loading data 1051/7253 ...done
# loading data 1052/7253 ...done
# loading data 1053/7253 ...done
# loading data 1054/7253 ...done
# loading data 1055/7253 ...done
# loading data 1056/7253 ...done
# loading data 1057/7253 ...done
# loading data 1058/7253 ...done
# loading data 1059/7253 ...done
# loading data 1060/7253 ...done
# loading data 1061/7253 ...done
# loading data 1062/7253 ...done
# loading data 1063/7253 ...done
# loading data 1064/7253 ...done
# loading data 1065/7253 ...done
# loading data 1066/7253 ...done
# loading data 1067/7253 ...done
# loading data 1068/7253 ...done
# loading data 1069/7253 ...done
# loading data 1070/7253 ...done
# loading data 1071/7253 ...done
# loading data 1072/7253 ...done
# loading data 1073/7253 ...done
# loading data 1074/7253 ...done
# loading data 1075/7253 ...done
# loading data 1076/7253 ...done
# loading data 1077/7253 ...done
# loading data 1078/7253 ...done
# loading data 1079/7253 ...done
# loading data 1080/7253 ...done
# loading data 1081/7253 ...done
# loading data 1082/7253 ...done
# loading data 1083/7253 ...done
# loading data 1084/7253 ...done
# loading data 1085/7253 ...done
# loading data 1086/7253 ...done
# loading data 1087/7253 ...done
# loading data 1088/7253 ...done
# loading data 1089/7253 ...done
# loading data 1090/7253 ...done
# loading data 1091/7253 ...done
# loading data 1092/7253 ...done
# loading data 1093/7253 ...done
# loading data 1094/7253 ...done
# loading data 1095/7253 ...done
# loading data 1096/7253 ...done
# loading data 1097/7253 ...done
# loading data 1098/7253 ...done
# loading data 1099/7253 ...done
# loading data 1100/7253 ...done
# loading data 1101/7253 ...done
# loading data 1102/7253 ...done
# loading data 1103/7253 ...done
# loading data 1104/7253 ...done
# loading data 1105/7253 ...done
# loading data 1106/7253 ...done
# loading data 1107/7253 ...done
# loading data 1108/7253 ...done
# loading data 1109/7253 ...done
# loading data 1110/7253 ...done
# loading data 1111/7253 ...done
# loading data 1112/7253 ...done
# loading data 1113/7253 ...done
# loading data 1114/7253 ...done
# loading data 1115/7253 ...done
# loading data 1116/7253 ...done
# loading data 1117/7253 ...done
# loading data 1118/7253 ...done
# loading data 1119/7253 ...done
# loading data 1120/7253 ...done
# loading data 1121/7253 ...done
# loading data 1122/7253 ...done
# loading data 1123/7253 ...done
# loading data 1124/7253 ...done
# loading data 1125/7253 ...done
# loading data 1126/7253 ...done
# loading data 1127/7253 ...done
# loading data 1128/7253 ...done
# loading data 1129/7253 ...done
# loading data 1130/7253 ...done
# loading data 1131/7253 ...done
# loading data 1132/7253 ...done
# loading data 1133/7253 ...done
# loading data 1134/7253 ...done
# loading data 1135/7253 ...done
# loading data 1136/7253 ...done
# loading data 1137/7253 ...done
# loading data 1138/7253 ...done
# loading data 1139/7253 ...done
# loading data 1140/7253 ...done
# loading data 1141/7253 ...done
# loading data 1142/7253 ...done
# loading data 1143/7253 ...done
# loading data 1144/7253 ...done
# loading data 1145/7253 ...done
# loading data 1146/7253 ...done
# loading data 1147/7253 ...done
# loading data 1148/7253 ...done
# loading data 1149/7253 ...done
# loading data 1150/7253 ...done
# loading data 1151/7253 ...done
# loading data 1152/7253 ...done
# loading data 1153/7253 ...done
# loading data 1154/7253 ...done
# loading data 1155/7253 ...done
# loading data 1156/7253 ...done
# loading data 1157/7253 ...done
# loading data 1158/7253 ...done
# loading data 1159/7253 ...done
# loading data 1160/7253 ...done
# loading data 1161/7253 ...done
# loading data 1162/7253 ...done
# loading data 1163/7253 ...done
# loading data 1164/7253 ...done
# loading data 1165/7253 ...done
# loading data 1166/7253 ...done
# loading data 1167/7253 ...done
# loading data 1168/7253 ...done
# loading data 1169/7253 ...done
# loading data 1170/7253 ...done
# loading data 1171/7253 ...done
# loading data 1172/7253 ...done
# loading data 1173/7253 ...done
# loading data 1174/7253 ...done
# loading data 1175/7253 ...done
# loading data 1176/7253 ...done
# loading data 1177/7253 ...done
# loading data 1178/7253 ...done
# loading data 1179/7253 ...done
# loading data 1180/7253 ...done
# loading data 1181/7253 ...done
# loading data 1182/7253 ...done
# loading data 1183/7253 ...done
# loading data 1184/7253 ...done
# loading data 1185/7253 ...done
# loading data 1186/7253 ...done
# loading data 1187/7253 ...done
# loading data 1188/7253 ...done
# loading data 1189/7253 ...done
# loading data 1190/7253 ...done
# loading data 1191/7253 ...done
# loading data 1192/7253 ...done
# loading data 1193/7253 ...done
# loading data 1194/7253 ...done
# loading data 1195/7253 ...done
# loading data 1196/7253 ...done
# loading data 1197/7253 ...done
# loading data 1198/7253 ...done
# loading data 1199/7253 ...done
# loading data 1200/7253 ...done
# loading data 1201/7253 ...done
# loading data 1202/7253 ...done
# loading data 1203/7253 ...done
# loading data 1204/7253 ...done
# loading data 1205/7253 ...done
# loading data 1206/7253 ...done
# loading data 1207/7253 ...done
# loading data 1208/7253 ...done
# loading data 1209/7253 ...done
# loading data 1210/7253 ...done
# loading data 1211/7253 ...done
# loading data 1212/7253 ...done
# loading data 1213/7253 ...done
# loading data 1214/7253 ...done
# loading data 1215/7253 ...done
# loading data 1216/7253 ...done
# loading data 1217/7253 ...done
# loading data 1218/7253 ...done
# loading data 1219/7253 ...done
# loading data 1220/7253 ...done
# loading data 1221/7253 ...done
# loading data 1222/7253 ...done
# loading data 1223/7253 ...done
# loading data 1224/7253 ...done
# loading data 1225/7253 ...done
# loading data 1226/7253 ...done
# loading data 1227/7253 ...done
# loading data 1228/7253 ...done
# loading data 1229/7253 ...done
# loading data 1230/7253 ...done
# loading data 1231/7253 ...done
# loading data 1232/7253 ...done
# loading data 1233/7253 ...done
# loading data 1234/7253 ...done
# loading data 1235/7253 ...done
# loading data 1236/7253 ...done
# loading data 1237/7253 ...done
# loading data 1238/7253 ...done
# loading data 1239/7253 ...done
# loading data 1240/7253 ...done
# loading data 1241/7253 ...done
# loading data 1242/7253 ...done
# loading data 1243/7253 ...done
# loading data 1244/7253 ...done
# loading data 1245/7253 ...done
# loading data 1246/7253 ...done
# loading data 1247/7253 ...done
# loading data 1248/7253 ...done
# loading data 1249/7253 ...done
# loading data 1250/7253 ...done
# loading data 1251/7253 ...done
# loading data 1252/7253 ...done
# loading data 1253/7253 ...done
# loading data 1254/7253 ...done
# loading data 1255/7253 ...done
# loading data 1256/7253 ...done
# loading data 1257/7253 ...done
# loading data 1258/7253 ...done
# loading data 1259/7253 ...done
# loading data 1260/7253 ...done
# loading data 1261/7253 ...done
# loading data 1262/7253 ...done
# loading data 1263/7253 ...done
# loading data 1264/7253 ...done
# loading data 1265/7253 ...done
# loading data 1266/7253 ...done
# loading data 1267/7253 ...done
# loading data 1268/7253 ...done
# loading data 1269/7253 ...done
# loading data 1270/7253 ...done
# loading data 1271/7253 ...done
# loading data 1272/7253 ...done
# loading data 1273/7253 ...done
# loading data 1274/7253 ...done
# loading data 1275/7253 ...done
# loading data 1276/7253 ...done
# loading data 1277/7253 ...done
# loading data 1278/7253 ...done
# loading data 1279/7253 ...done
# loading data 1280/7253 ...done
# loading data 1281/7253 ...done
# loading data 1282/7253 ...done
# loading data 1283/7253 ...done
# loading data 1284/7253 ...done
# loading data 1285/7253 ...done
# loading data 1286/7253 ...done
# loading data 1287/7253 ...done
# loading data 1288/7253 ...done
# loading data 1289/7253 ...done
# loading data 1290/7253 ...done
# loading data 1291/7253 ...done
# loading data 1292/7253 ...done
# loading data 1293/7253 ...done
# loading data 1294/7253 ...done
# loading data 1295/7253 ...done
# loading data 1296/7253 ...done
# loading data 1297/7253 ...done
# loading data 1298/7253 ...done
# loading data 1299/7253 ...done
# loading data 1300/7253 ...done
# loading data 1301/7253 ...done
# loading data 1302/7253 ...done
# loading data 1303/7253 ...done
# loading data 1304/7253 ...done
# loading data 1305/7253 ...done
# loading data 1306/7253 ...done
# loading data 1307/7253 ...done
# loading data 1308/7253 ...done
# loading data 1309/7253 ...done
# loading data 1310/7253 ...done
# loading data 1311/7253 ...done
# loading data 1312/7253 ...done
# loading data 1313/7253 ...done
# loading data 1314/7253 ...done
# loading data 1315/7253 ...done
# loading data 1316/7253 ...done
# loading data 1317/7253 ...done
# loading data 1318/7253 ...done
# loading data 1319/7253 ...done
# loading data 1320/7253 ...done
# loading data 1321/7253 ...done
# loading data 1322/7253 ...done
# loading data 1323/7253 ...done
# loading data 1324/7253 ...done
# loading data 1325/7253 ...done
# loading data 1326/7253 ...done
# loading data 1327/7253 ...done
# loading data 1328/7253 ...done
# loading data 1329/7253 ...done
# loading data 1330/7253 ...done
# loading data 1331/7253 ...done
# loading data 1332/7253 ...done
# loading data 1333/7253 ...done
# loading data 1334/7253 ...done
# loading data 1335/7253 ...done
# loading data 1336/7253 ...done
# loading data 1337/7253 ...done
# loading data 1338/7253 ...done
# loading data 1339/7253 ...done
# loading data 1340/7253 ...done
# loading data 1341/7253 ...done
# loading data 1342/7253 ...done
# loading data 1343/7253 ...done
# loading data 1344/7253 ...done
# loading data 1345/7253 ...done
# loading data 1346/7253 ...done
# loading data 1347/7253 ...done
# loading data 1348/7253 ...done
# loading data 1349/7253 ...done
# loading data 1350/7253 ...done
# loading data 1351/7253 ...done
# loading data 1352/7253 ...done
# loading data 1353/7253 ...done
# loading data 1354/7253 ...done
# loading data 1355/7253 ...done
# loading data 1356/7253 ...done
# loading data 1357/7253 ...done
# loading data 1358/7253 ...done
# loading data 1359/7253 ...done
# loading data 1360/7253 ...done
# loading data 1361/7253 ...done
# loading data 1362/7253 ...done
# loading data 1363/7253 ...done
# loading data 1364/7253 ...done
# loading data 1365/7253 ...done
# loading data 1366/7253 ...done
# loading data 1367/7253 ...done
# loading data 1368/7253 ...done
# loading data 1369/7253 ...done
# loading data 1370/7253 ...done
# loading data 1371/7253 ...done
# loading data 1372/7253 ...done
# loading data 1373/7253 ...done
# loading data 1374/7253 ...done
# loading data 1375/7253 ...done
# loading data 1376/7253 ...done
# loading data 1377/7253 ...done
# loading data 1378/7253 ...done
# loading data 1379/7253 ...done
# loading data 1380/7253 ...done
# loading data 1381/7253 ...done
# loading data 1382/7253 ...done
# loading data 1383/7253 ...done
# loading data 1384/7253 ...done
# loading data 1385/7253 ...done
# loading data 1386/7253 ...done
# loading data 1387/7253 ...done
# loading data 1388/7253 ...done
# loading data 1389/7253 ...done
# loading data 1390/7253 ...done
# loading data 1391/7253 ...done
# loading data 1392/7253 ...done
# loading data 1393/7253 ...done
# loading data 1394/7253 ...done
# loading data 1395/7253 ...done
# loading data 1396/7253 ...done
# loading data 1397/7253 ...done
# loading data 1398/7253 ...done
# loading data 1399/7253 ...done
# loading data 1400/7253 ...done
# loading data 1401/7253 ...done
# loading data 1402/7253 ...done
# loading data 1403/7253 ...done
# loading data 1404/7253 ...done
# loading data 1405/7253 ...done
# loading data 1406/7253 ...done
# loading data 1407/7253 ...done
# loading data 1408/7253 ...done
# loading data 1409/7253 ...done
# loading data 1410/7253 ...done
# loading data 1411/7253 ...done
# loading data 1412/7253 ...done
# loading data 1413/7253 ...done
# loading data 1414/7253 ...done
# loading data 1415/7253 ...done
# loading data 1416/7253 ...done
# loading data 1417/7253 ...done
# loading data 1418/7253 ...done
# loading data 1419/7253 ...done
# loading data 1420/7253 ...done
# loading data 1421/7253 ...done
# loading data 1422/7253 ...done
# loading data 1423/7253 ...done
# loading data 1424/7253 ...done
# loading data 1425/7253 ...done
# loading data 1426/7253 ...done
# loading data 1427/7253 ...done
# loading data 1428/7253 ...done
# loading data 1429/7253 ...done
# loading data 1430/7253 ...done
# loading data 1431/7253 ...done
# loading data 1432/7253 ...done
# loading data 1433/7253 ...done
# loading data 1434/7253 ...done
# loading data 1435/7253 ...done
# loading data 1436/7253 ...done
# loading data 1437/7253 ...done
# loading data 1438/7253 ...done
# loading data 1439/7253 ...done
# loading data 1440/7253 ...done
# loading data 1441/7253 ...done
# loading data 1442/7253 ...done
# loading data 1443/7253 ...done
# loading data 1444/7253 ...done
# loading data 1445/7253 ...done
# loading data 1446/7253 ...done
# loading data 1447/7253 ...done
# loading data 1448/7253 ...done
# loading data 1449/7253 ...done
# loading data 1450/7253 ...done
# loading data 1451/7253 ...done
# loading data 1452/7253 ...done
# loading data 1453/7253 ...done
# loading data 1454/7253 ...done
# loading data 1455/7253 ...done
# loading data 1456/7253 ...done
# loading data 1457/7253 ...done
# loading data 1458/7253 ...done
# loading data 1459/7253 ...done
# loading data 1460/7253 ...done
# loading data 1461/7253 ...done
# loading data 1462/7253 ...done
# loading data 1463/7253 ...done
# loading data 1464/7253 ...done
# loading data 1465/7253 ...done
# loading data 1466/7253 ...done
# loading data 1467/7253 ...done
# loading data 1468/7253 ...done
# loading data 1469/7253 ...done
# loading data 1470/7253 ...done
# loading data 1471/7253 ...done
# loading data 1472/7253 ...done
# loading data 1473/7253 ...done
# loading data 1474/7253 ...done
# loading data 1475/7253 ...done
# loading data 1476/7253 ...done
# loading data 1477/7253 ...done
# loading data 1478/7253 ...done
# loading data 1479/7253 ...done
# loading data 1480/7253 ...done
# loading data 1481/7253 ...done
# loading data 1482/7253 ...done
# loading data 1483/7253 ...done
# loading data 1484/7253 ...done
# loading data 1485/7253 ...done
# loading data 1486/7253 ...done
# loading data 1487/7253 ...done
# loading data 1488/7253 ...done
# loading data 1489/7253 ...done
# loading data 1490/7253 ...done
# loading data 1491/7253 ...done
# loading data 1492/7253 ...done
# loading data 1493/7253 ...done
# loading data 1494/7253 ...done
# loading data 1495/7253 ...done
# loading data 1496/7253 ...done
# loading data 1497/7253 ...done
# loading data 1498/7253 ...done
# loading data 1499/7253 ...done
# loading data 1500/7253 ...done
# loading data 1501/7253 ...done
# loading data 1502/7253 ...done
# loading data 1503/7253 ...done
# loading data 1504/7253 ...done
# loading data 1505/7253 ...done
# loading data 1506/7253 ...done
# loading data 1507/7253 ...done
# loading data 1508/7253 ...done
# loading data 1509/7253 ...done
# loading data 1510/7253 ...done
# loading data 1511/7253 ...done
# loading data 1512/7253 ...done
# loading data 1513/7253 ...done
# loading data 1514/7253 ...done
# loading data 1515/7253 ...done
# loading data 1516/7253 ...done
# loading data 1517/7253 ...done
# loading data 1518/7253 ...done
# loading data 1519/7253 ...done
# loading data 1520/7253 ...done
# loading data 1521/7253 ...done
# loading data 1522/7253 ...done
# loading data 1523/7253 ...done
# loading data 1524/7253 ...done
# loading data 1525/7253 ...done
# loading data 1526/7253 ...done
# loading data 1527/7253 ...done
# loading data 1528/7253 ...done
# loading data 1529/7253 ...done
# loading data 1530/7253 ...done
# loading data 1531/7253 ...done
# loading data 1532/7253 ...done
# loading data 1533/7253 ...done
# loading data 1534/7253 ...done
# loading data 1535/7253 ...done
# loading data 1536/7253 ...done
# loading data 1537/7253 ...done
# loading data 1538/7253 ...done
# loading data 1539/7253 ...done
# loading data 1540/7253 ...done
# loading data 1541/7253 ...done
# loading data 1542/7253 ...done
# loading data 1543/7253 ...done
# loading data 1544/7253 ...done
# loading data 1545/7253 ...done
# loading data 1546/7253 ...done
# loading data 1547/7253 ...done
# loading data 1548/7253 ...done
# loading data 1549/7253 ...done
# loading data 1550/7253 ...done
# loading data 1551/7253 ...done
# loading data 1552/7253 ...done
# loading data 1553/7253 ...done
# loading data 1554/7253 ...done
# loading data 1555/7253 ...done
# loading data 1556/7253 ...done
# loading data 1557/7253 ...done
# loading data 1558/7253 ...done
# loading data 1559/7253 ...done
# loading data 1560/7253 ...done
# loading data 1561/7253 ...done
# loading data 1562/7253 ...done
# loading data 1563/7253 ...done
# loading data 1564/7253 ...done
# loading data 1565/7253 ...done
# loading data 1566/7253 ...done
# loading data 1567/7253 ...done
# loading data 1568/7253 ...done
# loading data 1569/7253 ...done
# loading data 1570/7253 ...done
# loading data 1571/7253 ...done
# loading data 1572/7253 ...done
# loading data 1573/7253 ...done
# loading data 1574/7253 ...done
# loading data 1575/7253 ...done
# loading data 1576/7253 ...done
# loading data 1577/7253 ...done
# loading data 1578/7253 ...done
# loading data 1579/7253 ...done
# loading data 1580/7253 ...done
# loading data 1581/7253 ...done
# loading data 1582/7253 ...done
# loading data 1583/7253 ...done
# loading data 1584/7253 ...done
# ...
# loading data 6742/7253 ...done
# loading data 6743/7253 ...done
# loading data 6744/7253 ...done
# loading data 6745/7253 ...done
# loading data 6746/7253 ...done
# loading data 6747/7253 ...done
# loading data 6748/7253 ...done
# loading data 6749/7253 ...done
# loading data 6750/7253 ...done
# loading data 6751/7253 ...done
# loading data 6752/7253 ...done
# loading data 6753/7253 ...done
# loading data 6754/7253 ...done
# loading data 6755/7253 ...done
# loading data 6756/7253 ...done
# loading data 6757/7253 ...done
# loading data 6758/7253 ...done
# loading data 6759/7253 ...done
# loading data 6760/7253 ...done
# loading data 6761/7253 ...done
# loading data 6762/7253 ...done
# loading data 6763/7253 ...done
# loading data 6764/7253 ...done
# loading data 6765/7253 ...done
# loading data 6766/7253 ...done
# loading data 6767/7253 ...done
# loading data 6768/7253 ...done
# loading data 6769/7253 ...done
# loading data 6770/7253 ...done
# loading data 6771/7253 ...done
# loading data 6772/7253 ...done
# loading data 6773/7253 ...done
# loading data 6774/7253 ...done
# loading data 6775/7253 ...done
# loading data 6776/7253 ...done
# loading data 6777/7253 ...done
# loading data 6778/7253 ...done
# loading data 6779/7253 ...done
# loading data 6780/7253 ...done
# loading data 6781/7253 ...done
# loading data 6782/7253 ...done
# loading data 6783/7253 ...done
# loading data 6784/7253 ...done
# loading data 6785/7253 ...done
# loading data 6786/7253 ...done
# loading data 6787/7253 ...done
# loading data 6788/7253 ...done
# loading data 6789/7253 ...done
# loading data 6790/7253 ...done
# loading data 6791/7253 ...done
# loading data 6792/7253 ...done
# loading data 6793/7253 ...done
# loading data 6794/7253 ...done
# loading data 6795/7253 ...done
# loading data 6796/7253 ...done
# loading data 6797/7253 ...done
# loading data 6798/7253 ...done
# loading data 6799/7253 ...done
# loading data 6800/7253 ...done
# loading data 6801/7253 ...done
# loading data 6802/7253 ...done
# loading data 6803/7253 ...done
# loading data 6804/7253 ...done
# loading data 6805/7253 ...done
# loading data 6806/7253 ...done
# loading data 6807/7253 ...done
# loading data 6808/7253 ...done
# loading data 6809/7253 ...done
# loading data 6810/7253 ...done
# loading data 6811/7253 ...done
# loading data 6812/7253 ...done
# loading data 6813/7253 ...done
# loading data 6814/7253 ...done
# loading data 6815/7253 ...done
# loading data 6816/7253 ...done
# loading data 6817/7253 ...done
# loading data 6818/7253 ...done
# loading data 6819/7253 ...done
# loading data 6820/7253 ...done
# loading data 6821/7253 ...done
# loading data 6822/7253 ...done
# loading data 6823/7253 ...done
# loading data 6824/7253 ...done
# loading data 6825/7253 ...done
# loading data 6826/7253 ...done
# loading data 6827/7253 ...done
# loading data 6828/7253 ...done
# loading data 6829/7253 ...done
# loading data 6830/7253 ...done
# loading data 6831/7253 ...done
# loading data 6832/7253 ...done
# loading data 6833/7253 ...done
# loading data 6834/7253 ...done
# loading data 6835/7253 ...done
# loading data 6836/7253 ...done
# loading data 6837/7253 ...done
# loading data 6838/7253 ...done
# loading data 6839/7253 ...done
# loading data 6840/7253 ...done
# loading data 6841/7253 ...done
# loading data 6842/7253 ...done
# loading data 6843/7253 ...done
# loading data 6844/7253 ...done
# loading data 6845/7253 ...done
# loading data 6846/7253 ...done
# loading data 6847/7253 ...done
# loading data 6848/7253 ...done
# loading data 6849/7253 ...done
# loading data 6850/7253 ...done
# loading data 6851/7253 ...done
# loading data 6852/7253 ...done
# loading data 6853/7253 ...done
# loading data 6854/7253 ...done
# loading data 6855/7253 ...done
# loading data 6856/7253 ...done
# loading data 6857/7253 ...done
# loading data 6858/7253 ...done
# loading data 6859/7253 ...done
# loading data 6860/7253 ...done
# loading data 6861/7253 ...done
# loading data 6862/7253 ...done
# loading data 6863/7253 ...done
# loading data 6864/7253 ...done
# loading data 6865/7253 ...done
# loading data 6866/7253 ...done
# loading data 6867/7253 ...done
# loading data 6868/7253 ...done
# loading data 6869/7253 ...done
# loading data 6870/7253 ...done
# loading data 6871/7253 ...done
# loading data 6872/7253 ...done
# loading data 6873/7253 ...done
# loading data 6874/7253 ...done
# loading data 6875/7253 ...done
# loading data 6876/7253 ...done
# loading data 6877/7253 ...done
# loading data 6878/7253 ...done
# loading data 6879/7253 ...done
# loading data 6880/7253 ...done
# loading data 6881/7253 ...done
# loading data 6882/7253 ...done
# loading data 6883/7253 ...done
# loading data 6884/7253 ...done
# loading data 6885/7253 ...done
# loading data 6886/7253 ...done
# loading data 6887/7253 ...done
# loading data 6888/7253 ...done
# loading data 6889/7253 ...done
# loading data 6890/7253 ...done
# loading data 6891/7253 ...done
# loading data 6892/7253 ...done
# loading data 6893/7253 ...done
# loading data 6894/7253 ...done
# loading data 6895/7253 ...done
# loading data 6896/7253 ...done
# loading data 6897/7253 ...done
# loading data 6898/7253 ...done
# loading data 6899/7253 ...done
# loading data 6900/7253 ...done
# loading data 6901/7253 ...done
# loading data 6902/7253 ...done
# loading data 6903/7253 ...done
# loading data 6904/7253 ...done
# loading data 6905/7253 ...done
# loading data 6906/7253 ...done
# loading data 6907/7253 ...done
# loading data 6908/7253 ...done
# loading data 6909/7253 ...done
# loading data 6910/7253 ...done
# loading data 6911/7253 ...done
# loading data 6912/7253 ...done
# loading data 6913/7253 ...done
# loading data 6914/7253 ...done
# loading data 6915/7253 ...done
# loading data 6916/7253 ...done
# loading data 6917/7253 ...done
# loading data 6918/7253 ...done
# loading data 6919/7253 ...done
# loading data 6920/7253 ...done
# loading data 6921/7253 ...done
# loading data 6922/7253 ...done
# loading data 6923/7253 ...done
# loading data 6924/7253 ...done
# loading data 6925/7253 ...done
# loading data 6926/7253 ...done
# loading data 6927/7253 ...done
# loading data 6928/7253 ...done
# loading data 6929/7253 ...done
# loading data 6930/7253 ...done
# loading data 6931/7253 ...done
# loading data 6932/7253 ...done
# loading data 6933/7253 ...done
# loading data 6934/7253 ...done
# loading data 6935/7253 ...done
# loading data 6936/7253 ...done
# loading data 6937/7253 ...done
# loading data 6938/7253 ...done
# loading data 6939/7253 ...done
# loading data 6940/7253 ...done
# loading data 6941/7253 ...done
# loading data 6942/7253 ...done
# loading data 6943/7253 ...done
# loading data 6944/7253 ...done
# loading data 6945/7253 ...done
# loading data 6946/7253 ...done
# loading data 6947/7253 ...done
# loading data 6948/7253 ...done
# loading data 6949/7253 ...done
# loading data 6950/7253 ...done
# loading data 6951/7253 ...done
# loading data 6952/7253 ...done
# loading data 6953/7253 ...done
# loading data 6954/7253 ...done
# loading data 6955/7253 ...done
# loading data 6956/7253 ...done
# loading data 6957/7253 ...done
# loading data 6958/7253 ...done
# loading data 6959/7253 ...done
# loading data 6960/7253 ...done
# loading data 6961/7253 ...done
# loading data 6962/7253 ...done
# loading data 6963/7253 ...done
# loading data 6964/7253 ...done
# loading data 6965/7253 ...done
# loading data 6966/7253 ...done
# loading data 6967/7253 ...done
# loading data 6968/7253 ...done
# loading data 6969/7253 ...done
# loading data 6970/7253 ...done
# loading data 6971/7253 ...done
# loading data 6972/7253 ...done
# loading data 6973/7253 ...done
# loading data 6974/7253 ...done
# loading data 6975/7253 ...done
# loading data 6976/7253 ...done
# loading data 6977/7253 ...done
# loading data 6978/7253 ...done
# loading data 6979/7253 ...done
# loading data 6980/7253 ...done
# loading data 6981/7253 ...done
# loading data 6982/7253 ...done
# loading data 6983/7253 ...done
# loading data 6984/7253 ...done
# loading data 6985/7253 ...done
# loading data 6986/7253 ...done
# loading data 6987/7253 ...done
# loading data 6988/7253 ...done
# loading data 6989/7253 ...done
# loading data 6990/7253 ...done
# loading data 6991/7253 ...done
# loading data 6992/7253 ...done
# loading data 6993/7253 ...done
# loading data 6994/7253 ...done
# loading data 6995/7253 ...done
# loading data 6996/7253 ...done
# loading data 6997/7253 ...done
# loading data 6998/7253 ...done
# loading data 6999/7253 ...done
# loading data 7000/7253 ...done
# loading data 7001/7253 ...done
# loading data 7002/7253 ...done
# loading data 7003/7253 ...done
# loading data 7004/7253 ...done
# loading data 7005/7253 ...done
# loading data 7006/7253 ...done
# loading data 7007/7253 ...done
# loading data 7008/7253 ...done
# loading data 7009/7253 ...done
# loading data 7010/7253 ...done
# loading data 7011/7253 ...done
# loading data 7012/7253 ...done
# loading data 7013/7253 ...done
# loading data 7014/7253 ...done
# loading data 7015/7253 ...done
# loading data 7016/7253 ...done
# loading data 7017/7253 ...done
# loading data 7018/7253 ...done
# loading data 7019/7253 ...done
# loading data 7020/7253 ...done
# loading data 7021/7253 ...done
# loading data 7022/7253 ...done
# loading data 7023/7253 ...done
# loading data 7024/7253 ...done
# loading data 7025/7253 ...done
# loading data 7026/7253 ...done
# loading data 7027/7253 ...done
# loading data 7028/7253 ...done
# loading data 7029/7253 ...done
# loading data 7030/7253 ...done
# loading data 7031/7253 ...done
# loading data 7032/7253 ...done
# loading data 7033/7253 ...done
# loading data 7034/7253 ...done
# loading data 7035/7253 ...done
# loading data 7036/7253 ...done
# loading data 7037/7253 ...done
# loading data 7038/7253 ...done
# loading data 7039/7253 ...done
# loading data 7040/7253 ...done
# loading data 7041/7253 ...done
# loading data 7042/7253 ...done
# loading data 7043/7253 ...done
# loading data 7044/7253 ...done
# loading data 7045/7253 ...done
# loading data 7046/7253 ...done
# loading data 7047/7253 ...done
# loading data 7048/7253 ...done
# loading data 7049/7253 ...done
# loading data 7050/7253 ...done
# loading data 7051/7253 ...done
# loading data 7052/7253 ...done
# loading data 7053/7253 ...done
# loading data 7054/7253 ...done
# loading data 7055/7253 ...done
# loading data 7056/7253 ...done
# loading data 7057/7253 ...done
# loading data 7058/7253 ...done
# loading data 7059/7253 ...done
# loading data 7060/7253 ...done
# loading data 7061/7253 ...done
# loading data 7062/7253 ...done
# loading data 7063/7253 ...done
# loading data 7064/7253 ...done
# loading data 7065/7253 ...done
# loading data 7066/7253 ...done
# loading data 7067/7253 ...done
# loading data 7068/7253 ...done
# loading data 7069/7253 ...done
# loading data 7070/7253 ...done
# loading data 7071/7253 ...done
# loading data 7072/7253 ...done
# loading data 7073/7253 ...done
# loading data 7074/7253 ...done
# loading data 7075/7253 ...done
# loading data 7076/7253 ...done
# loading data 7077/7253 ...done
# loading data 7078/7253 ...done
# loading data 7079/7253 ...done
# loading data 7080/7253 ...done
# loading data 7081/7253 ...done
# loading data 7082/7253 ...done
# loading data 7083/7253 ...done
# loading data 7084/7253 ...done
# loading data 7085/7253 ...done
# loading data 7086/7253 ...done
# loading data 7087/7253 ...done
# loading data 7088/7253 ...done
# loading data 7089/7253 ...done
# loading data 7090/7253 ...done
# loading data 7091/7253 ...done
# loading data 7092/7253 ...done
# loading data 7093/7253 ...done
# loading data 7094/7253 ...done
# loading data 7095/7253 ...done
# loading data 7096/7253 ...done
# loading data 7097/7253 ...done
# loading data 7098/7253 ...done
# loading data 7099/7253 ...done
# loading data 7100/7253 ...done
# loading data 7101/7253 ...done
# loading data 7102/7253 ...done
# loading data 7103/7253 ...done
# loading data 7104/7253 ...done
# loading data 7105/7253 ...done
# loading data 7106/7253 ...done
# loading data 7107/7253 ...done
# loading data 7108/7253 ...done
# loading data 7109/7253 ...done
# loading data 7110/7253 ...done
# loading data 7111/7253 ...done
# loading data 7112/7253 ...done
# loading data 7113/7253 ...done
# loading data 7114/7253 ...done
# loading data 7115/7253 ...done
# loading data 7116/7253 ...done
# loading data 7117/7253 ...done
# loading data 7118/7253 ...done
# loading data 7119/7253 ...done
# loading data 7120/7253 ...done
# loading data 7121/7253 ...done
# loading data 7122/7253 ...done
# loading data 7123/7253 ...done
# loading data 7124/7253 ...done
# loading data 7125/7253 ...done
# loading data 7126/7253 ...done
# loading data 7127/7253 ...done
# loading data 7128/7253 ...done
# loading data 7129/7253 ...done
# loading data 7130/7253 ...done
# loading data 7131/7253 ...done
# loading data 7132/7253 ...done
# loading data 7133/7253 ...done
# loading data 7134/7253 ...done
# loading data 7135/7253 ...done
# loading data 7136/7253 ...done
# loading data 7137/7253 ...done
# loading data 7138/7253 ...done
# loading data 7139/7253 ...done
# loading data 7140/7253 ...done
# loading data 7141/7253 ...done
# loading data 7142/7253 ...done
# loading data 7143/7253 ...done
# loading data 7144/7253 ...done
# loading data 7145/7253 ...done
# loading data 7146/7253 ...done
# loading data 7147/7253 ...done
# loading data 7148/7253 ...done
# loading data 7149/7253 ...done
# loading data 7150/7253 ...done
# loading data 7151/7253 ...done
# loading data 7152/7253 ...done
# loading data 7153/7253 ...done
# loading data 7154/7253 ...done
# loading data 7155/7253 ...done
# loading data 7156/7253 ...done
# loading data 7157/7253 ...done
# loading data 7158/7253 ...done
# loading data 7159/7253 ...done
# loading data 7160/7253 ...done
# loading data 7161/7253 ...done
# loading data 7162/7253 ...done
# loading data 7163/7253 ...done
# loading data 7164/7253 ...done
# loading data 7165/7253 ...done
# loading data 7166/7253 ...done
# loading data 7167/7253 ...done
# loading data 7168/7253 ...done
# loading data 7169/7253 ...done
# loading data 7170/7253 ...done
# loading data 7171/7253 ...done
# loading data 7172/7253 ...done
# loading data 7173/7253 ...done
# loading data 7174/7253 ...done
# loading data 7175/7253 ...done
# loading data 7176/7253 ...done
# loading data 7177/7253 ...done
# loading data 7178/7253 ...done
# loading data 7179/7253 ...done
# loading data 7180/7253 ...done
# loading data 7181/7253 ...done
# loading data 7182/7253 ...done
# loading data 7183/7253 ...done
# loading data 7184/7253 ...done
# loading data 7185/7253 ...done
# loading data 7186/7253 ...done
# loading data 7187/7253 ...done
# loading data 7188/7253 ...done
# loading data 7189/7253 ...done
# loading data 7190/7253 ...done
# loading data 7191/7253 ...done
# loading data 7192/7253 ...done
# loading data 7193/7253 ...done
# loading data 7194/7253 ...done
# loading data 7195/7253 ...done
# loading data 7196/7253 ...done
# loading data 7197/7253 ...done
# loading data 7198/7253 ...done
# loading data 7199/7253 ...done
# loading data 7200/7253 ...done
# loading data 7201/7253 ...done
# loading data 7202/7253 ...done
# loading data 7203/7253 ...done
# loading data 7204/7253 ...done
# loading data 7205/7253 ...done
# loading data 7206/7253 ...done
# loading data 7207/7253 ...done
# loading data 7208/7253 ...done
# loading data 7209/7253 ...done
# loading data 7210/7253 ...done
# loading data 7211/7253 ...done
# loading data 7212/7253 ...done
# loading data 7213/7253 ...done
# loading data 7214/7253 ...done
# loading data 7215/7253 ...done
# loading data 7216/7253 ...done
# loading data 7217/7253 ...done
# loading data 7218/7253 ...done
# loading data 7219/7253 ...done
# loading data 7220/7253 ...done
# loading data 7221/7253 ...done
# loading data 7222/7253 ...done
# loading data 7223/7253 ...done
# loading data 7224/7253 ...done
# loading data 7225/7253 ...done
# loading data 7226/7253 ...done
# loading data 7227/7253 ...done
# loading data 7228/7253 ...done
# loading data 7229/7253 ...done
# loading data 7230/7253 ...done
# loading data 7231/7253 ...done
# loading data 7232/7253 ...done
# loading data 7233/7253 ...done
# loading data 7234/7253 ...done
# loading data 7235/7253 ...done
# loading data 7236/7253 ...done
# loading data 7237/7253 ...done
# loading data 7238/7253 ...done
# loading data 7239/7253 ...done
# loading data 7240/7253 ...done
# loading data 7241/7253 ...done
# loading data 7242/7253 ...done
# loading data 7243/7253 ...done
# loading data 7244/7253 ...done
# loading data 7245/7253 ...done
# loading data 7246/7253 ...done
# loading data 7247/7253 ...done
# loading data 7248/7253 ...done
# loading data 7249/7253 ...done
# loading data 7250/7253 ...done
# loading data 7251/7253 ...done
# loading data 7252/7253 ...done
# loading data 7253/7253 ...done
# size of training set(pacu): 63213
# size of validation set(pacu): 6894
# size of test set(pacu): 7494

# %%
df_preprocess_pacu
# Out:
#       level_0  index                     caseids  NRS  \
# 0           0      0   PACU1_2_190503_132609.csv  3.0
# 1           2      2  PACU1_12_200604_165543.csv  3.0
# 2           3      3  PACU1_12_200528_152944.csv  6.0
# 3           4      4  PACU1_12_201008_143103.csv  3.0
# 4           5      5  PACU1_12_200109_150545.csv  6.0
# ...       ...    ...                         ...  ...
# 7248     8288   8312   PACU1_3_200219_150005.csv  4.0
# 7249     8290   8314   PACU1_3_190723_083248.csv  6.0
# 7250     8291   8315   PACU1_3_200103_003134.csv  3.0
# 7251     8292   8316   PACU1_4_200317_113143.csv  7.0
# 7252     8293   8317   PACU1_7_200311_091556.csv  5.0
#
#                                 file_path      1      2      3      4      5  \
# 0       3.0,249,PACU1_2_190503_132609.csv  False  False  False  False  False
# 1     3.0,5650,PACU1_12_200604_165543.csv   True   True   True   True   True
# 2     6.0,5450,PACU1_12_200528_152944.csv  False  False  False  False  False
# 3     3.0,7909,PACU1_12_201008_143103.csv   True   True   True   True   True
# 4     6.0,2882,PACU1_12_200109_150545.csv  False  False  False  False  False
# ...                                   ...    ...    ...    ...    ...    ...
# 7248   4.0,3860,PACU1_3_200219_150005.csv   True   True   True   True   True
# 7249   6.0,1424,PACU1_3_190723_083248.csv   True   True   True   True   True
# 7250   3.0,2732,PACU1_3_200103_003134.csv  False  False  False  False  False
# 7251   7.0,4548,PACU1_4_200317_113143.csv  False  False  False  False  False
# 7252   5.0,4423,PACU1_7_200311_091556.csv  False  False  False  False  False
#
#       ...     44     45     46     47     48     49     50     51   age gender
# 0     ...  False  False  False  False  False  False  False  False  39.0      F
# 1     ...   True   True   True   True   True   True   True   True  51.0      M
# 2     ...  False  False  False  False  False  False  False  False  52.0      M
# 3     ...   True   True   True   True   True   True   True   True  41.0      F
# 4     ...  False  False  False  False  False  False  False  False  32.0      M
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...   ...    ...
# 7248  ...   True   True  False   True   True   True   True   True  60.0      F
# 7249  ...  False  False  False  False  False  False  False  False  24.0      M
# 7250  ...  False  False  False  False  False  False  False  False  26.0      M
# 7251  ...   True   True   True   True   True   True   True   True  64.0      F
# 7252  ...  False  False  False  False  False  False  False  False  35.0      F
#
# [7253 rows x 58 columns]

# %% [markdown]
# ## prepreocessing4/welch3
# - preprocess4/welch3: ECG 250Hz PPG 250Hz, window size 512/250s, stride 0.1s ->

# %% [markdown]
# ### preop

# %%
import numpy as np
import pandas as pd
import os, pickle, sys
from scipy import signal
from scipy.signal import windows



### input 설정
SRATE = 250 # 250Hz
LEN_INPUT = 20 # input 10s
LEN_PER_NRS = 60 # vital length for each NRS
OVERLAP = 2
n_aug = int((LEN_PER_NRS-LEN_INPUT)/OVERLAP) + 1 # data augmentation 개수

non_preop_list = []


input_path = 'dataset/preprocess4/welch3/'
if not os.path.exists(input_path[:-1]):
    os.mkdir(input_path[:-1])


if True:
    false_row_list_preop = []
    
    preop_ecg_path = "../../cranberry2/Preprocessing/vital_data/ECG_250Hz_preop_2min/"
    vital_path = '../../cranberry2/Preprocessing/vital_data/PPG_100Hz_ECG_100Hz_preop_2min/'
    df_preprocess_preop = pickle.load(open('cache/preprocess3/input3/df_preprocess_preop_agender','rb'))
    

    ### test set에 해당하는 file_path
    caseid_test = pickle.load(open('caseid_test_new', 'rb'))
    caseid_train = pickle.load(open('caseid_train_new', 'rb'))
    caseid_val = pickle.load(open('caseid_val_new', 'rb'))
    

    train_mask, val_mask, test_mask = [], [], []
    x_train_preop, y_train_preop = [], []
    x_test_preop, y_test_preop = [], []
    x_val_preop,y_val_preop = [], []

    cnt = 0
    for _, row in df_preprocess_preop.iterrows():
        cnt += 1
        print('loading data {}/{} ...'.format(cnt, len(df_preprocess_preop)), end='')

        # vital data - PPG (resampling 100 Hz to 250 Hz)
        df_vital = pickle.load(open(vital_path+row['file_path'], 'rb')).reset_index()
        pleth_samp = df_vital[['Pleth']].fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()
        pleth_resamp = signal.resample(pleth_samp, 120*SRATE)
        ppg_per_NRS = np.full(30000, np.nan)
        ppg_per_NRS[0:len(pleth_resamp)] = pleth_resamp
        ppg_per_NRS = pd.DataFrame(ppg_per_NRS).fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()
        
        
        # vital data - ECG (250Hz)       
        try:
            ecg_samp = pickle.load(open(preop_ecg_path+row['file_path'].split(',')[2], 'rb'))
            
        except:
            non_preop_list.append(row['file_path'])
            print('no preop data')
            continue
        else:
            ecg_samp = pd.DataFrame(ecg_samp).fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()[0:30000]       
            ecg_per_NRS = np.full(30000,np.nan)
            ecg_per_NRS[0:len(ecg_samp)] = ecg_samp
            ecg_per_NRS = pd.DataFrame(ecg_per_NRS).fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()
            
            # 한 NRS에 대해 23개의 input 확인
            for i in range(30,51):
                # input이 전처리 통과한 경우
                if row[str(i+1)]:
                    start_idx = i*OVERLAP*SRATE # 500i
                    end_idx = (i*OVERLAP+LEN_INPUT)*SRATE # 500i + 1000


                    # input의 normalization
                    ppg_inp = ppg_per_NRS[start_idx:end_idx]
                    #if np.sum(np.isnan(pleth_inp)) != 0:
                        #pleth_inp = (pd.DataFrame(pleth_inp)).fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()
                    
                    #pleth_inp = pleth_inp - np.nanmean(pleth_inp)

                    ecg_inp = ecg_per_NRS[start_idx:end_idx]
                    #ecg_inp = (ecg_inp - np.nanmean(ecg_inp)) / np.nanstd(ecg_inp)


                    switch = False
                    welch_ppg, welch_ecg = [], []
                    # 1024/250 의 window size로 1초 간격으로 fft
                    stride = 0.1 # 1초
                    fft_window_size = 512  # 약 512/250 = 2초
                    n_window = int((LEN_INPUT-fft_window_size/SRATE)/stride) + 1
                    for j in range(n_window):

                        # welch 작업 - hann window를 씌워주고 fft 적용
                        ppg1 = ppg_inp[int(j*SRATE*stride):int(j*SRATE*stride) + fft_window_size]
                        ecg1 = ecg_inp[int(j*SRATE*stride):int(j*SRATE*stride) + fft_window_size]
                        if np.sum(np.isnan(ppg1))!=0 or np.sum(np.isnan(ecg1))!=0:
                            switch = True
                            continue

                        #ppg1 = pd.DataFrame(ppg1).fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.faltten()
                        ppg2 = ppg1 - np.mean(ppg1)
                        fft_p = np.fft.fft(ppg2 * windows.hann(fft_window_size))
                        fft_p = fft_p[:fft_window_size // 2]
                        fft_p = np.reshape(fft_p, (-1, 2)).sum(axis=-1)
                        fft_p *= fft_p.conj()

                        ecg2 = (ecg1 - np.mean(ecg1)) / np.std(ecg1)
                        fft_e = np.fft.fft(ecg2 * windows.hann(fft_window_size))
                        fft_e = fft_e[:fft_window_size // 2]
                        fft_e = np.reshape(fft_e, (-1, 2)).sum(axis=-1)
                        fft_e *= fft_e.conj()

                        welch_ppg.append(fft_p)
                        welch_ecg.append(fft_e)


                    # 해당 caseid가 test set에 속하는 경우
                    if row['caseids'] in caseid_test:
                        if switch:
                            test_mask.append(False)
                            continue
                        test_mask.append(True)                    
                        x_test_preop.append([welch_ppg, welch_ecg])
                        y_test_preop.append(int(float(row['NRS'])))

                    # 해당 caseid가 train set에 해당하는 경우
                    elif row['caseids'] in caseid_val:
                        if switch:
                            val_mask.append(False)
                            continue
                        val_mask.append(True)                      
                        x_val_preop.append([welch_ppg, welch_ecg])
                        y_val_preop.append(int(float(row['NRS'])))

                    elif row['caseids'] in caseid_train:
                        if switch:
                            train_mask.append(False)
                            continue
                        train_mask.append(True)                      
                        x_train_preop.append([welch_ppg, welch_ecg])
                        y_train_preop.append(int(float(row['NRS'])))
                    
        print('completed')

    x_train_preop = np.array(x_train_preop, np.float32)
    x_test_preop = np.array(x_test_preop, np.float32)
    x_val_preop = np.array(x_val_preop, np.float32)
    y_train_preop = np.array(y_train_preop, int)
    y_test_preop = np.array(y_test_preop, int)
    y_val_preop = np.array(y_val_preop, int)

    
        
    # 저장하기
    print('saving...', end='', flush=True)
    np.savez_compressed(input_path+'x_train_preop.npz', x_train_preop)
    np.savez_compressed(input_path+'x_test_preop.npz', x_test_preop)
    np.savez_compressed(input_path+'x_val_preop.npz', x_val_preop)
    np.savez_compressed(input_path+'y_train_preop.npz', y_train_preop)
    np.savez_compressed(input_path+'y_test_preop.npz', y_test_preop)
    np.savez_compressed(input_path+'y_val_preop.npz', y_val_preop)
    print('done', flush=True)

    
    
    
print('size of training set(preop):', len(x_train_preop))
print('size of validation set(preop):', len(x_val_preop))
print('size of test set(preop):', len(x_test_preop))


import pickle


pickle.dump(test_mask, open(input_path+'test_mask_preop','wb'))
pickle.dump(train_mask, open(input_path+'train_mask_preop','wb'))
pickle.dump(val_mask, open(input_path+'val_mask_preop','wb'))
# Out:
# loading data 1/3861 ...completed
# loading data 2/3861 ...completed
# loading data 3/3861 ...completed
# loading data 4/3861 ...completed
# loading data 5/3861 ...completed
# loading data 6/3861 ...completed
# loading data 7/3861 ...completed
# loading data 8/3861 ...completed
# loading data 9/3861 ...completed
# loading data 10/3861 ...completed
# loading data 11/3861 ...completed
# loading data 12/3861 ...completed
# loading data 13/3861 ...completed
# loading data 14/3861 ...completed
# loading data 15/3861 ...completed
# loading data 16/3861 ...completed
# loading data 17/3861 ...completed
# loading data 18/3861 ...completed
# loading data 19/3861 ...completed
# loading data 20/3861 ...completed
# loading data 21/3861 ...completed
# loading data 22/3861 ...completed
# loading data 23/3861 ...completed
# loading data 24/3861 ...completed
# loading data 25/3861 ...completed
# loading data 26/3861 ...completed
# loading data 27/3861 ...completed
# loading data 28/3861 ...completed
# loading data 29/3861 ...completed
# loading data 30/3861 ...completed
# loading data 31/3861 ...completed
# loading data 32/3861 ...completed
# loading data 33/3861 ...completed
# loading data 34/3861 ...completed
# loading data 35/3861 ...completed
# loading data 36/3861 ...completed
# loading data 37/3861 ...completed
# loading data 38/3861 ...completed
# loading data 39/3861 ...completed
# loading data 40/3861 ...completed
# loading data 41/3861 ...completed
# loading data 42/3861 ...completed
# loading data 43/3861 ...completed
# loading data 44/3861 ...completed
# loading data 45/3861 ...completed
# loading data 46/3861 ...completed
# loading data 47/3861 ...completed
# loading data 48/3861 ...completed
# loading data 49/3861 ...completed
# loading data 50/3861 ...completed
# loading data 51/3861 ...completed
# loading data 52/3861 ...completed
# loading data 53/3861 ...completed
# loading data 54/3861 ...completed
# loading data 55/3861 ...completed
# loading data 56/3861 ...completed
# loading data 57/3861 ...completed
# loading data 58/3861 ...completed
# loading data 59/3861 ...completed
# loading data 60/3861 ...completed
# loading data 61/3861 ...completed
# loading data 62/3861 ...completed
# loading data 63/3861 ...completed
# loading data 64/3861 ...completed
# loading data 65/3861 ...completed
# loading data 66/3861 ...completed
# loading data 67/3861 ...completed
# loading data 68/3861 ...completed
# loading data 69/3861 ...completed
# loading data 70/3861 ...completed
# loading data 71/3861 ...completed
# loading data 72/3861 ...completed
# loading data 73/3861 ...completed
# loading data 74/3861 ...completed
# loading data 75/3861 ...completed
# loading data 76/3861 ...completed
# loading data 77/3861 ...completed
# loading data 78/3861 ...completed
# loading data 79/3861 ...completed
# loading data 80/3861 ...completed
# loading data 81/3861 ...completed
# loading data 82/3861 ...completed
# loading data 83/3861 ...completed
# loading data 84/3861 ...completed
# loading data 85/3861 ...completed
# loading data 86/3861 ...completed
# loading data 87/3861 ...completed
# loading data 88/3861 ...completed
# loading data 89/3861 ...completed
# loading data 90/3861 ...completed
# loading data 91/3861 ...completed
# loading data 92/3861 ...completed
# loading data 93/3861 ...completed
# loading data 94/3861 ...completed
# loading data 95/3861 ...completed
# loading data 96/3861 ...completed
# loading data 97/3861 ...completed
# loading data 98/3861 ...completed
# loading data 99/3861 ...completed
# loading data 100/3861 ...completed
# loading data 101/3861 ...completed
# loading data 102/3861 ...completed
# loading data 103/3861 ...completed
# loading data 104/3861 ...completed
# loading data 105/3861 ...completed
# loading data 106/3861 ...completed
# loading data 107/3861 ...completed
# loading data 108/3861 ...completed
# loading data 109/3861 ...completed
# loading data 110/3861 ...completed
# loading data 111/3861 ...completed
# loading data 112/3861 ...completed
# loading data 113/3861 ...completed
# loading data 114/3861 ...completed
# loading data 115/3861 ...completed
# loading data 116/3861 ...completed
# loading data 117/3861 ...completed
# loading data 118/3861 ...completed
# loading data 119/3861 ...completed
# loading data 120/3861 ...completed
# loading data 121/3861 ...completed
# loading data 122/3861 ...completed
# loading data 123/3861 ...completed
# loading data 124/3861 ...completed
# loading data 125/3861 ...completed
# loading data 126/3861 ...completed
# loading data 127/3861 ...completed
# loading data 128/3861 ...completed
# loading data 129/3861 ...completed
# loading data 130/3861 ...completed
# loading data 131/3861 ...completed
# loading data 132/3861 ...completed
# loading data 133/3861 ...completed
# loading data 134/3861 ...completed
# loading data 135/3861 ...completed
# loading data 136/3861 ...completed
# loading data 137/3861 ...completed
# loading data 138/3861 ...completed
# loading data 139/3861 ...completed
# loading data 140/3861 ...completed
# loading data 141/3861 ...completed
# loading data 142/3861 ...completed
# loading data 143/3861 ...completed
# loading data 144/3861 ...completed
# loading data 145/3861 ...completed
# loading data 146/3861 ...completed
# loading data 147/3861 ...completed
# loading data 148/3861 ...completed
# loading data 149/3861 ...completed
# loading data 150/3861 ...completed
# loading data 151/3861 ...completed
# loading data 152/3861 ...completed
# loading data 153/3861 ...completed
# loading data 154/3861 ...completed
# loading data 155/3861 ...completed
# loading data 156/3861 ...completed
# loading data 157/3861 ...completed
# loading data 158/3861 ...completed
# loading data 159/3861 ...completed
# loading data 160/3861 ...completed
# loading data 161/3861 ...completed
# loading data 162/3861 ...completed
# loading data 163/3861 ...completed
# loading data 164/3861 ...completed
# loading data 165/3861 ...completed
# loading data 166/3861 ...completed
# loading data 167/3861 ...completed
# loading data 168/3861 ...completed
# loading data 169/3861 ...completed
# loading data 170/3861 ...completed
# loading data 171/3861 ...completed
# loading data 172/3861 ...completed
# loading data 173/3861 ...completed
# loading data 174/3861 ...completed
# loading data 175/3861 ...completed
# loading data 176/3861 ...completed
# loading data 177/3861 ...completed
# loading data 178/3861 ...completed
# loading data 179/3861 ...completed
# loading data 180/3861 ...completed
# loading data 181/3861 ...completed
# loading data 182/3861 ...completed
# loading data 183/3861 ...completed
# loading data 184/3861 ...completed
# loading data 185/3861 ...completed
# loading data 186/3861 ...completed
# loading data 187/3861 ...completed
# loading data 188/3861 ...completed
# loading data 189/3861 ...completed
# loading data 190/3861 ...completed
# loading data 191/3861 ...completed
# loading data 192/3861 ...completed
# loading data 193/3861 ...completed
# loading data 194/3861 ...completed
# loading data 195/3861 ...completed
# loading data 196/3861 ...completed
# loading data 197/3861 ...completed
# loading data 198/3861 ...completed
# loading data 199/3861 ...completed
# loading data 200/3861 ...completed
# loading data 201/3861 ...completed
# loading data 202/3861 ...completed
# loading data 203/3861 ...completed
# loading data 204/3861 ...completed
# loading data 205/3861 ...completed
# loading data 206/3861 ...completed
# loading data 207/3861 ...completed
# loading data 208/3861 ...completed
# loading data 209/3861 ...completed
# loading data 210/3861 ...completed
# loading data 211/3861 ...completed
# loading data 212/3861 ...completed
# loading data 213/3861 ...completed
# loading data 214/3861 ...completed
# loading data 215/3861 ...completed
# loading data 216/3861 ...completed
# loading data 217/3861 ...completed
# loading data 218/3861 ...completed
# loading data 219/3861 ...completed
# loading data 220/3861 ...completed
# loading data 221/3861 ...completed
# loading data 222/3861 ...completed
# loading data 223/3861 ...completed
# loading data 224/3861 ...completed
# loading data 225/3861 ...completed
# loading data 226/3861 ...completed
# loading data 227/3861 ...completed
# loading data 228/3861 ...completed
# loading data 229/3861 ...completed
# loading data 230/3861 ...completed
# loading data 231/3861 ...completed
# loading data 232/3861 ...completed
# loading data 233/3861 ...completed
# loading data 234/3861 ...completed
# loading data 235/3861 ...completed
# loading data 236/3861 ...completed
# loading data 237/3861 ...completed
# loading data 238/3861 ...completed
# loading data 239/3861 ...completed
# loading data 240/3861 ...completed
# loading data 241/3861 ...completed
# loading data 242/3861 ...completed
# loading data 243/3861 ...completed
# loading data 244/3861 ...completed
# loading data 245/3861 ...completed
# loading data 246/3861 ...completed
# loading data 247/3861 ...completed
# loading data 248/3861 ...completed
# loading data 249/3861 ...completed
# loading data 250/3861 ...completed
# loading data 251/3861 ...completed
# loading data 252/3861 ...completed
# loading data 253/3861 ...completed
# loading data 254/3861 ...completed
# loading data 255/3861 ...completed
# loading data 256/3861 ...completed
# loading data 257/3861 ...completed
# loading data 258/3861 ...completed
# loading data 259/3861 ...completed
# loading data 260/3861 ...completed
# loading data 261/3861 ...completed
# loading data 262/3861 ...completed
# loading data 263/3861 ...completed
# loading data 264/3861 ...completed
# loading data 265/3861 ...completed
# loading data 266/3861 ...completed
# loading data 267/3861 ...completed
# loading data 268/3861 ...completed
# loading data 269/3861 ...completed
# loading data 270/3861 ...completed
# loading data 271/3861 ...completed
# loading data 272/3861 ...completed
# loading data 273/3861 ...completed
# loading data 274/3861 ...completed
# loading data 275/3861 ...completed
# loading data 276/3861 ...completed
# loading data 277/3861 ...completed
# loading data 278/3861 ...completed
# loading data 279/3861 ...completed
# loading data 280/3861 ...completed
# loading data 281/3861 ...completed
# loading data 282/3861 ...completed
# loading data 283/3861 ...completed
# loading data 284/3861 ...completed
# loading data 285/3861 ...completed
# loading data 286/3861 ...completed
# loading data 287/3861 ...completed
# loading data 288/3861 ...completed
# loading data 289/3861 ...completed
# loading data 290/3861 ...completed
# loading data 291/3861 ...completed
# loading data 292/3861 ...completed
# loading data 293/3861 ...completed
# loading data 294/3861 ...completed
# loading data 295/3861 ...completed
# loading data 296/3861 ...completed
# loading data 297/3861 ...completed
# loading data 298/3861 ...completed
# loading data 299/3861 ...completed
# loading data 300/3861 ...completed
# loading data 301/3861 ...completed
# loading data 302/3861 ...completed
# loading data 303/3861 ...completed
# loading data 304/3861 ...completed
# loading data 305/3861 ...completed
# loading data 306/3861 ...completed
# loading data 307/3861 ...completed
# loading data 308/3861 ...completed
# loading data 309/3861 ...completed
# loading data 310/3861 ...completed
# loading data 311/3861 ...completed
# loading data 312/3861 ...completed
# loading data 313/3861 ...completed
# loading data 314/3861 ...completed
# loading data 315/3861 ...completed
# loading data 316/3861 ...completed
# loading data 317/3861 ...completed
# loading data 318/3861 ...completed
# loading data 319/3861 ...completed
# loading data 320/3861 ...completed
# loading data 321/3861 ...completed
# loading data 322/3861 ...completed
# loading data 323/3861 ...completed
# loading data 324/3861 ...completed
# loading data 325/3861 ...completed
# loading data 326/3861 ...completed
# loading data 327/3861 ...completed
# loading data 328/3861 ...completed
# loading data 329/3861 ...completed
# loading data 330/3861 ...completed
# loading data 331/3861 ...completed
# loading data 332/3861 ...completed
# loading data 333/3861 ...completed
# loading data 334/3861 ...completed
# loading data 335/3861 ...completed
# loading data 336/3861 ...completed
# loading data 337/3861 ...completed
# loading data 338/3861 ...completed
# loading data 339/3861 ...completed
# loading data 340/3861 ...completed
# loading data 341/3861 ...completed
# loading data 342/3861 ...completed
# loading data 343/3861 ...completed
# loading data 344/3861 ...completed
# loading data 345/3861 ...completed
# loading data 346/3861 ...completed
# loading data 347/3861 ...completed
# loading data 348/3861 ...completed
# loading data 349/3861 ...completed
# loading data 350/3861 ...completed
# loading data 351/3861 ...completed
# loading data 352/3861 ...completed
# loading data 353/3861 ...completed
# loading data 354/3861 ...completed
# loading data 355/3861 ...completed
# loading data 356/3861 ...completed
# loading data 357/3861 ...completed
# loading data 358/3861 ...completed
# loading data 359/3861 ...completed
# loading data 360/3861 ...completed
# loading data 361/3861 ...completed
# loading data 362/3861 ...completed
# loading data 363/3861 ...completed
# loading data 364/3861 ...completed
# loading data 365/3861 ...completed
# loading data 366/3861 ...completed
# loading data 367/3861 ...completed
# loading data 368/3861 ...completed
# loading data 369/3861 ...completed
# loading data 370/3861 ...completed
# loading data 371/3861 ...completed
# loading data 372/3861 ...completed
# loading data 373/3861 ...completed
# loading data 374/3861 ...completed
# loading data 375/3861 ...completed
# loading data 376/3861 ...completed
# loading data 377/3861 ...completed
# loading data 378/3861 ...completed
# loading data 379/3861 ...completed
# loading data 380/3861 ...completed
# loading data 381/3861 ...completed
# loading data 382/3861 ...completed
# loading data 383/3861 ...completed
# loading data 384/3861 ...completed
# loading data 385/3861 ...completed
# loading data 386/3861 ...completed
# loading data 387/3861 ...completed
# loading data 388/3861 ...completed
# loading data 389/3861 ...completed
# loading data 390/3861 ...completed
# loading data 391/3861 ...completed
# loading data 392/3861 ...completed
# loading data 393/3861 ...completed
# loading data 394/3861 ...completed
# loading data 395/3861 ...completed
# loading data 396/3861 ...completed
# loading data 397/3861 ...completed
# loading data 398/3861 ...completed
# loading data 399/3861 ...completed
# loading data 400/3861 ...completed
# loading data 401/3861 ...completed
# loading data 402/3861 ...completed
# loading data 403/3861 ...completed
# loading data 404/3861 ...completed
# loading data 405/3861 ...completed
# loading data 406/3861 ...completed
# loading data 407/3861 ...completed
# loading data 408/3861 ...completed
# loading data 409/3861 ...completed
# loading data 410/3861 ...completed
# loading data 411/3861 ...completed
# loading data 412/3861 ...completed
# loading data 413/3861 ...completed
# loading data 414/3861 ...completed
# loading data 415/3861 ...completed
# loading data 416/3861 ...completed
# loading data 417/3861 ...completed
# loading data 418/3861 ...completed
# loading data 419/3861 ...completed
# loading data 420/3861 ...completed
# loading data 421/3861 ...completed
# loading data 422/3861 ...completed
# loading data 423/3861 ...completed
# loading data 424/3861 ...completed
# loading data 425/3861 ...completed
# loading data 426/3861 ...completed
# loading data 427/3861 ...completed
# loading data 428/3861 ...completed
# loading data 429/3861 ...completed
# loading data 430/3861 ...completed
# loading data 431/3861 ...completed
# loading data 432/3861 ...completed
# loading data 433/3861 ...completed
# loading data 434/3861 ...completed
# loading data 435/3861 ...completed
# loading data 436/3861 ...completed
# loading data 437/3861 ...completed
# loading data 438/3861 ...completed
# loading data 439/3861 ...completed
# loading data 440/3861 ...completed
# loading data 441/3861 ...completed
# loading data 442/3861 ...completed
# loading data 443/3861 ...completed
# loading data 444/3861 ...completed
# loading data 445/3861 ...completed
# loading data 446/3861 ...completed
# loading data 447/3861 ...completed
# loading data 448/3861 ...completed
# loading data 449/3861 ...completed
# loading data 450/3861 ...completed
# loading data 451/3861 ...completed
# loading data 452/3861 ...completed
# loading data 453/3861 ...completed
# loading data 454/3861 ...completed
# loading data 455/3861 ...completed
# loading data 456/3861 ...completed
# loading data 457/3861 ...completed
# loading data 458/3861 ...completed
# loading data 459/3861 ...completed
# loading data 460/3861 ...completed
# loading data 461/3861 ...completed
# loading data 462/3861 ...completed
# loading data 463/3861 ...completed
# loading data 464/3861 ...completed
# loading data 465/3861 ...completed
# loading data 466/3861 ...completed
# loading data 467/3861 ...completed
# loading data 468/3861 ...completed
# loading data 469/3861 ...completed
# loading data 470/3861 ...completed
# loading data 471/3861 ...completed
# loading data 472/3861 ...completed
# loading data 473/3861 ...completed
# loading data 474/3861 ...completed
# loading data 475/3861 ...completed
# loading data 476/3861 ...completed
# loading data 477/3861 ...completed
# loading data 478/3861 ...completed
# loading data 479/3861 ...completed
# loading data 480/3861 ...completed
# loading data 481/3861 ...completed
# loading data 482/3861 ...completed
# loading data 483/3861 ...completed
# loading data 484/3861 ...completed
# loading data 485/3861 ...completed
# loading data 486/3861 ...completed
# loading data 487/3861 ...completed
# loading data 488/3861 ...completed
# loading data 489/3861 ...completed
# loading data 490/3861 ...completed
# loading data 491/3861 ...completed
# loading data 492/3861 ...completed
# loading data 493/3861 ...completed
# loading data 494/3861 ...completed
# loading data 495/3861 ...completed
# loading data 496/3861 ...completed
# loading data 497/3861 ...completed
# loading data 498/3861 ...completed
# loading data 499/3861 ...completed
# loading data 500/3861 ...completed
# loading data 501/3861 ...completed
# loading data 502/3861 ...completed
# loading data 503/3861 ...completed
# loading data 504/3861 ...completed
# loading data 505/3861 ...completed
# loading data 506/3861 ...completed
# loading data 507/3861 ...completed
# loading data 508/3861 ...completed
# loading data 509/3861 ...completed
# loading data 510/3861 ...completed
# loading data 511/3861 ...completed
# loading data 512/3861 ...completed
# loading data 513/3861 ...completed
# loading data 514/3861 ...completed
# loading data 515/3861 ...completed
# loading data 516/3861 ...completed
# loading data 517/3861 ...completed
# loading data 518/3861 ...completed
# loading data 519/3861 ...completed
# loading data 520/3861 ...completed
# loading data 521/3861 ...completed
# loading data 522/3861 ...completed
# loading data 523/3861 ...completed
# loading data 524/3861 ...completed
# loading data 525/3861 ...completed
# loading data 526/3861 ...completed
# loading data 527/3861 ...completed
# loading data 528/3861 ...completed
# loading data 529/3861 ...completed
# loading data 530/3861 ...completed
# loading data 531/3861 ...completed
# loading data 532/3861 ...completed
# loading data 533/3861 ...completed
# loading data 534/3861 ...completed
# loading data 535/3861 ...completed
# loading data 536/3861 ...completed
# loading data 537/3861 ...completed
# loading data 538/3861 ...completed
# loading data 539/3861 ...completed
# loading data 540/3861 ...completed
# loading data 541/3861 ...completed
# loading data 542/3861 ...completed
# loading data 543/3861 ...completed
# loading data 544/3861 ...completed
# loading data 545/3861 ...completed
# loading data 546/3861 ...completed
# loading data 547/3861 ...completed
# loading data 548/3861 ...completed
# loading data 549/3861 ...completed
# loading data 550/3861 ...completed
# loading data 551/3861 ...completed
# loading data 552/3861 ...completed
# loading data 553/3861 ...completed
# loading data 554/3861 ...completed
# loading data 555/3861 ...completed
# loading data 556/3861 ...completed
# loading data 557/3861 ...completed
# loading data 558/3861 ...completed
# loading data 559/3861 ...completed
# loading data 560/3861 ...completed
# loading data 561/3861 ...completed
# loading data 562/3861 ...completed
# loading data 563/3861 ...completed
# loading data 564/3861 ...completed
# loading data 565/3861 ...completed
# loading data 566/3861 ...completed
# loading data 567/3861 ...completed
# loading data 568/3861 ...completed
# loading data 569/3861 ...completed
# loading data 570/3861 ...completed
# loading data 571/3861 ...completed
# loading data 572/3861 ...completed
# loading data 573/3861 ...completed
# loading data 574/3861 ...completed
# loading data 575/3861 ...completed
# loading data 576/3861 ...completed
# loading data 577/3861 ...completed
# loading data 578/3861 ...completed
# loading data 579/3861 ...completed
# loading data 580/3861 ...completed
# loading data 581/3861 ...completed
# loading data 582/3861 ...completed
# loading data 583/3861 ...completed
# loading data 584/3861 ...completed
# loading data 585/3861 ...completed
# loading data 586/3861 ...completed
# loading data 587/3861 ...completed
# loading data 588/3861 ...completed
# loading data 589/3861 ...completed
# loading data 590/3861 ...completed
# loading data 591/3861 ...completed
# loading data 592/3861 ...completed
# loading data 593/3861 ...completed
# loading data 594/3861 ...completed
# loading data 595/3861 ...completed
# loading data 596/3861 ...completed
# loading data 597/3861 ...completed
# loading data 598/3861 ...completed
# loading data 599/3861 ...completed
# loading data 600/3861 ...completed
# loading data 601/3861 ...completed
# loading data 602/3861 ...completed
# loading data 603/3861 ...completed
# loading data 604/3861 ...completed
# loading data 605/3861 ...completed
# loading data 606/3861 ...completed
# loading data 607/3861 ...completed
# loading data 608/3861 ...completed
# loading data 609/3861 ...completed
# loading data 610/3861 ...completed
# loading data 611/3861 ...completed
# loading data 612/3861 ...completed
# loading data 613/3861 ...completed
# loading data 614/3861 ...completed
# loading data 615/3861 ...completed
# loading data 616/3861 ...completed
# loading data 617/3861 ...completed
# loading data 618/3861 ...completed
# loading data 619/3861 ...completed
# loading data 620/3861 ...completed
# loading data 621/3861 ...completed
# loading data 622/3861 ...completed
# loading data 623/3861 ...completed
# loading data 624/3861 ...completed
# loading data 625/3861 ...completed
# loading data 626/3861 ...completed
# loading data 627/3861 ...completed
# loading data 628/3861 ...completed
# loading data 629/3861 ...completed
# loading data 630/3861 ...completed
# loading data 631/3861 ...completed
# loading data 632/3861 ...completed
# loading data 633/3861 ...completed
# loading data 634/3861 ...completed
# loading data 635/3861 ...completed
# loading data 636/3861 ...completed
# loading data 637/3861 ...completed
# loading data 638/3861 ...completed
# loading data 639/3861 ...completed
# loading data 640/3861 ...completed
# loading data 641/3861 ...completed
# loading data 642/3861 ...completed
# loading data 643/3861 ...completed
# loading data 644/3861 ...completed
# loading data 645/3861 ...completed
# loading data 646/3861 ...completed
# loading data 647/3861 ...completed
# loading data 648/3861 ...completed
# loading data 649/3861 ...completed
# loading data 650/3861 ...completed
# loading data 651/3861 ...completed
# loading data 652/3861 ...completed
# loading data 653/3861 ...completed
# loading data 654/3861 ...completed
# loading data 655/3861 ...completed
# loading data 656/3861 ...completed
# loading data 657/3861 ...completed
# loading data 658/3861 ...completed
# loading data 659/3861 ...completed
# loading data 660/3861 ...completed
# loading data 661/3861 ...completed
# loading data 662/3861 ...completed
# loading data 663/3861 ...completed
# loading data 664/3861 ...completed
# loading data 665/3861 ...completed
# loading data 666/3861 ...completed
# loading data 667/3861 ...completed
# loading data 668/3861 ...completed
# loading data 669/3861 ...completed
# loading data 670/3861 ...completed
# loading data 671/3861 ...completed
# loading data 672/3861 ...completed
# loading data 673/3861 ...completed
# loading data 674/3861 ...completed
# loading data 675/3861 ...completed
# loading data 676/3861 ...completed
# loading data 677/3861 ...completed
# loading data 678/3861 ...completed
# loading data 679/3861 ...completed
# loading data 680/3861 ...completed
# loading data 681/3861 ...completed
# loading data 682/3861 ...completed
# loading data 683/3861 ...completed
# loading data 684/3861 ...completed
# loading data 685/3861 ...completed
# loading data 686/3861 ...completed
# loading data 687/3861 ...completed
# loading data 688/3861 ...completed
# loading data 689/3861 ...completed
# loading data 690/3861 ...completed
# loading data 691/3861 ...completed
# loading data 692/3861 ...completed
# loading data 693/3861 ...completed
# loading data 694/3861 ...completed
# loading data 695/3861 ...completed
# loading data 696/3861 ...completed
# loading data 697/3861 ...completed
# loading data 698/3861 ...completed
# loading data 699/3861 ...completed
# loading data 700/3861 ...completed
# loading data 701/3861 ...completed
# loading data 702/3861 ...completed
# loading data 703/3861 ...completed
# loading data 704/3861 ...completed
# loading data 705/3861 ...completed
# loading data 706/3861 ...completed
# loading data 707/3861 ...completed
# loading data 708/3861 ...completed
# loading data 709/3861 ...completed
# loading data 710/3861 ...completed
# loading data 711/3861 ...completed
# loading data 712/3861 ...completed
# loading data 713/3861 ...completed
# loading data 714/3861 ...completed
# loading data 715/3861 ...completed
# loading data 716/3861 ...completed
# loading data 717/3861 ...completed
# loading data 718/3861 ...completed
# loading data 719/3861 ...completed
# loading data 720/3861 ...completed
# loading data 721/3861 ...completed
# loading data 722/3861 ...completed
# loading data 723/3861 ...completed
# loading data 724/3861 ...completed
# loading data 725/3861 ...completed
# loading data 726/3861 ...completed
# loading data 727/3861 ...completed
# loading data 728/3861 ...completed
# loading data 729/3861 ...completed
# loading data 730/3861 ...completed
# loading data 731/3861 ...completed
# loading data 732/3861 ...completed
# loading data 733/3861 ...completed
# loading data 734/3861 ...completed
# loading data 735/3861 ...completed
# loading data 736/3861 ...completed
# loading data 737/3861 ...completed
# loading data 738/3861 ...completed
# loading data 739/3861 ...completed
# loading data 740/3861 ...completed
# loading data 741/3861 ...completed
# loading data 742/3861 ...completed
# loading data 743/3861 ...completed
# loading data 744/3861 ...completed
# loading data 745/3861 ...completed
# loading data 746/3861 ...completed
# loading data 747/3861 ...completed
# loading data 748/3861 ...completed
# loading data 749/3861 ...completed
# loading data 750/3861 ...completed
# loading data 751/3861 ...completed
# loading data 752/3861 ...completed
# loading data 753/3861 ...completed
# loading data 754/3861 ...completed
# loading data 755/3861 ...completed
# loading data 756/3861 ...completed
# loading data 757/3861 ...completed
# loading data 758/3861 ...completed
# loading data 759/3861 ...completed
# loading data 760/3861 ...completed
# loading data 761/3861 ...completed
# loading data 762/3861 ...completed
# loading data 763/3861 ...completed
# loading data 764/3861 ...completed
# loading data 765/3861 ...completed
# loading data 766/3861 ...completed
# loading data 767/3861 ...completed
# loading data 768/3861 ...completed
# loading data 769/3861 ...completed
# loading data 770/3861 ...completed
# loading data 771/3861 ...completed
# loading data 772/3861 ...completed
# loading data 773/3861 ...completed
# loading data 774/3861 ...completed
# loading data 775/3861 ...completed
# loading data 776/3861 ...completed
# loading data 777/3861 ...completed
# loading data 778/3861 ...completed
# loading data 779/3861 ...completed
# loading data 780/3861 ...completed
# loading data 781/3861 ...completed
# loading data 782/3861 ...completed
# loading data 783/3861 ...completed
# loading data 784/3861 ...completed
# loading data 785/3861 ...completed
# loading data 786/3861 ...completed
# loading data 787/3861 ...completed
# loading data 788/3861 ...completed
# loading data 789/3861 ...completed
# loading data 790/3861 ...completed
# loading data 791/3861 ...completed
# loading data 792/3861 ...completed
# loading data 793/3861 ...completed
# loading data 794/3861 ...completed
# loading data 795/3861 ...completed
# loading data 796/3861 ...completed
# loading data 797/3861 ...completed
# loading data 798/3861 ...completed
# loading data 799/3861 ...completed
# loading data 800/3861 ...completed
# loading data 801/3861 ...completed
# loading data 802/3861 ...completed
# loading data 803/3861 ...completed
# loading data 804/3861 ...completed
# loading data 805/3861 ...completed
# loading data 806/3861 ...completed
# loading data 807/3861 ...completed
# loading data 808/3861 ...completed
# loading data 809/3861 ...completed
# loading data 810/3861 ...completed
# loading data 811/3861 ...completed
# loading data 812/3861 ...completed
# loading data 813/3861 ...completed
# loading data 814/3861 ...completed
# loading data 815/3861 ...completed
# loading data 816/3861 ...completed
# loading data 817/3861 ...completed
# loading data 818/3861 ...completed
# loading data 819/3861 ...completed
# loading data 820/3861 ...completed
# loading data 821/3861 ...completed
# loading data 822/3861 ...completed
# loading data 823/3861 ...completed
# loading data 824/3861 ...completed
# loading data 825/3861 ...completed
# loading data 826/3861 ...completed
# loading data 827/3861 ...completed
# loading data 828/3861 ...completed
# loading data 829/3861 ...completed
# loading data 830/3861 ...completed
# loading data 831/3861 ...completed
# loading data 832/3861 ...completed
# loading data 833/3861 ...completed
# loading data 834/3861 ...completed
# loading data 835/3861 ...completed
# loading data 836/3861 ...completed
# loading data 837/3861 ...completed
# loading data 838/3861 ...completed
# loading data 839/3861 ...completed
# loading data 840/3861 ...completed
# loading data 841/3861 ...completed
# loading data 842/3861 ...completed
# loading data 843/3861 ...completed
# loading data 844/3861 ...completed
# loading data 845/3861 ...completed
# loading data 846/3861 ...completed
# loading data 847/3861 ...completed
# loading data 848/3861 ...completed
# loading data 849/3861 ...completed
# loading data 850/3861 ...completed
# loading data 851/3861 ...completed
# loading data 852/3861 ...completed
# loading data 853/3861 ...completed
# loading data 854/3861 ...completed
# loading data 855/3861 ...completed
# loading data 856/3861 ...completed
# loading data 857/3861 ...completed
# loading data 858/3861 ...completed
# loading data 859/3861 ...completed
# loading data 860/3861 ...completed
# loading data 861/3861 ...completed
# loading data 862/3861 ...completed
# loading data 863/3861 ...completed
# loading data 864/3861 ...completed
# loading data 865/3861 ...completed
# loading data 866/3861 ...completed
# loading data 867/3861 ...completed
# loading data 868/3861 ...completed
# loading data 869/3861 ...completed
# loading data 870/3861 ...completed
# loading data 871/3861 ...completed
# loading data 872/3861 ...completed
# loading data 873/3861 ...completed
# loading data 874/3861 ...completed
# loading data 875/3861 ...completed
# loading data 876/3861 ...completed
# loading data 877/3861 ...completed
# loading data 878/3861 ...completed
# loading data 879/3861 ...completed
# loading data 880/3861 ...completed
# loading data 881/3861 ...completed
# loading data 882/3861 ...completed
# loading data 883/3861 ...completed
# loading data 884/3861 ...completed
# loading data 885/3861 ...completed
# loading data 886/3861 ...completed
# loading data 887/3861 ...completed
# loading data 888/3861 ...completed
# loading data 889/3861 ...completed
# loading data 890/3861 ...completed
# loading data 891/3861 ...completed
# loading data 892/3861 ...completed
# loading data 893/3861 ...completed
# loading data 894/3861 ...completed
# loading data 895/3861 ...completed
# loading data 896/3861 ...completed
# loading data 897/3861 ...completed
# loading data 898/3861 ...completed
# loading data 899/3861 ...completed
# loading data 900/3861 ...completed
# loading data 901/3861 ...completed
# loading data 902/3861 ...completed
# loading data 903/3861 ...completed
# loading data 904/3861 ...completed
# loading data 905/3861 ...completed
# loading data 906/3861 ...completed
# loading data 907/3861 ...completed
# loading data 908/3861 ...completed
# loading data 909/3861 ...completed
# loading data 910/3861 ...completed
# loading data 911/3861 ...completed
# loading data 912/3861 ...completed
# loading data 913/3861 ...completed
# loading data 914/3861 ...completed
# loading data 915/3861 ...completed
# loading data 916/3861 ...completed
# loading data 917/3861 ...completed
# loading data 918/3861 ...completed
# loading data 919/3861 ...completed
# loading data 920/3861 ...completed
# loading data 921/3861 ...completed
# loading data 922/3861 ...completed
# loading data 923/3861 ...completed
# loading data 924/3861 ...completed
# loading data 925/3861 ...completed
# loading data 926/3861 ...completed
# loading data 927/3861 ...completed
# loading data 928/3861 ...completed
# loading data 929/3861 ...completed
# loading data 930/3861 ...completed
# loading data 931/3861 ...completed
# loading data 932/3861 ...completed
# loading data 933/3861 ...completed
# loading data 934/3861 ...completed
# loading data 935/3861 ...completed
# loading data 936/3861 ...completed
# loading data 937/3861 ...completed
# loading data 938/3861 ...completed
# loading data 939/3861 ...completed
# loading data 940/3861 ...completed
# loading data 941/3861 ...completed
# loading data 942/3861 ...completed
# loading data 943/3861 ...completed
# loading data 944/3861 ...completed
# loading data 945/3861 ...completed
# loading data 946/3861 ...completed
# loading data 947/3861 ...completed
# loading data 948/3861 ...completed
# loading data 949/3861 ...completed
# loading data 950/3861 ...completed
# loading data 951/3861 ...completed
# loading data 952/3861 ...completed
# loading data 953/3861 ...completed
# loading data 954/3861 ...completed
# loading data 955/3861 ...completed
# loading data 956/3861 ...completed
# loading data 957/3861 ...completed
# loading data 958/3861 ...completed
# loading data 959/3861 ...completed
# loading data 960/3861 ...completed
# loading data 961/3861 ...completed
# loading data 962/3861 ...completed
# loading data 963/3861 ...completed
# loading data 964/3861 ...completed
# loading data 965/3861 ...completed
# loading data 966/3861 ...completed
# loading data 967/3861 ...completed
# loading data 968/3861 ...completed
# loading data 969/3861 ...completed
# loading data 970/3861 ...completed
# loading data 971/3861 ...completed
# loading data 972/3861 ...completed
# loading data 973/3861 ...completed
# loading data 974/3861 ...completed
# loading data 975/3861 ...completed
# loading data 976/3861 ...completed
# loading data 977/3861 ...completed
# loading data 978/3861 ...completed
# loading data 979/3861 ...completed
# loading data 980/3861 ...completed
# loading data 981/3861 ...completed
# loading data 982/3861 ...completed
# loading data 983/3861 ...completed
# loading data 984/3861 ...completed
# loading data 985/3861 ...completed
# loading data 986/3861 ...completed
# loading data 987/3861 ...completed
# loading data 988/3861 ...completed
# loading data 989/3861 ...completed
# loading data 990/3861 ...completed
# loading data 991/3861 ...completed
# loading data 992/3861 ...completed
# loading data 993/3861 ...completed
# loading data 994/3861 ...completed
# loading data 995/3861 ...completed
# loading data 996/3861 ...completed
# loading data 997/3861 ...completed
# loading data 998/3861 ...completed
# loading data 999/3861 ...completed
# loading data 1000/3861 ...completed
# loading data 1001/3861 ...completed
# loading data 1002/3861 ...completed
# loading data 1003/3861 ...completed
# loading data 1004/3861 ...completed
# loading data 1005/3861 ...completed
# loading data 1006/3861 ...completed
# loading data 1007/3861 ...completed
# loading data 1008/3861 ...completed
# loading data 1009/3861 ...completed
# loading data 1010/3861 ...completed
# loading data 1011/3861 ...completed
# loading data 1012/3861 ...completed
# loading data 1013/3861 ...completed
# loading data 1014/3861 ...completed
# loading data 1015/3861 ...completed
# loading data 1016/3861 ...completed
# loading data 1017/3861 ...completed
# loading data 1018/3861 ...completed
# loading data 1019/3861 ...completed
# loading data 1020/3861 ...completed
# loading data 1021/3861 ...completed
# loading data 1022/3861 ...completed
# loading data 1023/3861 ...completed
# loading data 1024/3861 ...completed
# loading data 1025/3861 ...completed
# loading data 1026/3861 ...completed
# loading data 1027/3861 ...completed
# loading data 1028/3861 ...completed
# loading data 1029/3861 ...completed
# loading data 1030/3861 ...completed
# loading data 1031/3861 ...completed
# loading data 1032/3861 ...completed
# loading data 1033/3861 ...completed
# loading data 1034/3861 ...completed
# loading data 1035/3861 ...completed
# loading data 1036/3861 ...completed
# loading data 1037/3861 ...completed
# loading data 1038/3861 ...completed
# loading data 1039/3861 ...completed
# loading data 1040/3861 ...completed
# loading data 1041/3861 ...completed
# loading data 1042/3861 ...completed
# loading data 1043/3861 ...completed
# loading data 1044/3861 ...completed
# loading data 1045/3861 ...completed
# loading data 1046/3861 ...completed
# loading data 1047/3861 ...completed
# loading data 1048/3861 ...completed
# loading data 1049/3861 ...completed
# loading data 1050/3861 ...completed
# loading data 1051/3861 ...completed
# loading data 1052/3861 ...completed
# loading data 1053/3861 ...completed
# loading data 1054/3861 ...completed
# loading data 1055/3861 ...completed
# loading data 1056/3861 ...completed
# loading data 1057/3861 ...completed
# loading data 1058/3861 ...completed
# loading data 1059/3861 ...completed
# loading data 1060/3861 ...completed
# loading data 1061/3861 ...completed
# loading data 1062/3861 ...completed
# loading data 1063/3861 ...completed
# loading data 1064/3861 ...completed
# loading data 1065/3861 ...completed
# loading data 1066/3861 ...completed
# loading data 1067/3861 ...completed
# loading data 1068/3861 ...completed
# loading data 1069/3861 ...completed
# loading data 1070/3861 ...completed
# loading data 1071/3861 ...completed
# loading data 1072/3861 ...completed
# loading data 1073/3861 ...completed
# loading data 1074/3861 ...completed
# loading data 1075/3861 ...completed
# loading data 1076/3861 ...completed
# loading data 1077/3861 ...completed
# loading data 1078/3861 ...completed
# loading data 1079/3861 ...completed
# loading data 1080/3861 ...completed
# loading data 1081/3861 ...completed
# loading data 1082/3861 ...completed
# loading data 1083/3861 ...completed
# loading data 1084/3861 ...completed
# loading data 1085/3861 ...completed
# loading data 1086/3861 ...completed
# loading data 1087/3861 ...completed
# loading data 1088/3861 ...completed
# loading data 1089/3861 ...completed
# loading data 1090/3861 ...completed
# loading data 1091/3861 ...completed
# loading data 1092/3861 ...completed
# loading data 1093/3861 ...completed
# loading data 1094/3861 ...completed
# loading data 1095/3861 ...completed
# loading data 1096/3861 ...completed
# loading data 1097/3861 ...completed
# loading data 1098/3861 ...completed
# loading data 1099/3861 ...completed
# loading data 1100/3861 ...completed
# loading data 1101/3861 ...completed
# loading data 1102/3861 ...completed
# loading data 1103/3861 ...completed
# loading data 1104/3861 ...completed
# loading data 1105/3861 ...completed
# loading data 1106/3861 ...completed
# loading data 1107/3861 ...completed
# loading data 1108/3861 ...completed
# loading data 1109/3861 ...completed
# loading data 1110/3861 ...completed
# loading data 1111/3861 ...completed
# loading data 1112/3861 ...completed
# loading data 1113/3861 ...completed
# loading data 1114/3861 ...completed
# loading data 1115/3861 ...completed
# loading data 1116/3861 ...completed
# loading data 1117/3861 ...completed
# loading data 1118/3861 ...completed
# loading data 1119/3861 ...completed
# loading data 1120/3861 ...completed
# loading data 1121/3861 ...completed
# loading data 1122/3861 ...completed
# loading data 1123/3861 ...completed
# loading data 1124/3861 ...completed
# loading data 1125/3861 ...completed
# loading data 1126/3861 ...completed
# loading data 1127/3861 ...completed
# loading data 1128/3861 ...completed
# loading data 1129/3861 ...completed
# loading data 1130/3861 ...completed
# loading data 1131/3861 ...completed
# loading data 1132/3861 ...completed
# loading data 1133/3861 ...completed
# loading data 1134/3861 ...completed
# loading data 1135/3861 ...completed
# loading data 1136/3861 ...completed
# loading data 1137/3861 ...completed
# loading data 1138/3861 ...completed
# loading data 1139/3861 ...completed
# loading data 1140/3861 ...completed
# loading data 1141/3861 ...completed
# loading data 1142/3861 ...completed
# loading data 1143/3861 ...completed
# loading data 1144/3861 ...completed
# loading data 1145/3861 ...completed
# loading data 1146/3861 ...completed
# loading data 1147/3861 ...completed
# loading data 1148/3861 ...completed
# loading data 1149/3861 ...completed
# loading data 1150/3861 ...completed
# loading data 1151/3861 ...completed
# loading data 1152/3861 ...completed
# loading data 1153/3861 ...completed
# loading data 1154/3861 ...completed
# loading data 1155/3861 ...completed
# loading data 1156/3861 ...completed
# loading data 1157/3861 ...completed
# loading data 1158/3861 ...completed
# loading data 1159/3861 ...completed
# loading data 1160/3861 ...completed
# loading data 1161/3861 ...completed
# loading data 1162/3861 ...completed
# loading data 1163/3861 ...completed
# loading data 1164/3861 ...completed
# loading data 1165/3861 ...completed
# loading data 1166/3861 ...completed
# loading data 1167/3861 ...completed
# loading data 1168/3861 ...completed
# loading data 1169/3861 ...completed
# loading data 1170/3861 ...completed
# loading data 1171/3861 ...completed
# loading data 1172/3861 ...completed
# loading data 1173/3861 ...completed
# loading data 1174/3861 ...completed
# loading data 1175/3861 ...completed
# loading data 1176/3861 ...completed
# loading data 1177/3861 ...completed
# loading data 1178/3861 ...completed
# loading data 1179/3861 ...completed
# loading data 1180/3861 ...completed
# loading data 1181/3861 ...completed
# loading data 1182/3861 ...completed
# loading data 1183/3861 ...completed
# loading data 1184/3861 ...completed
# loading data 1185/3861 ...completed
# loading data 1186/3861 ...completed
# loading data 1187/3861 ...completed
# loading data 1188/3861 ...completed
# loading data 1189/3861 ...completed
# loading data 1190/3861 ...completed
# loading data 1191/3861 ...completed
# loading data 1192/3861 ...completed
# loading data 1193/3861 ...completed
# loading data 1194/3861 ...completed
# loading data 1195/3861 ...completed
# loading data 1196/3861 ...completed
# loading data 1197/3861 ...completed
# loading data 1198/3861 ...completed
# loading data 1199/3861 ...completed
# loading data 1200/3861 ...completed
# loading data 1201/3861 ...completed
# loading data 1202/3861 ...completed
# loading data 1203/3861 ...completed
# loading data 1204/3861 ...completed
# loading data 1205/3861 ...completed
# loading data 1206/3861 ...completed
# loading data 1207/3861 ...completed
# loading data 1208/3861 ...completed
# loading data 1209/3861 ...completed
# loading data 1210/3861 ...completed
# loading data 1211/3861 ...completed
# loading data 1212/3861 ...completed
# loading data 1213/3861 ...completed
# loading data 1214/3861 ...completed
# loading data 1215/3861 ...completed
# loading data 1216/3861 ...completed
# loading data 1217/3861 ...completed
# loading data 1218/3861 ...completed
# loading data 1219/3861 ...completed
# loading data 1220/3861 ...completed
# loading data 1221/3861 ...completed
# loading data 1222/3861 ...completed
# loading data 1223/3861 ...completed
# loading data 1224/3861 ...completed
# loading data 1225/3861 ...completed
# loading data 1226/3861 ...completed
# loading data 1227/3861 ...completed
# loading data 1228/3861 ...completed
# loading data 1229/3861 ...completed
# loading data 1230/3861 ...completed
# loading data 1231/3861 ...completed
# loading data 1232/3861 ...completed
# loading data 1233/3861 ...completed
# loading data 1234/3861 ...completed
# loading data 1235/3861 ...completed
# loading data 1236/3861 ...completed
# loading data 1237/3861 ...completed
# loading data 1238/3861 ...completed
# loading data 1239/3861 ...completed
# loading data 1240/3861 ...completed
# loading data 1241/3861 ...completed
# loading data 1242/3861 ...completed
# loading data 1243/3861 ...completed
# loading data 1244/3861 ...completed
# loading data 1245/3861 ...completed
# loading data 1246/3861 ...completed
# loading data 1247/3861 ...completed
# loading data 1248/3861 ...completed
# loading data 1249/3861 ...completed
# loading data 1250/3861 ...completed
# loading data 1251/3861 ...completed
# loading data 1252/3861 ...completed
# loading data 1253/3861 ...completed
# loading data 1254/3861 ...completed
# loading data 1255/3861 ...completed
# loading data 1256/3861 ...completed
# loading data 1257/3861 ...completed
# loading data 1258/3861 ...completed
# loading data 1259/3861 ...completed
# loading data 1260/3861 ...completed
# loading data 1261/3861 ...completed
# loading data 1262/3861 ...completed
# loading data 1263/3861 ...completed
# loading data 1264/3861 ...completed
# loading data 1265/3861 ...completed
# loading data 1266/3861 ...completed
# loading data 1267/3861 ...completed
# loading data 1268/3861 ...completed
# loading data 1269/3861 ...completed
# loading data 1270/3861 ...completed
# loading data 1271/3861 ...completed
# loading data 1272/3861 ...completed
# loading data 1273/3861 ...completed
# loading data 1274/3861 ...completed
# loading data 1275/3861 ...completed
# loading data 1276/3861 ...completed
# loading data 1277/3861 ...completed
# loading data 1278/3861 ...completed
# loading data 1279/3861 ...completed
# loading data 1280/3861 ...completed
# loading data 1281/3861 ...completed
# loading data 1282/3861 ...completed
# loading data 1283/3861 ...completed
# loading data 1284/3861 ...completed
# loading data 1285/3861 ...completed
# loading data 1286/3861 ...completed
# loading data 1287/3861 ...completed
# loading data 1288/3861 ...completed
# loading data 1289/3861 ...completed
# loading data 1290/3861 ...completed
# loading data 1291/3861 ...completed
# loading data 1292/3861 ...completed
# loading data 1293/3861 ...completed
# loading data 1294/3861 ...completed
# loading data 1295/3861 ...completed
# loading data 1296/3861 ...completed
# loading data 1297/3861 ...completed
# loading data 1298/3861 ...completed
# loading data 1299/3861 ...completed
# loading data 1300/3861 ...completed
# loading data 1301/3861 ...completed
# loading data 1302/3861 ...completed
# loading data 1303/3861 ...completed
# loading data 1304/3861 ...completed
# loading data 1305/3861 ...completed
# loading data 1306/3861 ...completed
# loading data 1307/3861 ...completed
# loading data 1308/3861 ...completed
# loading data 1309/3861 ...completed
# loading data 1310/3861 ...completed
# loading data 1311/3861 ...completed
# loading data 1312/3861 ...completed
# loading data 1313/3861 ...completed
# loading data 1314/3861 ...completed
# loading data 1315/3861 ...completed
# loading data 1316/3861 ...completed
# loading data 1317/3861 ...completed
# loading data 1318/3861 ...completed
# loading data 1319/3861 ...completed
# loading data 1320/3861 ...completed
# loading data 1321/3861 ...completed
# loading data 1322/3861 ...completed
# loading data 1323/3861 ...completed
# loading data 1324/3861 ...completed
# loading data 1325/3861 ...completed
# loading data 1326/3861 ...completed
# loading data 1327/3861 ...completed
# loading data 1328/3861 ...completed
# loading data 1329/3861 ...completed
# loading data 1330/3861 ...completed
# loading data 1331/3861 ...completed
# loading data 1332/3861 ...completed
# loading data 1333/3861 ...completed
# loading data 1334/3861 ...completed
# loading data 1335/3861 ...completed
# loading data 1336/3861 ...completed
# loading data 1337/3861 ...completed
# loading data 1338/3861 ...completed
# loading data 1339/3861 ...completed
# loading data 1340/3861 ...completed
# loading data 1341/3861 ...completed
# loading data 1342/3861 ...completed
# loading data 1343/3861 ...completed
# loading data 1344/3861 ...completed
# loading data 1345/3861 ...completed
# loading data 1346/3861 ...completed
# loading data 1347/3861 ...completed
# loading data 1348/3861 ...completed
# loading data 1349/3861 ...completed
# loading data 1350/3861 ...completed
# loading data 1351/3861 ...completed
# loading data 1352/3861 ...completed
# loading data 1353/3861 ...completed
# loading data 1354/3861 ...completed
# loading data 1355/3861 ...completed
# loading data 1356/3861 ...completed
# loading data 1357/3861 ...completed
# loading data 1358/3861 ...completed
# loading data 1359/3861 ...completed
# loading data 1360/3861 ...completed
# loading data 1361/3861 ...completed
# loading data 1362/3861 ...completed
# loading data 1363/3861 ...completed
# loading data 1364/3861 ...completed
# ...
# loading data 3433/3861 ...completed
# loading data 3434/3861 ...completed
# loading data 3435/3861 ...completed
# loading data 3436/3861 ...completed
# loading data 3437/3861 ...completed
# loading data 3438/3861 ...completed
# loading data 3439/3861 ...completed
# loading data 3440/3861 ...completed
# loading data 3441/3861 ...completed
# loading data 3442/3861 ...completed
# loading data 3443/3861 ...completed
# loading data 3444/3861 ...completed
# loading data 3445/3861 ...completed
# loading data 3446/3861 ...completed
# loading data 3447/3861 ...completed
# loading data 3448/3861 ...completed
# loading data 3449/3861 ...completed
# loading data 3450/3861 ...completed
# loading data 3451/3861 ...completed
# loading data 3452/3861 ...completed
# loading data 3453/3861 ...completed
# loading data 3454/3861 ...completed
# loading data 3455/3861 ...completed
# loading data 3456/3861 ...completed
# loading data 3457/3861 ...completed
# loading data 3458/3861 ...completed
# loading data 3459/3861 ...completed
# loading data 3460/3861 ...completed
# loading data 3461/3861 ...completed
# loading data 3462/3861 ...completed
# loading data 3463/3861 ...completed
# loading data 3464/3861 ...completed
# loading data 3465/3861 ...completed
# loading data 3466/3861 ...completed
# loading data 3467/3861 ...completed
# loading data 3468/3861 ...completed
# loading data 3469/3861 ...completed
# loading data 3470/3861 ...completed
# loading data 3471/3861 ...completed
# loading data 3472/3861 ...completed
# loading data 3473/3861 ...completed
# loading data 3474/3861 ...completed
# loading data 3475/3861 ...completed
# loading data 3476/3861 ...completed
# loading data 3477/3861 ...completed
# loading data 3478/3861 ...completed
# loading data 3479/3861 ...completed
# loading data 3480/3861 ...completed
# loading data 3481/3861 ...completed
# loading data 3482/3861 ...completed
# loading data 3483/3861 ...completed
# loading data 3484/3861 ...completed
# loading data 3485/3861 ...completed
# loading data 3486/3861 ...completed
# loading data 3487/3861 ...completed
# loading data 3488/3861 ...completed
# loading data 3489/3861 ...completed
# loading data 3490/3861 ...completed
# loading data 3491/3861 ...completed
# loading data 3492/3861 ...completed
# loading data 3493/3861 ...completed
# loading data 3494/3861 ...completed
# loading data 3495/3861 ...completed
# loading data 3496/3861 ...completed
# loading data 3497/3861 ...completed
# loading data 3498/3861 ...completed
# loading data 3499/3861 ...completed
# loading data 3500/3861 ...completed
# loading data 3501/3861 ...completed
# loading data 3502/3861 ...completed
# loading data 3503/3861 ...completed
# loading data 3504/3861 ...completed
# loading data 3505/3861 ...completed
# loading data 3506/3861 ...completed
# loading data 3507/3861 ...completed
# loading data 3508/3861 ...completed
# loading data 3509/3861 ...completed
# loading data 3510/3861 ...completed
# loading data 3511/3861 ...completed
# loading data 3512/3861 ...completed
# loading data 3513/3861 ...completed
# loading data 3514/3861 ...completed
# loading data 3515/3861 ...completed
# loading data 3516/3861 ...completed
# loading data 3517/3861 ...completed
# loading data 3518/3861 ...completed
# loading data 3519/3861 ...completed
# loading data 3520/3861 ...completed
# loading data 3521/3861 ...completed
# loading data 3522/3861 ...completed
# loading data 3523/3861 ...completed
# loading data 3524/3861 ...completed
# loading data 3525/3861 ...completed
# loading data 3526/3861 ...completed
# loading data 3527/3861 ...completed
# loading data 3528/3861 ...completed
# loading data 3529/3861 ...completed
# loading data 3530/3861 ...completed
# loading data 3531/3861 ...completed
# loading data 3532/3861 ...completed
# loading data 3533/3861 ...completed
# loading data 3534/3861 ...completed
# loading data 3535/3861 ...completed
# loading data 3536/3861 ...completed
# loading data 3537/3861 ...completed
# loading data 3538/3861 ...completed
# loading data 3539/3861 ...completed
# loading data 3540/3861 ...completed
# loading data 3541/3861 ...completed
# loading data 3542/3861 ...completed
# loading data 3543/3861 ...completed
# loading data 3544/3861 ...completed
# loading data 3545/3861 ...completed
# loading data 3546/3861 ...completed
# loading data 3547/3861 ...completed
# loading data 3548/3861 ...completed
# loading data 3549/3861 ...completed
# loading data 3550/3861 ...completed
# loading data 3551/3861 ...completed
# loading data 3552/3861 ...completed
# loading data 3553/3861 ...completed
# loading data 3554/3861 ...completed
# loading data 3555/3861 ...completed
# loading data 3556/3861 ...completed
# loading data 3557/3861 ...completed
# loading data 3558/3861 ...completed
# loading data 3559/3861 ...completed
# loading data 3560/3861 ...completed
# loading data 3561/3861 ...completed
# loading data 3562/3861 ...completed
# loading data 3563/3861 ...completed
# loading data 3564/3861 ...completed
# loading data 3565/3861 ...completed
# loading data 3566/3861 ...completed
# loading data 3567/3861 ...completed
# loading data 3568/3861 ...completed
# loading data 3569/3861 ...completed
# loading data 3570/3861 ...completed
# loading data 3571/3861 ...completed
# loading data 3572/3861 ...completed
# loading data 3573/3861 ...completed
# loading data 3574/3861 ...completed
# loading data 3575/3861 ...completed
# loading data 3576/3861 ...completed
# loading data 3577/3861 ...completed
# loading data 3578/3861 ...completed
# loading data 3579/3861 ...completed
# loading data 3580/3861 ...completed
# loading data 3581/3861 ...completed
# loading data 3582/3861 ...completed
# loading data 3583/3861 ...completed
# loading data 3584/3861 ...completed
# loading data 3585/3861 ...completed
# loading data 3586/3861 ...completed
# loading data 3587/3861 ...completed
# loading data 3588/3861 ...completed
# loading data 3589/3861 ...completed
# loading data 3590/3861 ...completed
# loading data 3591/3861 ...completed
# loading data 3592/3861 ...completed
# loading data 3593/3861 ...completed
# loading data 3594/3861 ...completed
# loading data 3595/3861 ...completed
# loading data 3596/3861 ...completed
# loading data 3597/3861 ...completed
# loading data 3598/3861 ...completed
# loading data 3599/3861 ...completed
# loading data 3600/3861 ...completed
# loading data 3601/3861 ...completed
# loading data 3602/3861 ...completed
# loading data 3603/3861 ...completed
# loading data 3604/3861 ...completed
# loading data 3605/3861 ...completed
# loading data 3606/3861 ...completed
# loading data 3607/3861 ...completed
# loading data 3608/3861 ...completed
# loading data 3609/3861 ...completed
# loading data 3610/3861 ...completed
# loading data 3611/3861 ...completed
# loading data 3612/3861 ...completed
# loading data 3613/3861 ...completed
# loading data 3614/3861 ...completed
# loading data 3615/3861 ...completed
# loading data 3616/3861 ...completed
# loading data 3617/3861 ...completed
# loading data 3618/3861 ...completed
# loading data 3619/3861 ...completed
# loading data 3620/3861 ...completed
# loading data 3621/3861 ...completed
# loading data 3622/3861 ...completed
# loading data 3623/3861 ...completed
# loading data 3624/3861 ...completed
# loading data 3625/3861 ...completed
# loading data 3626/3861 ...completed
# loading data 3627/3861 ...completed
# loading data 3628/3861 ...completed
# loading data 3629/3861 ...completed
# loading data 3630/3861 ...completed
# loading data 3631/3861 ...completed
# loading data 3632/3861 ...completed
# loading data 3633/3861 ...completed
# loading data 3634/3861 ...completed
# loading data 3635/3861 ...completed
# loading data 3636/3861 ...completed
# loading data 3637/3861 ...completed
# loading data 3638/3861 ...completed
# loading data 3639/3861 ...completed
# loading data 3640/3861 ...completed
# loading data 3641/3861 ...completed
# loading data 3642/3861 ...completed
# loading data 3643/3861 ...completed
# loading data 3644/3861 ...completed
# loading data 3645/3861 ...completed
# loading data 3646/3861 ...completed
# loading data 3647/3861 ...completed
# loading data 3648/3861 ...completed
# loading data 3649/3861 ...completed
# loading data 3650/3861 ...completed
# loading data 3651/3861 ...completed
# loading data 3652/3861 ...completed
# loading data 3653/3861 ...completed
# loading data 3654/3861 ...completed
# loading data 3655/3861 ...completed
# loading data 3656/3861 ...completed
# loading data 3657/3861 ...completed
# loading data 3658/3861 ...completed
# loading data 3659/3861 ...completed
# loading data 3660/3861 ...completed
# loading data 3661/3861 ...completed
# loading data 3662/3861 ...completed
# loading data 3663/3861 ...completed
# loading data 3664/3861 ...completed
# loading data 3665/3861 ...completed
# loading data 3666/3861 ...completed
# loading data 3667/3861 ...completed
# loading data 3668/3861 ...completed
# loading data 3669/3861 ...completed
# loading data 3670/3861 ...completed
# loading data 3671/3861 ...completed
# loading data 3672/3861 ...completed
# loading data 3673/3861 ...completed
# loading data 3674/3861 ...completed
# loading data 3675/3861 ...completed
# loading data 3676/3861 ...completed
# loading data 3677/3861 ...completed
# loading data 3678/3861 ...completed
# loading data 3679/3861 ...completed
# loading data 3680/3861 ...completed
# loading data 3681/3861 ...completed
# loading data 3682/3861 ...completed
# loading data 3683/3861 ...completed
# loading data 3684/3861 ...completed
# loading data 3685/3861 ...completed
# loading data 3686/3861 ...completed
# loading data 3687/3861 ...completed
# loading data 3688/3861 ...completed
# loading data 3689/3861 ...completed
# loading data 3690/3861 ...completed
# loading data 3691/3861 ...completed
# loading data 3692/3861 ...completed
# loading data 3693/3861 ...completed
# loading data 3694/3861 ...completed
# loading data 3695/3861 ...completed
# loading data 3696/3861 ...completed
# loading data 3697/3861 ...completed
# loading data 3698/3861 ...completed
# loading data 3699/3861 ...completed
# loading data 3700/3861 ...completed
# loading data 3701/3861 ...completed
# loading data 3702/3861 ...completed
# loading data 3703/3861 ...completed
# loading data 3704/3861 ...completed
# loading data 3705/3861 ...completed
# loading data 3706/3861 ...completed
# loading data 3707/3861 ...completed
# loading data 3708/3861 ...completed
# loading data 3709/3861 ...completed
# loading data 3710/3861 ...completed
# loading data 3711/3861 ...completed
# loading data 3712/3861 ...completed
# loading data 3713/3861 ...completed
# loading data 3714/3861 ...completed
# loading data 3715/3861 ...completed
# loading data 3716/3861 ...completed
# loading data 3717/3861 ...completed
# loading data 3718/3861 ...completed
# loading data 3719/3861 ...completed
# loading data 3720/3861 ...completed
# loading data 3721/3861 ...completed
# loading data 3722/3861 ...completed
# loading data 3723/3861 ...completed
# loading data 3724/3861 ...completed
# loading data 3725/3861 ...completed
# loading data 3726/3861 ...completed
# loading data 3727/3861 ...completed
# loading data 3728/3861 ...completed
# loading data 3729/3861 ...completed
# loading data 3730/3861 ...completed
# loading data 3731/3861 ...completed
# loading data 3732/3861 ...completed
# loading data 3733/3861 ...completed
# loading data 3734/3861 ...completed
# loading data 3735/3861 ...completed
# loading data 3736/3861 ...completed
# loading data 3737/3861 ...completed
# loading data 3738/3861 ...completed
# loading data 3739/3861 ...completed
# loading data 3740/3861 ...completed
# loading data 3741/3861 ...completed
# loading data 3742/3861 ...completed
# loading data 3743/3861 ...completed
# loading data 3744/3861 ...completed
# loading data 3745/3861 ...completed
# loading data 3746/3861 ...completed
# loading data 3747/3861 ...completed
# loading data 3748/3861 ...completed
# loading data 3749/3861 ...completed
# loading data 3750/3861 ...completed
# loading data 3751/3861 ...completed
# loading data 3752/3861 ...completed
# loading data 3753/3861 ...completed
# loading data 3754/3861 ...completed
# loading data 3755/3861 ...completed
# loading data 3756/3861 ...completed
# loading data 3757/3861 ...completed
# loading data 3758/3861 ...completed
# loading data 3759/3861 ...completed
# loading data 3760/3861 ...completed
# loading data 3761/3861 ...completed
# loading data 3762/3861 ...completed
# loading data 3763/3861 ...completed
# loading data 3764/3861 ...completed
# loading data 3765/3861 ...completed
# loading data 3766/3861 ...completed
# loading data 3767/3861 ...completed
# loading data 3768/3861 ...completed
# loading data 3769/3861 ...completed
# loading data 3770/3861 ...completed
# loading data 3771/3861 ...completed
# loading data 3772/3861 ...completed
# loading data 3773/3861 ...completed
# loading data 3774/3861 ...completed
# loading data 3775/3861 ...completed
# loading data 3776/3861 ...completed
# loading data 3777/3861 ...completed
# loading data 3778/3861 ...completed
# loading data 3779/3861 ...completed
# loading data 3780/3861 ...completed
# loading data 3781/3861 ...completed
# loading data 3782/3861 ...completed
# loading data 3783/3861 ...completed
# loading data 3784/3861 ...completed
# loading data 3785/3861 ...completed
# loading data 3786/3861 ...completed
# loading data 3787/3861 ...completed
# loading data 3788/3861 ...completed
# loading data 3789/3861 ...completed
# loading data 3790/3861 ...completed
# loading data 3791/3861 ...completed
# loading data 3792/3861 ...completed
# loading data 3793/3861 ...completed
# loading data 3794/3861 ...completed
# loading data 3795/3861 ...completed
# loading data 3796/3861 ...completed
# loading data 3797/3861 ...completed
# loading data 3798/3861 ...completed
# loading data 3799/3861 ...completed
# loading data 3800/3861 ...completed
# loading data 3801/3861 ...completed
# loading data 3802/3861 ...completed
# loading data 3803/3861 ...completed
# loading data 3804/3861 ...completed
# loading data 3805/3861 ...completed
# loading data 3806/3861 ...completed
# loading data 3807/3861 ...completed
# loading data 3808/3861 ...completed
# loading data 3809/3861 ...completed
# loading data 3810/3861 ...completed
# loading data 3811/3861 ...completed
# loading data 3812/3861 ...completed
# loading data 3813/3861 ...completed
# loading data 3814/3861 ...completed
# loading data 3815/3861 ...completed
# loading data 3816/3861 ...completed
# loading data 3817/3861 ...completed
# loading data 3818/3861 ...completed
# loading data 3819/3861 ...completed
# loading data 3820/3861 ...completed
# loading data 3821/3861 ...completed
# loading data 3822/3861 ...completed
# loading data 3823/3861 ...completed
# loading data 3824/3861 ...completed
# loading data 3825/3861 ...completed
# loading data 3826/3861 ...completed
# loading data 3827/3861 ...completed
# loading data 3828/3861 ...completed
# loading data 3829/3861 ...completed
# loading data 3830/3861 ...completed
# loading data 3831/3861 ...completed
# loading data 3832/3861 ...completed
# loading data 3833/3861 ...completed
# loading data 3834/3861 ...completed
# loading data 3835/3861 ...completed
# loading data 3836/3861 ...completed
# loading data 3837/3861 ...completed
# loading data 3838/3861 ...completed
# loading data 3839/3861 ...completed
# loading data 3840/3861 ...completed
# loading data 3841/3861 ...completed
# loading data 3842/3861 ...completed
# loading data 3843/3861 ...completed
# loading data 3844/3861 ...completed
# loading data 3845/3861 ...completed
# loading data 3846/3861 ...completed
# loading data 3847/3861 ...completed
# loading data 3848/3861 ...completed
# loading data 3849/3861 ...completed
# loading data 3850/3861 ...completed
# loading data 3851/3861 ...completed
# loading data 3852/3861 ...completed
# loading data 3853/3861 ...completed
# loading data 3854/3861 ...completed
# loading data 3855/3861 ...completed
# loading data 3856/3861 ...completed
# loading data 3857/3861 ...completed
# loading data 3858/3861 ...completed
# loading data 3859/3861 ...completed
# loading data 3860/3861 ...completed
# loading data 3861/3861 ...completed
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:150: ComplexWarning: Casting complex values to real discards the imaginary part
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:151: ComplexWarning: Casting complex values to real discards the imaginary part
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:152: ComplexWarning: Casting complex values to real discards the imaginary part
# saving...done
# size of training set(preop): 11380
# size of validation set(preop): 1231
# size of test set(preop): 1298

# %%
np.array(x_train_preop).shape
# Out:
# (5489, 2, 180, 128)

# %%
n_window
# Out:
# 180
