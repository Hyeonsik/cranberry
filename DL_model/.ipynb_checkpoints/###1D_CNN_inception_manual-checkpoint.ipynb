# %% [markdown]
# # Train, test loading

# %%
print('loading train...', flush=True, end='')

# x를 loading해서 (batch_size, step, channel)
input_path = '../DL_model/dataset/preprocess2/input3-2/'
x_train = np.load(input_path+'x_train.npz', allow_pickle=True)['arr_0']
x_test = np.load(input_path+'x_test.npz', allow_pickle=True)['arr_0']
x_val = np.load(input_path+'x_val.npz', allow_pickle=True)['arr_0']
y_train = np.load(input_path+'y_train.npz')['arr_0']
y_test = np.load(input_path+'y_test.npz')['arr_0']
y_val = np.load(input_path+'y_val.npz')['arr_0']
print('done', flush=True)


print('x_train shape:', x_train.shape)
print('x_test.shape:', x_test.shape)
print('x_val.shape:', x_val.shape)

                              
# binary classification
y_train_bin = y_train >= 4
y_test_bin = y_test >= 4
y_val_bin = y_val >= 4
# Out:
# loading train...done
# x_train shape: (116619, 5000, 2)
# x_test.shape: (13749, 5000, 2)
# x_val.shape: (13128, 5000, 2)

# %% [markdown]
# ## Sample weight

# %% [markdown]
# ### 2 class

# %%
# 2 class에 대한 sample weight
train_w_samp2 = np.ones(shape=(len(y_train),))
train_w_samp2[y_train_bin==0]= len(y_train) / np.sum(y_train_bin)
train_w_samp2[y_train_bin!=0]= len(y_train) / np.sum(~y_train_bin)


print('train set')
print('sample weight for no pain: {:.2f}, moderate pain: {:.2f}'
      .format(len(y_train) / np.sum(y_train_bin), len(y_train) / np.sum(~y_train_bin)))


# 2 class에 대한 sample weight
val_w_samp2 = np.ones(shape=(len(y_val),))
val_w_samp2[y_val_bin==0]= len(y_val) / np.sum(y_val_bin)
val_w_samp2[y_val_bin!=0]= len(y_val) / np.sum(~y_val_bin)

print('val set')
print('sample weight for no pain: {:.2f}, moderate pain: {:.2f}'
      .format(len(y_val) / np.sum(y_val_bin), len(y_val) / np.sum(~y_val_bin)))

# 2 class에 대한 sample weight
test_w_samp2 = np.ones(shape=(len(y_test),))
test_w_samp2[y_test_bin==0]= len(y_test) / np.sum(y_test_bin)
test_w_samp2[y_test_bin!=0]= len(y_test) / np.sum(~y_test_bin)


print('test set')
print('sample weight for no pain: {:.2f}, moderate pain: {:.2f}'
      .format(len(y_test) / np.sum(y_test_bin), len(y_test) / np.sum(~y_test_bin)))
# Out:
# train set
# sample weight for no pain: 1.65, moderate pain: 2.54
# val set
# sample weight for no pain: 1.64, moderate pain: 2.57
# test set
# sample weight for no pain: 1.73, moderate pain: 2.38

# %% [markdown]
# ## cf) shuffling

# %%
# random shuffling - train set
ids = np.arange(x_train.shape[0])
np.random.shuffle(ids)

x_train = x_train[ids]
y_train = y_train[ids]


# random shuffling - vall set
ids = np.arange(x_val.shape[0])
np.random.shuffle(ids)

x_val = x_val[ids]
y_val = y_val[ids]


# random shuffling
ids = np.arange(x_test.shape[0])
np.random.shuffle(ids)

x_test = x_test[ids]
y_test = y_test[ids]

# %%
print('y_train의 평균: {:.4f}, y_test의 평균: {:.4f}'.format(np.mean(y_train_bin), np.mean(y_test_bin)))
print('y_val의 평균: {:.4f}'.format(np.mean(y_val_bin)))
# Out:
# y_train의 평균: 0.6065, y_test의 평균: 0.5790
# y_val의 평균: 0.6111

# %% [markdown]
# ## GPU settings

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 4 Physical GPUs, 4 Logical GPUs

# %% [markdown]
# # Model

# %%
from keras.models import Sequential
from keras.models import Model, load_model
from keras.optimizers import Adam as Adam
from keras.layers import Dense, Conv1D, MaxPooling1D, GlobalMaxPool1D, BatchNormalization, Dropout, Activation
from keras.layers import GlobalAveragePooling1D, Flatten, SeparableConv1D, AveragePooling1D, Input, concatenate, add, LSTM, Average
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import auc, classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score, f1_score, precision_recall_curve
import tensorflow as tf
import os, pickle
from keras import backend as K


def inception(inp, nfilters=32):
    # 각각은 길이가 줄어들지 않는다

    # 1 conv
    c1 = Conv1D(filters=nfilters, kernel_size=1, kernel_initializer='glorot_uniform', padding='same', activation='relu')(inp)

    # 3 reduce
    c2 = Conv1D(filters=nfilters  , kernel_size=1, kernel_initializer='glorot_uniform', padding='same', activation='relu')(inp)
    # 3 conv
    c2 = Conv1D(filters=nfilters, kernel_size=3, kernel_initializer='glorot_uniform', padding='same', activation='relu')(c2)

    # 5 reduce
    c3 = Conv1D(filters=nfilters, kernel_size=1, kernel_initializer='glorot_uniform', padding='same', activation='relu')(inp)
    # 5 conv
    c3 = Conv1D(filters=nfilters, kernel_size=5, kernel_initializer='glorot_uniform', padding='same', activation='relu')(c3)

    # pooling
    m1 = MaxPooling1D(pool_size=3, strides=1, padding='same')(inp)
    # pooling proj
    m1 = Conv1D(filters=nfilters, kernel_size=1, kernel_initializer='glorot_uniform', padding='same', activation='relu')(m1)

    return concatenate([c1, c2, c3, m1], axis=-1)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Inception with depth

# %%
from keras.models import Sequential
from keras.models import Model, load_model
from keras.optimizers import Adam as Adam
from keras.layers import Dense, Conv1D, MaxPooling1D, GlobalMaxPool1D, BatchNormalization, Dropout, Activation
from keras.layers import GlobalAveragePooling1D, Flatten, SeparableConv1D, AveragePooling1D, Input, concatenate, add, LSTM, Average
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import auc, classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score, f1_score, precision_recall_curve
import tensorflow as tf
import os, pickle
from keras import backend as K


# learning related hyperparamters
BATCH_SIZE = 1024
learning_rate = 0.002


# inception paramters
ngpu = 1
nfilters= 16
nlayer= 20
conv1 = 128
dense = 0
dropout1 = 0.2
dropout2 = 0
kernel1 = 3
kernel2 = 7


# 출력 폴더를 생성
model_name = 'Inception_bin_batch{}_conv{}_k{}x2_nfilter{}_nlayer{}_drop{}_dense{}_drop{}'.format(BATCH_SIZE, conv1,kernel1,nfilters,nlayer,dropout1,dense,dropout2)

save_path = "output/preprocess3/input3-2_PPG+ECG/"+model_name
if not os.path.exists(save_path):
    os.mkdir(save_path)
weight_path = save_path + "/weights.hdf5"



# GPU 설정
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"])
with strategy.scope():
    
    #inp_fnn = Input(shape=(x_train[0].shape[1],))
    inp_cnn = Input(shape=(x_train.shape[1], x_train.shape[2]))

    #out_fnn = inp_fnn
    #out_fnn = Dense(256,  activation='relu')(out_fnn)

    out_cnn = inp_cnn
    out_cnn = Conv1D(filters=conv1, kernel_size=kernel1, padding='same')(out_cnn)
    out_cnn = Conv1D(filters=conv1, kernel_size=kernel1, padding='same')(out_cnn)
    #out_cnn = Conv1D(filters=conv1, kernel_size=kernel_size, padding='same', activation='relu')(out_cnn)
    out_cnn = Activation('relu') (out_cnn)
    out_cnn = MaxPooling1D(pool_size=3, strides=2)(out_cnn)
    out_cnn = BatchNormalization()(out_cnn)

    out_cnn = Conv1D(filters=nfilters*4, kernel_size=7, padding='same', activation='relu')(out_cnn)
    out_cnn = MaxPooling1D(pool_size=3, strides=2)(out_cnn)
    out_cnn = BatchNormalization()(out_cnn)
    
    for ilayer in range(nlayer):
        #inp_blk = out_cnn
        out_cnn = inception(out_cnn, nfilters=nfilters)
        #out_cnn = Conv1D(filters=64, kernel_size=1, padding='same')(out_cnn)
        #out_cnn = add([out_cnn, inp_blk])
        #out_cnn = AveragePooling1D(pool_size=2)(out_cnn)
        
    out_cnn = GlobalAveragePooling1D()(out_cnn)
    out_cnn = Dropout(dropout1)(out_cnn)
    #out = concatenate([out_cnn, out_fnn])
    out = out_cnn
    if dense != 0:
        out = Dense(dense,  activation='tanh')(out)
        out = Dropout(dropout2)(out)
    out = Dense(1, activation='sigmoid')(out)

    model = Model(inputs=[inp_cnn], outputs=[out])
    
    
    # model 학습 설정
    model.compile(loss='binary_crossentropy', optimizer=Adam(lr=learning_rate), metrics=["acc", tf.keras.metrics.AUC()])
    hist = model.fit(x_train, y_train_bin, sample_weight = train_w_samp2, validation_data=(x_val, y_val_bin, val_w_samp2), epochs=100, batch_size=BATCH_SIZE, #class_weight={0:2, 1:1}, 
                            callbacks=[ModelCheckpoint(monitor='val_loss', filepath=weight_path, verbose=1, save_best_only=True),
                                        EarlyStopping(monitor='val_loss', patience=5, verbose=0, mode='auto')])

    #tf.keras.backend.clear_session()

model.load_weights(weight_path)
    
# 모델의 아키텍처 및 구조 저장
open(save_path + "/model.json", "wt").write(model.to_json())

# 전체 test 샘플을 한번에 예측
y_pred = model.predict(x_test).flatten()

# 결과를 저장
#np.savetxt(save_path+'/pred_y.txt', y_pred)


# 모델의 history log 저장 - binary classification
for key in hist.history.keys():
    if 'auc' in key and not 'val' in key:
        auc_key = key
#pickle.dump((hist.history['loss'], hist.history['val_loss'], hist.history['accuracy'], hist.history['val_accuracy'], hist.history[auc], hist.history['val_'+auc]), open(save_path+'/history', 'wb'))

# 모델의 history log 저장 - regression
pickle.dump((hist.history['loss'], hist.history['val_loss'], hist.history['acc'], hist.history['val_acc'], hist.history[auc_key], hist.history['val_'+auc_key]), open(save_path+'/history', 'wb'))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Epoch 1/100

# %% [markdown]
# #### Evaluation

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve
from numpy import interp
from keras import losses, metrics
import keras.backend as K
import matplotlib.pyplot as plt

### Classification
# Model Accuracy of test set
#model_y = y_pred>=0.5
#acc_val = np.mean(model_y==y_test_bin)
acc = metrics.Accuracy()
acc.update_state(y_pred>=0.5, y_test_bin, sample_weight=test_w_samp2)
acc_val = acc.result().numpy()
print('test set accuracy:{:.2f}'.format(acc_val))


# moderate pain
false_positive_rate, true_positive_rate, threshold = roc_curve(y_test_bin, y_pred, sample_weight = test_w_samp2)
precision, recall, _ = precision_recall_curve(y_test_bin, y_pred, sample_weight = test_w_samp2)
roc_auc = auc(false_positive_rate, true_positive_rate)
prc_auc = auc(recall, precision)
print('test set AUROC:', roc_auc)
print('test set AUPRC:', prc_auc)


# Adding evaluation results to file name
test_path = 'output/preprocess3/input3-2_PPG+ECG/auroc{:.4f}_auprc{:.4f}_{}acc{:.2f}'.format(roc_auc,prc_auc,model_name,acc_val)
os.rename(save_path, test_path)

# Plotting ROC, PRC
fig = plt.figure(figsize=(12,6))

# ax1: auroc
ax1 = fig.add_subplot(1,2,1)
ax1.set_title('Receiver Operating Characteristic')
ax1.set_xlabel("False Positive Rate(1 - Specificity)")
ax1.set_ylabel('True Positive Rate(Sensitivity)')
ax1.plot([0,1],[1,1],'y--')
ax1.plot([0,1],[0,1],'r--')
ax1.plot(false_positive_rate, true_positive_rate, 'b', label='moderate pain (AUC = %0.4f)'% roc_auc)

# ax2: auprc
ax2 = fig.add_subplot(1,2,2)
ax2.set_title('Precision - Recall Curve')
ax2.set_xlabel("Precision")
ax2.set_ylabel('Recall')
ax2.plot(recall, precision, 'b', label='moderate pain (AUC = %0.4f)'% prc_auc)

plt.savefig(test_path + '/roc_prc.png', bbox_inches="tight", pad_inches=0.5)
# Out:
# test set accuracy:0.82
# test set AUROC: 0.7683966993370343
# test set AUPRC: 0.813655427290173

# %%
model.summary()
# Out:
# Model: "functional_17"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 5000, 2)]    0
# __________________________________________________________________________________________________
# conv1d_684 (Conv1D)             (None, 5000, 128)    896         input_9[0][0]
# __________________________________________________________________________________________________
# conv1d_685 (Conv1D)             (None, 5000, 128)    49280       conv1d_684[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 5000, 128)    0           conv1d_685[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_126 (MaxPooling1D (None, 2499, 128)    0           activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 2499, 128)    512         max_pooling1d_126[0][0]
# __________________________________________________________________________________________________
# conv1d_686 (Conv1D)             (None, 2499, 64)     57408       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_127 (MaxPooling1D (None, 1249, 64)     0           conv1d_686[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 1249, 64)     256         max_pooling1d_127[0][0]
# __________________________________________________________________________________________________
# conv1d_688 (Conv1D)             (None, 1249, 16)     1040        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_690 (Conv1D)             (None, 1249, 16)     1040        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_128 (MaxPooling1D (None, 1249, 64)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_687 (Conv1D)             (None, 1249, 16)     1040        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_689 (Conv1D)             (None, 1249, 16)     784         conv1d_688[0][0]
# __________________________________________________________________________________________________
# conv1d_691 (Conv1D)             (None, 1249, 16)     1296        conv1d_690[0][0]
# __________________________________________________________________________________________________
# conv1d_692 (Conv1D)             (None, 1249, 16)     1040        max_pooling1d_128[0][0]
# __________________________________________________________________________________________________
# concatenate_110 (Concatenate)   (None, 1249, 64)     0           conv1d_687[0][0]
#                                                                  conv1d_689[0][0]
#                                                                  conv1d_691[0][0]
#                                                                  conv1d_692[0][0]
# __________________________________________________________________________________________________
# conv1d_694 (Conv1D)             (None, 1249, 16)     1040        concatenate_110[0][0]
# __________________________________________________________________________________________________
# conv1d_696 (Conv1D)             (None, 1249, 16)     1040        concatenate_110[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_129 (MaxPooling1D (None, 1249, 64)     0           concatenate_110[0][0]
# __________________________________________________________________________________________________
# conv1d_693 (Conv1D)             (None, 1249, 16)     1040        concatenate_110[0][0]
# __________________________________________________________________________________________________
# conv1d_695 (Conv1D)             (None, 1249, 16)     784         conv1d_694[0][0]
# __________________________________________________________________________________________________
# conv1d_697 (Conv1D)             (None, 1249, 16)     1296        conv1d_696[0][0]
# __________________________________________________________________________________________________
# conv1d_698 (Conv1D)             (None, 1249, 16)     1040        max_pooling1d_129[0][0]
# __________________________________________________________________________________________________
# concatenate_111 (Concatenate)   (None, 1249, 64)     0           conv1d_693[0][0]
#                                                                  conv1d_695[0][0]
#                                                                  conv1d_697[0][0]
#                                                                  conv1d_698[0][0]
# __________________________________________________________________________________________________
# conv1d_700 (Conv1D)             (None, 1249, 16)     1040        concatenate_111[0][0]
# __________________________________________________________________________________________________
# conv1d_702 (Conv1D)             (None, 1249, 16)     1040        concatenate_111[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_130 (MaxPooling1D (None, 1249, 64)     0           concatenate_111[0][0]
# __________________________________________________________________________________________________
# conv1d_699 (Conv1D)             (None, 1249, 16)     1040        concatenate_111[0][0]
# __________________________________________________________________________________________________
# conv1d_701 (Conv1D)             (None, 1249, 16)     784         conv1d_700[0][0]
# __________________________________________________________________________________________________
# conv1d_703 (Conv1D)             (None, 1249, 16)     1296        conv1d_702[0][0]
# __________________________________________________________________________________________________
# conv1d_704 (Conv1D)             (None, 1249, 16)     1040        max_pooling1d_130[0][0]
# __________________________________________________________________________________________________
# concatenate_112 (Concatenate)   (None, 1249, 64)     0           conv1d_699[0][0]
#                                                                  conv1d_701[0][0]
#                                                                  conv1d_703[0][0]
#                                                                  conv1d_704[0][0]
# __________________________________________________________________________________________________
# conv1d_706 (Conv1D)             (None, 1249, 16)     1040        concatenate_112[0][0]
# __________________________________________________________________________________________________
# conv1d_708 (Conv1D)             (None, 1249, 16)     1040        concatenate_112[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_131 (MaxPooling1D (None, 1249, 64)     0           concatenate_112[0][0]
# __________________________________________________________________________________________________
# conv1d_705 (Conv1D)             (None, 1249, 16)     1040        concatenate_112[0][0]
# __________________________________________________________________________________________________
# conv1d_707 (Conv1D)             (None, 1249, 16)     784         conv1d_706[0][0]
# __________________________________________________________________________________________________
# conv1d_709 (Conv1D)             (None, 1249, 16)     1296        conv1d_708[0][0]
# __________________________________________________________________________________________________
# conv1d_710 (Conv1D)             (None, 1249, 16)     1040        max_pooling1d_131[0][0]
# __________________________________________________________________________________________________
# concatenate_113 (Concatenate)   (None, 1249, 64)     0           conv1d_705[0][0]
#                                                                  conv1d_707[0][0]
#                                                                  conv1d_709[0][0]
#                                                                  conv1d_710[0][0]
# __________________________________________________________________________________________________
# conv1d_712 (Conv1D)             (None, 1249, 16)     1040        concatenate_113[0][0]
# __________________________________________________________________________________________________
# conv1d_714 (Conv1D)             (None, 1249, 16)     1040        concatenate_113[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_132 (MaxPooling1D (None, 1249, 64)     0           concatenate_113[0][0]
# __________________________________________________________________________________________________
# conv1d_711 (Conv1D)             (None, 1249, 16)     1040        concatenate_113[0][0]
# __________________________________________________________________________________________________
# conv1d_713 (Conv1D)             (None, 1249, 16)     784         conv1d_712[0][0]
# __________________________________________________________________________________________________
# conv1d_715 (Conv1D)             (None, 1249, 16)     1296        conv1d_714[0][0]
# __________________________________________________________________________________________________
# conv1d_716 (Conv1D)             (None, 1249, 16)     1040        max_pooling1d_132[0][0]
# __________________________________________________________________________________________________
# concatenate_114 (Concatenate)   (None, 1249, 64)     0           conv1d_711[0][0]
#                                                                  conv1d_713[0][0]
#                                                                  conv1d_715[0][0]
#                                                                  conv1d_716[0][0]
# __________________________________________________________________________________________________
# conv1d_718 (Conv1D)             (None, 1249, 16)     1040        concatenate_114[0][0]
# __________________________________________________________________________________________________
# conv1d_720 (Conv1D)             (None, 1249, 16)     1040        concatenate_114[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_133 (MaxPooling1D (None, 1249, 64)     0           concatenate_114[0][0]
# __________________________________________________________________________________________________
# conv1d_717 (Conv1D)             (None, 1249, 16)     1040        concatenate_114[0][0]
# __________________________________________________________________________________________________
# conv1d_719 (Conv1D)             (None, 1249, 16)     784         conv1d_718[0][0]
# __________________________________________________________________________________________________
# conv1d_721 (Conv1D)             (None, 1249, 16)     1296        conv1d_720[0][0]
# __________________________________________________________________________________________________
# conv1d_722 (Conv1D)             (None, 1249, 16)     1040        max_pooling1d_133[0][0]
# __________________________________________________________________________________________________
# concatenate_115 (Concatenate)   (None, 1249, 64)     0           conv1d_717[0][0]
#                                                                  conv1d_719[0][0]
#                                                                  conv1d_721[0][0]
#                                                                  conv1d_722[0][0]
# __________________________________________________________________________________________________
# conv1d_724 (Conv1D)             (None, 1249, 16)     1040        concatenate_115[0][0]
# __________________________________________________________________________________________________
# conv1d_726 (Conv1D)             (None, 1249, 16)     1040        concatenate_115[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_134 (MaxPooling1D (None, 1249, 64)     0           concatenate_115[0][0]
# __________________________________________________________________________________________________
# conv1d_723 (Conv1D)             (None, 1249, 16)     1040        concatenate_115[0][0]
# __________________________________________________________________________________________________
# conv1d_725 (Conv1D)             (None, 1249, 16)     784         conv1d_724[0][0]
# __________________________________________________________________________________________________
# conv1d_727 (Conv1D)             (None, 1249, 16)     1296        conv1d_726[0][0]
# __________________________________________________________________________________________________
# conv1d_728 (Conv1D)             (None, 1249, 16)     1040        max_pooling1d_134[0][0]
# __________________________________________________________________________________________________
# concatenate_116 (Concatenate)   (None, 1249, 64)     0           conv1d_723[0][0]
#                                                                  conv1d_725[0][0]
#                                                                  conv1d_727[0][0]
#                                                                  conv1d_728[0][0]
# __________________________________________________________________________________________________
# conv1d_730 (Conv1D)             (None, 1249, 16)     1040        concatenate_116[0][0]
# __________________________________________________________________________________________________
# conv1d_732 (Conv1D)             (None, 1249, 16)     1040        concatenate_116[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_135 (MaxPooling1D (None, 1249, 64)     0           concatenate_116[0][0]
# __________________________________________________________________________________________________
# conv1d_729 (Conv1D)             (None, 1249, 16)     1040        concatenate_116[0][0]
# __________________________________________________________________________________________________
# conv1d_731 (Conv1D)             (None, 1249, 16)     784         conv1d_730[0][0]
# __________________________________________________________________________________________________
# conv1d_733 (Conv1D)             (None, 1249, 16)     1296        conv1d_732[0][0]
# __________________________________________________________________________________________________
# conv1d_734 (Conv1D)             (None, 1249, 16)     1040        max_pooling1d_135[0][0]
# __________________________________________________________________________________________________
# concatenate_117 (Concatenate)   (None, 1249, 64)     0           conv1d_729[0][0]
#                                                                  conv1d_731[0][0]
#                                                                  conv1d_733[0][0]
#                                                                  conv1d_734[0][0]
# __________________________________________________________________________________________________
# conv1d_736 (Conv1D)             (None, 1249, 16)     1040        concatenate_117[0][0]
# __________________________________________________________________________________________________
# conv1d_738 (Conv1D)             (None, 1249, 16)     1040        concatenate_117[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_136 (MaxPooling1D (None, 1249, 64)     0           concatenate_117[0][0]
# __________________________________________________________________________________________________
# conv1d_735 (Conv1D)             (None, 1249, 16)     1040        concatenate_117[0][0]
# __________________________________________________________________________________________________
# conv1d_737 (Conv1D)             (None, 1249, 16)     784         conv1d_736[0][0]
# __________________________________________________________________________________________________
# conv1d_739 (Conv1D)             (None, 1249, 16)     1296        conv1d_738[0][0]
# __________________________________________________________________________________________________
# conv1d_740 (Conv1D)             (None, 1249, 16)     1040        max_pooling1d_136[0][0]
# __________________________________________________________________________________________________
# concatenate_118 (Concatenate)   (None, 1249, 64)     0           conv1d_735[0][0]
#                                                                  conv1d_737[0][0]
#                                                                  conv1d_739[0][0]
#                                                                  conv1d_740[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_8 (Glo (None, 64)           0           concatenate_118[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64)           0           global_average_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            65          dropout_8[0][0]
# ==================================================================================================
# Total params: 164,577
# Trainable params: 164,193
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %% [markdown]
# ### Simple Inception

# %%
from keras.models import Sequential
from keras.models import Model, load_model
from keras.optimizers import Adam as Adam
from keras.layers import Dense, Conv1D, MaxPooling1D, GlobalMaxPool1D, BatchNormalization, Dropout, Activation
from keras.layers import GlobalAveragePooling1D, Flatten, SeparableConv1D, AveragePooling1D, Input, concatenate, add, LSTM, Average
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import auc, classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score, f1_score, precision_recall_curve
import tensorflow as tf
import os, pickle
from keras import backend as K


# learning related hyperparamters
BATCH_SIZE = 512
learning_rate = 0.002


# inception paramters
ngpu = 1
nfilters=32
nlayer=1
conv1 = 64
dense = 8
dropout1 = 0.2
dropout2 = 0.2


# initializer & regularizer
#k_init = he_normal(seed=None)
#k_init = None
b_init = None
k_l2 = 0
#k_reg = regularizers.l2(l2=k_l2)
k_reg = None
b_reg = None




# 출력 폴더를 생성
model_name = 'model(NRS4)_bin_batch{}_nfilter{}_nlayer{}_drop{}_dense{}_drop{}'.format(BATCH_SIZE,nfilters,nlayer,dropout1,dense,dropout2)

save_path = "output/input3-2_PPG+ECG/Inception_"+model_name
if not os.path.exists(save_path):
    os.mkdir(save_path)
weight_path = save_path + "/weights.hdf5"



# GPU 설정
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:2", "/gpu:3"])
with strategy.scope():
    
    #inp_fnn = Input(shape=(x_train[0].shape[1],))
    inp_cnn = Input(shape=(x_train.shape[1], x_train.shape[2]))
    out_cnn = inp_cnn
    
    for ilayer in range(nlayer):
        #inp_blk = out_cnn
        out_cnn = inception(out_cnn, nfilters=nfilters)
        #out_cnn = Conv1D(filters=64, kernel_size=1, padding='same')(out_cnn)
        #out_cnn = add([out_cnn, inp_blk])
        #out_cnn = AveragePooling1D(pool_size=2)(out_cnn)
    out_cnn = GlobalAveragePooling1D()(out_cnn)
    out_cnn = Dropout(dropout1)(out_cnn)
    #out = concatenate([out_cnn, out_fnn])
    out = out_cnn
    #out = Dense(256,  activation='relu')(out)
    #out = Dense(dense,  activation='tanh')(out)
    #out = Dropout(dropout2)(out)
    out = Dense(1, activation='sigmoid', kernel_initializer = k_init)(out)

    model = Model(inputs=[inp_cnn], outputs=[out])
    
    
    # model 학습 설정
    model.compile(loss='binary_crossentropy', optimizer=Adam(lr=learning_rate), metrics=["acc", tf.keras.metrics.AUC()])
    hist = model.fit(x_train, y_train_bin, validation_data=(x_val, y_val_bin), epochs=100, batch_size=BATCH_SIZE, #class_weight={0:2, 1:1}, 
                            callbacks=[ModelCheckpoint(monitor='val_loss', filepath=weight_path, verbose=1, save_best_only=True),
                                        EarlyStopping(monitor='val_loss', patience=5, verbose=0, mode='auto')])

    #tf.keras.backend.clear_session()

model.load_weights(weight_path)
    
# 모델의 아키텍처 및 구조 저장
open(save_path + "/model.json", "wt").write(model.to_json())

# 전체 test 샘플을 한번에 예측
y_pred = model.predict(x_test).flatten()

# 결과를 저장
#np.savetxt(save_path+'/pred_y.txt', y_pred)


# 모델의 history log 저장 - binary classification
for key in hist.history.keys():
    if 'auc' in key and not 'val' in key:
        auc_key = key
#pickle.dump((hist.history['loss'], hist.history['val_loss'], hist.history['accuracy'], hist.history['val_accuracy'], hist.history[auc], hist.history['val_'+auc]), open(save_path+'/history', 'wb'))

# 모델의 history log 저장 - regression
pickle.dump((hist.history['loss'], hist.history['val_loss'], hist.history['acc'], hist.history['val_acc'], hist.history[auc_key], hist.history['val_'+auc_key]), open(save_path+'/history', 'wb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-8df76ee19b0c> in <module>
#      43 save_path = "output/input3-2_PPG+ECG/Inception_"+model_name
#      44 if not os.path.exists(save_path):
# ---> 45     os.mkdir(save_path)
#      46 weight_path = save_path + "/weights.hdf5"
#      47
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/input3-2_PPG+ECG/Inception_model(NRS4)_bin_batch512_nfilter32_nlayer1_drop0.2_dense8_drop0.2'

# %%
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 5000, 2)]    0
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, 5000, 128)    896         input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, 5000, 128)    49280       conv1d_63[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 5000, 128)    0           conv1d_64[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_12 (MaxPooling1D) (None, 2499, 128)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 2499, 128)    512         max_pooling1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, 2499, 64)     57408       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_13 (MaxPooling1D) (None, 1249, 64)     0           conv1d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 1249, 64)     256         max_pooling1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_67 (Conv1D)              (None, 1249, 16)     1040        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv1d_69 (Conv1D)              (None, 1249, 16)     1040        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_14 (MaxPooling1D) (None, 1249, 64)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv1d_66 (Conv1D)              (None, 1249, 16)     1040        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv1d_68 (Conv1D)              (None, 1249, 16)     784         conv1d_67[0][0]
# __________________________________________________________________________________________________
# conv1d_70 (Conv1D)              (None, 1249, 16)     1296        conv1d_69[0][0]
# __________________________________________________________________________________________________
# conv1d_71 (Conv1D)              (None, 1249, 16)     1040        max_pooling1d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 1249, 64)     0           conv1d_66[0][0]
#                                                                  conv1d_68[0][0]
#                                                                  conv1d_70[0][0]
#                                                                  conv1d_71[0][0]
# __________________________________________________________________________________________________
# conv1d_73 (Conv1D)              (None, 1249, 16)     1040        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_75 (Conv1D)              (None, 1249, 16)     1040        concatenate_10[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_15 (MaxPooling1D) (None, 1249, 64)     0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_72 (Conv1D)              (None, 1249, 16)     1040        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_74 (Conv1D)              (None, 1249, 16)     784         conv1d_73[0][0]
# __________________________________________________________________________________________________
# conv1d_76 (Conv1D)              (None, 1249, 16)     1296        conv1d_75[0][0]
# __________________________________________________________________________________________________
# conv1d_77 (Conv1D)              (None, 1249, 16)     1040        max_pooling1d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 1249, 64)     0           conv1d_72[0][0]
#                                                                  conv1d_74[0][0]
#                                                                  conv1d_76[0][0]
#                                                                  conv1d_77[0][0]
# __________________________________________________________________________________________________
# conv1d_79 (Conv1D)              (None, 1249, 16)     1040        concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv1d_81 (Conv1D)              (None, 1249, 16)     1040        concatenate_11[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_16 (MaxPooling1D) (None, 1249, 64)     0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv1d_78 (Conv1D)              (None, 1249, 16)     1040        concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv1d_80 (Conv1D)              (None, 1249, 16)     784         conv1d_79[0][0]
# __________________________________________________________________________________________________
# conv1d_82 (Conv1D)              (None, 1249, 16)     1296        conv1d_81[0][0]
# __________________________________________________________________________________________________
# conv1d_83 (Conv1D)              (None, 1249, 16)     1040        max_pooling1d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 1249, 64)     0           conv1d_78[0][0]
#                                                                  conv1d_80[0][0]
#                                                                  conv1d_82[0][0]
#                                                                  conv1d_83[0][0]
# __________________________________________________________________________________________________
# conv1d_85 (Conv1D)              (None, 1249, 16)     1040        concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv1d_87 (Conv1D)              (None, 1249, 16)     1040        concatenate_12[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_17 (MaxPooling1D) (None, 1249, 64)     0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv1d_84 (Conv1D)              (None, 1249, 16)     1040        concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv1d_86 (Conv1D)              (None, 1249, 16)     784         conv1d_85[0][0]
# __________________________________________________________________________________________________
# conv1d_88 (Conv1D)              (None, 1249, 16)     1296        conv1d_87[0][0]
# __________________________________________________________________________________________________
# conv1d_89 (Conv1D)              (None, 1249, 16)     1040        max_pooling1d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 1249, 64)     0           conv1d_84[0][0]
#                                                                  conv1d_86[0][0]
#                                                                  conv1d_88[0][0]
#                                                                  conv1d_89[0][0]
# __________________________________________________________________________________________________
# conv1d_91 (Conv1D)              (None, 1249, 16)     1040        concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv1d_93 (Conv1D)              (None, 1249, 16)     1040        concatenate_13[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_18 (MaxPooling1D) (None, 1249, 64)     0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv1d_90 (Conv1D)              (None, 1249, 16)     1040        concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv1d_92 (Conv1D)              (None, 1249, 16)     784         conv1d_91[0][0]
# __________________________________________________________________________________________________
# conv1d_94 (Conv1D)              (None, 1249, 16)     1296        conv1d_93[0][0]
# __________________________________________________________________________________________________
# conv1d_95 (Conv1D)              (None, 1249, 16)     1040        max_pooling1d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 1249, 64)     0           conv1d_90[0][0]
#                                                                  conv1d_92[0][0]
#                                                                  conv1d_94[0][0]
#                                                                  conv1d_95[0][0]
# __________________________________________________________________________________________________
# conv1d_97 (Conv1D)              (None, 1249, 16)     1040        concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv1d_99 (Conv1D)              (None, 1249, 16)     1040        concatenate_14[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_19 (MaxPooling1D) (None, 1249, 64)     0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv1d_96 (Conv1D)              (None, 1249, 16)     1040        concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv1d_98 (Conv1D)              (None, 1249, 16)     784         conv1d_97[0][0]
# __________________________________________________________________________________________________
# conv1d_100 (Conv1D)             (None, 1249, 16)     1296        conv1d_99[0][0]
# __________________________________________________________________________________________________
# conv1d_101 (Conv1D)             (None, 1249, 16)     1040        max_pooling1d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 1249, 64)     0           conv1d_96[0][0]
#                                                                  conv1d_98[0][0]
#                                                                  conv1d_100[0][0]
#                                                                  conv1d_101[0][0]
# __________________________________________________________________________________________________
# conv1d_103 (Conv1D)             (None, 1249, 16)     1040        concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv1d_105 (Conv1D)             (None, 1249, 16)     1040        concatenate_15[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_20 (MaxPooling1D) (None, 1249, 64)     0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv1d_102 (Conv1D)             (None, 1249, 16)     1040        concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv1d_104 (Conv1D)             (None, 1249, 16)     784         conv1d_103[0][0]
# __________________________________________________________________________________________________
# conv1d_106 (Conv1D)             (None, 1249, 16)     1296        conv1d_105[0][0]
# __________________________________________________________________________________________________
# conv1d_107 (Conv1D)             (None, 1249, 16)     1040        max_pooling1d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 1249, 64)     0           conv1d_102[0][0]
#                                                                  conv1d_104[0][0]
#                                                                  conv1d_106[0][0]
#                                                                  conv1d_107[0][0]
# __________________________________________________________________________________________________
# conv1d_109 (Conv1D)             (None, 1249, 16)     1040        concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv1d_111 (Conv1D)             (None, 1249, 16)     1040        concatenate_16[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_21 (MaxPooling1D) (None, 1249, 64)     0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv1d_108 (Conv1D)             (None, 1249, 16)     1040        concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv1d_110 (Conv1D)             (None, 1249, 16)     784         conv1d_109[0][0]
# __________________________________________________________________________________________________
# conv1d_112 (Conv1D)             (None, 1249, 16)     1296        conv1d_111[0][0]
# __________________________________________________________________________________________________
# conv1d_113 (Conv1D)             (None, 1249, 16)     1040        max_pooling1d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 1249, 64)     0           conv1d_108[0][0]
#                                                                  conv1d_110[0][0]
#                                                                  conv1d_112[0][0]
#                                                                  conv1d_113[0][0]
# __________________________________________________________________________________________________
# conv1d_115 (Conv1D)             (None, 1249, 16)     1040        concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv1d_117 (Conv1D)             (None, 1249, 16)     1040        concatenate_17[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_22 (MaxPooling1D) (None, 1249, 64)     0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv1d_114 (Conv1D)             (None, 1249, 16)     1040        concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv1d_116 (Conv1D)             (None, 1249, 16)     784         conv1d_115[0][0]
# __________________________________________________________________________________________________
# conv1d_118 (Conv1D)             (None, 1249, 16)     1296        conv1d_117[0][0]
# __________________________________________________________________________________________________
# conv1d_119 (Conv1D)             (None, 1249, 16)     1040        max_pooling1d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 1249, 64)     0           conv1d_114[0][0]
#                                                                  conv1d_116[0][0]
#                                                                  conv1d_118[0][0]
#                                                                  conv1d_119[0][0]
# __________________________________________________________________________________________________
# conv1d_121 (Conv1D)             (None, 1249, 16)     1040        concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv1d_123 (Conv1D)             (None, 1249, 16)     1040        concatenate_18[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_23 (MaxPooling1D) (None, 1249, 64)     0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv1d_120 (Conv1D)             (None, 1249, 16)     1040        concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv1d_122 (Conv1D)             (None, 1249, 16)     784         conv1d_121[0][0]
# __________________________________________________________________________________________________
# conv1d_124 (Conv1D)             (None, 1249, 16)     1296        conv1d_123[0][0]
# __________________________________________________________________________________________________
# conv1d_125 (Conv1D)             (None, 1249, 16)     1040        max_pooling1d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 1249, 64)     0           conv1d_120[0][0]
#                                                                  conv1d_122[0][0]
#                                                                  conv1d_124[0][0]
#                                                                  conv1d_125[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 64)           0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            65          dropout_1[0][0]
# ==================================================================================================
# Total params: 170,817
# Trainable params: 170,433
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %% [markdown]
# ## Model evaluation

# %%
from sklearn.metrics import roc_curve, auc, r2_score
from numpy import interp
from keras import losses, metrics
import keras.backend as K
import matplotlib.pyplot as plt

### Classification
# Model Accuracy of test set
model_y = y_pred>=0.5
acc_val = np.mean(model_y==y_test_bin)
print('test set accuracy:{:.2f}'.format(acc_val))


# Model AUROC
false_positive_rate, true_positive_rate, threshold = roc_curve(y_test_bin, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
print('test set auroc:', roc_auc)

# Model R_square
#print('test set R2:', r2_score(y_test, y_pred*9))


# Adding evaluation results to file name
# classification
#os.rename(save_path, save_path+'_auc{:.4f}_acc{:.4f}'.format(roc_auc,np.mean(model_y==y_test_bin)))

# regression
os.rename(save_path, 'output/input3-2_PPG+ECG/auc{:.4f}_Inception_{}acc{:.2f}'.format(roc_auc,model_name,acc_val))


# plotting roc
plt.figure(figsize=(6,6))
plt.title('Receiver Operating Characteristic')
plt.xlabel("False Positive Rate(1 - Specificity)")
plt.ylabel('True Positive Rate(Sensitivity)')

plt.plot(false_positive_rate, true_positive_rate, 'b', label='Model 1 (AUC = %0.4f)'% roc_auc)
plt.plot([0,1],[1,1],'y--')
plt.plot([0,1],[0,1],'r--')

plt.legend(loc='lower right')
plt.show()
# Out:
# test set accuracy:0.78
# test set auroc: 0.7635833772420577

# %% [markdown]
# ## Model History Plot

# %%
# model auroc 0.719짜리
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots(figsize=(20,10))

#x-axis는 공유하지만 y-axis는 공유x
acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', linestyle='dashed', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

#acc_ax.plot(hist.history['mean_absolute_error'], 'b', linestyle='dashed',label='train mae')
#acc_ax.plot(hist.history['val_mean_absolute_error'], 'g', label='val mae')
acc_ax.plot(hist.history['acc'], 'b', linestyle='dashed',label='train acc')
acc_ax.plot(hist.history['val_acc'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylim(0.5,1.0)
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %% [markdown]
# ## 검증

# %%
test_result = model.evaluate(x=x_test, y=y_test_bin, batch_size=512, verbose=1, sample_weight=None, steps=None, callbacks=None)
# Out:
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5131 - acc: 0.7736 - auc: 0.7675

# %%
val_result = model.evaluate(x=x_val, y=y_val_bin, batch_size=BATCH_SIZE, verbose=1, sample_weight=None, steps=None, callbacks=None)
# Out:
# 26/26 [==============================] - 1s 29ms/step - loss: 0.4640 - acc: 0.7982 - auc: 0.7986

# %%
train_result = model.evaluate(x=x_train, y=y_train_bin, batch_size=BATCH_SIZE, verbose=1, sample_weight=None, steps=None, callbacks=None)
# Out:
# 228/228 [==============================] - 7s 32ms/step - loss: 0.3732 - acc: 0.8316 - auc: 0.8806

# %%
y_val_pred = model.predict(x_train[-13130:]).flatten()
y_val_pred = y_val_pred>=0.5

np.mean(y_train_bin[-13130:]==np.array(y_val_pred))
# Out:
# 0.970982482863671

# %%
print('y_train의 평균: {:.4f}, y_test의 평균: {:.4f}'.format(np.mean(y_train_bin), np.mean(y_test_bin)))
print('y_val의 평균: {:.4f}'.format(np.mean(y_train_bin[-13130:])))
# Out:
# y_train의 평균: 0.4847, y_test의 평균: 0.4669
# y_val의 평균: 0.4855

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.hist(y_train, bins='auto', color='b', label='train set')
plt.hist(y_test, bins='auto', color='r', label='test set')
plt.xticks(np.arange(0,11))
plt.legend(loc='best')

plt.figure(figsize=(20,10))
plt.hist(y_train, bins='auto', color='b', label='train set')
plt.hist(y_test, bins='auto', color='r', label='test set')
plt.xticks(np.arange(0,11))
plt.legend(loc='best')

# %%
plt.figure(figsize=(20,10))
plt.hist(y_train[:-13130], bins='auto', color='b', label='train set')
plt.xticks(np.arange(0,11))
plt.legend(loc='best')

plt.figure(figsize=(20,10))
plt.hist(y_train[-13130:], bins='auto', color='b', label='val set')
plt.xticks(np.arange(0,11))
plt.legend(loc='best')



plt.figure(figsize=(20,10))
plt.hist(y_test, bins='auto', color='r', label='test set')
plt.xticks(np.arange(0,11))
plt.legend(loc='best')

# %%
plt.plot(x_test[0,:,0])
plt.plot(x_test[1,:,0])
plt.show()

# %%
input_path = 'dataset/preprocess2/input3-2/'

# loading pacu
print('loading pacu data...', flush=True, end='')
x_train_pacu = np.load(input_path+'x_train_pacu.npz', allow_pickle=True)['arr_0']
# Out:
# loading pacu data...

# %%
np.mean(x_train_pacu[2,:,0])
# Out:
# -3.646425

# %%
plt.plot(x_train_pacu[0,0,:])
plt.plot(x_train_pacu[1,0,:])
plt.show()
