# %%
import statsmodels.api as sm


def smooth(y):
    #return savitzky_golay(y, window_size=2001, order=3)
    return lowess(y)

# 0.2가 제일 잘 없앴음
def lowess(y, f=0.2):
    x = np.arange(0, len(y))
    return sm.nonparametric.lowess(y, x, frac=f, it=0)[:, 1].T


import numpy as np
import pandas as pd
import os, pickle, sys
from scipy import signal
#sys.path.append('DL_model')


### input 설정
SRATE = 100 # 250Hz
LEN_INPUT = 20 # input 10s
LEN_PER_NRS = 60 # vital length for each NRS
OVERLAP = 2
n_aug = int((LEN_PER_NRS-LEN_INPUT)/OVERLAP) + 1 # data augmentation 개수




input_path = '../DL_model/dataset/preprocess4/PPG_100Hz/'
if not os.path.exists(input_path[:-1]):
    os.mkdir(input_path[:-1])

if os.path.exists(input_path+'x_train_pacu.npz'):
    print('loading train...', flush=True, end='')
    x_train_pacu = np.load(input_path+'x_train_pacu.npz', allow_pickle=True)['arr_0']
    y_train_pacu = np.load(input_path+'y_train_pacu.npz')['arr_0']
    x_test_pacu = np.load(input_path+'x_test_pacu.npz', allow_pickle=True)['arr_0']
    y_test_pacu = np.load(input_path+'y_test_pacu.npz')['arr_0']
    print('done', flush=True)

else:
    false_row_list_preop = []
    
    vital_path = '../../cranberry2/Preprocessing/vital_data/PPG_100Hz_ECG_100Hz_pacu_2min/'
    ecg_path = '../../cranberry2/Preprocessing/vital_data/ECG_250Hz_pacu_2min/ECG,'
    df_preprocess_pacu = pickle.load(open('../DL_model/cache/preprocess3/input3/df_preprocess_pacu_agender','rb'))
    df_demograph = pd.read_csv('../DL_model/caseids_age_gender.csv')
    

    ### test set에 해당하는 file_path
    caseid_test = pickle.load(open('../DL_model/caseid_test_new', 'rb'))
    caseid_train = pickle.load(open('../DL_model/caseid_train_new', 'rb'))
    caseid_val = pickle.load(open('../DL_model/caseid_val_new', 'rb'))
    
    non_lis = []
    x_train_pacu, y_train_pacu = [], []
    x_test_pacu, y_test_pacu = [], []
    x_val_pacu, y_val_pacu = [], []
    age_train_pacu, gender_train_pacu = [], []
    age_test_pacu, gender_test_pacu = [], []
    age_val_pacu, gender_val_pacu = [], []

    cnt = 0
    for _, row in df_preprocess_pacu.iterrows():
        cnt += 1
        if cnt <=3600:
            continue
        print('loading data {}/{} ...'.format(cnt, len(df_preprocess_pacu)), end='')
                    
        
        row_demo = df_demograph[df_demograph['caseids']==row['caseids']].iloc[0]
            

        # vital data - PPG (resampling 100 Hz to 250 Hz)
        df_vital = pickle.load(open(vital_path+row['file_path'], 'rb')).reset_index()
        pleth_samp = df_vital[['Pleth']].fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()[:12000]
        ppg_per_NRS = np.full(12000, np.nan)
        ppg_per_NRS[0:len(pleth_samp)] = pleth_samp
        

   

        save_path = '../../cranberry2/Preprocessing/cache/lowess_filtered_PPG_100Hz/pacu_'+row['caseids']
        # 한 NRS에 대해 23개의 input 확인
        for i in range(30,51):
            # input이 전처리 통과한 경우
            if row[str(i+1)]:
                start_idx = i*OVERLAP*SRATE # 500i
                end_idx = (i*OVERLAP+LEN_INPUT)*SRATE # 500i + 1000
                
                # input의 normalization
                ppg_inp = np.copy(ppg_per_NRS[start_idx:end_idx])
                if np.sum(np.isnan(ppg_inp))!=0:
                    ppg_inp = pd.DataFrame(ppg_inp).fillna(method='ffill', axis=0).fillna(method='bfill', axis=0).values.flatten()
    
                pleth_inp = ppg_inp - smooth(ppg_inp)
                pleth_inp = pleth_inp - np.nanmean(pleth_inp)
                
                
                pickle.dump(pleth_inp, open(save_path+'_{}'.format(i), 'wb'))
                # 해당 caseid가 test set에 속하는 경우
                if row['caseids'] in caseid_test:
                    x_test_pacu.append(pleth_inp)
                    y_test_pacu.append(int(float(row['NRS'])))

                # 해당 caseid가 train set에 해당하는 경우
                elif row['caseids'] in caseid_val:                
                    x_val_pacu.append(pleth_inp)
                    y_val_pacu.append(int(float(row['NRS'])))
                    
                elif row['caseids'] in caseid_train:                 
                    x_train_pacu.append(pleth_inp)
                    y_train_pacu.append(int(float(row['NRS'])))
                    
                else:
                    non_lis.append(row['caseids'])
                    
        print('completed')

    
    x_train_pacu = np.array(x_train_pacu, np.float32)
    x_test_pacu = np.array(x_test_pacu, np.float32)
    y_train_pacu = np.array(y_train_pacu, int)
    y_test_pacu = np.array(y_test_pacu, int)
    x_val_pacu = np.array(x_val_pacu, np.float32)
    y_val_pacu = np.array(y_val_pacu, int)
    
            
    # 저장하기
    print('saving...', end='', flush=True)
    np.savez_compressed(input_path+'x_train_pacu2.npz', x_train_pacu)
    np.savez_compressed(input_path+'x_test_pacu2.npz', x_test_pacu)
    np.savez_compressed(input_path+'x_val_pacu2.npz', x_val_pacu)
    np.savez_compressed(input_path+'y_train_pacu2.npz', y_train_pacu)
    np.savez_compressed(input_path+'y_test_pacu2.npz', y_test_pacu)
    np.savez_compressed(input_path+'y_val_pacu2.npz', y_val_pacu)
    print('done', flush=True)

    
    
    
print('size of training set(pacu):', len(x_train_pacu))
print('size of validation set(pacu):', len(x_val_pacu))
print('size of test set(pacu):', len(x_test_pacu))
# Out:
# loading data 3601/7253 ...completed
# loading data 3602/7253 ...completed
# loading data 3603/7253 ...completed
# loading data 3604/7253 ...completed
# loading data 3605/7253 ...completed
# loading data 3606/7253 ...completed
# loading data 3607/7253 ...completed
# loading data 3608/7253 ...completed
# loading data 3609/7253 ...completed
# loading data 3610/7253 ...completed
# loading data 3611/7253 ...completed
# loading data 3612/7253 ...completed
# loading data 3613/7253 ...completed
# loading data 3614/7253 ...completed
# loading data 3615/7253 ...completed
# loading data 3616/7253 ...completed
# loading data 3617/7253 ...completed
# loading data 3618/7253 ...completed
# loading data 3619/7253 ...completed
# loading data 3620/7253 ...completed
# loading data 3621/7253 ...completed
# loading data 3622/7253 ...completed
# loading data 3623/7253 ...completed
# loading data 3624/7253 ...completed
# loading data 3625/7253 ...completed
# loading data 3626/7253 ...completed
# loading data 3627/7253 ...completed
# loading data 3628/7253 ...completed
# loading data 3629/7253 ...completed
# loading data 3630/7253 ...completed
# loading data 3631/7253 ...completed
# loading data 3632/7253 ...completed
# loading data 3633/7253 ...completed
# loading data 3634/7253 ...completed
# loading data 3635/7253 ...completed
# loading data 3636/7253 ...completed
# loading data 3637/7253 ...completed
# loading data 3638/7253 ...completed
# loading data 3639/7253 ...completed
# loading data 3640/7253 ...completed
# loading data 3641/7253 ...completed
# loading data 3642/7253 ...completed
# loading data 3643/7253 ...completed
# loading data 3644/7253 ...completed
# loading data 3645/7253 ...completed
# loading data 3646/7253 ...completed
# loading data 3647/7253 ...completed
# loading data 3648/7253 ...completed
# loading data 3649/7253 ...completed
# loading data 3650/7253 ...completed
# loading data 3651/7253 ...completed
# loading data 3652/7253 ...completed
# loading data 3653/7253 ...completed
# loading data 3654/7253 ...completed
# loading data 3655/7253 ...completed
# loading data 3656/7253 ...completed
# loading data 3657/7253 ...completed
# loading data 3658/7253 ...completed
# loading data 3659/7253 ...completed
# loading data 3660/7253 ...completed
# loading data 3661/7253 ...completed
# loading data 3662/7253 ...completed
# loading data 3663/7253 ...completed
# loading data 3664/7253 ...completed
# loading data 3665/7253 ...completed
# loading data 3666/7253 ...completed
# loading data 3667/7253 ...completed
# loading data 3668/7253 ...completed
# loading data 3669/7253 ...completed
# loading data 3670/7253 ...completed
# loading data 3671/7253 ...completed
# loading data 3672/7253 ...completed
# loading data 3673/7253 ...completed
# loading data 3674/7253 ...completed
# loading data 3675/7253 ...completed
# loading data 3676/7253 ...completed
# loading data 3677/7253 ...completed
# loading data 3678/7253 ...completed
# loading data 3679/7253 ...completed
# loading data 3680/7253 ...completed
# loading data 3681/7253 ...completed
# loading data 3682/7253 ...completed
# loading data 3683/7253 ...completed
# loading data 3684/7253 ...completed
# loading data 3685/7253 ...completed
# loading data 3686/7253 ...completed
# loading data 3687/7253 ...completed
# loading data 3688/7253 ...completed
# loading data 3689/7253 ...completed
# loading data 3690/7253 ...completed
# loading data 3691/7253 ...completed
# loading data 3692/7253 ...completed
# loading data 3693/7253 ...completed
# loading data 3694/7253 ...completed
# loading data 3695/7253 ...completed
# loading data 3696/7253 ...completed
# loading data 3697/7253 ...completed
# loading data 3698/7253 ...completed
# loading data 3699/7253 ...completed
# loading data 3700/7253 ...completed
# loading data 3701/7253 ...completed
# loading data 3702/7253 ...completed
# loading data 3703/7253 ...completed
# loading data 3704/7253 ...completed
# loading data 3705/7253 ...completed
# loading data 3706/7253 ...completed
# loading data 3707/7253 ...completed
# loading data 3708/7253 ...completed
# loading data 3709/7253 ...completed
# loading data 3710/7253 ...completed
# loading data 3711/7253 ...completed
# loading data 3712/7253 ...completed
# loading data 3713/7253 ...completed
# loading data 3714/7253 ...completed
# loading data 3715/7253 ...completed
# loading data 3716/7253 ...completed
# loading data 3717/7253 ...completed
# loading data 3718/7253 ...completed
# loading data 3719/7253 ...completed
# loading data 3720/7253 ...completed
# loading data 3721/7253 ...completed
# loading data 3722/7253 ...completed
# loading data 3723/7253 ...completed
# loading data 3724/7253 ...completed
# loading data 3725/7253 ...completed
# loading data 3726/7253 ...completed
# loading data 3727/7253 ...completed
# loading data 3728/7253 ...completed
# loading data 3729/7253 ...completed
# loading data 3730/7253 ...completed
# loading data 3731/7253 ...completed
# loading data 3732/7253 ...completed
# loading data 3733/7253 ...completed
# loading data 3734/7253 ...completed
# loading data 3735/7253 ...completed
# loading data 3736/7253 ...completed
# loading data 3737/7253 ...completed
# loading data 3738/7253 ...completed
# loading data 3739/7253 ...completed
# loading data 3740/7253 ...completed
# loading data 3741/7253 ...completed
# loading data 3742/7253 ...completed
# loading data 3743/7253 ...completed
# loading data 3744/7253 ...completed
# loading data 3745/7253 ...completed
# loading data 3746/7253 ...completed
# loading data 3747/7253 ...completed
# loading data 3748/7253 ...completed
# loading data 3749/7253 ...completed
# loading data 3750/7253 ...completed
# loading data 3751/7253 ...completed
# loading data 3752/7253 ...completed
# loading data 3753/7253 ...completed
# loading data 3754/7253 ...completed
# loading data 3755/7253 ...completed
# loading data 3756/7253 ...completed
# loading data 3757/7253 ...completed
# loading data 3758/7253 ...completed
# loading data 3759/7253 ...completed
# loading data 3760/7253 ...completed
# loading data 3761/7253 ...completed
# loading data 3762/7253 ...completed
# loading data 3763/7253 ...completed
# loading data 3764/7253 ...completed
# loading data 3765/7253 ...completed
# loading data 3766/7253 ...completed
# loading data 3767/7253 ...completed
# loading data 3768/7253 ...completed
# loading data 3769/7253 ...completed
# loading data 3770/7253 ...completed
# loading data 3771/7253 ...completed
# loading data 3772/7253 ...completed
# loading data 3773/7253 ...completed
# loading data 3774/7253 ...completed
# loading data 3775/7253 ...completed
# loading data 3776/7253 ...completed
# loading data 3777/7253 ...completed
# loading data 3778/7253 ...completed
# loading data 3779/7253 ...completed
# loading data 3780/7253 ...completed
# loading data 3781/7253 ...completed
# loading data 3782/7253 ...completed
# loading data 3783/7253 ...completed
# loading data 3784/7253 ...completed
# loading data 3785/7253 ...completed
# loading data 3786/7253 ...completed
# loading data 3787/7253 ...completed
# loading data 3788/7253 ...completed
# loading data 3789/7253 ...completed
# loading data 3790/7253 ...completed
# loading data 3791/7253 ...completed
# loading data 3792/7253 ...completed
# loading data 3793/7253 ...completed
# loading data 3794/7253 ...completed
# loading data 3795/7253 ...completed
# loading data 3796/7253 ...completed
# loading data 3797/7253 ...completed
# loading data 3798/7253 ...completed
# loading data 3799/7253 ...completed
# loading data 3800/7253 ...completed
# loading data 3801/7253 ...completed
# loading data 3802/7253 ...completed
# loading data 3803/7253 ...completed
# loading data 3804/7253 ...completed
# loading data 3805/7253 ...completed
# loading data 3806/7253 ...completed
# loading data 3807/7253 ...completed
# loading data 3808/7253 ...completed
# loading data 3809/7253 ...completed
# loading data 3810/7253 ...completed
# loading data 3811/7253 ...completed
# loading data 3812/7253 ...completed
# loading data 3813/7253 ...completed
# loading data 3814/7253 ...completed
# loading data 3815/7253 ...completed
# loading data 3816/7253 ...completed
# loading data 3817/7253 ...completed
# loading data 3818/7253 ...completed
# loading data 3819/7253 ...completed
# loading data 3820/7253 ...completed
# loading data 3821/7253 ...completed
# loading data 3822/7253 ...completed
# loading data 3823/7253 ...completed
# loading data 3824/7253 ...completed
# loading data 3825/7253 ...completed
# loading data 3826/7253 ...completed
# loading data 3827/7253 ...completed
# loading data 3828/7253 ...completed
# loading data 3829/7253 ...completed
# loading data 3830/7253 ...completed
# loading data 3831/7253 ...completed
# loading data 3832/7253 ...completed
# loading data 3833/7253 ...completed
# loading data 3834/7253 ...completed
# loading data 3835/7253 ...completed
# loading data 3836/7253 ...completed
# loading data 3837/7253 ...completed
# loading data 3838/7253 ...completed
# loading data 3839/7253 ...completed
# loading data 3840/7253 ...completed
# loading data 3841/7253 ...completed
# loading data 3842/7253 ...completed
# loading data 3843/7253 ...completed
# loading data 3844/7253 ...completed
# loading data 3845/7253 ...completed
# loading data 3846/7253 ...completed
# loading data 3847/7253 ...completed
# loading data 3848/7253 ...completed
# loading data 3849/7253 ...completed
# loading data 3850/7253 ...completed
# loading data 3851/7253 ...completed
# loading data 3852/7253 ...completed
# loading data 3853/7253 ...completed
# loading data 3854/7253 ...completed
# loading data 3855/7253 ...completed
# loading data 3856/7253 ...completed
# loading data 3857/7253 ...completed
# loading data 3858/7253 ...completed
# loading data 3859/7253 ...completed
# loading data 3860/7253 ...completed
# loading data 3861/7253 ...completed
# loading data 3862/7253 ...completed
# loading data 3863/7253 ...completed
# loading data 3864/7253 ...completed
# loading data 3865/7253 ...completed
# loading data 3866/7253 ...completed
# loading data 3867/7253 ...completed
# loading data 3868/7253 ...completed
# loading data 3869/7253 ...completed
# loading data 3870/7253 ...completed
# loading data 3871/7253 ...completed
# loading data 3872/7253 ...completed
# loading data 3873/7253 ...completed
# loading data 3874/7253 ...completed
# loading data 3875/7253 ...completed
# loading data 3876/7253 ...completed
# loading data 3877/7253 ...completed
# loading data 3878/7253 ...completed
# loading data 3879/7253 ...completed
# loading data 3880/7253 ...completed
# loading data 3881/7253 ...completed
# loading data 3882/7253 ...completed
# loading data 3883/7253 ...completed
# loading data 3884/7253 ...completed
# loading data 3885/7253 ...completed
# loading data 3886/7253 ...completed
# loading data 3887/7253 ...completed
# loading data 3888/7253 ...completed
# loading data 3889/7253 ...completed
# loading data 3890/7253 ...completed
# loading data 3891/7253 ...completed
# loading data 3892/7253 ...completed
# loading data 3893/7253 ...completed
# loading data 3894/7253 ...completed
# loading data 3895/7253 ...completed
# loading data 3896/7253 ...completed
# loading data 3897/7253 ...completed
# loading data 3898/7253 ...completed
# loading data 3899/7253 ...completed
# loading data 3900/7253 ...completed
# loading data 3901/7253 ...completed
# loading data 3902/7253 ...completed
# loading data 3903/7253 ...completed
# loading data 3904/7253 ...completed
# loading data 3905/7253 ...completed
# loading data 3906/7253 ...completed
# loading data 3907/7253 ...completed
# loading data 3908/7253 ...completed
# loading data 3909/7253 ...completed
# loading data 3910/7253 ...completed
# loading data 3911/7253 ...completed
# loading data 3912/7253 ...completed
# loading data 3913/7253 ...completed
# loading data 3914/7253 ...completed
# loading data 3915/7253 ...completed
# loading data 3916/7253 ...completed
# loading data 3917/7253 ...completed
# loading data 3918/7253 ...completed
# loading data 3919/7253 ...completed
# loading data 3920/7253 ...completed
# loading data 3921/7253 ...completed
# loading data 3922/7253 ...completed
# loading data 3923/7253 ...completed
# loading data 3924/7253 ...completed
# loading data 3925/7253 ...completed
# loading data 3926/7253 ...completed
# loading data 3927/7253 ...completed
# loading data 3928/7253 ...completed
# loading data 3929/7253 ...completed
# loading data 3930/7253 ...completed
# loading data 3931/7253 ...completed
# loading data 3932/7253 ...completed
# loading data 3933/7253 ...completed
# loading data 3934/7253 ...completed
# loading data 3935/7253 ...completed
# loading data 3936/7253 ...completed
# loading data 3937/7253 ...completed
# loading data 3938/7253 ...completed
# loading data 3939/7253 ...completed
# loading data 3940/7253 ...completed
# loading data 3941/7253 ...completed
# loading data 3942/7253 ...completed
# loading data 3943/7253 ...completed
# loading data 3944/7253 ...completed
# loading data 3945/7253 ...completed
# loading data 3946/7253 ...completed
# loading data 3947/7253 ...completed
# loading data 3948/7253 ...completed
# loading data 3949/7253 ...completed
# loading data 3950/7253 ...completed
# loading data 3951/7253 ...completed
# loading data 3952/7253 ...completed
# loading data 3953/7253 ...completed
# loading data 3954/7253 ...completed
# loading data 3955/7253 ...completed
# loading data 3956/7253 ...completed
# loading data 3957/7253 ...completed
# loading data 3958/7253 ...completed
# loading data 3959/7253 ...completed
# loading data 3960/7253 ...completed
# loading data 3961/7253 ...completed
# loading data 3962/7253 ...completed
# loading data 3963/7253 ...completed
# loading data 3964/7253 ...completed
# loading data 3965/7253 ...completed
# loading data 3966/7253 ...completed
# loading data 3967/7253 ...completed
# loading data 3968/7253 ...completed
# loading data 3969/7253 ...completed
# loading data 3970/7253 ...completed
# loading data 3971/7253 ...completed
# loading data 3972/7253 ...completed
# loading data 3973/7253 ...completed
# loading data 3974/7253 ...completed
# loading data 3975/7253 ...completed
# loading data 3976/7253 ...completed
# loading data 3977/7253 ...completed
# loading data 3978/7253 ...completed
# loading data 3979/7253 ...completed
# loading data 3980/7253 ...completed
# loading data 3981/7253 ...completed
# loading data 3982/7253 ...completed
# loading data 3983/7253 ...completed
# loading data 3984/7253 ...completed
# loading data 3985/7253 ...completed
# loading data 3986/7253 ...completed
# loading data 3987/7253 ...completed
# loading data 3988/7253 ...completed
# loading data 3989/7253 ...completed
# loading data 3990/7253 ...completed
# loading data 3991/7253 ...completed
# loading data 3992/7253 ...completed
# loading data 3993/7253 ...completed
# loading data 3994/7253 ...completed
# loading data 3995/7253 ...completed
# loading data 3996/7253 ...completed
# loading data 3997/7253 ...completed
# loading data 3998/7253 ...completed
# loading data 3999/7253 ...completed
# loading data 4000/7253 ...completed
# loading data 4001/7253 ...completed
# loading data 4002/7253 ...completed
# loading data 4003/7253 ...completed
# loading data 4004/7253 ...completed
# loading data 4005/7253 ...completed
# loading data 4006/7253 ...completed
# loading data 4007/7253 ...completed
# loading data 4008/7253 ...completed
# loading data 4009/7253 ...completed
# loading data 4010/7253 ...completed
# loading data 4011/7253 ...completed
# loading data 4012/7253 ...completed
# loading data 4013/7253 ...completed
# loading data 4014/7253 ...completed
# loading data 4015/7253 ...completed
# loading data 4016/7253 ...completed
# loading data 4017/7253 ...completed
# loading data 4018/7253 ...completed
# loading data 4019/7253 ...completed
# loading data 4020/7253 ...completed
# loading data 4021/7253 ...completed
# loading data 4022/7253 ...completed
# loading data 4023/7253 ...completed
# loading data 4024/7253 ...completed
# loading data 4025/7253 ...completed
# loading data 4026/7253 ...completed
# loading data 4027/7253 ...completed
# loading data 4028/7253 ...completed
# loading data 4029/7253 ...completed
# loading data 4030/7253 ...completed
# loading data 4031/7253 ...completed
# loading data 4032/7253 ...completed
# loading data 4033/7253 ...completed
# loading data 4034/7253 ...completed
# loading data 4035/7253 ...completed
# loading data 4036/7253 ...completed
# loading data 4037/7253 ...completed
# loading data 4038/7253 ...completed
# loading data 4039/7253 ...completed
# loading data 4040/7253 ...completed
# loading data 4041/7253 ...completed
# loading data 4042/7253 ...completed
# loading data 4043/7253 ...completed
# loading data 4044/7253 ...completed
# loading data 4045/7253 ...completed
# loading data 4046/7253 ...completed
# loading data 4047/7253 ...completed
# loading data 4048/7253 ...completed
# loading data 4049/7253 ...completed
# loading data 4050/7253 ...completed
# loading data 4051/7253 ...completed
# loading data 4052/7253 ...completed
# loading data 4053/7253 ...completed
# loading data 4054/7253 ...completed
# loading data 4055/7253 ...completed
# loading data 4056/7253 ...completed
# loading data 4057/7253 ...completed
# loading data 4058/7253 ...completed
# loading data 4059/7253 ...completed
# loading data 4060/7253 ...completed
# loading data 4061/7253 ...completed
# loading data 4062/7253 ...completed
# loading data 4063/7253 ...completed
# loading data 4064/7253 ...completed
# loading data 4065/7253 ...completed
# loading data 4066/7253 ...completed
# loading data 4067/7253 ...completed
# loading data 4068/7253 ...completed
# loading data 4069/7253 ...completed
# loading data 4070/7253 ...completed
# loading data 4071/7253 ...completed
# loading data 4072/7253 ...completed
# loading data 4073/7253 ...completed
# loading data 4074/7253 ...completed
# loading data 4075/7253 ...completed
# loading data 4076/7253 ...completed
# loading data 4077/7253 ...completed
# loading data 4078/7253 ...completed
# loading data 4079/7253 ...completed
# loading data 4080/7253 ...completed
# loading data 4081/7253 ...completed
# loading data 4082/7253 ...completed
# loading data 4083/7253 ...completed
# loading data 4084/7253 ...completed
# loading data 4085/7253 ...completed
# loading data 4086/7253 ...completed
# loading data 4087/7253 ...completed
# loading data 4088/7253 ...completed
# loading data 4089/7253 ...completed
# loading data 4090/7253 ...completed
# loading data 4091/7253 ...completed
# loading data 4092/7253 ...completed
# loading data 4093/7253 ...completed
# loading data 4094/7253 ...completed
# loading data 4095/7253 ...completed
# loading data 4096/7253 ...completed
# loading data 4097/7253 ...completed
# loading data 4098/7253 ...completed
# loading data 4099/7253 ...completed
# loading data 4100/7253 ...completed
# loading data 4101/7253 ...completed
# loading data 4102/7253 ...completed
# loading data 4103/7253 ...completed
# loading data 4104/7253 ...completed
# loading data 4105/7253 ...completed
# loading data 4106/7253 ...completed
# loading data 4107/7253 ...completed
# loading data 4108/7253 ...completed
# loading data 4109/7253 ...completed
# loading data 4110/7253 ...completed
# loading data 4111/7253 ...completed
# loading data 4112/7253 ...completed
# loading data 4113/7253 ...completed
# loading data 4114/7253 ...completed
# loading data 4115/7253 ...completed
# loading data 4116/7253 ...completed
# loading data 4117/7253 ...completed
# loading data 4118/7253 ...completed
# loading data 4119/7253 ...completed
# loading data 4120/7253 ...completed
# loading data 4121/7253 ...completed
# loading data 4122/7253 ...completed
# loading data 4123/7253 ...completed
# loading data 4124/7253 ...completed
# loading data 4125/7253 ...completed
# loading data 4126/7253 ...completed
# loading data 4127/7253 ...completed
# loading data 4128/7253 ...completed
# loading data 4129/7253 ...completed
# loading data 4130/7253 ...completed
# loading data 4131/7253 ...completed
# loading data 4132/7253 ...completed
# loading data 4133/7253 ...completed
# loading data 4134/7253 ...completed
# loading data 4135/7253 ...completed
# loading data 4136/7253 ...completed
# loading data 4137/7253 ...completed
# loading data 4138/7253 ...completed
# loading data 4139/7253 ...completed
# loading data 4140/7253 ...completed
# loading data 4141/7253 ...completed
# loading data 4142/7253 ...completed
# loading data 4143/7253 ...completed
# loading data 4144/7253 ...completed
# loading data 4145/7253 ...completed
# loading data 4146/7253 ...completed
# loading data 4147/7253 ...completed
# loading data 4148/7253 ...completed
# loading data 4149/7253 ...completed
# loading data 4150/7253 ...completed
# loading data 4151/7253 ...completed
# loading data 4152/7253 ...completed
# loading data 4153/7253 ...completed
# loading data 4154/7253 ...completed
# loading data 4155/7253 ...completed
# loading data 4156/7253 ...completed
# loading data 4157/7253 ...completed
# loading data 4158/7253 ...completed
# loading data 4159/7253 ...completed
# loading data 4160/7253 ...completed
# loading data 4161/7253 ...completed
# loading data 4162/7253 ...completed
# loading data 4163/7253 ...completed
# loading data 4164/7253 ...completed
# loading data 4165/7253 ...completed
# loading data 4166/7253 ...completed
# loading data 4167/7253 ...completed
# loading data 4168/7253 ...completed
# loading data 4169/7253 ...completed
# loading data 4170/7253 ...completed
# loading data 4171/7253 ...completed
# loading data 4172/7253 ...completed
# loading data 4173/7253 ...completed
# loading data 4174/7253 ...completed
# loading data 4175/7253 ...completed
# loading data 4176/7253 ...completed
# loading data 4177/7253 ...completed
# loading data 4178/7253 ...completed
# loading data 4179/7253 ...completed
# loading data 4180/7253 ...completed
# loading data 4181/7253 ...completed
# loading data 4182/7253 ...completed
# loading data 4183/7253 ...completed
# loading data 4184/7253 ...completed
# loading data 4185/7253 ...completed
# loading data 4186/7253 ...completed
# loading data 4187/7253 ...completed
# loading data 4188/7253 ...completed
# loading data 4189/7253 ...completed
# loading data 4190/7253 ...completed
# loading data 4191/7253 ...completed
# loading data 4192/7253 ...completed
# loading data 4193/7253 ...completed
# loading data 4194/7253 ...completed
# loading data 4195/7253 ...completed
# loading data 4196/7253 ...completed
# loading data 4197/7253 ...completed
# loading data 4198/7253 ...completed
# loading data 4199/7253 ...completed
# loading data 4200/7253 ...completed
# loading data 4201/7253 ...completed
# loading data 4202/7253 ...completed
# loading data 4203/7253 ...completed
# loading data 4204/7253 ...completed
# loading data 4205/7253 ...completed
# loading data 4206/7253 ...completed
# loading data 4207/7253 ...completed
# loading data 4208/7253 ...completed
# loading data 4209/7253 ...completed
# loading data 4210/7253 ...completed
# loading data 4211/7253 ...completed
# loading data 4212/7253 ...completed
# loading data 4213/7253 ...completed
# loading data 4214/7253 ...completed
# loading data 4215/7253 ...completed
# loading data 4216/7253 ...completed
# loading data 4217/7253 ...completed
# loading data 4218/7253 ...completed
# loading data 4219/7253 ...completed
# loading data 4220/7253 ...completed
# loading data 4221/7253 ...completed
# loading data 4222/7253 ...completed
# loading data 4223/7253 ...completed
# loading data 4224/7253 ...completed
# loading data 4225/7253 ...completed
# loading data 4226/7253 ...completed
# loading data 4227/7253 ...completed
# loading data 4228/7253 ...completed
# loading data 4229/7253 ...completed
# loading data 4230/7253 ...completed
# loading data 4231/7253 ...completed
# loading data 4232/7253 ...completed
# loading data 4233/7253 ...completed
# loading data 4234/7253 ...completed
# loading data 4235/7253 ...completed
# loading data 4236/7253 ...completed
# loading data 4237/7253 ...completed
# loading data 4238/7253 ...completed
# loading data 4239/7253 ...completed
# loading data 4240/7253 ...completed
# loading data 4241/7253 ...completed
# loading data 4242/7253 ...completed
# loading data 4243/7253 ...completed
# loading data 4244/7253 ...completed
# loading data 4245/7253 ...completed
# loading data 4246/7253 ...completed
# loading data 4247/7253 ...completed
# loading data 4248/7253 ...completed
# loading data 4249/7253 ...completed
# loading data 4250/7253 ...completed
# loading data 4251/7253 ...completed
# loading data 4252/7253 ...completed
# loading data 4253/7253 ...completed
# loading data 4254/7253 ...completed
# loading data 4255/7253 ...completed
# loading data 4256/7253 ...completed
# loading data 4257/7253 ...completed
# loading data 4258/7253 ...completed
# loading data 4259/7253 ...completed
# loading data 4260/7253 ...completed
# loading data 4261/7253 ...completed
# loading data 4262/7253 ...completed
# loading data 4263/7253 ...completed
# loading data 4264/7253 ...completed
# loading data 4265/7253 ...completed
# loading data 4266/7253 ...completed
# loading data 4267/7253 ...completed
# loading data 4268/7253 ...completed
# loading data 4269/7253 ...completed
# loading data 4270/7253 ...completed
# loading data 4271/7253 ...completed
# loading data 4272/7253 ...completed
# loading data 4273/7253 ...completed
# loading data 4274/7253 ...completed
# loading data 4275/7253 ...completed
# loading data 4276/7253 ...completed
# loading data 4277/7253 ...completed
# loading data 4278/7253 ...completed
# loading data 4279/7253 ...completed
# loading data 4280/7253 ...completed
# loading data 4281/7253 ...completed
# loading data 4282/7253 ...completed
# loading data 4283/7253 ...completed
# loading data 4284/7253 ...completed
# loading data 4285/7253 ...completed
# loading data 4286/7253 ...completed
# loading data 4287/7253 ...completed
# loading data 4288/7253 ...completed
# loading data 4289/7253 ...completed
# loading data 4290/7253 ...completed
# loading data 4291/7253 ...completed
# loading data 4292/7253 ...completed
# loading data 4293/7253 ...completed
# loading data 4294/7253 ...completed
# loading data 4295/7253 ...completed
# loading data 4296/7253 ...completed
# loading data 4297/7253 ...completed
# loading data 4298/7253 ...completed
# loading data 4299/7253 ...completed
# loading data 4300/7253 ...completed
# loading data 4301/7253 ...completed
# loading data 4302/7253 ...completed
# loading data 4303/7253 ...completed
# loading data 4304/7253 ...completed
# loading data 4305/7253 ...completed
# loading data 4306/7253 ...completed
# loading data 4307/7253 ...completed
# loading data 4308/7253 ...completed
# loading data 4309/7253 ...completed
# loading data 4310/7253 ...completed
# loading data 4311/7253 ...completed
# loading data 4312/7253 ...completed
# loading data 4313/7253 ...completed
# loading data 4314/7253 ...completed
# loading data 4315/7253 ...completed
# loading data 4316/7253 ...completed
# loading data 4317/7253 ...completed
# loading data 4318/7253 ...completed
# loading data 4319/7253 ...completed
# loading data 4320/7253 ...completed
# loading data 4321/7253 ...completed
# loading data 4322/7253 ...completed
# loading data 4323/7253 ...completed
# loading data 4324/7253 ...completed
# loading data 4325/7253 ...completed
# loading data 4326/7253 ...completed
# loading data 4327/7253 ...completed
# loading data 4328/7253 ...completed
# loading data 4329/7253 ...completed
# loading data 4330/7253 ...completed
# loading data 4331/7253 ...completed
# loading data 4332/7253 ...completed
# loading data 4333/7253 ...completed
# loading data 4334/7253 ...completed
# loading data 4335/7253 ...completed
# loading data 4336/7253 ...completed
# loading data 4337/7253 ...completed
# loading data 4338/7253 ...completed
# loading data 4339/7253 ...completed
# loading data 4340/7253 ...completed
# loading data 4341/7253 ...completed
# loading data 4342/7253 ...completed
# loading data 4343/7253 ...completed
# loading data 4344/7253 ...completed
# loading data 4345/7253 ...completed
# loading data 4346/7253 ...completed
# loading data 4347/7253 ...completed
# loading data 4348/7253 ...completed
# loading data 4349/7253 ...completed
# loading data 4350/7253 ...completed
# loading data 4351/7253 ...completed
# loading data 4352/7253 ...completed
# loading data 4353/7253 ...completed
# loading data 4354/7253 ...completed
# loading data 4355/7253 ...completed
# loading data 4356/7253 ...completed
# loading data 4357/7253 ...completed
# loading data 4358/7253 ...completed
# loading data 4359/7253 ...completed
# loading data 4360/7253 ...completed
# loading data 4361/7253 ...completed
# loading data 4362/7253 ...completed
# loading data 4363/7253 ...completed
# loading data 4364/7253 ...completed
# loading data 4365/7253 ...completed
# loading data 4366/7253 ...completed
# loading data 4367/7253 ...completed
# loading data 4368/7253 ...completed
# loading data 4369/7253 ...completed
# loading data 4370/7253 ...completed
# loading data 4371/7253 ...completed
# loading data 4372/7253 ...completed
# loading data 4373/7253 ...completed
# loading data 4374/7253 ...completed
# loading data 4375/7253 ...completed
# loading data 4376/7253 ...completed
# loading data 4377/7253 ...completed
# loading data 4378/7253 ...completed
# loading data 4379/7253 ...completed
# loading data 4380/7253 ...completed
# loading data 4381/7253 ...completed
# loading data 4382/7253 ...completed
# loading data 4383/7253 ...completed
# loading data 4384/7253 ...completed
# loading data 4385/7253 ...completed
# loading data 4386/7253 ...completed
# loading data 4387/7253 ...completed
# loading data 4388/7253 ...completed
# loading data 4389/7253 ...completed
# loading data 4390/7253 ...completed
# loading data 4391/7253 ...completed
# loading data 4392/7253 ...completed
# loading data 4393/7253 ...completed
# loading data 4394/7253 ...completed
# loading data 4395/7253 ...completed
# loading data 4396/7253 ...completed
# loading data 4397/7253 ...completed
# loading data 4398/7253 ...completed
# loading data 4399/7253 ...completed
# loading data 4400/7253 ...completed
# loading data 4401/7253 ...completed
# loading data 4402/7253 ...completed
# loading data 4403/7253 ...completed
# loading data 4404/7253 ...completed
# loading data 4405/7253 ...completed
# loading data 4406/7253 ...completed
# loading data 4407/7253 ...completed
# loading data 4408/7253 ...completed
# loading data 4409/7253 ...completed
# loading data 4410/7253 ...completed
# loading data 4411/7253 ...completed
# loading data 4412/7253 ...completed
# loading data 4413/7253 ...completed
# loading data 4414/7253 ...completed
# loading data 4415/7253 ...completed
# loading data 4416/7253 ...completed
# loading data 4417/7253 ...completed
# loading data 4418/7253 ...completed
# loading data 4419/7253 ...completed
# loading data 4420/7253 ...completed
# loading data 4421/7253 ...completed
# loading data 4422/7253 ...completed
# loading data 4423/7253 ...completed
# loading data 4424/7253 ...completed
# loading data 4425/7253 ...completed
# loading data 4426/7253 ...completed
# loading data 4427/7253 ...completed
# loading data 4428/7253 ...completed
# loading data 4429/7253 ...completed
# loading data 4430/7253 ...completed
# loading data 4431/7253 ...completed
# loading data 4432/7253 ...completed
# loading data 4433/7253 ...completed
# loading data 4434/7253 ...completed
# loading data 4435/7253 ...completed
# loading data 4436/7253 ...completed
# loading data 4437/7253 ...completed
# loading data 4438/7253 ...completed
# loading data 4439/7253 ...completed
# loading data 4440/7253 ...completed
# loading data 4441/7253 ...completed
# loading data 4442/7253 ...completed
# loading data 4443/7253 ...completed
# loading data 4444/7253 ...completed
# loading data 4445/7253 ...completed
# loading data 4446/7253 ...completed
# loading data 4447/7253 ...completed
# loading data 4448/7253 ...completed
# loading data 4449/7253 ...completed
# loading data 4450/7253 ...completed
# loading data 4451/7253 ...completed
# loading data 4452/7253 ...completed
# loading data 4453/7253 ...completed
# loading data 4454/7253 ...completed
# loading data 4455/7253 ...completed
# loading data 4456/7253 ...completed
# loading data 4457/7253 ...completed
# loading data 4458/7253 ...completed
# loading data 4459/7253 ...completed
# loading data 4460/7253 ...completed
# loading data 4461/7253 ...completed
# loading data 4462/7253 ...completed
# loading data 4463/7253 ...completed
# loading data 4464/7253 ...completed
# loading data 4465/7253 ...completed
# loading data 4466/7253 ...completed
# loading data 4467/7253 ...completed
# loading data 4468/7253 ...completed
# loading data 4469/7253 ...completed
# loading data 4470/7253 ...completed
# loading data 4471/7253 ...completed
# loading data 4472/7253 ...completed
# loading data 4473/7253 ...completed
# loading data 4474/7253 ...completed
# loading data 4475/7253 ...completed
# loading data 4476/7253 ...completed
# loading data 4477/7253 ...completed
# loading data 4478/7253 ...completed
# loading data 4479/7253 ...completed
# loading data 4480/7253 ...completed
# loading data 4481/7253 ...completed
# loading data 4482/7253 ...completed
# loading data 4483/7253 ...completed
# loading data 4484/7253 ...completed
# loading data 4485/7253 ...completed
# loading data 4486/7253 ...completed
# loading data 4487/7253 ...completed
# loading data 4488/7253 ...completed
# loading data 4489/7253 ...completed
# loading data 4490/7253 ...completed
# loading data 4491/7253 ...completed
# loading data 4492/7253 ...completed
# loading data 4493/7253 ...completed
# loading data 4494/7253 ...completed
# loading data 4495/7253 ...completed
# loading data 4496/7253 ...completed
# loading data 4497/7253 ...completed
# loading data 4498/7253 ...completed
# loading data 4499/7253 ...completed
# loading data 4500/7253 ...completed
# loading data 4501/7253 ...completed
# loading data 4502/7253 ...completed
# loading data 4503/7253 ...completed
# loading data 4504/7253 ...completed
# loading data 4505/7253 ...completed
# loading data 4506/7253 ...completed
# loading data 4507/7253 ...completed
# loading data 4508/7253 ...completed
# loading data 4509/7253 ...completed
# loading data 4510/7253 ...completed
# loading data 4511/7253 ...completed
# loading data 4512/7253 ...completed
# loading data 4513/7253 ...completed
# loading data 4514/7253 ...completed
# loading data 4515/7253 ...completed
# loading data 4516/7253 ...completed
# loading data 4517/7253 ...completed
# loading data 4518/7253 ...completed
# loading data 4519/7253 ...completed
# loading data 4520/7253 ...completed
# loading data 4521/7253 ...completed
# loading data 4522/7253 ...completed
# loading data 4523/7253 ...completed
# loading data 4524/7253 ...completed
# loading data 4525/7253 ...completed
# loading data 4526/7253 ...completed
# loading data 4527/7253 ...completed
# loading data 4528/7253 ...completed
# loading data 4529/7253 ...completed
# loading data 4530/7253 ...completed
# loading data 4531/7253 ...completed
# loading data 4532/7253 ...completed
# loading data 4533/7253 ...completed
# loading data 4534/7253 ...completed
# loading data 4535/7253 ...completed
# loading data 4536/7253 ...completed
# loading data 4537/7253 ...completed
# loading data 4538/7253 ...completed
# loading data 4539/7253 ...completed
# loading data 4540/7253 ...completed
# loading data 4541/7253 ...completed
# loading data 4542/7253 ...completed
# loading data 4543/7253 ...completed
# loading data 4544/7253 ...completed
# loading data 4545/7253 ...completed
# loading data 4546/7253 ...completed
# loading data 4547/7253 ...completed
# loading data 4548/7253 ...completed
# loading data 4549/7253 ...completed
# loading data 4550/7253 ...completed
# loading data 4551/7253 ...completed
# loading data 4552/7253 ...completed
# loading data 4553/7253 ...completed
# loading data 4554/7253 ...completed
# loading data 4555/7253 ...completed
# loading data 4556/7253 ...completed
# loading data 4557/7253 ...completed
# loading data 4558/7253 ...completed
# loading data 4559/7253 ...completed
# loading data 4560/7253 ...completed
# loading data 4561/7253 ...completed
# loading data 4562/7253 ...completed
# loading data 4563/7253 ...completed
# loading data 4564/7253 ...completed
# loading data 4565/7253 ...completed
# loading data 4566/7253 ...completed
# loading data 4567/7253 ...completed
# loading data 4568/7253 ...completed
# loading data 4569/7253 ...completed
# loading data 4570/7253 ...completed
# loading data 4571/7253 ...completed
# loading data 4572/7253 ...completed
# loading data 4573/7253 ...completed
# loading data 4574/7253 ...completed
# loading data 4575/7253 ...completed
# loading data 4576/7253 ...completed
# loading data 4577/7253 ...completed
# loading data 4578/7253 ...completed
# loading data 4579/7253 ...completed
# loading data 4580/7253 ...completed
# loading data 4581/7253 ...completed
# loading data 4582/7253 ...completed
# loading data 4583/7253 ...completed
# loading data 4584/7253 ...completed
# loading data 4585/7253 ...completed
# loading data 4586/7253 ...completed
# loading data 4587/7253 ...completed
# loading data 4588/7253 ...completed
# loading data 4589/7253 ...completed
# loading data 4590/7253 ...completed
# loading data 4591/7253 ...completed
# loading data 4592/7253 ...completed
# loading data 4593/7253 ...completed
# loading data 4594/7253 ...completed
# loading data 4595/7253 ...completed
# loading data 4596/7253 ...completed
# loading data 4597/7253 ...completed
# loading data 4598/7253 ...completed
# loading data 4599/7253 ...completed
# loading data 4600/7253 ...completed
# loading data 4601/7253 ...completed
# loading data 4602/7253 ...completed
# loading data 4603/7253 ...completed
# loading data 4604/7253 ...completed
# loading data 4605/7253 ...completed
# loading data 4606/7253 ...completed
# loading data 4607/7253 ...completed
# loading data 4608/7253 ...completed
# loading data 4609/7253 ...completed
# loading data 4610/7253 ...completed
# loading data 4611/7253 ...completed
# loading data 4612/7253 ...completed
# loading data 4613/7253 ...completed
# loading data 4614/7253 ...completed
# loading data 4615/7253 ...completed
# loading data 4616/7253 ...completed
# loading data 4617/7253 ...completed
# loading data 4618/7253 ...completed
# loading data 4619/7253 ...completed
# loading data 4620/7253 ...completed
# loading data 4621/7253 ...completed
# loading data 4622/7253 ...completed
# loading data 4623/7253 ...completed
# loading data 4624/7253 ...completed
# loading data 4625/7253 ...completed
# loading data 4626/7253 ...completed
# loading data 4627/7253 ...completed
# loading data 4628/7253 ...completed
# loading data 4629/7253 ...completed
# loading data 4630/7253 ...completed
# loading data 4631/7253 ...completed
# loading data 4632/7253 ...completed
# loading data 4633/7253 ...completed
# loading data 4634/7253 ...completed
# loading data 4635/7253 ...completed
# loading data 4636/7253 ...completed
# loading data 4637/7253 ...completed
# loading data 4638/7253 ...completed
# loading data 4639/7253 ...completed
# loading data 4640/7253 ...completed
# loading data 4641/7253 ...completed
# loading data 4642/7253 ...completed
# loading data 4643/7253 ...completed
# loading data 4644/7253 ...completed
# loading data 4645/7253 ...completed
# loading data 4646/7253 ...completed
# loading data 4647/7253 ...completed
# loading data 4648/7253 ...completed
# loading data 4649/7253 ...completed
# loading data 4650/7253 ...completed
# loading data 4651/7253 ...completed
# loading data 4652/7253 ...completed
# loading data 4653/7253 ...completed
# loading data 4654/7253 ...completed
# loading data 4655/7253 ...completed
# loading data 4656/7253 ...completed
# loading data 4657/7253 ...completed
# loading data 4658/7253 ...completed
# loading data 4659/7253 ...completed
# loading data 4660/7253 ...completed
# loading data 4661/7253 ...completed
# loading data 4662/7253 ...completed
# loading data 4663/7253 ...completed
# loading data 4664/7253 ...completed
# loading data 4665/7253 ...completed
# loading data 4666/7253 ...completed
# loading data 4667/7253 ...completed
# loading data 4668/7253 ...completed
# loading data 4669/7253 ...completed
# loading data 4670/7253 ...completed
# loading data 4671/7253 ...completed
# loading data 4672/7253 ...completed
# loading data 4673/7253 ...completed
# loading data 4674/7253 ...completed
# loading data 4675/7253 ...completed
# loading data 4676/7253 ...completed
# loading data 4677/7253 ...completed
# loading data 4678/7253 ...completed
# loading data 4679/7253 ...completed
# loading data 4680/7253 ...completed
# loading data 4681/7253 ...completed
# loading data 4682/7253 ...completed
# loading data 4683/7253 ...completed
# loading data 4684/7253 ...completed
# loading data 4685/7253 ...completed
# loading data 4686/7253 ...completed
# loading data 4687/7253 ...completed
# loading data 4688/7253 ...completed
# loading data 4689/7253 ...completed
# loading data 4690/7253 ...completed
# loading data 4691/7253 ...completed
# loading data 4692/7253 ...completed
# loading data 4693/7253 ...completed
# loading data 4694/7253 ...completed
# loading data 4695/7253 ...completed
# loading data 4696/7253 ...completed
# loading data 4697/7253 ...completed
# loading data 4698/7253 ...completed
# loading data 4699/7253 ...completed
# loading data 4700/7253 ...completed
# loading data 4701/7253 ...completed
# loading data 4702/7253 ...completed
# loading data 4703/7253 ...completed
# loading data 4704/7253 ...completed
# loading data 4705/7253 ...completed
# loading data 4706/7253 ...completed
# loading data 4707/7253 ...completed
# loading data 4708/7253 ...completed
# loading data 4709/7253 ...completed
# loading data 4710/7253 ...completed
# loading data 4711/7253 ...completed
# loading data 4712/7253 ...completed
# loading data 4713/7253 ...completed
# loading data 4714/7253 ...completed
# loading data 4715/7253 ...completed
# loading data 4716/7253 ...completed
# loading data 4717/7253 ...completed
# loading data 4718/7253 ...completed
# loading data 4719/7253 ...completed
# loading data 4720/7253 ...completed
# loading data 4721/7253 ...completed
# loading data 4722/7253 ...completed
# loading data 4723/7253 ...completed
# loading data 4724/7253 ...completed
# loading data 4725/7253 ...completed
# loading data 4726/7253 ...completed
# loading data 4727/7253 ...completed
# loading data 4728/7253 ...completed
# loading data 4729/7253 ...completed
# loading data 4730/7253 ...completed
# loading data 4731/7253 ...completed
# loading data 4732/7253 ...completed
# loading data 4733/7253 ...completed
# loading data 4734/7253 ...completed
# loading data 4735/7253 ...completed
# loading data 4736/7253 ...completed
# loading data 4737/7253 ...completed
# loading data 4738/7253 ...completed
# loading data 4739/7253 ...completed
# loading data 4740/7253 ...completed
# loading data 4741/7253 ...completed
# loading data 4742/7253 ...completed
# loading data 4743/7253 ...completed
# loading data 4744/7253 ...completed
# loading data 4745/7253 ...completed
# loading data 4746/7253 ...completed
# loading data 4747/7253 ...completed
# loading data 4748/7253 ...completed
# loading data 4749/7253 ...completed
# loading data 4750/7253 ...completed
# loading data 4751/7253 ...completed
# loading data 4752/7253 ...completed
# loading data 4753/7253 ...completed
# loading data 4754/7253 ...completed
# loading data 4755/7253 ...completed
# loading data 4756/7253 ...completed
# loading data 4757/7253 ...completed
# loading data 4758/7253 ...completed
# loading data 4759/7253 ...completed
# loading data 4760/7253 ...completed
# loading data 4761/7253 ...completed
# loading data 4762/7253 ...completed
# loading data 4763/7253 ...completed
# loading data 4764/7253 ...completed
# loading data 4765/7253 ...completed
# loading data 4766/7253 ...completed
# loading data 4767/7253 ...completed
# loading data 4768/7253 ...completed
# loading data 4769/7253 ...completed
# loading data 4770/7253 ...completed
# loading data 4771/7253 ...completed
# loading data 4772/7253 ...completed
# loading data 4773/7253 ...completed
# loading data 4774/7253 ...completed
# loading data 4775/7253 ...completed
# loading data 4776/7253 ...completed
# loading data 4777/7253 ...completed
# loading data 4778/7253 ...completed
# loading data 4779/7253 ...completed
# loading data 4780/7253 ...completed
# loading data 4781/7253 ...completed
# loading data 4782/7253 ...completed
# loading data 4783/7253 ...completed
# loading data 4784/7253 ...completed
# loading data 4785/7253 ...completed
# loading data 4786/7253 ...completed
# loading data 4787/7253 ...completed
# loading data 4788/7253 ...completed
# loading data 4789/7253 ...completed
# loading data 4790/7253 ...completed
# loading data 4791/7253 ...completed
# loading data 4792/7253 ...completed
# loading data 4793/7253 ...completed
# loading data 4794/7253 ...completed
# loading data 4795/7253 ...completed
# loading data 4796/7253 ...completed
# loading data 4797/7253 ...completed
# loading data 4798/7253 ...completed
# loading data 4799/7253 ...completed
# loading data 4800/7253 ...completed
# loading data 4801/7253 ...completed
# loading data 4802/7253 ...completed
# loading data 4803/7253 ...completed
# loading data 4804/7253 ...completed
# loading data 4805/7253 ...completed
# loading data 4806/7253 ...completed
# loading data 4807/7253 ...completed
# loading data 4808/7253 ...completed
# loading data 4809/7253 ...completed
# loading data 4810/7253 ...completed
# loading data 4811/7253 ...completed
# loading data 4812/7253 ...completed
# loading data 4813/7253 ...completed
# loading data 4814/7253 ...completed
# loading data 4815/7253 ...completed
# loading data 4816/7253 ...completed
# loading data 4817/7253 ...completed
# loading data 4818/7253 ...completed
# loading data 4819/7253 ...completed
# loading data 4820/7253 ...completed
# loading data 4821/7253 ...completed
# loading data 4822/7253 ...completed
# loading data 4823/7253 ...completed
# loading data 4824/7253 ...completed
# loading data 4825/7253 ...completed
# loading data 4826/7253 ...completed
# loading data 4827/7253 ...completed
# loading data 4828/7253 ...completed
# loading data 4829/7253 ...completed
# loading data 4830/7253 ...completed
# loading data 4831/7253 ...completed
# loading data 4832/7253 ...completed
# loading data 4833/7253 ...completed
# loading data 4834/7253 ...completed
# loading data 4835/7253 ...completed
# loading data 4836/7253 ...completed
# loading data 4837/7253 ...completed
# loading data 4838/7253 ...completed
# loading data 4839/7253 ...completed
# loading data 4840/7253 ...completed
# loading data 4841/7253 ...completed
# loading data 4842/7253 ...completed
# loading data 4843/7253 ...completed
# loading data 4844/7253 ...completed
# loading data 4845/7253 ...completed
# loading data 4846/7253 ...completed
# loading data 4847/7253 ...completed
# loading data 4848/7253 ...completed
# loading data 4849/7253 ...completed
# loading data 4850/7253 ...completed
# loading data 4851/7253 ...completed
# loading data 4852/7253 ...completed
# loading data 4853/7253 ...completed
# loading data 4854/7253 ...completed
# loading data 4855/7253 ...completed
# loading data 4856/7253 ...completed
# loading data 4857/7253 ...completed
# loading data 4858/7253 ...completed
# loading data 4859/7253 ...completed
# loading data 4860/7253 ...completed
# loading data 4861/7253 ...completed
# loading data 4862/7253 ...completed
# loading data 4863/7253 ...completed
# loading data 4864/7253 ...completed
# loading data 4865/7253 ...completed
# loading data 4866/7253 ...completed
# loading data 4867/7253 ...completed
# loading data 4868/7253 ...completed
# loading data 4869/7253 ...completed
# loading data 4870/7253 ...completed
# loading data 4871/7253 ...completed
# loading data 4872/7253 ...completed
# loading data 4873/7253 ...completed
# loading data 4874/7253 ...completed
# loading data 4875/7253 ...completed
# loading data 4876/7253 ...completed
# loading data 4877/7253 ...completed
# loading data 4878/7253 ...completed
# loading data 4879/7253 ...completed
# loading data 4880/7253 ...completed
# loading data 4881/7253 ...completed
# loading data 4882/7253 ...completed
# loading data 4883/7253 ...completed
# loading data 4884/7253 ...completed
# loading data 4885/7253 ...completed
# loading data 4886/7253 ...completed
# loading data 4887/7253 ...completed
# loading data 4888/7253 ...completed
# loading data 4889/7253 ...completed
# loading data 4890/7253 ...completed
# loading data 4891/7253 ...completed
# loading data 4892/7253 ...completed
# loading data 4893/7253 ...completed
# loading data 4894/7253 ...completed
# loading data 4895/7253 ...completed
# loading data 4896/7253 ...completed
# loading data 4897/7253 ...completed
# loading data 4898/7253 ...completed
# loading data 4899/7253 ...completed
# loading data 4900/7253 ...completed
# loading data 4901/7253 ...completed
# loading data 4902/7253 ...completed
# loading data 4903/7253 ...completed
# loading data 4904/7253 ...completed
# loading data 4905/7253 ...completed
# loading data 4906/7253 ...completed
# loading data 4907/7253 ...completed
# loading data 4908/7253 ...completed
# loading data 4909/7253 ...completed
# loading data 4910/7253 ...completed
# loading data 4911/7253 ...completed
# loading data 4912/7253 ...completed
# loading data 4913/7253 ...completed
# loading data 4914/7253 ...completed
# loading data 4915/7253 ...completed
# loading data 4916/7253 ...completed
# loading data 4917/7253 ...completed
# loading data 4918/7253 ...completed
# loading data 4919/7253 ...completed
# loading data 4920/7253 ...completed
# loading data 4921/7253 ...completed
# loading data 4922/7253 ...completed
# loading data 4923/7253 ...completed
# loading data 4924/7253 ...completed
# loading data 4925/7253 ...completed
# loading data 4926/7253 ...completed
# loading data 4927/7253 ...completed
# loading data 4928/7253 ...completed
# loading data 4929/7253 ...completed
# loading data 4930/7253 ...completed
# loading data 4931/7253 ...completed
# loading data 4932/7253 ...completed
# loading data 4933/7253 ...completed
# ...
# loading data 6813/7253 ...completed
# loading data 6814/7253 ...completed
# loading data 6815/7253 ...completed
# loading data 6816/7253 ...completed
# loading data 6817/7253 ...completed
# loading data 6818/7253 ...completed
# loading data 6819/7253 ...completed
# loading data 6820/7253 ...completed
# loading data 6821/7253 ...completed
# loading data 6822/7253 ...completed
# loading data 6823/7253 ...completed
# loading data 6824/7253 ...completed
# loading data 6825/7253 ...completed
# loading data 6826/7253 ...completed
# loading data 6827/7253 ...completed
# loading data 6828/7253 ...completed
# loading data 6829/7253 ...completed
# loading data 6830/7253 ...completed
# loading data 6831/7253 ...completed
# loading data 6832/7253 ...completed
# loading data 6833/7253 ...completed
# loading data 6834/7253 ...completed
# loading data 6835/7253 ...completed
# loading data 6836/7253 ...completed
# loading data 6837/7253 ...completed
# loading data 6838/7253 ...completed
# loading data 6839/7253 ...completed
# loading data 6840/7253 ...completed
# loading data 6841/7253 ...completed
# loading data 6842/7253 ...completed
# loading data 6843/7253 ...completed
# loading data 6844/7253 ...completed
# loading data 6845/7253 ...completed
# loading data 6846/7253 ...completed
# loading data 6847/7253 ...completed
# loading data 6848/7253 ...completed
# loading data 6849/7253 ...completed
# loading data 6850/7253 ...completed
# loading data 6851/7253 ...completed
# loading data 6852/7253 ...completed
# loading data 6853/7253 ...completed
# loading data 6854/7253 ...completed
# loading data 6855/7253 ...completed
# loading data 6856/7253 ...completed
# loading data 6857/7253 ...completed
# loading data 6858/7253 ...completed
# loading data 6859/7253 ...completed
# loading data 6860/7253 ...completed
# loading data 6861/7253 ...completed
# loading data 6862/7253 ...completed
# loading data 6863/7253 ...completed
# loading data 6864/7253 ...completed
# loading data 6865/7253 ...completed
# loading data 6866/7253 ...completed
# loading data 6867/7253 ...completed
# loading data 6868/7253 ...completed
# loading data 6869/7253 ...completed
# loading data 6870/7253 ...completed
# loading data 6871/7253 ...completed
# loading data 6872/7253 ...completed
# loading data 6873/7253 ...completed
# loading data 6874/7253 ...completed
# loading data 6875/7253 ...completed
# loading data 6876/7253 ...completed
# loading data 6877/7253 ...completed
# loading data 6878/7253 ...completed
# loading data 6879/7253 ...completed
# loading data 6880/7253 ...completed
# loading data 6881/7253 ...completed
# loading data 6882/7253 ...completed
# loading data 6883/7253 ...completed
# loading data 6884/7253 ...completed
# loading data 6885/7253 ...completed
# loading data 6886/7253 ...completed
# loading data 6887/7253 ...completed
# loading data 6888/7253 ...completed
# loading data 6889/7253 ...completed
# loading data 6890/7253 ...completed
# loading data 6891/7253 ...completed
# loading data 6892/7253 ...completed
# loading data 6893/7253 ...completed
# loading data 6894/7253 ...completed
# loading data 6895/7253 ...completed
# loading data 6896/7253 ...completed
# loading data 6897/7253 ...completed
# loading data 6898/7253 ...completed
# loading data 6899/7253 ...completed
# loading data 6900/7253 ...completed
# loading data 6901/7253 ...completed
# loading data 6902/7253 ...completed
# loading data 6903/7253 ...completed
# loading data 6904/7253 ...completed
# loading data 6905/7253 ...completed
# loading data 6906/7253 ...completed
# loading data 6907/7253 ...completed
# loading data 6908/7253 ...completed
# loading data 6909/7253 ...completed
# loading data 6910/7253 ...completed
# loading data 6911/7253 ...completed
# loading data 6912/7253 ...completed
# loading data 6913/7253 ...completed
# loading data 6914/7253 ...completed
# loading data 6915/7253 ...completed
# loading data 6916/7253 ...completed
# loading data 6917/7253 ...completed
# loading data 6918/7253 ...completed
# loading data 6919/7253 ...completed
# loading data 6920/7253 ...completed
# loading data 6921/7253 ...completed
# loading data 6922/7253 ...completed
# loading data 6923/7253 ...completed
# loading data 6924/7253 ...completed
# loading data 6925/7253 ...completed
# loading data 6926/7253 ...completed
# loading data 6927/7253 ...completed
# loading data 6928/7253 ...completed
# loading data 6929/7253 ...completed
# loading data 6930/7253 ...completed
# loading data 6931/7253 ...completed
# loading data 6932/7253 ...completed
# loading data 6933/7253 ...completed
# loading data 6934/7253 ...completed
# loading data 6935/7253 ...completed
# loading data 6936/7253 ...completed
# loading data 6937/7253 ...completed
# loading data 6938/7253 ...completed
# loading data 6939/7253 ...completed
# loading data 6940/7253 ...completed
# loading data 6941/7253 ...completed
# loading data 6942/7253 ...completed
# loading data 6943/7253 ...completed
# loading data 6944/7253 ...completed
# loading data 6945/7253 ...completed
# loading data 6946/7253 ...completed
# loading data 6947/7253 ...completed
# loading data 6948/7253 ...completed
# loading data 6949/7253 ...completed
# loading data 6950/7253 ...completed
# loading data 6951/7253 ...completed
# loading data 6952/7253 ...completed
# loading data 6953/7253 ...completed
# loading data 6954/7253 ...completed
# loading data 6955/7253 ...completed
# loading data 6956/7253 ...completed
# loading data 6957/7253 ...completed
# loading data 6958/7253 ...completed
# loading data 6959/7253 ...completed
# loading data 6960/7253 ...completed
# loading data 6961/7253 ...completed
# loading data 6962/7253 ...completed
# loading data 6963/7253 ...completed
# loading data 6964/7253 ...completed
# loading data 6965/7253 ...completed
# loading data 6966/7253 ...completed
# loading data 6967/7253 ...completed
# loading data 6968/7253 ...completed
# loading data 6969/7253 ...completed
# loading data 6970/7253 ...completed
# loading data 6971/7253 ...completed
# loading data 6972/7253 ...completed
# loading data 6973/7253 ...completed
# loading data 6974/7253 ...completed
# loading data 6975/7253 ...completed
# loading data 6976/7253 ...completed
# loading data 6977/7253 ...completed
# loading data 6978/7253 ...completed
# loading data 6979/7253 ...completed
# loading data 6980/7253 ...completed
# loading data 6981/7253 ...completed
# loading data 6982/7253 ...completed
# loading data 6983/7253 ...completed
# loading data 6984/7253 ...completed
# loading data 6985/7253 ...completed
# loading data 6986/7253 ...completed
# loading data 6987/7253 ...completed
# loading data 6988/7253 ...completed
# loading data 6989/7253 ...completed
# loading data 6990/7253 ...completed
# loading data 6991/7253 ...completed
# loading data 6992/7253 ...completed
# loading data 6993/7253 ...completed
# loading data 6994/7253 ...completed
# loading data 6995/7253 ...completed
# loading data 6996/7253 ...completed
# loading data 6997/7253 ...completed
# loading data 6998/7253 ...completed
# loading data 6999/7253 ...completed
# loading data 7000/7253 ...completed
# loading data 7001/7253 ...completed
# loading data 7002/7253 ...completed
# loading data 7003/7253 ...completed
# loading data 7004/7253 ...completed
# loading data 7005/7253 ...completed
# loading data 7006/7253 ...completed
# loading data 7007/7253 ...completed
# loading data 7008/7253 ...completed
# loading data 7009/7253 ...completed
# loading data 7010/7253 ...completed
# loading data 7011/7253 ...completed
# loading data 7012/7253 ...completed
# loading data 7013/7253 ...completed
# loading data 7014/7253 ...completed
# loading data 7015/7253 ...completed
# loading data 7016/7253 ...completed
# loading data 7017/7253 ...completed
# loading data 7018/7253 ...completed
# loading data 7019/7253 ...completed
# loading data 7020/7253 ...completed
# loading data 7021/7253 ...completed
# loading data 7022/7253 ...completed
# loading data 7023/7253 ...completed
# loading data 7024/7253 ...completed
# loading data 7025/7253 ...completed
# loading data 7026/7253 ...completed
# loading data 7027/7253 ...completed
# loading data 7028/7253 ...completed
# loading data 7029/7253 ...completed
# loading data 7030/7253 ...completed
# loading data 7031/7253 ...completed
# loading data 7032/7253 ...completed
# loading data 7033/7253 ...completed
# loading data 7034/7253 ...completed
# loading data 7035/7253 ...completed
# loading data 7036/7253 ...completed
# loading data 7037/7253 ...completed
# loading data 7038/7253 ...completed
# loading data 7039/7253 ...completed
# loading data 7040/7253 ...completed
# loading data 7041/7253 ...completed
# loading data 7042/7253 ...completed
# loading data 7043/7253 ...completed
# loading data 7044/7253 ...completed
# loading data 7045/7253 ...completed
# loading data 7046/7253 ...completed
# loading data 7047/7253 ...completed
# loading data 7048/7253 ...completed
# loading data 7049/7253 ...completed
# loading data 7050/7253 ...completed
# loading data 7051/7253 ...completed
# loading data 7052/7253 ...completed
# loading data 7053/7253 ...completed
# loading data 7054/7253 ...completed
# loading data 7055/7253 ...completed
# loading data 7056/7253 ...completed
# loading data 7057/7253 ...completed
# loading data 7058/7253 ...completed
# loading data 7059/7253 ...completed
# loading data 7060/7253 ...completed
# loading data 7061/7253 ...completed
# loading data 7062/7253 ...completed
# loading data 7063/7253 ...completed
# loading data 7064/7253 ...completed
# loading data 7065/7253 ...completed
# loading data 7066/7253 ...completed
# loading data 7067/7253 ...completed
# loading data 7068/7253 ...completed
# loading data 7069/7253 ...completed
# loading data 7070/7253 ...completed
# loading data 7071/7253 ...completed
# loading data 7072/7253 ...completed
# loading data 7073/7253 ...completed
# loading data 7074/7253 ...completed
# loading data 7075/7253 ...completed
# loading data 7076/7253 ...completed
# loading data 7077/7253 ...completed
# loading data 7078/7253 ...completed
# loading data 7079/7253 ...completed
# loading data 7080/7253 ...completed
# loading data 7081/7253 ...completed
# loading data 7082/7253 ...completed
# loading data 7083/7253 ...completed
# loading data 7084/7253 ...completed
# loading data 7085/7253 ...completed
# loading data 7086/7253 ...completed
# loading data 7087/7253 ...completed
# loading data 7088/7253 ...completed
# loading data 7089/7253 ...completed
# loading data 7090/7253 ...completed
# loading data 7091/7253 ...completed
# loading data 7092/7253 ...completed
# loading data 7093/7253 ...completed
# loading data 7094/7253 ...completed
# loading data 7095/7253 ...completed
# loading data 7096/7253 ...completed
# loading data 7097/7253 ...completed
# loading data 7098/7253 ...completed
# loading data 7099/7253 ...completed
# loading data 7100/7253 ...completed
# loading data 7101/7253 ...completed
# loading data 7102/7253 ...completed
# loading data 7103/7253 ...completed
# loading data 7104/7253 ...completed
# loading data 7105/7253 ...completed
# loading data 7106/7253 ...completed
# loading data 7107/7253 ...completed
# loading data 7108/7253 ...completed
# loading data 7109/7253 ...completed
# loading data 7110/7253 ...completed
# loading data 7111/7253 ...completed
# loading data 7112/7253 ...completed
# loading data 7113/7253 ...completed
# loading data 7114/7253 ...completed
# loading data 7115/7253 ...completed
# loading data 7116/7253 ...completed
# loading data 7117/7253 ...completed
# loading data 7118/7253 ...completed
# loading data 7119/7253 ...completed
# loading data 7120/7253 ...completed
# loading data 7121/7253 ...completed
# loading data 7122/7253 ...completed
# loading data 7123/7253 ...completed
# loading data 7124/7253 ...completed
# loading data 7125/7253 ...completed
# loading data 7126/7253 ...completed
# loading data 7127/7253 ...completed
# loading data 7128/7253 ...completed
# loading data 7129/7253 ...completed
# loading data 7130/7253 ...completed
# loading data 7131/7253 ...completed
# loading data 7132/7253 ...completed
# loading data 7133/7253 ...completed
# loading data 7134/7253 ...completed
# loading data 7135/7253 ...completed
# loading data 7136/7253 ...completed
# loading data 7137/7253 ...completed
# loading data 7138/7253 ...completed
# loading data 7139/7253 ...completed
# loading data 7140/7253 ...completed
# loading data 7141/7253 ...completed
# loading data 7142/7253 ...completed
# loading data 7143/7253 ...completed
# loading data 7144/7253 ...completed
# loading data 7145/7253 ...completed
# loading data 7146/7253 ...completed
# loading data 7147/7253 ...completed
# loading data 7148/7253 ...completed
# loading data 7149/7253 ...completed
# loading data 7150/7253 ...completed
# loading data 7151/7253 ...completed
# loading data 7152/7253 ...completed
# loading data 7153/7253 ...completed
# loading data 7154/7253 ...completed
# loading data 7155/7253 ...completed
# loading data 7156/7253 ...completed
# loading data 7157/7253 ...completed
# loading data 7158/7253 ...completed
# loading data 7159/7253 ...completed
# loading data 7160/7253 ...completed
# loading data 7161/7253 ...completed
# loading data 7162/7253 ...completed
# loading data 7163/7253 ...completed
# loading data 7164/7253 ...completed
# loading data 7165/7253 ...completed
# loading data 7166/7253 ...completed
# loading data 7167/7253 ...completed
# loading data 7168/7253 ...completed
# loading data 7169/7253 ...completed
# loading data 7170/7253 ...completed
# loading data 7171/7253 ...completed
# loading data 7172/7253 ...completed
# loading data 7173/7253 ...completed
# loading data 7174/7253 ...completed
# loading data 7175/7253 ...completed
# loading data 7176/7253 ...completed
# loading data 7177/7253 ...completed
# loading data 7178/7253 ...completed
# loading data 7179/7253 ...completed
# loading data 7180/7253 ...completed
# loading data 7181/7253 ...completed
# loading data 7182/7253 ...completed
# loading data 7183/7253 ...completed
# loading data 7184/7253 ...completed
# loading data 7185/7253 ...completed
# loading data 7186/7253 ...completed
# loading data 7187/7253 ...completed
# loading data 7188/7253 ...completed
# loading data 7189/7253 ...completed
# loading data 7190/7253 ...completed
# loading data 7191/7253 ...completed
# loading data 7192/7253 ...completed
# loading data 7193/7253 ...completed
# loading data 7194/7253 ...completed
# loading data 7195/7253 ...completed
# loading data 7196/7253 ...completed
# loading data 7197/7253 ...completed
# loading data 7198/7253 ...completed
# loading data 7199/7253 ...completed
# loading data 7200/7253 ...completed
# loading data 7201/7253 ...completed
# loading data 7202/7253 ...completed
# loading data 7203/7253 ...completed
# loading data 7204/7253 ...completed
# loading data 7205/7253 ...completed
# loading data 7206/7253 ...completed
# loading data 7207/7253 ...completed
# loading data 7208/7253 ...completed
# loading data 7209/7253 ...completed
# loading data 7210/7253 ...completed
# loading data 7211/7253 ...completed
# loading data 7212/7253 ...completed
# loading data 7213/7253 ...completed
# loading data 7214/7253 ...completed
# loading data 7215/7253 ...completed
# loading data 7216/7253 ...completed
# loading data 7217/7253 ...completed
# loading data 7218/7253 ...completed
# loading data 7219/7253 ...completed
# loading data 7220/7253 ...completed
# loading data 7221/7253 ...completed
# loading data 7222/7253 ...completed
# loading data 7223/7253 ...completed
# loading data 7224/7253 ...completed
# loading data 7225/7253 ...completed
# loading data 7226/7253 ...completed
# loading data 7227/7253 ...completed
# loading data 7228/7253 ...completed
# loading data 7229/7253 ...completed
# loading data 7230/7253 ...completed
# loading data 7231/7253 ...completed
# loading data 7232/7253 ...completed
# loading data 7233/7253 ...completed
# loading data 7234/7253 ...completed
# loading data 7235/7253 ...completed
# loading data 7236/7253 ...completed
# loading data 7237/7253 ...completed
# loading data 7238/7253 ...completed
# loading data 7239/7253 ...completed
# loading data 7240/7253 ...completed
# loading data 7241/7253 ...completed
# loading data 7242/7253 ...completed
# loading data 7243/7253 ...completed
# loading data 7244/7253 ...completed
# loading data 7245/7253 ...completed
# loading data 7246/7253 ...completed
# loading data 7247/7253 ...completed
# loading data 7248/7253 ...completed
# loading data 7249/7253 ...completed
# loading data 7250/7253 ...completed
# loading data 7251/7253 ...completed
# loading data 7252/7253 ...completed
# loading data 7253/7253 ...completed
# saving...done
# size of training set(pacu): 32160
# size of validation set(pacu): 3500
# size of test set(pacu): 3904
